# %%
import icalendar

# %%
import pytz, zoneinfo, dateutil.tz  # timezone libraries
import datetime, icalendar
import pyaml
import pandas as pd

# %%
import yaml
from datetime import datetime, timedelta
import re
from ics import Calendar, Event



def convert_datestring (datestring):
    format = "%m/%d/%Y"
    date_object = datetime.strptime(datestring, format)
    return date_object


def get_start_end_dates(block_id, my_dict):
    start, end = (my_dict['block_dates'][block_id].split())
    start = convert_datestring(start)
    end = convert_datestring(end)
    return start, end


def date_lists(start_date, end_date):
    current_date = start_date
    dates = []
    while current_date <= end_date:
        dates.append(current_date)
        current_date += timedelta(days=1)
    return dates
    
    
def get_specific_rotation_schedule(block_id, rotation, my_dict):
    rotation = re.sub('\s', '', rotation)
    

        
    try:
        rotation, individual = rotation.split('-')
    except:
        rotation = rotation
        individual = 'A'
        
    if re.search('Janeway|Barker|Longcope|Thayer', rotation):
        rotation_category = 'O'    
    elif re.search('CJ|Polk|MEG', rotation):
        rotation_category = 'Subspecialty'    
        
    elif re.search('PCCU|Addiction', rotation):
        # these rotation have MTWTF rotation with weekends off
        rotation_category = 'Ambulatory'
    else:
        rotation_category = rotation
        
    for schedule_type, schedule in my_dict[rotation_category].items():
        if block_id in schedule['blocks']:
            return schedule[individual].split()
        
        
        
def block_dates (block_id, my_dict):
    """get start and end date for each block by going through the master yaml """
    start_date, end_date = (get_start_end_dates(block_id, my_dict))
    block_duration = date_lists(start_date, end_date)    
    return block_duration
 

def add_date_postcall_into_next_block(call_cycle, block_days):
    print(call_cycle[-1])
    if re.search(r'^\*', call_cycle[-1]):
        # Step 1: Get the last date in the list
        last_date = block_days[-1]

        # Step 2: Calculate the next date (assuming consecutive days, so add 1 day)
        next_date = last_date + timedelta(days=1)

        # Step 3: Add the new date to the list
        block_days.append(next_date)
    return block_days
    
    
def create_daily_inpatient_schedule(block_id, rotation, my_dict):
    """creates a inpatient schedule"""

# %%
# Read master tables

    
with open("/Users/cjyoon/Dropbox/Osler/Osler_shiny/call_schedule_master.yaml") as f:
    my_dict = yaml.safe_load(f)

    
master_schedule = pd.read_excel('~/Dropbox/Osler/Intern Schedule 2024-2025.xlsx', sheet_name='Schedule')
resident_names = master_schedule.iloc[:, 0].to_list()
series = pd.Series(resident_names)

# Remove NaN values
cleaned_series = series.dropna()

# Convert back to a list
resident_names = cleaned_series.tolist()
print(resident_names)
# Out:
# ['Alexander_Mathew', 'Ancha_Bhavya', 'Arahirwa_Victor', 'Bothwell_James', 'Broshkevitch_Anna', 'Bullock_Avery', 'Carter_Julia', 'Kesaf_Ayse', 'Chabaan_Lara', 'Chang_Michael', 'Clinton_Ivor', 'Ermolovich_Jake', 'Fatteh_Maria', 'Goren_Lea', 'Guo_Matthew', 'Holler_Albert', 'Jabboure_Fayez', 'Cazimir_Catherine', 'Khunsriraksakul_Chachrit', 'Kim_Minjoo', 'Kodukula_Sai', 'Koul_Kayshap', 'Kuzma_Irena', 'Littman_Emily', 'Lopez_Christina', 'Lutz_Lydia', 'Mathias_Trevor', 'Mhaimeed_Nour', 'Mollenkopf_Sarah', 'Moore_Erica', 'Morcos_George', 'Murphy_Cara', 'Ozkan_Bige', 'Payne_Lauren', 'Pazzi_Carlotta', 'Potharazu_Archit', 'Rao_Rohit', 'Reddy_Tina', 'Riddick_Erica', 'Rodriguez-Fernandez_Monica', 'Lopez-Silva_Carolina', 'Suresh_Abhilash', 'Tarasco_Alexander', 'Tracey_Evan', 'Vasoya_Roshan', 'Weinstein_Robert', 'Ye_Congxie', 'Yeudall_Scott', 'Yoon_Christopher', 'Zarker_Andrew', 'Ziogos_Timos', 'ED_MICU', 'ED_CCU', 'OPH_Morello_Tim', 'OPH_Kim_Suzie', 'OPH_Shah_Rohan', 'OPH_Ali_Muhammad', 'OPH_Pan-Doh_Nathan']

# %%
def get_schedule(resident_name, master_schedule):
    """gets the specific intern's schedule from the table"""
    filtered_df = master_schedule[master_schedule.iloc[:, 0] == resident_name]
    return (filtered_df.squeeze().to_list()[1:])

# %%
new_column_names = [
    f"{col} {master_schedule.iloc[0, idx].strftime('%m/%d')}-{master_schedule.iloc[1, idx].strftime('%m/%d')}"
    if not isinstance(master_schedule.iloc[0, idx], float) and not isinstance(master_schedule.iloc[1, idx], float) 
    else f"{col}"
    for idx, col in enumerate(master_schedule.columns) if not isinstance(col, float)
]

# Update the column names in the DataFrame
master_schedule.columns = new_column_names
print(new_column_names)


master_table_tsv = master_schedule.iloc[3:].fillna('')
master_table_tsv.columns.values[0] = 'name'
master_table_tsv.to_csv('/Users/cjyoon/Dropbox/Osler/Osler_shiny/schedule/block_view.tsv', sep='\t', index=False)
# Out:
# ['Unnamed: 0', '1A 07/01-07/10', '1B 07/11-07/24', '2A 07/25-08/07', '2B 08/08-08/21', '3A 08/22-09/04', '3B 09/05-09/18', '4A 09/19-10/02', '4B 10/03-10/16', '5A 10/17-10/30', '5B 10/31-11/13', '6A 11/14-11/27', '6B 11/28-12/11', '7A 12/12-12/19', 'HOLIDAY 1 12/20-12/26', 'HOLIDAY 2 12/27-01/02', '7B 01/03-01/15', '8A 01/16-01/29', '8B 01/30-02/12', '9A 02/13-02/26', '9B 02/27-03/12', '10A 03/13-03/26', '10B 03/27-04/09', '11A 04/10-04/23', '11B 04/24-05/07', '12A 05/08-05/21', '12B 05/22-06/04', '13A 06/05-06/18', '13B 06/19-06/30']

# %%
july1_offset = my_dict['july1_offset']
# Create a calendar and event


for resident_name in resident_names:
    date_list = []
    schedule_list = []        
    my_blocks = (get_schedule(resident_name, master_schedule))
    print(my_blocks)
    

    calendar = Calendar()
    event = Event()
    with open(f"/Users/cjyoon/Dropbox/Osler/Osler2024_schedule/{resident_name}_schedule_2024_only.tsv", "w") as g:
        g.write('name\tdate\tschedule\n')
        for block_id, rotation in zip(my_dict['block_dates'].keys(), my_blocks):
            # only write out upto holiday block 2 since remaining scheudle has not been finalized yet
            if block_id in ['1A', '1B', '2A', '2B', '3A', '3B', '4A', '4B', '5A', '5B', '6A', '6B', '7A', 'Holiday 1', "Holiday 2"]:

                rotation = re.sub('\s', '', rotation)

                print(block_id, rotation)

                block_days = block_dates(block_id, my_dict)        

                try:
                    call_cycle = get_specific_rotation_schedule(block_id, rotation, my_dict)
                except:
                    # if specific call cycle is unknown for a rotation, then default to unknown so manual creation can be made
                    call_cycle = ['UNKNOWN'] * 14


                print(f'{block_days} {len(block_days)}')
                print(f'{call_cycle} {len(call_cycle)}')


                if block_id == '1A':
                    # create call cycle that is offset to account for different start date for july1 cycle
                    del call_cycle[:july1_offset]

                # check if block call cycle ends in a post call
                block_days = add_date_postcall_into_next_block(call_cycle, block_days)

                # Loop through each date and corresponding schedule
                for date, schedule in zip(block_days, call_cycle):
                    event = Event()  # Create a new event object inside the loop
                    event.name = f'{block_id} {rotation} {schedule}'
                    event.begin = date
                    event.make_all_day()  # Make the event an all-day event
                    print(date, block_id, rotation, schedule)
                    # Add event to calendar
                    calendar.events.add(event)
                    date_string = date.strftime('%m-%d-%Y')
                    g.write(f'{resident_name}\t{date_string}\t{event.name}\n')



        # Write the calendar to a .ics file
    with open(f"/Users/cjyoon/Dropbox/Osler/Osler2024_schedule/{resident_name}_schedule_2024_only.ics", "w") as f:
        f.writelines(calendar.serialize_iter())
# Out:
# ['Ambulatory', 'MICU - F', 'Thayer - C', 'Thayer - C', 'Ambulatory', 'Brancati - B', 'Vacation', 'Subspecialty', 'Ambulatory', 'Thayer - C', 'Thayer - D', 'MPC - C', 'Ambulatory', 'Off', 'Thayer - B', 'Thayer', 'MTL', 'MICU', 'Ambulatory', 'MICU', 'Thayer', 'Thayer', 'Ambulatory', 'Vacation', 'Thayer', 'Thayer', 'Ambulatory', 'CCU']
# 1A Ambulatory
# [datetime.datetime(2024, 7, 1, 0, 0), datetime.datetime(2024, 7, 2, 0, 0), datetime.datetime(2024, 7, 3, 0, 0), datetime.datetime(2024, 7, 4, 0, 0), datetime.datetime(2024, 7, 5, 0, 0), datetime.datetime(2024, 7, 6, 0, 0), datetime.datetime(2024, 7, 7, 0, 0), datetime.datetime(2024, 7, 8, 0, 0), datetime.datetime(2024, 7, 9, 0, 0), datetime.datetime(2024, 7, 10, 0, 0)] 10
# ['DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-07-01 00:00:00 1A Ambulatory DAY
# 2024-07-02 00:00:00 1A Ambulatory DAY
# 2024-07-03 00:00:00 1A Ambulatory DAY
# 2024-07-04 00:00:00 1A Ambulatory DAY
# 2024-07-05 00:00:00 1A Ambulatory DAY
# 2024-07-06 00:00:00 1A Ambulatory OFF
# 2024-07-07 00:00:00 1A Ambulatory OFF
# 2024-07-08 00:00:00 1A Ambulatory DAY
# 2024-07-09 00:00:00 1A Ambulatory DAY
# 2024-07-10 00:00:00 1A Ambulatory DAY
# 1B MICU-F
# [datetime.datetime(2024, 7, 11, 0, 0), datetime.datetime(2024, 7, 12, 0, 0), datetime.datetime(2024, 7, 13, 0, 0), datetime.datetime(2024, 7, 14, 0, 0), datetime.datetime(2024, 7, 15, 0, 0), datetime.datetime(2024, 7, 16, 0, 0), datetime.datetime(2024, 7, 17, 0, 0), datetime.datetime(2024, 7, 18, 0, 0), datetime.datetime(2024, 7, 19, 0, 0), datetime.datetime(2024, 7, 20, 0, 0), datetime.datetime(2024, 7, 21, 0, 0), datetime.datetime(2024, 7, 22, 0, 0), datetime.datetime(2024, 7, 23, 0, 0), datetime.datetime(2024, 7, 24, 0, 0)] 14
# ['CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST'] 14
# POST
# 2024-07-11 00:00:00 1B MICU-F CALL
# 2024-07-12 00:00:00 1B MICU-F POST
# 2024-07-13 00:00:00 1B MICU-F OFF
# 2024-07-14 00:00:00 1B MICU-F CALL
# 2024-07-15 00:00:00 1B MICU-F POST
# 2024-07-16 00:00:00 1B MICU-F GOOD
# 2024-07-17 00:00:00 1B MICU-F CALL
# 2024-07-18 00:00:00 1B MICU-F POST
# 2024-07-19 00:00:00 1B MICU-F OFF
# 2024-07-20 00:00:00 1B MICU-F CALL
# 2024-07-21 00:00:00 1B MICU-F POST
# 2024-07-22 00:00:00 1B MICU-F GOOD
# 2024-07-23 00:00:00 1B MICU-F CALL
# 2024-07-24 00:00:00 1B MICU-F POST
# 2A Thayer-C
# [datetime.datetime(2024, 7, 25, 0, 0), datetime.datetime(2024, 7, 26, 0, 0), datetime.datetime(2024, 7, 27, 0, 0), datetime.datetime(2024, 7, 28, 0, 0), datetime.datetime(2024, 7, 29, 0, 0), datetime.datetime(2024, 7, 30, 0, 0), datetime.datetime(2024, 7, 31, 0, 0), datetime.datetime(2024, 8, 1, 0, 0), datetime.datetime(2024, 8, 2, 0, 0), datetime.datetime(2024, 8, 3, 0, 0), datetime.datetime(2024, 8, 4, 0, 0), datetime.datetime(2024, 8, 5, 0, 0), datetime.datetime(2024, 8, 6, 0, 0), datetime.datetime(2024, 8, 7, 0, 0)] 14
# ['DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD'] 14
# GOOD
# 2024-07-25 00:00:00 2A Thayer-C DAY
# 2024-07-26 00:00:00 2A Thayer-C OFF
# 2024-07-27 00:00:00 2A Thayer-C CALL
# 2024-07-28 00:00:00 2A Thayer-C POST
# 2024-07-29 00:00:00 2A Thayer-C DAY
# 2024-07-30 00:00:00 2A Thayer-C GOOD
# 2024-07-31 00:00:00 2A Thayer-C CALL
# 2024-08-01 00:00:00 2A Thayer-C POST
# 2024-08-02 00:00:00 2A Thayer-C DAY
# 2024-08-03 00:00:00 2A Thayer-C OFF
# 2024-08-04 00:00:00 2A Thayer-C CALL
# 2024-08-05 00:00:00 2A Thayer-C POST
# 2024-08-06 00:00:00 2A Thayer-C DAY
# 2024-08-07 00:00:00 2A Thayer-C GOOD
# 2B Thayer-C
# [datetime.datetime(2024, 8, 8, 0, 0), datetime.datetime(2024, 8, 9, 0, 0), datetime.datetime(2024, 8, 10, 0, 0), datetime.datetime(2024, 8, 11, 0, 0), datetime.datetime(2024, 8, 12, 0, 0), datetime.datetime(2024, 8, 13, 0, 0), datetime.datetime(2024, 8, 14, 0, 0), datetime.datetime(2024, 8, 15, 0, 0), datetime.datetime(2024, 8, 16, 0, 0), datetime.datetime(2024, 8, 17, 0, 0), datetime.datetime(2024, 8, 18, 0, 0), datetime.datetime(2024, 8, 19, 0, 0), datetime.datetime(2024, 8, 20, 0, 0), datetime.datetime(2024, 8, 21, 0, 0)] 14
# ['CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST'] 14
# POST
# 2024-08-08 00:00:00 2B Thayer-C CALL
# 2024-08-09 00:00:00 2B Thayer-C POST
# 2024-08-10 00:00:00 2B Thayer-C DAY
# 2024-08-11 00:00:00 2B Thayer-C OFF
# 2024-08-12 00:00:00 2B Thayer-C CALL
# 2024-08-13 00:00:00 2B Thayer-C POST
# 2024-08-14 00:00:00 2B Thayer-C DAY
# 2024-08-15 00:00:00 2B Thayer-C GOOD
# 2024-08-16 00:00:00 2B Thayer-C CALL
# 2024-08-17 00:00:00 2B Thayer-C POST
# 2024-08-18 00:00:00 2B Thayer-C DAY
# 2024-08-19 00:00:00 2B Thayer-C OFF
# 2024-08-20 00:00:00 2B Thayer-C CALL
# 2024-08-21 00:00:00 2B Thayer-C POST
# 3A Ambulatory
# [datetime.datetime(2024, 8, 22, 0, 0), datetime.datetime(2024, 8, 23, 0, 0), datetime.datetime(2024, 8, 24, 0, 0), datetime.datetime(2024, 8, 25, 0, 0), datetime.datetime(2024, 8, 26, 0, 0), datetime.datetime(2024, 8, 27, 0, 0), datetime.datetime(2024, 8, 28, 0, 0), datetime.datetime(2024, 8, 29, 0, 0), datetime.datetime(2024, 8, 30, 0, 0), datetime.datetime(2024, 8, 31, 0, 0), datetime.datetime(2024, 9, 1, 0, 0), datetime.datetime(2024, 9, 2, 0, 0), datetime.datetime(2024, 9, 3, 0, 0), datetime.datetime(2024, 9, 4, 0, 0)] 14
# ['DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-08-22 00:00:00 3A Ambulatory DAY
# 2024-08-23 00:00:00 3A Ambulatory DAY
# 2024-08-24 00:00:00 3A Ambulatory OFF
# 2024-08-25 00:00:00 3A Ambulatory OFF
# 2024-08-26 00:00:00 3A Ambulatory DAY
# 2024-08-27 00:00:00 3A Ambulatory DAY
# 2024-08-28 00:00:00 3A Ambulatory DAY
# 2024-08-29 00:00:00 3A Ambulatory DAY
# 2024-08-30 00:00:00 3A Ambulatory DAY
# 2024-08-31 00:00:00 3A Ambulatory OFF
# 2024-09-01 00:00:00 3A Ambulatory OFF
# 2024-09-02 00:00:00 3A Ambulatory DAY
# 2024-09-03 00:00:00 3A Ambulatory DAY
# 2024-09-04 00:00:00 3A Ambulatory DAY
# 3B Brancati-B
# [datetime.datetime(2024, 9, 5, 0, 0), datetime.datetime(2024, 9, 6, 0, 0), datetime.datetime(2024, 9, 7, 0, 0), datetime.datetime(2024, 9, 8, 0, 0), datetime.datetime(2024, 9, 9, 0, 0), datetime.datetime(2024, 9, 10, 0, 0), datetime.datetime(2024, 9, 11, 0, 0), datetime.datetime(2024, 9, 12, 0, 0), datetime.datetime(2024, 9, 13, 0, 0), datetime.datetime(2024, 9, 14, 0, 0), datetime.datetime(2024, 9, 15, 0, 0), datetime.datetime(2024, 9, 16, 0, 0), datetime.datetime(2024, 9, 17, 0, 0), datetime.datetime(2024, 9, 18, 0, 0)] 14
# ['DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'DAY', 'DAY', 'DAY', 'OFF', 'NIGHT', 'NIGHT', 'NIGHT', '*POST'] 15
# *POST
# 2024-09-05 00:00:00 3B Brancati-B DAY
# 2024-09-06 00:00:00 3B Brancati-B DAY
# 2024-09-07 00:00:00 3B Brancati-B DAY
# 2024-09-08 00:00:00 3B Brancati-B DAY
# 2024-09-09 00:00:00 3B Brancati-B DAY
# 2024-09-10 00:00:00 3B Brancati-B DAY
# 2024-09-11 00:00:00 3B Brancati-B OFF
# 2024-09-12 00:00:00 3B Brancati-B DAY
# 2024-09-13 00:00:00 3B Brancati-B DAY
# 2024-09-14 00:00:00 3B Brancati-B DAY
# 2024-09-15 00:00:00 3B Brancati-B OFF
# 2024-09-16 00:00:00 3B Brancati-B NIGHT
# 2024-09-17 00:00:00 3B Brancati-B NIGHT
# 2024-09-18 00:00:00 3B Brancati-B NIGHT
# 2024-09-19 00:00:00 3B Brancati-B *POST
# 4A Vacation
# [datetime.datetime(2024, 9, 19, 0, 0), datetime.datetime(2024, 9, 20, 0, 0), datetime.datetime(2024, 9, 21, 0, 0), datetime.datetime(2024, 9, 22, 0, 0), datetime.datetime(2024, 9, 23, 0, 0), datetime.datetime(2024, 9, 24, 0, 0), datetime.datetime(2024, 9, 25, 0, 0), datetime.datetime(2024, 9, 26, 0, 0), datetime.datetime(2024, 9, 27, 0, 0), datetime.datetime(2024, 9, 28, 0, 0), datetime.datetime(2024, 9, 29, 0, 0), datetime.datetime(2024, 9, 30, 0, 0), datetime.datetime(2024, 10, 1, 0, 0), datetime.datetime(2024, 10, 2, 0, 0)] 14
# ['VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION'] 14
# VACATION
# 2024-09-19 00:00:00 4A Vacation VACATION
# 2024-09-20 00:00:00 4A Vacation VACATION
# 2024-09-21 00:00:00 4A Vacation VACATION
# 2024-09-22 00:00:00 4A Vacation VACATION
# 2024-09-23 00:00:00 4A Vacation VACATION
# 2024-09-24 00:00:00 4A Vacation VACATION
# 2024-09-25 00:00:00 4A Vacation VACATION
# 2024-09-26 00:00:00 4A Vacation VACATION
# 2024-09-27 00:00:00 4A Vacation VACATION
# 2024-09-28 00:00:00 4A Vacation VACATION
# 2024-09-29 00:00:00 4A Vacation VACATION
# 2024-09-30 00:00:00 4A Vacation VACATION
# 2024-10-01 00:00:00 4A Vacation VACATION
# 2024-10-02 00:00:00 4A Vacation VACATION
# 4B Subspecialty
# [datetime.datetime(2024, 10, 3, 0, 0), datetime.datetime(2024, 10, 4, 0, 0), datetime.datetime(2024, 10, 5, 0, 0), datetime.datetime(2024, 10, 6, 0, 0), datetime.datetime(2024, 10, 7, 0, 0), datetime.datetime(2024, 10, 8, 0, 0), datetime.datetime(2024, 10, 9, 0, 0), datetime.datetime(2024, 10, 10, 0, 0), datetime.datetime(2024, 10, 11, 0, 0), datetime.datetime(2024, 10, 12, 0, 0), datetime.datetime(2024, 10, 13, 0, 0), datetime.datetime(2024, 10, 14, 0, 0), datetime.datetime(2024, 10, 15, 0, 0), datetime.datetime(2024, 10, 16, 0, 0)] 14
# ['NIGHTS', 'NIGHTS', 'NIGHTS', 'OFF', 'NIGHTS', 'NIGHTS', 'NIGHTS', 'NIGHTS', 'NIGHTS', 'NIGHTS', 'OFF', 'NIGHTS', 'NIGHTS', 'NIGHTS', 'POST'] 15
# POST
# 2024-10-03 00:00:00 4B Subspecialty NIGHTS
# 2024-10-04 00:00:00 4B Subspecialty NIGHTS
# 2024-10-05 00:00:00 4B Subspecialty NIGHTS
# 2024-10-06 00:00:00 4B Subspecialty OFF
# 2024-10-07 00:00:00 4B Subspecialty NIGHTS
# 2024-10-08 00:00:00 4B Subspecialty NIGHTS
# 2024-10-09 00:00:00 4B Subspecialty NIGHTS
# 2024-10-10 00:00:00 4B Subspecialty NIGHTS
# 2024-10-11 00:00:00 4B Subspecialty NIGHTS
# 2024-10-12 00:00:00 4B Subspecialty NIGHTS
# 2024-10-13 00:00:00 4B Subspecialty OFF
# 2024-10-14 00:00:00 4B Subspecialty NIGHTS
# 2024-10-15 00:00:00 4B Subspecialty NIGHTS
# 2024-10-16 00:00:00 4B Subspecialty NIGHTS
# 5A Ambulatory
# [datetime.datetime(2024, 10, 17, 0, 0), datetime.datetime(2024, 10, 18, 0, 0), datetime.datetime(2024, 10, 19, 0, 0), datetime.datetime(2024, 10, 20, 0, 0), datetime.datetime(2024, 10, 21, 0, 0), datetime.datetime(2024, 10, 22, 0, 0), datetime.datetime(2024, 10, 23, 0, 0), datetime.datetime(2024, 10, 24, 0, 0), datetime.datetime(2024, 10, 25, 0, 0), datetime.datetime(2024, 10, 26, 0, 0), datetime.datetime(2024, 10, 27, 0, 0), datetime.datetime(2024, 10, 28, 0, 0), datetime.datetime(2024, 10, 29, 0, 0), datetime.datetime(2024, 10, 30, 0, 0)] 14
# ['DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-10-17 00:00:00 5A Ambulatory DAY
# 2024-10-18 00:00:00 5A Ambulatory DAY
# 2024-10-19 00:00:00 5A Ambulatory OFF
# 2024-10-20 00:00:00 5A Ambulatory OFF
# 2024-10-21 00:00:00 5A Ambulatory DAY
# 2024-10-22 00:00:00 5A Ambulatory DAY
# 2024-10-23 00:00:00 5A Ambulatory DAY
# 2024-10-24 00:00:00 5A Ambulatory DAY
# 2024-10-25 00:00:00 5A Ambulatory DAY
# 2024-10-26 00:00:00 5A Ambulatory OFF
# 2024-10-27 00:00:00 5A Ambulatory OFF
# 2024-10-28 00:00:00 5A Ambulatory DAY
# 2024-10-29 00:00:00 5A Ambulatory DAY
# 2024-10-30 00:00:00 5A Ambulatory DAY
# 5B Thayer-C
# [datetime.datetime(2024, 10, 31, 0, 0), datetime.datetime(2024, 11, 1, 0, 0), datetime.datetime(2024, 11, 2, 0, 0), datetime.datetime(2024, 11, 3, 0, 0), datetime.datetime(2024, 11, 4, 0, 0), datetime.datetime(2024, 11, 5, 0, 0), datetime.datetime(2024, 11, 6, 0, 0), datetime.datetime(2024, 11, 7, 0, 0), datetime.datetime(2024, 11, 8, 0, 0), datetime.datetime(2024, 11, 9, 0, 0), datetime.datetime(2024, 11, 10, 0, 0), datetime.datetime(2024, 11, 11, 0, 0), datetime.datetime(2024, 11, 12, 0, 0), datetime.datetime(2024, 11, 13, 0, 0)] 14
# ['CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST'] 14
# POST
# 2024-10-31 00:00:00 5B Thayer-C CALL
# 2024-11-01 00:00:00 5B Thayer-C POST
# 2024-11-02 00:00:00 5B Thayer-C DAY
# 2024-11-03 00:00:00 5B Thayer-C OFF
# 2024-11-04 00:00:00 5B Thayer-C CALL
# 2024-11-05 00:00:00 5B Thayer-C POST
# 2024-11-06 00:00:00 5B Thayer-C DAY
# 2024-11-07 00:00:00 5B Thayer-C GOOD
# 2024-11-08 00:00:00 5B Thayer-C CALL
# 2024-11-09 00:00:00 5B Thayer-C POST
# 2024-11-10 00:00:00 5B Thayer-C DAY
# 2024-11-11 00:00:00 5B Thayer-C OFF
# 2024-11-12 00:00:00 5B Thayer-C CALL
# 2024-11-13 00:00:00 5B Thayer-C POST
# 6A Thayer-D
# [datetime.datetime(2024, 11, 14, 0, 0), datetime.datetime(2024, 11, 15, 0, 0), datetime.datetime(2024, 11, 16, 0, 0), datetime.datetime(2024, 11, 17, 0, 0), datetime.datetime(2024, 11, 18, 0, 0), datetime.datetime(2024, 11, 19, 0, 0), datetime.datetime(2024, 11, 20, 0, 0), datetime.datetime(2024, 11, 21, 0, 0), datetime.datetime(2024, 11, 22, 0, 0), datetime.datetime(2024, 11, 23, 0, 0), datetime.datetime(2024, 11, 24, 0, 0), datetime.datetime(2024, 11, 25, 0, 0), datetime.datetime(2024, 11, 26, 0, 0), datetime.datetime(2024, 11, 27, 0, 0)] 14
# ['POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY'] 14
# DAY
# 2024-11-14 00:00:00 6A Thayer-D POST
# 2024-11-15 00:00:00 6A Thayer-D DAY
# 2024-11-16 00:00:00 6A Thayer-D OFF
# 2024-11-17 00:00:00 6A Thayer-D CALL
# 2024-11-18 00:00:00 6A Thayer-D POST
# 2024-11-19 00:00:00 6A Thayer-D DAY
# 2024-11-20 00:00:00 6A Thayer-D GOOD
# 2024-11-21 00:00:00 6A Thayer-D CALL
# 2024-11-22 00:00:00 6A Thayer-D POST
# 2024-11-23 00:00:00 6A Thayer-D DAY
# 2024-11-24 00:00:00 6A Thayer-D OFF
# 2024-11-25 00:00:00 6A Thayer-D CALL
# 2024-11-26 00:00:00 6A Thayer-D POST
# 2024-11-27 00:00:00 6A Thayer-D DAY
# 6B MPC-C
# [datetime.datetime(2024, 11, 28, 0, 0), datetime.datetime(2024, 11, 29, 0, 0), datetime.datetime(2024, 11, 30, 0, 0), datetime.datetime(2024, 12, 1, 0, 0), datetime.datetime(2024, 12, 2, 0, 0), datetime.datetime(2024, 12, 3, 0, 0), datetime.datetime(2024, 12, 4, 0, 0), datetime.datetime(2024, 12, 5, 0, 0), datetime.datetime(2024, 12, 6, 0, 0), datetime.datetime(2024, 12, 7, 0, 0), datetime.datetime(2024, 12, 8, 0, 0), datetime.datetime(2024, 12, 9, 0, 0), datetime.datetime(2024, 12, 10, 0, 0), datetime.datetime(2024, 12, 11, 0, 0)] 14
# ['POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD'] 14
# GOOD
# 2024-11-28 00:00:00 6B MPC-C POST
# 2024-11-29 00:00:00 6B MPC-C GOOD
# 2024-11-30 00:00:00 6B MPC-C CALL
# 2024-12-01 00:00:00 6B MPC-C POST
# 2024-12-02 00:00:00 6B MPC-C OFF
# 2024-12-03 00:00:00 6B MPC-C CALL
# 2024-12-04 00:00:00 6B MPC-C POST
# 2024-12-05 00:00:00 6B MPC-C GOOD
# 2024-12-06 00:00:00 6B MPC-C CALL
# 2024-12-07 00:00:00 6B MPC-C POST
# 2024-12-08 00:00:00 6B MPC-C OFF
# 2024-12-09 00:00:00 6B MPC-C CALL
# 2024-12-10 00:00:00 6B MPC-C POST
# 2024-12-11 00:00:00 6B MPC-C GOOD
# 7A Ambulatory
# [datetime.datetime(2024, 12, 12, 0, 0), datetime.datetime(2024, 12, 13, 0, 0), datetime.datetime(2024, 12, 14, 0, 0), datetime.datetime(2024, 12, 15, 0, 0), datetime.datetime(2024, 12, 16, 0, 0), datetime.datetime(2024, 12, 17, 0, 0), datetime.datetime(2024, 12, 18, 0, 0), datetime.datetime(2024, 12, 19, 0, 0)] 8
# ['DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-12-12 00:00:00 7A Ambulatory DAY
# 2024-12-13 00:00:00 7A Ambulatory DAY
# 2024-12-14 00:00:00 7A Ambulatory OFF
# 2024-12-15 00:00:00 7A Ambulatory OFF
# 2024-12-16 00:00:00 7A Ambulatory DAY
# 2024-12-17 00:00:00 7A Ambulatory DAY
# 2024-12-18 00:00:00 7A Ambulatory DAY
# 2024-12-19 00:00:00 7A Ambulatory DAY
# Holiday 1 Off
# [datetime.datetime(2024, 12, 20, 0, 0), datetime.datetime(2024, 12, 21, 0, 0), datetime.datetime(2024, 12, 22, 0, 0), datetime.datetime(2024, 12, 23, 0, 0), datetime.datetime(2024, 12, 24, 0, 0), datetime.datetime(2024, 12, 25, 0, 0), datetime.datetime(2024, 12, 26, 0, 0)] 7
# ['OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF'] 14
# OFF
# 2024-12-20 00:00:00 Holiday 1 Off OFF
# 2024-12-21 00:00:00 Holiday 1 Off OFF
# 2024-12-22 00:00:00 Holiday 1 Off OFF
# 2024-12-23 00:00:00 Holiday 1 Off OFF
# 2024-12-24 00:00:00 Holiday 1 Off OFF
# 2024-12-25 00:00:00 Holiday 1 Off OFF
# 2024-12-26 00:00:00 Holiday 1 Off OFF
# Holiday 2 Thayer-B
# [datetime.datetime(2024, 12, 27, 0, 0), datetime.datetime(2024, 12, 28, 0, 0), datetime.datetime(2024, 12, 29, 0, 0), datetime.datetime(2024, 12, 30, 0, 0), datetime.datetime(2024, 12, 31, 0, 0), datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 2, 0, 0)] 7
# ['CALL', 'POST', 'DAY', 'CALL', 'POST', 'DAY', 'CALL', '*POST'] 8
# *POST
# 2024-12-27 00:00:00 Holiday 2 Thayer-B CALL
# 2024-12-28 00:00:00 Holiday 2 Thayer-B POST
# 2024-12-29 00:00:00 Holiday 2 Thayer-B DAY
# 2024-12-30 00:00:00 Holiday 2 Thayer-B CALL
# 2024-12-31 00:00:00 Holiday 2 Thayer-B POST
# 2025-01-01 00:00:00 Holiday 2 Thayer-B DAY
# 2025-01-02 00:00:00 Holiday 2 Thayer-B CALL
# 2025-01-03 00:00:00 Holiday 2 Thayer-B *POST
# ['MPC - C', 'Brancati - D', 'Ambulatory', 'MICU - D', 'Barker - D', 'Barker - D', 'Ambulatory', 'Solids', 'Barker - C', 'CCU - A', 'Ambulatory', 'Barker - C', 'Vacation', 'MTL', 'Off', 'MICU', 'Ambulatory', 'Barker', 'Barker', 'Brancati', 'Ambulatory', 'MPC', 'Barker', 'Barker', 'Ambulatory', 'Subspecialty', 'MICU', 'Vacation']
# 1A MPC-C
# [datetime.datetime(2024, 7, 1, 0, 0), datetime.datetime(2024, 7, 2, 0, 0), datetime.datetime(2024, 7, 3, 0, 0), datetime.datetime(2024, 7, 4, 0, 0), datetime.datetime(2024, 7, 5, 0, 0), datetime.datetime(2024, 7, 6, 0, 0), datetime.datetime(2024, 7, 7, 0, 0), datetime.datetime(2024, 7, 8, 0, 0), datetime.datetime(2024, 7, 9, 0, 0), datetime.datetime(2024, 7, 10, 0, 0)] 10
# ['POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD'] 14
# GOOD
# 2024-07-01 00:00:00 1A MPC-C OFF
# 2024-07-02 00:00:00 1A MPC-C CALL
# 2024-07-03 00:00:00 1A MPC-C POST
# 2024-07-04 00:00:00 1A MPC-C GOOD
# 2024-07-05 00:00:00 1A MPC-C CALL
# 2024-07-06 00:00:00 1A MPC-C POST
# 2024-07-07 00:00:00 1A MPC-C OFF
# 2024-07-08 00:00:00 1A MPC-C CALL
# 2024-07-09 00:00:00 1A MPC-C POST
# 2024-07-10 00:00:00 1A MPC-C GOOD
# 1B Brancati-D
# [datetime.datetime(2024, 7, 11, 0, 0), datetime.datetime(2024, 7, 12, 0, 0), datetime.datetime(2024, 7, 13, 0, 0), datetime.datetime(2024, 7, 14, 0, 0), datetime.datetime(2024, 7, 15, 0, 0), datetime.datetime(2024, 7, 16, 0, 0), datetime.datetime(2024, 7, 17, 0, 0), datetime.datetime(2024, 7, 18, 0, 0), datetime.datetime(2024, 7, 19, 0, 0), datetime.datetime(2024, 7, 20, 0, 0), datetime.datetime(2024, 7, 21, 0, 0), datetime.datetime(2024, 7, 22, 0, 0), datetime.datetime(2024, 7, 23, 0, 0), datetime.datetime(2024, 7, 24, 0, 0)] 14
# ['NIGHT', 'NIGHT', 'NIGHT', 'NIGHT', 'POST', 'OFF', 'DAY', 'DAY', 'DAY', 'OFF', 'DAY', 'DAY', 'DAY', 'OFF'] 14
# OFF
# 2024-07-11 00:00:00 1B Brancati-D NIGHT
# 2024-07-12 00:00:00 1B Brancati-D NIGHT
# 2024-07-13 00:00:00 1B Brancati-D NIGHT
# 2024-07-14 00:00:00 1B Brancati-D NIGHT
# 2024-07-15 00:00:00 1B Brancati-D POST
# 2024-07-16 00:00:00 1B Brancati-D OFF
# 2024-07-17 00:00:00 1B Brancati-D DAY
# 2024-07-18 00:00:00 1B Brancati-D DAY
# 2024-07-19 00:00:00 1B Brancati-D DAY
# 2024-07-20 00:00:00 1B Brancati-D OFF
# 2024-07-21 00:00:00 1B Brancati-D DAY
# 2024-07-22 00:00:00 1B Brancati-D DAY
# 2024-07-23 00:00:00 1B Brancati-D DAY
# 2024-07-24 00:00:00 1B Brancati-D OFF
# 2A Ambulatory
# [datetime.datetime(2024, 7, 25, 0, 0), datetime.datetime(2024, 7, 26, 0, 0), datetime.datetime(2024, 7, 27, 0, 0), datetime.datetime(2024, 7, 28, 0, 0), datetime.datetime(2024, 7, 29, 0, 0), datetime.datetime(2024, 7, 30, 0, 0), datetime.datetime(2024, 7, 31, 0, 0), datetime.datetime(2024, 8, 1, 0, 0), datetime.datetime(2024, 8, 2, 0, 0), datetime.datetime(2024, 8, 3, 0, 0), datetime.datetime(2024, 8, 4, 0, 0), datetime.datetime(2024, 8, 5, 0, 0), datetime.datetime(2024, 8, 6, 0, 0), datetime.datetime(2024, 8, 7, 0, 0)] 14
# ['DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-07-25 00:00:00 2A Ambulatory DAY
# 2024-07-26 00:00:00 2A Ambulatory DAY
# 2024-07-27 00:00:00 2A Ambulatory OFF
# 2024-07-28 00:00:00 2A Ambulatory OFF
# 2024-07-29 00:00:00 2A Ambulatory DAY
# 2024-07-30 00:00:00 2A Ambulatory DAY
# 2024-07-31 00:00:00 2A Ambulatory DAY
# 2024-08-01 00:00:00 2A Ambulatory DAY
# 2024-08-02 00:00:00 2A Ambulatory DAY
# 2024-08-03 00:00:00 2A Ambulatory OFF
# 2024-08-04 00:00:00 2A Ambulatory OFF
# 2024-08-05 00:00:00 2A Ambulatory DAY
# 2024-08-06 00:00:00 2A Ambulatory DAY
# 2024-08-07 00:00:00 2A Ambulatory DAY
# 2B MICU-D
# [datetime.datetime(2024, 8, 8, 0, 0), datetime.datetime(2024, 8, 9, 0, 0), datetime.datetime(2024, 8, 10, 0, 0), datetime.datetime(2024, 8, 11, 0, 0), datetime.datetime(2024, 8, 12, 0, 0), datetime.datetime(2024, 8, 13, 0, 0), datetime.datetime(2024, 8, 14, 0, 0), datetime.datetime(2024, 8, 15, 0, 0), datetime.datetime(2024, 8, 16, 0, 0), datetime.datetime(2024, 8, 17, 0, 0), datetime.datetime(2024, 8, 18, 0, 0), datetime.datetime(2024, 8, 19, 0, 0), datetime.datetime(2024, 8, 20, 0, 0), datetime.datetime(2024, 8, 21, 0, 0)] 14
# ['OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', '*POST'] 15
# *POST
# 2024-08-08 00:00:00 2B MICU-D OFF
# 2024-08-09 00:00:00 2B MICU-D CALL
# 2024-08-10 00:00:00 2B MICU-D POST
# 2024-08-11 00:00:00 2B MICU-D GOOD
# 2024-08-12 00:00:00 2B MICU-D CALL
# 2024-08-13 00:00:00 2B MICU-D POST
# 2024-08-14 00:00:00 2B MICU-D OFF
# 2024-08-15 00:00:00 2B MICU-D CALL
# 2024-08-16 00:00:00 2B MICU-D POST
# 2024-08-17 00:00:00 2B MICU-D GOOD
# 2024-08-18 00:00:00 2B MICU-D CALL
# 2024-08-19 00:00:00 2B MICU-D POST
# 2024-08-20 00:00:00 2B MICU-D OFF
# 2024-08-21 00:00:00 2B MICU-D CALL
# 2024-08-22 00:00:00 2B MICU-D *POST
# 3A Barker-D
# [datetime.datetime(2024, 8, 22, 0, 0), datetime.datetime(2024, 8, 23, 0, 0), datetime.datetime(2024, 8, 24, 0, 0), datetime.datetime(2024, 8, 25, 0, 0), datetime.datetime(2024, 8, 26, 0, 0), datetime.datetime(2024, 8, 27, 0, 0), datetime.datetime(2024, 8, 28, 0, 0), datetime.datetime(2024, 8, 29, 0, 0), datetime.datetime(2024, 8, 30, 0, 0), datetime.datetime(2024, 8, 31, 0, 0), datetime.datetime(2024, 9, 1, 0, 0), datetime.datetime(2024, 9, 2, 0, 0), datetime.datetime(2024, 9, 3, 0, 0), datetime.datetime(2024, 9, 4, 0, 0)] 14
# ['POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY'] 14
# DAY
# 2024-08-22 00:00:00 3A Barker-D POST
# 2024-08-23 00:00:00 3A Barker-D DAY
# 2024-08-24 00:00:00 3A Barker-D OFF
# 2024-08-25 00:00:00 3A Barker-D CALL
# 2024-08-26 00:00:00 3A Barker-D POST
# 2024-08-27 00:00:00 3A Barker-D DAY
# 2024-08-28 00:00:00 3A Barker-D GOOD
# 2024-08-29 00:00:00 3A Barker-D CALL
# 2024-08-30 00:00:00 3A Barker-D POST
# 2024-08-31 00:00:00 3A Barker-D DAY
# 2024-09-01 00:00:00 3A Barker-D OFF
# 2024-09-02 00:00:00 3A Barker-D CALL
# 2024-09-03 00:00:00 3A Barker-D POST
# 2024-09-04 00:00:00 3A Barker-D DAY
# 3B Barker-D
# [datetime.datetime(2024, 9, 5, 0, 0), datetime.datetime(2024, 9, 6, 0, 0), datetime.datetime(2024, 9, 7, 0, 0), datetime.datetime(2024, 9, 8, 0, 0), datetime.datetime(2024, 9, 9, 0, 0), datetime.datetime(2024, 9, 10, 0, 0), datetime.datetime(2024, 9, 11, 0, 0), datetime.datetime(2024, 9, 12, 0, 0), datetime.datetime(2024, 9, 13, 0, 0), datetime.datetime(2024, 9, 14, 0, 0), datetime.datetime(2024, 9, 15, 0, 0), datetime.datetime(2024, 9, 16, 0, 0), datetime.datetime(2024, 9, 17, 0, 0), datetime.datetime(2024, 9, 18, 0, 0)] 14
# ['GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', '*POST'] 15
# *POST
# 2024-09-05 00:00:00 3B Barker-D GOOD
# 2024-09-06 00:00:00 3B Barker-D CALL
# 2024-09-07 00:00:00 3B Barker-D POST
# 2024-09-08 00:00:00 3B Barker-D DAY
# 2024-09-09 00:00:00 3B Barker-D OFF
# 2024-09-10 00:00:00 3B Barker-D CALL
# 2024-09-11 00:00:00 3B Barker-D POST
# 2024-09-12 00:00:00 3B Barker-D DAY
# 2024-09-13 00:00:00 3B Barker-D OFF
# 2024-09-14 00:00:00 3B Barker-D CALL
# 2024-09-15 00:00:00 3B Barker-D POST
# 2024-09-16 00:00:00 3B Barker-D DAY
# 2024-09-17 00:00:00 3B Barker-D GOOD
# 2024-09-18 00:00:00 3B Barker-D CALL
# 2024-09-19 00:00:00 3B Barker-D *POST
# 4A Ambulatory
# [datetime.datetime(2024, 9, 19, 0, 0), datetime.datetime(2024, 9, 20, 0, 0), datetime.datetime(2024, 9, 21, 0, 0), datetime.datetime(2024, 9, 22, 0, 0), datetime.datetime(2024, 9, 23, 0, 0), datetime.datetime(2024, 9, 24, 0, 0), datetime.datetime(2024, 9, 25, 0, 0), datetime.datetime(2024, 9, 26, 0, 0), datetime.datetime(2024, 9, 27, 0, 0), datetime.datetime(2024, 9, 28, 0, 0), datetime.datetime(2024, 9, 29, 0, 0), datetime.datetime(2024, 9, 30, 0, 0), datetime.datetime(2024, 10, 1, 0, 0), datetime.datetime(2024, 10, 2, 0, 0)] 14
# ['DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-09-19 00:00:00 4A Ambulatory DAY
# 2024-09-20 00:00:00 4A Ambulatory DAY
# 2024-09-21 00:00:00 4A Ambulatory OFF
# 2024-09-22 00:00:00 4A Ambulatory OFF
# 2024-09-23 00:00:00 4A Ambulatory DAY
# 2024-09-24 00:00:00 4A Ambulatory DAY
# 2024-09-25 00:00:00 4A Ambulatory DAY
# 2024-09-26 00:00:00 4A Ambulatory DAY
# 2024-09-27 00:00:00 4A Ambulatory DAY
# 2024-09-28 00:00:00 4A Ambulatory OFF
# 2024-09-29 00:00:00 4A Ambulatory OFF
# 2024-09-30 00:00:00 4A Ambulatory DAY
# 2024-10-01 00:00:00 4A Ambulatory DAY
# 2024-10-02 00:00:00 4A Ambulatory DAY
# 4B Solids
# [datetime.datetime(2024, 10, 3, 0, 0), datetime.datetime(2024, 10, 4, 0, 0), datetime.datetime(2024, 10, 5, 0, 0), datetime.datetime(2024, 10, 6, 0, 0), datetime.datetime(2024, 10, 7, 0, 0), datetime.datetime(2024, 10, 8, 0, 0), datetime.datetime(2024, 10, 9, 0, 0), datetime.datetime(2024, 10, 10, 0, 0), datetime.datetime(2024, 10, 11, 0, 0), datetime.datetime(2024, 10, 12, 0, 0), datetime.datetime(2024, 10, 13, 0, 0), datetime.datetime(2024, 10, 14, 0, 0), datetime.datetime(2024, 10, 15, 0, 0), datetime.datetime(2024, 10, 16, 0, 0)] 14
# ['DAY', 'DAY', 'DAY', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-10-03 00:00:00 4B Solids DAY
# 2024-10-04 00:00:00 4B Solids DAY
# 2024-10-05 00:00:00 4B Solids DAY
# 2024-10-06 00:00:00 4B Solids OFF
# 2024-10-07 00:00:00 4B Solids DAY
# 2024-10-08 00:00:00 4B Solids DAY
# 2024-10-09 00:00:00 4B Solids DAY
# 2024-10-10 00:00:00 4B Solids DAY
# 2024-10-11 00:00:00 4B Solids DAY
# 2024-10-12 00:00:00 4B Solids DAY
# 2024-10-13 00:00:00 4B Solids OFF
# 2024-10-14 00:00:00 4B Solids DAY
# 2024-10-15 00:00:00 4B Solids DAY
# 2024-10-16 00:00:00 4B Solids DAY
# 5A Barker-C
# [datetime.datetime(2024, 10, 17, 0, 0), datetime.datetime(2024, 10, 18, 0, 0), datetime.datetime(2024, 10, 19, 0, 0), datetime.datetime(2024, 10, 20, 0, 0), datetime.datetime(2024, 10, 21, 0, 0), datetime.datetime(2024, 10, 22, 0, 0), datetime.datetime(2024, 10, 23, 0, 0), datetime.datetime(2024, 10, 24, 0, 0), datetime.datetime(2024, 10, 25, 0, 0), datetime.datetime(2024, 10, 26, 0, 0), datetime.datetime(2024, 10, 27, 0, 0), datetime.datetime(2024, 10, 28, 0, 0), datetime.datetime(2024, 10, 29, 0, 0), datetime.datetime(2024, 10, 30, 0, 0)] 14
# ['DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD'] 14
# GOOD
# 2024-10-17 00:00:00 5A Barker-C DAY
# 2024-10-18 00:00:00 5A Barker-C OFF
# 2024-10-19 00:00:00 5A Barker-C CALL
# 2024-10-20 00:00:00 5A Barker-C POST
# 2024-10-21 00:00:00 5A Barker-C DAY
# 2024-10-22 00:00:00 5A Barker-C GOOD
# 2024-10-23 00:00:00 5A Barker-C CALL
# 2024-10-24 00:00:00 5A Barker-C POST
# 2024-10-25 00:00:00 5A Barker-C DAY
# 2024-10-26 00:00:00 5A Barker-C OFF
# 2024-10-27 00:00:00 5A Barker-C CALL
# 2024-10-28 00:00:00 5A Barker-C POST
# 2024-10-29 00:00:00 5A Barker-C DAY
# 2024-10-30 00:00:00 5A Barker-C GOOD
# 5B CCU-A
# [datetime.datetime(2024, 10, 31, 0, 0), datetime.datetime(2024, 11, 1, 0, 0), datetime.datetime(2024, 11, 2, 0, 0), datetime.datetime(2024, 11, 3, 0, 0), datetime.datetime(2024, 11, 4, 0, 0), datetime.datetime(2024, 11, 5, 0, 0), datetime.datetime(2024, 11, 6, 0, 0), datetime.datetime(2024, 11, 7, 0, 0), datetime.datetime(2024, 11, 8, 0, 0), datetime.datetime(2024, 11, 9, 0, 0), datetime.datetime(2024, 11, 10, 0, 0), datetime.datetime(2024, 11, 11, 0, 0), datetime.datetime(2024, 11, 12, 0, 0), datetime.datetime(2024, 11, 13, 0, 0)] 14
# ['GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', '*POST'] 15
# *POST
# 2024-10-31 00:00:00 5B CCU-A GOOD
# 2024-11-01 00:00:00 5B CCU-A CALL
# 2024-11-02 00:00:00 5B CCU-A POST
# 2024-11-03 00:00:00 5B CCU-A OFF
# 2024-11-04 00:00:00 5B CCU-A CALL
# 2024-11-05 00:00:00 5B CCU-A POST
# 2024-11-06 00:00:00 5B CCU-A GOOD
# 2024-11-07 00:00:00 5B CCU-A CALL
# 2024-11-08 00:00:00 5B CCU-A POST
# 2024-11-09 00:00:00 5B CCU-A OFF
# 2024-11-10 00:00:00 5B CCU-A CALL
# 2024-11-11 00:00:00 5B CCU-A POST
# 2024-11-12 00:00:00 5B CCU-A GOOD
# 2024-11-13 00:00:00 5B CCU-A CALL
# 2024-11-14 00:00:00 5B CCU-A *POST
# 6A Ambulatory
# [datetime.datetime(2024, 11, 14, 0, 0), datetime.datetime(2024, 11, 15, 0, 0), datetime.datetime(2024, 11, 16, 0, 0), datetime.datetime(2024, 11, 17, 0, 0), datetime.datetime(2024, 11, 18, 0, 0), datetime.datetime(2024, 11, 19, 0, 0), datetime.datetime(2024, 11, 20, 0, 0), datetime.datetime(2024, 11, 21, 0, 0), datetime.datetime(2024, 11, 22, 0, 0), datetime.datetime(2024, 11, 23, 0, 0), datetime.datetime(2024, 11, 24, 0, 0), datetime.datetime(2024, 11, 25, 0, 0), datetime.datetime(2024, 11, 26, 0, 0), datetime.datetime(2024, 11, 27, 0, 0)] 14
# ['DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-11-14 00:00:00 6A Ambulatory DAY
# 2024-11-15 00:00:00 6A Ambulatory DAY
# 2024-11-16 00:00:00 6A Ambulatory OFF
# 2024-11-17 00:00:00 6A Ambulatory OFF
# 2024-11-18 00:00:00 6A Ambulatory DAY
# 2024-11-19 00:00:00 6A Ambulatory DAY
# 2024-11-20 00:00:00 6A Ambulatory DAY
# 2024-11-21 00:00:00 6A Ambulatory DAY
# 2024-11-22 00:00:00 6A Ambulatory DAY
# 2024-11-23 00:00:00 6A Ambulatory OFF
# 2024-11-24 00:00:00 6A Ambulatory OFF
# 2024-11-25 00:00:00 6A Ambulatory DAY
# 2024-11-26 00:00:00 6A Ambulatory DAY
# 2024-11-27 00:00:00 6A Ambulatory DAY
# 6B Barker-C
# [datetime.datetime(2024, 11, 28, 0, 0), datetime.datetime(2024, 11, 29, 0, 0), datetime.datetime(2024, 11, 30, 0, 0), datetime.datetime(2024, 12, 1, 0, 0), datetime.datetime(2024, 12, 2, 0, 0), datetime.datetime(2024, 12, 3, 0, 0), datetime.datetime(2024, 12, 4, 0, 0), datetime.datetime(2024, 12, 5, 0, 0), datetime.datetime(2024, 12, 6, 0, 0), datetime.datetime(2024, 12, 7, 0, 0), datetime.datetime(2024, 12, 8, 0, 0), datetime.datetime(2024, 12, 9, 0, 0), datetime.datetime(2024, 12, 10, 0, 0), datetime.datetime(2024, 12, 11, 0, 0)] 14
# ['CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST'] 14
# POST
# 2024-11-28 00:00:00 6B Barker-C CALL
# 2024-11-29 00:00:00 6B Barker-C POST
# 2024-11-30 00:00:00 6B Barker-C DAY
# 2024-12-01 00:00:00 6B Barker-C OFF
# 2024-12-02 00:00:00 6B Barker-C CALL
# 2024-12-03 00:00:00 6B Barker-C POST
# 2024-12-04 00:00:00 6B Barker-C DAY
# 2024-12-05 00:00:00 6B Barker-C GOOD
# 2024-12-06 00:00:00 6B Barker-C CALL
# 2024-12-07 00:00:00 6B Barker-C POST
# 2024-12-08 00:00:00 6B Barker-C DAY
# 2024-12-09 00:00:00 6B Barker-C OFF
# 2024-12-10 00:00:00 6B Barker-C CALL
# 2024-12-11 00:00:00 6B Barker-C POST
# 7A Vacation
# [datetime.datetime(2024, 12, 12, 0, 0), datetime.datetime(2024, 12, 13, 0, 0), datetime.datetime(2024, 12, 14, 0, 0), datetime.datetime(2024, 12, 15, 0, 0), datetime.datetime(2024, 12, 16, 0, 0), datetime.datetime(2024, 12, 17, 0, 0), datetime.datetime(2024, 12, 18, 0, 0), datetime.datetime(2024, 12, 19, 0, 0)] 8
# ['VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION'] 14
# VACATION
# 2024-12-12 00:00:00 7A Vacation VACATION
# 2024-12-13 00:00:00 7A Vacation VACATION
# 2024-12-14 00:00:00 7A Vacation VACATION
# 2024-12-15 00:00:00 7A Vacation VACATION
# 2024-12-16 00:00:00 7A Vacation VACATION
# 2024-12-17 00:00:00 7A Vacation VACATION
# 2024-12-18 00:00:00 7A Vacation VACATION
# 2024-12-19 00:00:00 7A Vacation VACATION
# Holiday 1 MTL
# [datetime.datetime(2024, 12, 20, 0, 0), datetime.datetime(2024, 12, 21, 0, 0), datetime.datetime(2024, 12, 22, 0, 0), datetime.datetime(2024, 12, 23, 0, 0), datetime.datetime(2024, 12, 24, 0, 0), datetime.datetime(2024, 12, 25, 0, 0), datetime.datetime(2024, 12, 26, 0, 0)] 7
# ['DAY', 'DAY', 'DAY', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-12-20 00:00:00 Holiday 1 MTL DAY
# 2024-12-21 00:00:00 Holiday 1 MTL DAY
# 2024-12-22 00:00:00 Holiday 1 MTL DAY
# 2024-12-23 00:00:00 Holiday 1 MTL OFF
# 2024-12-24 00:00:00 Holiday 1 MTL DAY
# 2024-12-25 00:00:00 Holiday 1 MTL DAY
# 2024-12-26 00:00:00 Holiday 1 MTL DAY
# Holiday 2 Off
# [datetime.datetime(2024, 12, 27, 0, 0), datetime.datetime(2024, 12, 28, 0, 0), datetime.datetime(2024, 12, 29, 0, 0), datetime.datetime(2024, 12, 30, 0, 0), datetime.datetime(2024, 12, 31, 0, 0), datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 2, 0, 0)] 7
# ['OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF'] 14
# OFF
# 2024-12-27 00:00:00 Holiday 2 Off OFF
# 2024-12-28 00:00:00 Holiday 2 Off OFF
# 2024-12-29 00:00:00 Holiday 2 Off OFF
# 2024-12-30 00:00:00 Holiday 2 Off OFF
# 2024-12-31 00:00:00 Holiday 2 Off OFF
# 2025-01-01 00:00:00 Holiday 2 Off OFF
# 2025-01-02 00:00:00 Holiday 2 Off OFF
# ['Thayer - D', 'Thayer - D', 'Ambulatory', 'Brancati - B', 'MICU - B', 'Vacation', 'Ambulatory', 'Thayer - B', 'Thayer - B', 'MPC - C', 'Ambulatory', 'Thayer - C', 'MTL', 'Off', 'MICU - A', 'MICU', 'Ambulatory', 'Thayer', 'Thayer', 'MPC', 'Ambulatory', 'Thayer', 'CCU', 'Vacation', 'Ambulatory', 'Thayer', 'Brancati', 'MICU']
# 1A Thayer-D
# [datetime.datetime(2024, 7, 1, 0, 0), datetime.datetime(2024, 7, 2, 0, 0), datetime.datetime(2024, 7, 3, 0, 0), datetime.datetime(2024, 7, 4, 0, 0), datetime.datetime(2024, 7, 5, 0, 0), datetime.datetime(2024, 7, 6, 0, 0), datetime.datetime(2024, 7, 7, 0, 0), datetime.datetime(2024, 7, 8, 0, 0), datetime.datetime(2024, 7, 9, 0, 0), datetime.datetime(2024, 7, 10, 0, 0)] 10
# ['POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY'] 14
# DAY
# 2024-07-01 00:00:00 1A Thayer-D POST
# 2024-07-02 00:00:00 1A Thayer-D DAY
# 2024-07-03 00:00:00 1A Thayer-D GOOD
# 2024-07-04 00:00:00 1A Thayer-D CALL
# 2024-07-05 00:00:00 1A Thayer-D POST
# 2024-07-06 00:00:00 1A Thayer-D DAY
# 2024-07-07 00:00:00 1A Thayer-D OFF
# 2024-07-08 00:00:00 1A Thayer-D CALL
# 2024-07-09 00:00:00 1A Thayer-D POST
# 2024-07-10 00:00:00 1A Thayer-D DAY
# 1B Thayer-D
# [datetime.datetime(2024, 7, 11, 0, 0), datetime.datetime(2024, 7, 12, 0, 0), datetime.datetime(2024, 7, 13, 0, 0), datetime.datetime(2024, 7, 14, 0, 0), datetime.datetime(2024, 7, 15, 0, 0), datetime.datetime(2024, 7, 16, 0, 0), datetime.datetime(2024, 7, 17, 0, 0), datetime.datetime(2024, 7, 18, 0, 0), datetime.datetime(2024, 7, 19, 0, 0), datetime.datetime(2024, 7, 20, 0, 0), datetime.datetime(2024, 7, 21, 0, 0), datetime.datetime(2024, 7, 22, 0, 0), datetime.datetime(2024, 7, 23, 0, 0), datetime.datetime(2024, 7, 24, 0, 0)] 14
# ['GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', '*POST'] 15
# *POST
# 2024-07-11 00:00:00 1B Thayer-D GOOD
# 2024-07-12 00:00:00 1B Thayer-D CALL
# 2024-07-13 00:00:00 1B Thayer-D POST
# 2024-07-14 00:00:00 1B Thayer-D DAY
# 2024-07-15 00:00:00 1B Thayer-D OFF
# 2024-07-16 00:00:00 1B Thayer-D CALL
# 2024-07-17 00:00:00 1B Thayer-D POST
# 2024-07-18 00:00:00 1B Thayer-D DAY
# 2024-07-19 00:00:00 1B Thayer-D OFF
# 2024-07-20 00:00:00 1B Thayer-D CALL
# 2024-07-21 00:00:00 1B Thayer-D POST
# 2024-07-22 00:00:00 1B Thayer-D DAY
# 2024-07-23 00:00:00 1B Thayer-D GOOD
# 2024-07-24 00:00:00 1B Thayer-D CALL
# 2024-07-25 00:00:00 1B Thayer-D *POST
# 2A Ambulatory
# [datetime.datetime(2024, 7, 25, 0, 0), datetime.datetime(2024, 7, 26, 0, 0), datetime.datetime(2024, 7, 27, 0, 0), datetime.datetime(2024, 7, 28, 0, 0), datetime.datetime(2024, 7, 29, 0, 0), datetime.datetime(2024, 7, 30, 0, 0), datetime.datetime(2024, 7, 31, 0, 0), datetime.datetime(2024, 8, 1, 0, 0), datetime.datetime(2024, 8, 2, 0, 0), datetime.datetime(2024, 8, 3, 0, 0), datetime.datetime(2024, 8, 4, 0, 0), datetime.datetime(2024, 8, 5, 0, 0), datetime.datetime(2024, 8, 6, 0, 0), datetime.datetime(2024, 8, 7, 0, 0)] 14
# ['DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-07-25 00:00:00 2A Ambulatory DAY
# 2024-07-26 00:00:00 2A Ambulatory DAY
# 2024-07-27 00:00:00 2A Ambulatory OFF
# 2024-07-28 00:00:00 2A Ambulatory OFF
# 2024-07-29 00:00:00 2A Ambulatory DAY
# 2024-07-30 00:00:00 2A Ambulatory DAY
# 2024-07-31 00:00:00 2A Ambulatory DAY
# 2024-08-01 00:00:00 2A Ambulatory DAY
# 2024-08-02 00:00:00 2A Ambulatory DAY
# 2024-08-03 00:00:00 2A Ambulatory OFF
# 2024-08-04 00:00:00 2A Ambulatory OFF
# 2024-08-05 00:00:00 2A Ambulatory DAY
# 2024-08-06 00:00:00 2A Ambulatory DAY
# 2024-08-07 00:00:00 2A Ambulatory DAY
# 2B Brancati-B
# [datetime.datetime(2024, 8, 8, 0, 0), datetime.datetime(2024, 8, 9, 0, 0), datetime.datetime(2024, 8, 10, 0, 0), datetime.datetime(2024, 8, 11, 0, 0), datetime.datetime(2024, 8, 12, 0, 0), datetime.datetime(2024, 8, 13, 0, 0), datetime.datetime(2024, 8, 14, 0, 0), datetime.datetime(2024, 8, 15, 0, 0), datetime.datetime(2024, 8, 16, 0, 0), datetime.datetime(2024, 8, 17, 0, 0), datetime.datetime(2024, 8, 18, 0, 0), datetime.datetime(2024, 8, 19, 0, 0), datetime.datetime(2024, 8, 20, 0, 0), datetime.datetime(2024, 8, 21, 0, 0)] 14
# ['DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'DAY', 'DAY', 'DAY', 'OFF', 'NIGHT', 'NIGHT', 'NIGHT', '*POST'] 15
# *POST
# 2024-08-08 00:00:00 2B Brancati-B DAY
# 2024-08-09 00:00:00 2B Brancati-B DAY
# 2024-08-10 00:00:00 2B Brancati-B DAY
# 2024-08-11 00:00:00 2B Brancati-B DAY
# 2024-08-12 00:00:00 2B Brancati-B DAY
# 2024-08-13 00:00:00 2B Brancati-B DAY
# 2024-08-14 00:00:00 2B Brancati-B OFF
# 2024-08-15 00:00:00 2B Brancati-B DAY
# 2024-08-16 00:00:00 2B Brancati-B DAY
# 2024-08-17 00:00:00 2B Brancati-B DAY
# 2024-08-18 00:00:00 2B Brancati-B OFF
# 2024-08-19 00:00:00 2B Brancati-B NIGHT
# 2024-08-20 00:00:00 2B Brancati-B NIGHT
# 2024-08-21 00:00:00 2B Brancati-B NIGHT
# 2024-08-22 00:00:00 2B Brancati-B *POST
# 3A MICU-B
# [datetime.datetime(2024, 8, 22, 0, 0), datetime.datetime(2024, 8, 23, 0, 0), datetime.datetime(2024, 8, 24, 0, 0), datetime.datetime(2024, 8, 25, 0, 0), datetime.datetime(2024, 8, 26, 0, 0), datetime.datetime(2024, 8, 27, 0, 0), datetime.datetime(2024, 8, 28, 0, 0), datetime.datetime(2024, 8, 29, 0, 0), datetime.datetime(2024, 8, 30, 0, 0), datetime.datetime(2024, 8, 31, 0, 0), datetime.datetime(2024, 9, 1, 0, 0), datetime.datetime(2024, 9, 2, 0, 0), datetime.datetime(2024, 9, 3, 0, 0), datetime.datetime(2024, 9, 4, 0, 0)] 14
# ['POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD'] 14
# GOOD
# 2024-08-22 00:00:00 3A MICU-B POST
# 2024-08-23 00:00:00 3A MICU-B GOOD
# 2024-08-24 00:00:00 3A MICU-B CALL
# 2024-08-25 00:00:00 3A MICU-B POST
# 2024-08-26 00:00:00 3A MICU-B OFF
# 2024-08-27 00:00:00 3A MICU-B CALL
# 2024-08-28 00:00:00 3A MICU-B POST
# 2024-08-29 00:00:00 3A MICU-B GOOD
# 2024-08-30 00:00:00 3A MICU-B CALL
# 2024-08-31 00:00:00 3A MICU-B POST
# 2024-09-01 00:00:00 3A MICU-B OFF
# 2024-09-02 00:00:00 3A MICU-B CALL
# 2024-09-03 00:00:00 3A MICU-B POST
# 2024-09-04 00:00:00 3A MICU-B GOOD
# 3B Vacation
# [datetime.datetime(2024, 9, 5, 0, 0), datetime.datetime(2024, 9, 6, 0, 0), datetime.datetime(2024, 9, 7, 0, 0), datetime.datetime(2024, 9, 8, 0, 0), datetime.datetime(2024, 9, 9, 0, 0), datetime.datetime(2024, 9, 10, 0, 0), datetime.datetime(2024, 9, 11, 0, 0), datetime.datetime(2024, 9, 12, 0, 0), datetime.datetime(2024, 9, 13, 0, 0), datetime.datetime(2024, 9, 14, 0, 0), datetime.datetime(2024, 9, 15, 0, 0), datetime.datetime(2024, 9, 16, 0, 0), datetime.datetime(2024, 9, 17, 0, 0), datetime.datetime(2024, 9, 18, 0, 0)] 14
# ['VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION'] 14
# VACATION
# 2024-09-05 00:00:00 3B Vacation VACATION
# 2024-09-06 00:00:00 3B Vacation VACATION
# 2024-09-07 00:00:00 3B Vacation VACATION
# 2024-09-08 00:00:00 3B Vacation VACATION
# 2024-09-09 00:00:00 3B Vacation VACATION
# 2024-09-10 00:00:00 3B Vacation VACATION
# 2024-09-11 00:00:00 3B Vacation VACATION
# 2024-09-12 00:00:00 3B Vacation VACATION
# 2024-09-13 00:00:00 3B Vacation VACATION
# 2024-09-14 00:00:00 3B Vacation VACATION
# 2024-09-15 00:00:00 3B Vacation VACATION
# 2024-09-16 00:00:00 3B Vacation VACATION
# 2024-09-17 00:00:00 3B Vacation VACATION
# 2024-09-18 00:00:00 3B Vacation VACATION
# 4A Ambulatory
# [datetime.datetime(2024, 9, 19, 0, 0), datetime.datetime(2024, 9, 20, 0, 0), datetime.datetime(2024, 9, 21, 0, 0), datetime.datetime(2024, 9, 22, 0, 0), datetime.datetime(2024, 9, 23, 0, 0), datetime.datetime(2024, 9, 24, 0, 0), datetime.datetime(2024, 9, 25, 0, 0), datetime.datetime(2024, 9, 26, 0, 0), datetime.datetime(2024, 9, 27, 0, 0), datetime.datetime(2024, 9, 28, 0, 0), datetime.datetime(2024, 9, 29, 0, 0), datetime.datetime(2024, 9, 30, 0, 0), datetime.datetime(2024, 10, 1, 0, 0), datetime.datetime(2024, 10, 2, 0, 0)] 14
# ['DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-09-19 00:00:00 4A Ambulatory DAY
# 2024-09-20 00:00:00 4A Ambulatory DAY
# 2024-09-21 00:00:00 4A Ambulatory OFF
# 2024-09-22 00:00:00 4A Ambulatory OFF
# 2024-09-23 00:00:00 4A Ambulatory DAY
# 2024-09-24 00:00:00 4A Ambulatory DAY
# 2024-09-25 00:00:00 4A Ambulatory DAY
# 2024-09-26 00:00:00 4A Ambulatory DAY
# 2024-09-27 00:00:00 4A Ambulatory DAY
# 2024-09-28 00:00:00 4A Ambulatory OFF
# 2024-09-29 00:00:00 4A Ambulatory OFF
# 2024-09-30 00:00:00 4A Ambulatory DAY
# 2024-10-01 00:00:00 4A Ambulatory DAY
# 2024-10-02 00:00:00 4A Ambulatory DAY
# 4B Thayer-B
# [datetime.datetime(2024, 10, 3, 0, 0), datetime.datetime(2024, 10, 4, 0, 0), datetime.datetime(2024, 10, 5, 0, 0), datetime.datetime(2024, 10, 6, 0, 0), datetime.datetime(2024, 10, 7, 0, 0), datetime.datetime(2024, 10, 8, 0, 0), datetime.datetime(2024, 10, 9, 0, 0), datetime.datetime(2024, 10, 10, 0, 0), datetime.datetime(2024, 10, 11, 0, 0), datetime.datetime(2024, 10, 12, 0, 0), datetime.datetime(2024, 10, 13, 0, 0), datetime.datetime(2024, 10, 14, 0, 0), datetime.datetime(2024, 10, 15, 0, 0), datetime.datetime(2024, 10, 16, 0, 0)] 14
# ['POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY'] 14
# DAY
# 2024-10-03 00:00:00 4B Thayer-B POST
# 2024-10-04 00:00:00 4B Thayer-B DAY
# 2024-10-05 00:00:00 4B Thayer-B OFF
# 2024-10-06 00:00:00 4B Thayer-B CALL
# 2024-10-07 00:00:00 4B Thayer-B POST
# 2024-10-08 00:00:00 4B Thayer-B DAY
# 2024-10-09 00:00:00 4B Thayer-B GOOD
# 2024-10-10 00:00:00 4B Thayer-B CALL
# 2024-10-11 00:00:00 4B Thayer-B POST
# 2024-10-12 00:00:00 4B Thayer-B DAY
# 2024-10-13 00:00:00 4B Thayer-B OFF
# 2024-10-14 00:00:00 4B Thayer-B CALL
# 2024-10-15 00:00:00 4B Thayer-B POST
# 2024-10-16 00:00:00 4B Thayer-B DAY
# 5A Thayer-B
# [datetime.datetime(2024, 10, 17, 0, 0), datetime.datetime(2024, 10, 18, 0, 0), datetime.datetime(2024, 10, 19, 0, 0), datetime.datetime(2024, 10, 20, 0, 0), datetime.datetime(2024, 10, 21, 0, 0), datetime.datetime(2024, 10, 22, 0, 0), datetime.datetime(2024, 10, 23, 0, 0), datetime.datetime(2024, 10, 24, 0, 0), datetime.datetime(2024, 10, 25, 0, 0), datetime.datetime(2024, 10, 26, 0, 0), datetime.datetime(2024, 10, 27, 0, 0), datetime.datetime(2024, 10, 28, 0, 0), datetime.datetime(2024, 10, 29, 0, 0), datetime.datetime(2024, 10, 30, 0, 0)] 14
# ['GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', '*POST'] 15
# *POST
# 2024-10-17 00:00:00 5A Thayer-B GOOD
# 2024-10-18 00:00:00 5A Thayer-B CALL
# 2024-10-19 00:00:00 5A Thayer-B POST
# 2024-10-20 00:00:00 5A Thayer-B DAY
# 2024-10-21 00:00:00 5A Thayer-B OFF
# 2024-10-22 00:00:00 5A Thayer-B CALL
# 2024-10-23 00:00:00 5A Thayer-B POST
# 2024-10-24 00:00:00 5A Thayer-B DAY
# 2024-10-25 00:00:00 5A Thayer-B OFF
# 2024-10-26 00:00:00 5A Thayer-B CALL
# 2024-10-27 00:00:00 5A Thayer-B POST
# 2024-10-28 00:00:00 5A Thayer-B DAY
# 2024-10-29 00:00:00 5A Thayer-B GOOD
# 2024-10-30 00:00:00 5A Thayer-B CALL
# 2024-10-31 00:00:00 5A Thayer-B *POST
# 5B MPC-C
# [datetime.datetime(2024, 10, 31, 0, 0), datetime.datetime(2024, 11, 1, 0, 0), datetime.datetime(2024, 11, 2, 0, 0), datetime.datetime(2024, 11, 3, 0, 0), datetime.datetime(2024, 11, 4, 0, 0), datetime.datetime(2024, 11, 5, 0, 0), datetime.datetime(2024, 11, 6, 0, 0), datetime.datetime(2024, 11, 7, 0, 0), datetime.datetime(2024, 11, 8, 0, 0), datetime.datetime(2024, 11, 9, 0, 0), datetime.datetime(2024, 11, 10, 0, 0), datetime.datetime(2024, 11, 11, 0, 0), datetime.datetime(2024, 11, 12, 0, 0), datetime.datetime(2024, 11, 13, 0, 0)] 14
# ['POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD'] 14
# GOOD
# 2024-10-31 00:00:00 5B MPC-C POST
# 2024-11-01 00:00:00 5B MPC-C GOOD
# 2024-11-02 00:00:00 5B MPC-C CALL
# 2024-11-03 00:00:00 5B MPC-C POST
# 2024-11-04 00:00:00 5B MPC-C OFF
# 2024-11-05 00:00:00 5B MPC-C CALL
# 2024-11-06 00:00:00 5B MPC-C POST
# 2024-11-07 00:00:00 5B MPC-C GOOD
# 2024-11-08 00:00:00 5B MPC-C CALL
# 2024-11-09 00:00:00 5B MPC-C POST
# 2024-11-10 00:00:00 5B MPC-C OFF
# 2024-11-11 00:00:00 5B MPC-C CALL
# 2024-11-12 00:00:00 5B MPC-C POST
# 2024-11-13 00:00:00 5B MPC-C GOOD
# 6A Ambulatory
# [datetime.datetime(2024, 11, 14, 0, 0), datetime.datetime(2024, 11, 15, 0, 0), datetime.datetime(2024, 11, 16, 0, 0), datetime.datetime(2024, 11, 17, 0, 0), datetime.datetime(2024, 11, 18, 0, 0), datetime.datetime(2024, 11, 19, 0, 0), datetime.datetime(2024, 11, 20, 0, 0), datetime.datetime(2024, 11, 21, 0, 0), datetime.datetime(2024, 11, 22, 0, 0), datetime.datetime(2024, 11, 23, 0, 0), datetime.datetime(2024, 11, 24, 0, 0), datetime.datetime(2024, 11, 25, 0, 0), datetime.datetime(2024, 11, 26, 0, 0), datetime.datetime(2024, 11, 27, 0, 0)] 14
# ['DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-11-14 00:00:00 6A Ambulatory DAY
# 2024-11-15 00:00:00 6A Ambulatory DAY
# 2024-11-16 00:00:00 6A Ambulatory OFF
# 2024-11-17 00:00:00 6A Ambulatory OFF
# 2024-11-18 00:00:00 6A Ambulatory DAY
# 2024-11-19 00:00:00 6A Ambulatory DAY
# 2024-11-20 00:00:00 6A Ambulatory DAY
# 2024-11-21 00:00:00 6A Ambulatory DAY
# 2024-11-22 00:00:00 6A Ambulatory DAY
# 2024-11-23 00:00:00 6A Ambulatory OFF
# 2024-11-24 00:00:00 6A Ambulatory OFF
# 2024-11-25 00:00:00 6A Ambulatory DAY
# 2024-11-26 00:00:00 6A Ambulatory DAY
# 2024-11-27 00:00:00 6A Ambulatory DAY
# 6B Thayer-C
# [datetime.datetime(2024, 11, 28, 0, 0), datetime.datetime(2024, 11, 29, 0, 0), datetime.datetime(2024, 11, 30, 0, 0), datetime.datetime(2024, 12, 1, 0, 0), datetime.datetime(2024, 12, 2, 0, 0), datetime.datetime(2024, 12, 3, 0, 0), datetime.datetime(2024, 12, 4, 0, 0), datetime.datetime(2024, 12, 5, 0, 0), datetime.datetime(2024, 12, 6, 0, 0), datetime.datetime(2024, 12, 7, 0, 0), datetime.datetime(2024, 12, 8, 0, 0), datetime.datetime(2024, 12, 9, 0, 0), datetime.datetime(2024, 12, 10, 0, 0), datetime.datetime(2024, 12, 11, 0, 0)] 14
# ['CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST'] 14
# POST
# 2024-11-28 00:00:00 6B Thayer-C CALL
# 2024-11-29 00:00:00 6B Thayer-C POST
# 2024-11-30 00:00:00 6B Thayer-C DAY
# 2024-12-01 00:00:00 6B Thayer-C OFF
# 2024-12-02 00:00:00 6B Thayer-C CALL
# 2024-12-03 00:00:00 6B Thayer-C POST
# 2024-12-04 00:00:00 6B Thayer-C DAY
# 2024-12-05 00:00:00 6B Thayer-C GOOD
# 2024-12-06 00:00:00 6B Thayer-C CALL
# 2024-12-07 00:00:00 6B Thayer-C POST
# 2024-12-08 00:00:00 6B Thayer-C DAY
# 2024-12-09 00:00:00 6B Thayer-C OFF
# 2024-12-10 00:00:00 6B Thayer-C CALL
# 2024-12-11 00:00:00 6B Thayer-C POST
# 7A MTL
# [datetime.datetime(2024, 12, 12, 0, 0), datetime.datetime(2024, 12, 13, 0, 0), datetime.datetime(2024, 12, 14, 0, 0), datetime.datetime(2024, 12, 15, 0, 0), datetime.datetime(2024, 12, 16, 0, 0), datetime.datetime(2024, 12, 17, 0, 0), datetime.datetime(2024, 12, 18, 0, 0), datetime.datetime(2024, 12, 19, 0, 0)] 8
# ['DAY', 'DAY', 'DAY', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-12-12 00:00:00 7A MTL DAY
# 2024-12-13 00:00:00 7A MTL DAY
# 2024-12-14 00:00:00 7A MTL DAY
# 2024-12-15 00:00:00 7A MTL OFF
# 2024-12-16 00:00:00 7A MTL DAY
# ...
# 2024-07-17 00:00:00 1B MPC-B GOOD
# 2024-07-18 00:00:00 1B MPC-B CALL
# 2024-07-19 00:00:00 1B MPC-B POST
# 2024-07-20 00:00:00 1B MPC-B OFF
# 2024-07-21 00:00:00 1B MPC-B CALL
# 2024-07-22 00:00:00 1B MPC-B POST
# 2024-07-23 00:00:00 1B MPC-B GOOD
# 2024-07-24 00:00:00 1B MPC-B CALL
# 2024-07-25 00:00:00 1B MPC-B *POST
# 2A Ambulatory
# [datetime.datetime(2024, 7, 25, 0, 0), datetime.datetime(2024, 7, 26, 0, 0), datetime.datetime(2024, 7, 27, 0, 0), datetime.datetime(2024, 7, 28, 0, 0), datetime.datetime(2024, 7, 29, 0, 0), datetime.datetime(2024, 7, 30, 0, 0), datetime.datetime(2024, 7, 31, 0, 0), datetime.datetime(2024, 8, 1, 0, 0), datetime.datetime(2024, 8, 2, 0, 0), datetime.datetime(2024, 8, 3, 0, 0), datetime.datetime(2024, 8, 4, 0, 0), datetime.datetime(2024, 8, 5, 0, 0), datetime.datetime(2024, 8, 6, 0, 0), datetime.datetime(2024, 8, 7, 0, 0)] 14
# ['DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-07-25 00:00:00 2A Ambulatory DAY
# 2024-07-26 00:00:00 2A Ambulatory DAY
# 2024-07-27 00:00:00 2A Ambulatory OFF
# 2024-07-28 00:00:00 2A Ambulatory OFF
# 2024-07-29 00:00:00 2A Ambulatory DAY
# 2024-07-30 00:00:00 2A Ambulatory DAY
# 2024-07-31 00:00:00 2A Ambulatory DAY
# 2024-08-01 00:00:00 2A Ambulatory DAY
# 2024-08-02 00:00:00 2A Ambulatory DAY
# 2024-08-03 00:00:00 2A Ambulatory OFF
# 2024-08-04 00:00:00 2A Ambulatory OFF
# 2024-08-05 00:00:00 2A Ambulatory DAY
# 2024-08-06 00:00:00 2A Ambulatory DAY
# 2024-08-07 00:00:00 2A Ambulatory DAY
# 2B Brancati-C
# [datetime.datetime(2024, 8, 8, 0, 0), datetime.datetime(2024, 8, 9, 0, 0), datetime.datetime(2024, 8, 10, 0, 0), datetime.datetime(2024, 8, 11, 0, 0), datetime.datetime(2024, 8, 12, 0, 0), datetime.datetime(2024, 8, 13, 0, 0), datetime.datetime(2024, 8, 14, 0, 0), datetime.datetime(2024, 8, 15, 0, 0), datetime.datetime(2024, 8, 16, 0, 0), datetime.datetime(2024, 8, 17, 0, 0), datetime.datetime(2024, 8, 18, 0, 0), datetime.datetime(2024, 8, 19, 0, 0), datetime.datetime(2024, 8, 20, 0, 0), datetime.datetime(2024, 8, 21, 0, 0)] 14
# ['DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'NIGHT', 'NIGHT', 'NIGHT', 'NIGHT', 'POST', 'OFF', 'DAY'] 14
# DAY
# 2024-08-08 00:00:00 2B Brancati-C DAY
# 2024-08-09 00:00:00 2B Brancati-C OFF
# 2024-08-10 00:00:00 2B Brancati-C OFF
# 2024-08-11 00:00:00 2B Brancati-C DAY
# 2024-08-12 00:00:00 2B Brancati-C DAY
# 2024-08-13 00:00:00 2B Brancati-C DAY
# 2024-08-14 00:00:00 2B Brancati-C DAY
# 2024-08-15 00:00:00 2B Brancati-C NIGHT
# 2024-08-16 00:00:00 2B Brancati-C NIGHT
# 2024-08-17 00:00:00 2B Brancati-C NIGHT
# 2024-08-18 00:00:00 2B Brancati-C NIGHT
# 2024-08-19 00:00:00 2B Brancati-C POST
# 2024-08-20 00:00:00 2B Brancati-C OFF
# 2024-08-21 00:00:00 2B Brancati-C DAY
# 3A Janeway-A
# [datetime.datetime(2024, 8, 22, 0, 0), datetime.datetime(2024, 8, 23, 0, 0), datetime.datetime(2024, 8, 24, 0, 0), datetime.datetime(2024, 8, 25, 0, 0), datetime.datetime(2024, 8, 26, 0, 0), datetime.datetime(2024, 8, 27, 0, 0), datetime.datetime(2024, 8, 28, 0, 0), datetime.datetime(2024, 8, 29, 0, 0), datetime.datetime(2024, 8, 30, 0, 0), datetime.datetime(2024, 8, 31, 0, 0), datetime.datetime(2024, 9, 1, 0, 0), datetime.datetime(2024, 9, 2, 0, 0), datetime.datetime(2024, 9, 3, 0, 0), datetime.datetime(2024, 9, 4, 0, 0)] 14
# ['CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST'] 14
# POST
# 2024-08-22 00:00:00 3A Janeway-A CALL
# 2024-08-23 00:00:00 3A Janeway-A POST
# 2024-08-24 00:00:00 3A Janeway-A DAY
# 2024-08-25 00:00:00 3A Janeway-A OFF
# 2024-08-26 00:00:00 3A Janeway-A CALL
# 2024-08-27 00:00:00 3A Janeway-A POST
# 2024-08-28 00:00:00 3A Janeway-A DAY
# 2024-08-29 00:00:00 3A Janeway-A GOOD
# 2024-08-30 00:00:00 3A Janeway-A CALL
# 2024-08-31 00:00:00 3A Janeway-A POST
# 2024-09-01 00:00:00 3A Janeway-A DAY
# 2024-09-02 00:00:00 3A Janeway-A OFF
# 2024-09-03 00:00:00 3A Janeway-A CALL
# 2024-09-04 00:00:00 3A Janeway-A POST
# 3B Vacation
# [datetime.datetime(2024, 9, 5, 0, 0), datetime.datetime(2024, 9, 6, 0, 0), datetime.datetime(2024, 9, 7, 0, 0), datetime.datetime(2024, 9, 8, 0, 0), datetime.datetime(2024, 9, 9, 0, 0), datetime.datetime(2024, 9, 10, 0, 0), datetime.datetime(2024, 9, 11, 0, 0), datetime.datetime(2024, 9, 12, 0, 0), datetime.datetime(2024, 9, 13, 0, 0), datetime.datetime(2024, 9, 14, 0, 0), datetime.datetime(2024, 9, 15, 0, 0), datetime.datetime(2024, 9, 16, 0, 0), datetime.datetime(2024, 9, 17, 0, 0), datetime.datetime(2024, 9, 18, 0, 0)] 14
# ['VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION'] 14
# VACATION
# 2024-09-05 00:00:00 3B Vacation VACATION
# 2024-09-06 00:00:00 3B Vacation VACATION
# 2024-09-07 00:00:00 3B Vacation VACATION
# 2024-09-08 00:00:00 3B Vacation VACATION
# 2024-09-09 00:00:00 3B Vacation VACATION
# 2024-09-10 00:00:00 3B Vacation VACATION
# 2024-09-11 00:00:00 3B Vacation VACATION
# 2024-09-12 00:00:00 3B Vacation VACATION
# 2024-09-13 00:00:00 3B Vacation VACATION
# 2024-09-14 00:00:00 3B Vacation VACATION
# 2024-09-15 00:00:00 3B Vacation VACATION
# 2024-09-16 00:00:00 3B Vacation VACATION
# 2024-09-17 00:00:00 3B Vacation VACATION
# 2024-09-18 00:00:00 3B Vacation VACATION
# 4A Ambulatory
# [datetime.datetime(2024, 9, 19, 0, 0), datetime.datetime(2024, 9, 20, 0, 0), datetime.datetime(2024, 9, 21, 0, 0), datetime.datetime(2024, 9, 22, 0, 0), datetime.datetime(2024, 9, 23, 0, 0), datetime.datetime(2024, 9, 24, 0, 0), datetime.datetime(2024, 9, 25, 0, 0), datetime.datetime(2024, 9, 26, 0, 0), datetime.datetime(2024, 9, 27, 0, 0), datetime.datetime(2024, 9, 28, 0, 0), datetime.datetime(2024, 9, 29, 0, 0), datetime.datetime(2024, 9, 30, 0, 0), datetime.datetime(2024, 10, 1, 0, 0), datetime.datetime(2024, 10, 2, 0, 0)] 14
# ['DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-09-19 00:00:00 4A Ambulatory DAY
# 2024-09-20 00:00:00 4A Ambulatory DAY
# 2024-09-21 00:00:00 4A Ambulatory OFF
# 2024-09-22 00:00:00 4A Ambulatory OFF
# 2024-09-23 00:00:00 4A Ambulatory DAY
# 2024-09-24 00:00:00 4A Ambulatory DAY
# 2024-09-25 00:00:00 4A Ambulatory DAY
# 2024-09-26 00:00:00 4A Ambulatory DAY
# 2024-09-27 00:00:00 4A Ambulatory DAY
# 2024-09-28 00:00:00 4A Ambulatory OFF
# 2024-09-29 00:00:00 4A Ambulatory OFF
# 2024-09-30 00:00:00 4A Ambulatory DAY
# 2024-10-01 00:00:00 4A Ambulatory DAY
# 2024-10-02 00:00:00 4A Ambulatory DAY
# 4B Janeway-C
# [datetime.datetime(2024, 10, 3, 0, 0), datetime.datetime(2024, 10, 4, 0, 0), datetime.datetime(2024, 10, 5, 0, 0), datetime.datetime(2024, 10, 6, 0, 0), datetime.datetime(2024, 10, 7, 0, 0), datetime.datetime(2024, 10, 8, 0, 0), datetime.datetime(2024, 10, 9, 0, 0), datetime.datetime(2024, 10, 10, 0, 0), datetime.datetime(2024, 10, 11, 0, 0), datetime.datetime(2024, 10, 12, 0, 0), datetime.datetime(2024, 10, 13, 0, 0), datetime.datetime(2024, 10, 14, 0, 0), datetime.datetime(2024, 10, 15, 0, 0), datetime.datetime(2024, 10, 16, 0, 0)] 14
# ['CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST'] 14
# POST
# 2024-10-03 00:00:00 4B Janeway-C CALL
# 2024-10-04 00:00:00 4B Janeway-C POST
# 2024-10-05 00:00:00 4B Janeway-C DAY
# 2024-10-06 00:00:00 4B Janeway-C OFF
# 2024-10-07 00:00:00 4B Janeway-C CALL
# 2024-10-08 00:00:00 4B Janeway-C POST
# 2024-10-09 00:00:00 4B Janeway-C DAY
# 2024-10-10 00:00:00 4B Janeway-C GOOD
# 2024-10-11 00:00:00 4B Janeway-C CALL
# 2024-10-12 00:00:00 4B Janeway-C POST
# 2024-10-13 00:00:00 4B Janeway-C DAY
# 2024-10-14 00:00:00 4B Janeway-C OFF
# 2024-10-15 00:00:00 4B Janeway-C CALL
# 2024-10-16 00:00:00 4B Janeway-C POST
# 5A Janeway-C
# [datetime.datetime(2024, 10, 17, 0, 0), datetime.datetime(2024, 10, 18, 0, 0), datetime.datetime(2024, 10, 19, 0, 0), datetime.datetime(2024, 10, 20, 0, 0), datetime.datetime(2024, 10, 21, 0, 0), datetime.datetime(2024, 10, 22, 0, 0), datetime.datetime(2024, 10, 23, 0, 0), datetime.datetime(2024, 10, 24, 0, 0), datetime.datetime(2024, 10, 25, 0, 0), datetime.datetime(2024, 10, 26, 0, 0), datetime.datetime(2024, 10, 27, 0, 0), datetime.datetime(2024, 10, 28, 0, 0), datetime.datetime(2024, 10, 29, 0, 0), datetime.datetime(2024, 10, 30, 0, 0)] 14
# ['DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD'] 14
# GOOD
# 2024-10-17 00:00:00 5A Janeway-C DAY
# 2024-10-18 00:00:00 5A Janeway-C OFF
# 2024-10-19 00:00:00 5A Janeway-C CALL
# 2024-10-20 00:00:00 5A Janeway-C POST
# 2024-10-21 00:00:00 5A Janeway-C DAY
# 2024-10-22 00:00:00 5A Janeway-C GOOD
# 2024-10-23 00:00:00 5A Janeway-C CALL
# 2024-10-24 00:00:00 5A Janeway-C POST
# 2024-10-25 00:00:00 5A Janeway-C DAY
# 2024-10-26 00:00:00 5A Janeway-C OFF
# 2024-10-27 00:00:00 5A Janeway-C CALL
# 2024-10-28 00:00:00 5A Janeway-C POST
# 2024-10-29 00:00:00 5A Janeway-C DAY
# 2024-10-30 00:00:00 5A Janeway-C GOOD
# 5B MICU-A
# [datetime.datetime(2024, 10, 31, 0, 0), datetime.datetime(2024, 11, 1, 0, 0), datetime.datetime(2024, 11, 2, 0, 0), datetime.datetime(2024, 11, 3, 0, 0), datetime.datetime(2024, 11, 4, 0, 0), datetime.datetime(2024, 11, 5, 0, 0), datetime.datetime(2024, 11, 6, 0, 0), datetime.datetime(2024, 11, 7, 0, 0), datetime.datetime(2024, 11, 8, 0, 0), datetime.datetime(2024, 11, 9, 0, 0), datetime.datetime(2024, 11, 10, 0, 0), datetime.datetime(2024, 11, 11, 0, 0), datetime.datetime(2024, 11, 12, 0, 0), datetime.datetime(2024, 11, 13, 0, 0)] 14
# ['GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', '*POST'] 15
# *POST
# 2024-10-31 00:00:00 5B MICU-A GOOD
# 2024-11-01 00:00:00 5B MICU-A CALL
# 2024-11-02 00:00:00 5B MICU-A POST
# 2024-11-03 00:00:00 5B MICU-A OFF
# 2024-11-04 00:00:00 5B MICU-A CALL
# 2024-11-05 00:00:00 5B MICU-A POST
# 2024-11-06 00:00:00 5B MICU-A GOOD
# 2024-11-07 00:00:00 5B MICU-A CALL
# 2024-11-08 00:00:00 5B MICU-A POST
# 2024-11-09 00:00:00 5B MICU-A OFF
# 2024-11-10 00:00:00 5B MICU-A CALL
# 2024-11-11 00:00:00 5B MICU-A POST
# 2024-11-12 00:00:00 5B MICU-A GOOD
# 2024-11-13 00:00:00 5B MICU-A CALL
# 2024-11-14 00:00:00 5B MICU-A *POST
# 6A Ambulatory
# [datetime.datetime(2024, 11, 14, 0, 0), datetime.datetime(2024, 11, 15, 0, 0), datetime.datetime(2024, 11, 16, 0, 0), datetime.datetime(2024, 11, 17, 0, 0), datetime.datetime(2024, 11, 18, 0, 0), datetime.datetime(2024, 11, 19, 0, 0), datetime.datetime(2024, 11, 20, 0, 0), datetime.datetime(2024, 11, 21, 0, 0), datetime.datetime(2024, 11, 22, 0, 0), datetime.datetime(2024, 11, 23, 0, 0), datetime.datetime(2024, 11, 24, 0, 0), datetime.datetime(2024, 11, 25, 0, 0), datetime.datetime(2024, 11, 26, 0, 0), datetime.datetime(2024, 11, 27, 0, 0)] 14
# ['DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-11-14 00:00:00 6A Ambulatory DAY
# 2024-11-15 00:00:00 6A Ambulatory DAY
# 2024-11-16 00:00:00 6A Ambulatory OFF
# 2024-11-17 00:00:00 6A Ambulatory OFF
# 2024-11-18 00:00:00 6A Ambulatory DAY
# 2024-11-19 00:00:00 6A Ambulatory DAY
# 2024-11-20 00:00:00 6A Ambulatory DAY
# 2024-11-21 00:00:00 6A Ambulatory DAY
# 2024-11-22 00:00:00 6A Ambulatory DAY
# 2024-11-23 00:00:00 6A Ambulatory OFF
# 2024-11-24 00:00:00 6A Ambulatory OFF
# 2024-11-25 00:00:00 6A Ambulatory DAY
# 2024-11-26 00:00:00 6A Ambulatory DAY
# 2024-11-27 00:00:00 6A Ambulatory DAY
# 6B Janeway-C
# [datetime.datetime(2024, 11, 28, 0, 0), datetime.datetime(2024, 11, 29, 0, 0), datetime.datetime(2024, 11, 30, 0, 0), datetime.datetime(2024, 12, 1, 0, 0), datetime.datetime(2024, 12, 2, 0, 0), datetime.datetime(2024, 12, 3, 0, 0), datetime.datetime(2024, 12, 4, 0, 0), datetime.datetime(2024, 12, 5, 0, 0), datetime.datetime(2024, 12, 6, 0, 0), datetime.datetime(2024, 12, 7, 0, 0), datetime.datetime(2024, 12, 8, 0, 0), datetime.datetime(2024, 12, 9, 0, 0), datetime.datetime(2024, 12, 10, 0, 0), datetime.datetime(2024, 12, 11, 0, 0)] 14
# ['CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST'] 14
# POST
# 2024-11-28 00:00:00 6B Janeway-C CALL
# 2024-11-29 00:00:00 6B Janeway-C POST
# 2024-11-30 00:00:00 6B Janeway-C DAY
# 2024-12-01 00:00:00 6B Janeway-C OFF
# 2024-12-02 00:00:00 6B Janeway-C CALL
# 2024-12-03 00:00:00 6B Janeway-C POST
# 2024-12-04 00:00:00 6B Janeway-C DAY
# 2024-12-05 00:00:00 6B Janeway-C GOOD
# 2024-12-06 00:00:00 6B Janeway-C CALL
# 2024-12-07 00:00:00 6B Janeway-C POST
# 2024-12-08 00:00:00 6B Janeway-C DAY
# 2024-12-09 00:00:00 6B Janeway-C OFF
# 2024-12-10 00:00:00 6B Janeway-C CALL
# 2024-12-11 00:00:00 6B Janeway-C POST
# 7A Solids
# [datetime.datetime(2024, 12, 12, 0, 0), datetime.datetime(2024, 12, 13, 0, 0), datetime.datetime(2024, 12, 14, 0, 0), datetime.datetime(2024, 12, 15, 0, 0), datetime.datetime(2024, 12, 16, 0, 0), datetime.datetime(2024, 12, 17, 0, 0), datetime.datetime(2024, 12, 18, 0, 0), datetime.datetime(2024, 12, 19, 0, 0)] 8
# ['DAY', 'DAY', 'DAY', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-12-12 00:00:00 7A Solids DAY
# 2024-12-13 00:00:00 7A Solids DAY
# 2024-12-14 00:00:00 7A Solids DAY
# 2024-12-15 00:00:00 7A Solids OFF
# 2024-12-16 00:00:00 7A Solids DAY
# 2024-12-17 00:00:00 7A Solids DAY
# 2024-12-18 00:00:00 7A Solids DAY
# 2024-12-19 00:00:00 7A Solids DAY
# Holiday 1 Solids
# [datetime.datetime(2024, 12, 20, 0, 0), datetime.datetime(2024, 12, 21, 0, 0), datetime.datetime(2024, 12, 22, 0, 0), datetime.datetime(2024, 12, 23, 0, 0), datetime.datetime(2024, 12, 24, 0, 0), datetime.datetime(2024, 12, 25, 0, 0), datetime.datetime(2024, 12, 26, 0, 0)] 7
# ['DAY', 'DAY', 'DAY', 'OFF', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'DAY', 'OFF', 'DAY', 'DAY', 'DAY'] 14
# DAY
# 2024-12-20 00:00:00 Holiday 1 Solids DAY
# 2024-12-21 00:00:00 Holiday 1 Solids DAY
# 2024-12-22 00:00:00 Holiday 1 Solids DAY
# 2024-12-23 00:00:00 Holiday 1 Solids OFF
# 2024-12-24 00:00:00 Holiday 1 Solids DAY
# 2024-12-25 00:00:00 Holiday 1 Solids DAY
# 2024-12-26 00:00:00 Holiday 1 Solids DAY
# Holiday 2 Off
# [datetime.datetime(2024, 12, 27, 0, 0), datetime.datetime(2024, 12, 28, 0, 0), datetime.datetime(2024, 12, 29, 0, 0), datetime.datetime(2024, 12, 30, 0, 0), datetime.datetime(2024, 12, 31, 0, 0), datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 2, 0, 0)] 7
# ['OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF'] 14
# OFF
# 2024-12-27 00:00:00 Holiday 2 Off OFF
# 2024-12-28 00:00:00 Holiday 2 Off OFF
# 2024-12-29 00:00:00 Holiday 2 Off OFF
# 2024-12-30 00:00:00 Holiday 2 Off OFF
# 2024-12-31 00:00:00 Holiday 2 Off OFF
# 2025-01-01 00:00:00 Holiday 2 Off OFF
# 2025-01-02 00:00:00 Holiday 2 Off OFF
# [nan, nan, 'MICU - E', 'MICU - F', 'MICU - D', 'MICU - E', 'MICU - D', 'MICU - E', 'MICU - D', 'MICU - E', 'MICU - D', 'MICU - E', 'MICU - D', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 20
#      16 for block_id, rotation in zip(my_dict['block_dates'].keys(), my_blocks):
#      17     # only write out upto holiday block 2 since remaining scheudle has not been finalized yet
#      18     if block_id in ['1A', '1B', '2A', '2B', '3A', '3B', '4A', '4B', '5A', '5B', '6A', '6B', '7A', 'Holiday 1', "Holiday 2"]:
# ---> 20         rotation = re.sub('\s', '', rotation)
#      22         print(block_id, rotation)
#      24         block_days = block_dates(block_id, my_dict)
#
# File ~/anaconda3/lib/python3.11/re/__init__.py:185, in sub(pattern, repl, string, count, flags)
#     178 def sub(pattern, repl, string, count=0, flags=0):
#     179     """Return the string obtained by replacing the leftmost
#     180     non-overlapping occurrences of the pattern in string by the
#     181     replacement repl.  repl can be either a string or a callable;
#     182     if a string, backslash escapes in it are processed.  If it is
#     183     a callable, it's passed the Match object and must return
#     184     a replacement string to be used."""
# --> 185     return _compile(pattern, flags).sub(repl, string, count)
#
# TypeError: expected string or bytes-like object, got 'float'

# %%
def authenticate_google_drive():
    creds = None

    # Use token.json to store the user's access and refresh tokens
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    
    # If there are no valid credentials, let the user log in and authorize the app
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            # Use the client_secret.json to start the OAuth flow
            flow = InstalledAppFlow.from_client_secrets_file(
                '/Users/cjyoon/Dropbox/Osler/osler/client_secret_257342927366-4q3itidpqit3vcehjca5rvlg9m2evhsi.apps.googleusercontent.com.json', SCOPES)
            creds = flow.run_local_server(port=0)
        
        # Save the credentials for future runs in token.json
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    # Build the Google Drive service object
    service = build('drive', 'v3', credentials=creds)
    return service



def upload_ics_to_drive(file_path):
    service = authenticate_google_drive()

    # Upload the file to Google Drive with the correct MIME type for .ics files
    file_metadata = {'name': os.path.basename(file_path), 'mimeType': 'text/calendar'}
    media = MediaFileUpload(file_path, mimetype='text/calendar', parent='osler_schedule' )
    file = service.files().create(body=file_metadata, media_body=media, fields='id').execute()

    # Make the file public and get the shareable link
    file_id = file.get('id')
    service.permissions().create(fileId=file_id, body={'type': 'anyone', 'role': 'reader'}).execute()
    shareable_url = f"https://drive.google.com/file/d/osler_schedule/{file_id}/view"
    
    return shareable_url


# for resident in resident_names:
#     file_path = f'/Users/cjyoon/Dropbox/Osler/osler/data/{resident}_schedule.ics'
#     shareable_link = upload_ics_to_drive(file_path)
#     print(f"{resident} schedule: {shareable_link}")
