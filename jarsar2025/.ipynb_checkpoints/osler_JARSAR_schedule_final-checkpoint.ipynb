# %%
import icalendar
import pytz, zoneinfo, dateutil.tz  # timezone libraries
import datetime, icalendar
import pyaml
import pandas as pd 
import numpy as np
import yaml
from datetime import datetime, timedelta
import re
from ics import Calendar, Event
import math

# %%
def convert_datestring (datestring):
    format = "%m/%d/%Y"
    date_object = datetime.strptime(datestring, format)
    return date_object


def get_start_end_dates(block_id, my_dict):
    start, end = (my_dict['block_dates'][block_id].split())
    start = convert_datestring(start)
    end = convert_datestring(end)
    return start, end


def date_lists(start_date, end_date):
    current_date = start_date
    dates = []
    while current_date <= end_date:
        dates.append(current_date)
        current_date += timedelta(days=1)
    return dates
    

        
def block_dates (block_id, my_dict):
    """get start and end date for each block by going through the master yaml """
    start_date, end_date = (get_start_end_dates(block_id, my_dict))
    block_duration = date_lists(start_date, end_date)    
    return block_duration
 

def add_date_postcall_into_next_block(call_cycle, block_days):
    print(call_cycle[-1])
    if re.search(r'^\*', call_cycle[-1]):
        # Step 1: Get the last date in the list
        last_date = block_days[-1]

        # Step 2: Calculate the next date (assuming consecutive days, so add 1 day)
        next_date = last_date + timedelta(days=1)

        # Step 3: Add the new date to the list
        block_days.append(next_date)
    return block_days
    
    
def get_specific_rotation_schedule(block_id, rotation, my_dict):
    rotation = re.sub('\s', '', rotation)
    

        
    try:
        rotation, individual = rotation.split('-')
    except:
        rotation = rotation
        individual = 'Z'
        
    if re.search('Janeway|Barker|Longcope|Thayer', rotation):
        rotation_category = 'FirmSAR'    
    elif re.search('CJ|Polk|MEG|Liver', rotation):
        rotation_category = 'Subspecialty'    
        
    else:
        rotation_category = rotation
    print(rotation_category)
    print(individual)
    print(my_dict[rotation_category])
    for schedule_type, schedule in my_dict[rotation_category].items():
        print(schedule['blocks'])
        if block_id in schedule['blocks']:
            print(block_id)
            return schedule[individual].split()
    # if no schedule is found return '-' list
    return ['-'] *14

# %%
# Read master tables

    
with open("/Users/cjyoon/Dropbox/Osler/Osler_shiny/jarsar2025//call_schedule_master.yaml") as f:
    my_dict = yaml.safe_load(f)

    

    
master_schedule = pd.read_excel('/Users/cjyoon/Dropbox/Osler/Osler_shiny/jarsar2025/Resident Schedule 2025-2026.xlsx', sheet_name='Schedule')

# Combine first two columns into a new 'name' column
master_schedule['name'] = master_schedule.iloc[:, 0] + '_' + master_schedule.iloc[:, 1]

# Optional: drop the original first two columns
master_schedule = master_schedule.drop(master_schedule.columns[[0, 1]], axis=1)
master_schedule = master_schedule[['name'] + [col for col in master_schedule.columns if col != 'name']]

resident_names = master_schedule['name'].tolist()
resident_names = [x for x in resident_names if not (isinstance(x, float) and math.isnan(x))]
resident_names
# Out:
# ['Kuzma_Irena',
#  'Karatela_Maham',
#  'Zeitoun_Ralph',
#  'Chabaan_Lara',
#  'Morcos_George',
#  'Gupta_Vrinda',
#  'Rodriguez-Fernandez_Monica',
#  'Gharios_Charbel',
#  'Goren_Lea',
#  'Ye_Kevin',
#  'Bshesh_Khalifa',
#  'Bothwell_James',
#  'Sokolsky_Mark',
#  'Verma_Rohan',
#  'Robertson_Nicole',
#  'Koul_Kash',
#  'Khunsriraksakul_Chachrit',
#  'Guo_Matthew',
#  'Kesaf_Ayse',
#  'Kankaria_Rohan',
#  'Rajaei_Jennia',
#  'Connolly_John',
#  'Abou Diwan_Elizabeth',
#  'Gasperetti_Alessio',
#  'Stanwyck_Lynn',
#  'Aduboffour_Akwasi',
#  'Suresh_Abhilash',
#  'Pazzi_Carlotta',
#  'Kodukula_Sai',
#  'Tarasco_Mario',
#  'Carter_Julia',
#  'Alexander_Mathew',
#  'Jabboure_Fayez',
#  'Littman_Emily',
#  'Ancha_Bhavya',
#  'Clinton_Ivor',
#  'Jo_Allen',
#  'Kosoko_Idris',
#  'Udoh_Karen',
#  'Weinstein_Robert',
#  'Lopez_Christine',
#  'Rao_Rohit',
#  'Mathias_Trevor',
#  'Holler_Albert',
#  'Kee_Dustin',
#  'Yeudall_Scott',
#  'Ziogos_Timos',
#  'Potharazu_Archit',
#  'Vasoya_Roshan',
#  'Payne_Lauren',
#  'Tracey_Evan',
#  'Reddy_Tina',
#  'Sequeira_Lynette',
#  'Meyer_David',
#  'Kodali_Sreeja',
#  'Johnson_Adrienne',
#  'Ermolovich_Jake',
#  'Kim_Minjoo',
#  'Rahim_Muhammed',
#  'Cazimir_Catherine',
#  'Tran_Thi My Linh',
#  'Gao_Ruiyi',
#  'Arahirwa_Victor',
#  'Zarker_Andrew',
#  'Zerjav_Dylan',
#  'Preston_Anna',
#  'Gaona_Geyner',
#  'Pronovost_Henry',
#  'Dobbs_John',
#  'Mhaimeed_Nada',
#  'Dong_Matthew',
#  'Mansour_Alexandra',
#  'Hawkins_Stephanie',
#  'Amundson_Danielle',
#  'Murphy_Cara',
#  'Bullock_Avery',
#  'Emetu_Sophia',
#  'Wang_Tiffany',
#  'Wilson_Grant',
#  'Coyne_Liam',
#  'Ramesh_Harrine',
#  'Broshkevitch_Anna',
#  'Goplerud_Dana',
#  'Lutz_Lydia',
#  'Rosas_Lauren',
#  'Moore_Erica',
#  'Mhaimeed_Nour',
#  'Riddick_Erica',
#  'Blazoski_Cameron',
#  'Yimer_Diborah',
#  'Bediako_Hilary',
#  'Hutto_David',
#  'McLeish_Colin',
#  'Zale_Andrew',
#  'Sandoval_Raquel',
#  'Yoon_Chris',
#  'Shim_Jalene',
#  'McGredy_Maxine',
#  'Mollenkopf_Sarah',
#  'Lopez-Silva_Carolina',
#  'Ozkan_Bige',
#  'Chang_Michael',
#  'Fatteh_Maria',
#  'Buyske_John']

# %%
def update_values_to_uppercase(data):
    """
    Recursively updates all string values in a nested dictionary to uppercase.
    """
    if isinstance(data, dict):
        return {key: update_values_to_uppercase(value) for key, value in data.items()}
    elif isinstance(data, list):
        return [update_values_to_uppercase(item) for item in data]
    elif isinstance(data, str):
        return data.upper()
    else:
        return data


def add_combined_key(data):
    for key, value in data.items():
        if key.endswith('_') and isinstance(value, dict) and 'A' in value and 'B' in value:
            # Create a list of combined A and B values
            combined = [f"{a.strip()}/{b.strip()}" for (a, b) in zip(value['A'].split(), value['B'].split())]
            value['Z'] = ' '.join(combined)
    return data



def oncology_schedule(rotation, date): 
    schedule = 'DAY'
    
    if date.weekday() == 5 and rotation == 'MTL': #off day is Saturday
        schedule = 'OFF'
    elif date.weekday() == 5 and rotation in ['Heme']: #off day is Saturday
        schedule = 'OFF'
    elif date.weekday() == 6 and rotation in ['Solids', 'Leuks']: # off day is Sunday
        schedule = 'OFF'
    elif date.weekday() in  [5, 6] and  re.search(r'Pathway|Elective|Research|Geri|UH|Addiction|Women|HCH|HIV|Ambulatory', rotation): #ambo off day is Saturday and Sunday
        schedule = 'OFF'
    else:
        pass
    
    return schedule

# bayview schedule to stadard call formats. Changed in 2025-2026
bayview_conversion = dict({'Call': 'CALL', 'Post': 'POST', 'Continuity': 'CONT', 'Off': "OFF"})

# read in bayview schedule and format column to a string form of dates     
bayview_schedule = pd.read_excel('/Users/cjyoon/Dropbox/Osler/Osler_shiny/jarsar2025/bayview_unit_2025.xlsx')
# Convert columns to string format
# Convert columns to datetime where possible
new_columns = []
for col in bayview_schedule.columns:
    try:
        # Attempt to convert to datetime and format as string
        new_columns.append(pd.to_datetime(col).strftime('%Y-%m-%d'))
    except (ValueError, TypeError):
        # If conversion fails, keep the original column name
        new_columns.append(col)

# Assign the new column names
bayview_schedule.columns = new_columns

def get_bayview_schedule(rotation, date, schedule_df):
    """
    Retrieve the schedule for a specific rotation and date.
    
    Args:
    rotation (str): The rotation type, e.g., 'BMICU-1'.
    date (datetime): The date for which to get the schedule.
    schedule_df (pd.DataFrame): The schedule DataFrame.
    
    Returns:
    str: The schedule activity for the given rotation and date.
    """
#     # Convert the date to string format
#     date_str = date.strftime('%Y-%m-%d')
    
#     # Debug: Print column names and check for the date
#     if date_str not in schedule_df.columns:
#         return f"Date {date_str} not found in the schedule.\nAvailable dates: {schedule_df.columns.tolist()}"

    try:
        # Find the schedule for the given rotation and date
        result = schedule_df.loc[schedule_df['Unnamed: 0'] == rotation, date]
        if not result.empty:
            return result.values[0]
        else:
            return f"Rotation {rotation} not found."
    except KeyError:
        return f"Error occurred while looking up the schedule."


updated_dict = dict()
for key, value in my_dict.items():
    updated_val =  add_combined_key(my_dict[key])
    updated_dict.update({key: updated_val})
    
    
updated_dict = update_values_to_uppercase(updated_dict)
my_dict = updated_dict # overwrite after adding the 'Z' keys for blocks which specific resident role is not defined

# %%
my_dict
# Out:
# {'block_dates': {'1A': '7/1/2025  7/7/2025',
#   '1B': '7/8/2025  7/21/2025',
#   '2A': '7/22/2025 8/4/2025',
#   '2B': '8/5/2025  8/18/2025',
#   '3A': '8/19/2025 9/1/2025',
#   '3B': '9/2/2025  9/15/2025',
#   '4A': '9/16/2025 9/29/2025',
#   '4B': '9/30/2025 10/13/2025',
#   '5A': '10/14/2025  10/27/2025',
#   '5B': '10/28/2025  11/10/2025',
#   '6A': '11/11/2025  11/24/2025',
#   '6B': '11/25/2025  12/8/2025',
#   '7A': '12/9/2025  12/19/2025',
#   'Holiday 1': '12/20/2025 12/26/2025',
#   'Holiday 2': '12/27/2025 1/2/2026',
#   '7B': '1/3/2026  1/12/2026',
#   '8A': '1/13/2026 1/26/2026',
#   '8B': '1/27/2026 2/9/2026',
#   '9A': '2/10/2026 2/23/2026',
#   '9B': '2/24/2026 3/09/2026',
#   '10A': '3/10/2026  3/23/2026',
#   '10B': '3/24/2026  4/6/2026',
#   '11A': '4/7/2026  4/20/2026',
#   '11B': '4/21/2026  5/4/2026',
#   '12A': '5/5/2026 5/18/2026',
#   '12B': '5/19/2026  6/1/2026',
#   '13A': '6/2/2026 6/15/2026',
#   '13B': '6/16/2026  6/30/2026'},
#  'FirmSAR': {'type1': {'blocks': ['1A'],
#    'A': 'OLDS  OLDS  BOOK  OLDS  OFF BOOK  NEWS',
#    'B': 'NEWS  NEWS  OFF NIGHTS  NIGHTS  NIGHTS  NIGHTS  *POST',
#    'C': 'NIGHTS  NIGHTS  NIGHTS  NEWS*  BOOK  OFF OLDS'},
#   'type2': {'blocks': ['1B', '2A', '2B', '3A', '3B'],
#    'A': 'NEWS  NEWS  OLDS  OLDS  BOOK  BOOK  NIGHTS NIGHTS NIGHTS  NIGHTS  NEWS* OFF OFF NEWS',
#    'B': 'NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NEWS OFF  OFF NEWS  OLDS  BOOK  BOOK  OLDS',
#    'C': 'OLDS  OLDS  NEWS  NEWS  OFF OFF OLDS BOOK BOOK  OLDS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  *POST'},
#   'type3_': {'blocks': ['4A',
#     '4B',
#     '5A',
#     '5B',
#     '6A',
#     '6B',
#     '8A',
#     '8B',
#     '9A',
#     '9B',
#     '10A',
#     '10B',
#     '11A',
#     '11B',
#     '12A',
#     '12B',
#     '13A',
#     '13B'],
#    'A': 'OLDS  OLDS  OLDS  OLDS  BOOK  BOOK  OLDS NEWS NEWS  NEWS  NEWS  OFF OFF NEWS',
#    'B': 'NEWS  NEWS  NEWS  NEWS  OFF OFF NEWS OLDS OLDS  OLDS  OLDS  BOOK  BOOK  OLDS',
#    'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK OFF/BOOK NEWS/OLDS'},
#   'type4_': {'blocks': ['7A'],
#    'A': 'NEWS  NEWS  NEWS  NEWS  OFF BOOK  OLDS  OLDS  OLDS  OLDS  OLDS',
#    'B': 'OLDS  OLDS  OLDS  OLDS  BOOK  OFF NEWS  NEWS  NEWS  NEWS  NEWS',
#    'Z': 'NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK BOOK/OFF OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS'},
#   'type5_': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'],
#    'A': 'OLDS  OLDS  OLDS  NEWS  NEWS  NEWS  NEWS',
#    'B': 'NEWS  NEWS  NEWS  OLDS  OLDS  OLDS  OLDS',
#    'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS'},
#   'type6_': {'blocks': ['7B'],
#    'A': 'OFF OFF NEWS  NEWS  NEWS  OLDS  OLDS  BOOK  BOOK  OLDS',
#    'B': 'BOOK  BOOK  OLDS  OLDS  OLDS  NEWS  NEWS  OFF OFF NEWS',
#    'Z': 'OFF/BOOK OFF/BOOK NEWS/OLDS NEWS/OLDS NEWS/OLDS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS'}},
#  'FirmJAR': {'type1': {'blocks': ['1A'],
#    'A': 'BARKER  OFF BARKER  BARKER  BARKER  BARKER  BARKER/THAYER',
#    'B': 'JANEWAY OFF JANEWAY JANEWAY/LONGCOPE  JANEWAY JANEWAY JANEWAY',
#    'C': 'LONGCOPE  LONGCOPE/JANEWAY  LONGCOPE  OFF LONGCOPE  LONGCOPE  LONGCOPE',
#    'D': 'THAYER  BARKER/THAYER THAYER  THAYER  THAYER  THAYER  OFF',
#    'E': 'BRANCATI  BRANCATI  BRANCATI  BRANCATI/MPC  BRANCATI  BRANCATI  OFF',
#    'F': 'MPC MPC MPC OFF MPC MPC MPC/BRANCATI'},
#   'type2': {'blocks': ['1B', '2A', '2B', '3A', '3B'],
#    'A': 'BARKER  BARKER  BARKER  BARKER  BARKER/THAYER BARKER/THAYER BARKER BARKER BARKER  BARKER  BARKER  OFF OFF BARKER',
#    'B': 'JANEWAY JANEWAY JANEWAY JANEWAY OFF OFF JANEWAY JANEWAY JANEWAY JANEWAY JANEWAY JANEWAY/LONGCOPE  JANEWAY/LONGCOPE  JANEWAY',
#    'C': 'LONGCOPE  LONGCOPE  LONGCOPE  LONGCOPE  LONGCOPE/JANEWAY  LONGCOPE/JANEWAY  LONGCOPE LONGCOPE LONGCOPE  LONGCOPE  LONGCOPE  OFF OFF LONGCOPE',
#    'D': 'THAYER  THAYER  THAYER  THAYER  OFF OFF THAYER THAYER THAYER  THAYER  THAYER  THAYER/BARKER THAYER/BARKER THAYER',
#    'E': 'BRANCATI  BRANCATI  BRANCATI/MPC  BRANCATI  BRANCATI  BRANCATI  OFF BRANCATI  BRANCATI  BRANCATI/MPC  BRANCATI  BRANCATI  BRANCATI  OFF',
#    'F': 'MPC MPC OFF MPC MPC MPC MPC/BRANCATI MPC  MPC OFF MPC MPC MPC MPC/BRANCATI'}},
#  'MPC/NWJAR': {'type1': {'blocks': ['1A'],
#    'Z': 'NIGHTS  NIGHTS  NIGHTS  NIGHTS  OFF NIGHTS  NIGHTS  *POST'},
#   'type2': {'blocks': ['1B', '2A', '2B', '3A', '3B'],
#    'Z': 'NIGHTS  NIGHTS  NIGHTS  NIGHTS  OFF NIGHTS  NIGHTS NIGHTS NIGHTS  NIGHTS  NIGHTS  OFF NIGHTS  NIGHTS POST'}},
#  'MPC': {'type1': {'blocks': ['1A'],
#    'Z': 'DAYS  DAYS  OFF DAYS  DAYS  DAYS  DAYS'},
#   'type2': {'blocks': ['1B', '2A', '2B', '3A', '3B'],
#    'Z': 'DAYS  DAYS  DAYS  OFF DAYS  DAYS  DAYS DAYS DAYS  DAYS  OFF DAYS  DAYS  DAYS'},
#   'type3': {'blocks': ['4A',
#     '4B',
#     '5A',
#     '5B',
#     '6A',
#     '6B',
#     '8A',
#     '8B',
#     '9A',
#     '9B',
#     '10A',
#     '10B',
#     '11A',
#     '11B',
#     '12A',
#     '12B'],
#    'Z': 'DAYS  DAYS  DAYS  OFF DAYS  DAYS  DAYS DAYS DAYS  DAYS  OFF DAYS  DAYS  DAYS'},
#   'type4': {'blocks': ['7A'],
#    'Z': 'DAYS  DAYS  DAYS  OFF DAYS  DAYS  DAYS  DAYS  DAYS  DAYS  DAYS'},
#   'type5': {'blocks': ['7B'], 'Z': 'DAYS  DAYS  DAYS  DAYS  DAYS  DAYS  DAYS'},
#   'type6': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'],
#    'Z': 'DAYS  DAYS  DAYS  DAYS  DAYS  DAYS  OFF DAYS  DAYS  DAYS'}},
#  'Brancati': {'type1': {'blocks': ['1A'],
#    'A': 'DAYS  DAYS  BOOK  DAYS* OFF BOOK  DAYS',
#    'B': 'DAYS  DAYS  OFF NIGHTS  NIGHTS  NIGHTS  NIGHTS  *POST',
#    'C': 'NIGHTS  NIGHTS  NIGHTS  HALFDAY*  BOOK  OFF DAYS'},
#   'type2': {'blocks': ['1B', '2A', '2B', '3A', '3B'],
#    'A': 'DAYS  DAYS  DAYS  DAYS  OFF OFF DAYS NIGHTS NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  *POST',
#    'B': 'DAYS  DAYS  DAYS  DAYS  BOOK  BOOK  DAYS BOOK BOOK  DAYS  DAYS  OFF OFF DAYS ',
#    'C': 'NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS POST OFF DAYS  DAYS  BOOK  BOOK  DAYS'},
#   'type3_': {'blocks': ['4A',
#     '4B',
#     '5A',
#     '5B',
#     '6A',
#     '6B',
#     '8A',
#     '8B',
#     '9A',
#     '9B',
#     '10A',
#     '10B',
#     '11A',
#     '11B',
#     '12A',
#     '12B',
#     '13A',
#     '13B'],
#    'A': 'OLDS  OLDS  OLDS  OLDS  BOOK  BOOK  OLDS NEWS NEWS  NEWS  NEWS  OFF OFF NEWS',
#    'B': 'NEWS  NEWS  NEWS  NEWS  OFF OFF NEWS OLDS OLDS  OLDS  OLDS  BOOK  BOOK  OLDS',
#    'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK OFF/BOOK NEWS/OLDS'},
#   'type4_': {'blocks': ['7A'],
#    'A': 'NEWS  NEWS  NEWS  NEWS  OFF BOOK  OLDS  OLDS  OLDS  OLDS  OLDS ',
#    'B': 'OLDS  OLDS  OLDS  OLDS  BOOK  OFF NEWS  NEWS  NEWS  NEWS  NEWS',
#    'Z': 'NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK BOOK/OFF OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS'},
#   'type5_': {'blocks': ['7B'],
#    'A': 'OFF OFF NEWS  NEWS  OLDS  OLDS  OLDS  BOOK  BOOK  OLDS',
#    'B': 'BOOK  BOOK  OLDS  OLDS  NEWS  NEWS  NEWS  OFF OFF NEWS',
#    'Z': 'OFF/BOOK OFF/BOOK NEWS/OLDS NEWS/OLDS OLDS/NEWS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS'},
#   'type6_': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'],
#    'A': 'OLDS  OLDS  OLDS  NEWS  NEWS  NEWS  NEWS',
#    'B': 'NEWS  NEWS  NEWS  OLDS  OLDS  OLDS  OLDS',
#    'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS'}},
#  'MICU': {'type1': {'blocks': ['1A'],
#    'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST',
#    'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST',
#    'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD',
#    'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST',
#    'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST',
#    'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF'},
#   'type2a': {'blocks': ['2A',
#     '3A',
#     '4A',
#     '5A',
#     '6A',
#     '8A',
#     '9A',
#     '10A',
#     '11A',
#     '12A',
#     '13A'],
#    'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST',
#    'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST',
#    'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD',
#    'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST',
#    'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST',
#    'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF'},
#   'type2b': {'blocks': ['1B',
#     '2B',
#     '3B',
#     '4B',
#     '5B',
#     '6B',
#     '8B',
#     '9B',
#     '10B',
#     '11B',
#     '12B',
#     '13B'],
#    'A': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST',
#    'B': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD',
#    'C': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST',
#    'D': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST',
#    'E': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF',
#    'F': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST'},
#   'type3': {'blocks': ['7A'],
#    'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST',
#    'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST',
#    'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF',
#    'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST',
#    'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST',
#    'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD'},
#   'type4': {'blocks': ['7B'],
#    'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST',
#    'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD',
#    'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST',
#    'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST',
#    'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF',
#    'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST'},
#   'type5': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'],
#    'A': 'GOOD  CALL  POST  GOOD  CALL  POST  GOOD',
#    'B': 'POST  GOOD  CALL  POST  GOOD  CALL  POST',
#    'C': 'CALL  POST  GOOD  CALL  POST  GOOD  CALL *POST',
#    'D': 'GOOD  CALL  POST  GOOD  CALL  POST  GOOD',
#    'E': 'POST  GOOD  CALL  POST  GOOD  CALL  POST',
#    'F': 'CALL  POST  GOOD  CALL  POST  GOOD  CALL *POST'}},
#  'CCU': {'type1': {'blocks': ['1A'],
#    'A': 'POST  GOOD  CALL  POST  OFF CALL  POST',
#    'B': 'CALL  POST  GOOD  CALL  POST  OFF CALL  *POST',
#    'C': 'GOOD  CALL  POST  OFF CALL  POST  GOOD'},
#   'type2a': {'blocks': ['2A',
#     '3A',
#     '4A',
#     '5A',
#     '6A',
#     '8A',
#     '9A',
#     '10A',
#     '11A',
#     '12A',
#     '13A'],
#    'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL POST GOOD  CALL  POST  OFF CALL  POST',
#    'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST',
#    'C': 'POST  GOOD  CALL  POST  OFF CALL  POST GOOD CALL  POST  OFF CALL  POST  GOOD'},
#   'type2b': {'blocks': ['1B',
#     '2B',
#     '3B',
#     '4B',
#     '5B',
#     '6B',
#     '8B',
#     '9B',
#     '10B',
#     '11B',
#     '12B',
#     '13B'],
#    'A': 'GOOD  CALL  POST  OFF CALL  POST  GOOD CALL POST  OFF CALL  POST  GOOD  CALL  *POST',
#    'B': 'POST  GOOD  CALL  POST  OFF CALL  POST GOOD CALL  POST  OFF CALL  POST  GOOD',
#    'C': 'CALL  POST  OFF CALL  POST  GOOD  CALL POST OFF CALL  POST  GOOD  CALL  POST'},
#   'type4': {'blocks': ['7A'],
#    'A': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF',
#    'B': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST',
#    'C': 'GOOD  CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST'},
#   'type5': {'blocks': ['7B'],
#    'A': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST',
#    'B': 'CALL  POST  OFF CALL  POST  OFF CALL  POST  GOOD  CALL  *POST',
#    'C': 'OFF CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF'},
#   'type6': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'],
#    'A': 'GOOD  CALL  POST  GOOD  CALL  POST  GOOD',
#    'B': 'POST  GOOD  CALL  POST  GOOD  CALL  POST',
#    'C': 'CALL  POST  GOOD  CALL  POST  GOOD  CALL  *POST'}},
#  'Subspecialty': {'type1_': {'blocks': ['1A'],
#    'A': 'DAYS  DAYS  DAYS  DAYS  BOOK  OFF DAYS',
#    'B': 'DAYS  DAYS  DAYS  DAYS  OFF BOOK  DAYS',
#    'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF OFF/BOOK DAYS/DAYS'},
#   'type2_': {'blocks': ['1B',
#     '2A',
#     '2B',
#     '3A',
#     '3B',
#     '4A',
#     '4B',
#     '5A',
#     '5B',
#     '6A',
#     '6B',
#     '8A',
#     '8B',
#     '9A',
#     '9B',
#     '10A',
#     '10B',
#     '11A',
#     '11B',
#     '12A',
#     '12B',
#     '13A',
#     '13B'],
#    'A': 'DAYS  DAYS  DAYS  DAYS  BOOK  BOOK  DAYS DAYS DAYS  DAYS  DAYS  OFF OFF DAYS',
#    'B': 'DAYS  DAYS  DAYS  DAYS  OFF OFF DAYS DAYS DAYS  DAYS  DAYS  BOOK  BOOK  DAYS',
#    'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF BOOK/OFF DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS OFF/BOOK OFF/BOOK DAYS/DAYS'},
#   'type3_': {'blocks': ['7A'],
#    'A': 'DAYS  DAYS  DAYS  DAYS  BOOK  OFF DAYS  DAYS  DAYS  DAYS  DAYS',
#    'B': 'DAYS  DAYS  DAYS  DAYS  OFF BOOK  DAYS  DAYS  DAYS  DAYS  DAYS',
#    'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF OFF/BOOK DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS'},
#   'type4_': {'blocks': ['7B'],
#    'A': 'OFF OFF DAYS  DAYS  DAYS  DAYS  DAYS  BOOK  BOOK  DAYS',
#    'B': 'BOOK  BOOK  DAYS  DAYS  DAYS  DAYS  DAYS  OFF OFF DAYS',
#    'Z': 'OFF/BOOK OFF/BOOK DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF BOOK/OFF DAYS/DAYS'},
#   'type5_': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'],
#    'A': 'DAYS  DAYS  DAYS  DAYS  DAYS  DAYS  DAYS',
#    'B': 'DAYS  DAYS  DAYS  DAYS  DAYS  DAYS  DAYS',
#    'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS'}},
#  'Solids': {'type1': {'blocks': ['1A',
#     '2A',
#     '3A',
#     '4A',
#     '5A',
#     '6A',
#     '7A',
#     '8A',
#     '9A',
#     '10A',
#     '11A',
#     '12A',
#     '13A',
#     '1B',
#     '2B',
#     '3B',
#     '4B',
#     '5B',
#     '6B',
#     '7B',
#     '8B',
#     '9B',
#     '10B',
#     '11B',
#     '12B',
#     '13B',
#     'HOLIDAY 1',
#     'HOLIDAY 2'],
#    False: 'SATURDAY'}},
#  'MTL': {'type1': {'blocks': ['1A',
#     '2A',
#     '3A',
#     '4A',
#     '5A',
#     '6A',
#     '7A',
#     '8A',
#     '9A',
#     '10A',
#     '11A',
#     '12A',
#     '13A',
#     '1B',
#     '2B',
#     '3B',
#     '4B',
#     '5B',
#     '6B',
#     '7B',
#     '8B',
#     '9B',
#     '10B',
#     '11B',
#     '12B',
#     '13B',
#     'HOLIDAY 1',
#     'HOLIDAY 2'],
#    False: 'SATURDAY'}},
#  'Leuks': {'type1': {'blocks': ['1A',
#     '2A',
#     '3A',
#     '4A',
#     '5A',
#     '6A',
#     '7A',
#     '8A',
#     '9A',
#     '10A',
#     '11A',
#     '12A',
#     '13A',
#     '1B',
#     '2B',
#     '3B',
#     '4B',
#     '5B',
#     '6B',
#     '7B',
#     '8B',
#     '9B',
#     '10B',
#     '11B',
#     '12B',
#     '13B',
#     'HOLIDAY 1',
#     'HOLIDAY 2'],
#    False: 'MONDAY'}},
#  'GenCards': {'type1': {'blocks': ['1A'], 'Z': 'DAY DAY OFF DAY DAY DAY DAY'},
#   'type2': {'blocks': ['1B',
#     '2A',
#     '3A',
#     '4A',
#     '5A',
#     '6A',
#     '8A',
#     '9A',
#     '10A',
#     '11A',
#     '12A',
#     '13A',
#     '2B',
#     '3B',
#     '4B',
#     '5B',
#     '6B',
#     '8B',
#     '9B',
#     '10B',
#     '11B',
#     '12B',
#     '13B'],
#    'Z': 'DAY DAY DAY OFF DAY DAY DAY DAY DAY OFF DAY DAY DAY DAY'},
#   'type3': {'blocks': ['7A'],
#    'Z': 'DAY DAY DAY OFF DAY DAY DAY DAY DAY OFF DAY'},
#   'type5': {'blocks': ['7B'], 'Z': 'DAY DAY DAY DAY DAY OFF DAY DAY DAY DAY'},
#   'type6': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'],
#    'Z': 'DAY DAY DAY DAY DAY DAY DAY'}},
#  'Cardiomyopathy': {'type1': {'blocks': ['1A'],
#    '1': 'CALL  POST  GENCARDS DAY CALL  POST  OFF',
#    '2': 'DAY CALL  POST  OFF DAY CALL  POST',
#    '3': 'DAY DAY CALL  POST  OFF DAY CALL  POST',
#    '4': 'POST  DAY DAY CALL  POST  OFF DAY'},
#   'type2': {'blocks': ['1B',
#     '2A',
#     '3A',
#     '4A',
#     '5A',
#     '6A',
#     '8A',
#     '9A',
#     '10A',
#     '11A',
#     '12A',
#     '13A',
#     '2B',
#     '3B',
#     '4B',
#     '5B',
#     '6B',
#     '8B',
#     '9B',
#     '10B',
#     '11B',
#     '12B',
#     '13B'],
#    '1': 'CALL  POST  OFF DAY CALL  POST  DAY DAY CALL  POST  OFF DAY CALL  POST',
#    '2': 'DAY CALL  POST  GENCARDS DAY CALL  POST  OFF DAY CALL  POST  OFF DAY CALL  *POST',
#    '3': 'DAY DAY CALL  POST  OFF DAY CALL  POST  DAY DAY CALL  POST  OFF DAY',
#    '4': 'POST DAY DAY CALL  POST  OFF DAY CALL  POST  GENCARDS DAY CALL  POST  OFF'},
#   'type3': {'blocks': ['7A'],
#    '1': 'CALL  POST  OFF DAY CALL  POST  DAY DAY CALL  POST  DAY',
#    '2': 'DAY CALL  POST  GENCARDS DAY CALL  POST  OFF DAY CALL  POST',
#    '3': 'DAY DAY CALL  POST  OFF DAY CALL  POST  DAY DAY CALL',
#    '4': 'POST  DAY DAY CALL  POST  OFF DAY CALL  POST  GENCARDS DAY'},
#   'type4': {'blocks': ['7B'],
#    '1': 'CALL  POST  DAY DAY CALL  POST  OFF DAY CALL  POST',
#    '2': 'DAY CALL  POST  OFF DAY CALL  POST  OFF DAY CALL',
#    '3': 'OFF DAY CALL  POST  DAY DAY CALL  POST  OFF DAY',
#    '4': 'POST  OFF DAY CALL  POST  GENCARDS DAY CALL  POST  OFF'},
#   'type6': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'],
#    '1': 'CALL  POST  DAY CALL  POST  DAY CALL  *POST',
#    '2': 'DAY CALL  POST  DAY CALL  POST  DAY',
#    '3': 'DAY DAY CALL  POST  DAY CALL  POST'}},
#  'Supervisor': {'type1': {'blocks': ['4A',
#     '4B',
#     '5A',
#     '5B',
#     '6A',
#     '6B',
#     '8A',
#     '8B',
#     '9A',
#     '9B',
#     '10A',
#     '10B',
#     '11A',
#     '11B',
#     '12A',
#     '12B',
#     '13A',
#     '13B'],
#    'Z': 'WOLF  WOLF  WOLF  WOLF  OFF WOLF  WOLF WOLF WOLF  WOLF  WOLF  OFF WOLF  WOLF  *POST'},
#   'type2': {'blocks': ['7A'],
#    'Z': 'WOLF  WOLF  WOLF  WOLF  OFF WOLF  WOLF  WOLF  WOLF  WOLF  WOLF  *POST'},
#   'type3': {'blocks': ['7B'],
#    'Z': 'OFF WOLF  WOLF  WOLF  WOLF  WOLF  WOLF  OFF WOLF  WOLF  *POST'},
#   'type4': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'],
#    'Z': 'WOLF  WOLF  WOLF  WOLF  WOLF  WOLF  WOLF  *POST'}},
#  'NightWatch': {'type1': {'blocks': ['1A'],
#    'Z': 'NIGHTS  NIGHTS  NIGHTS  OFF NIGHTS  NIGHTS  NIGHTS  *POST'},
#   'type2': {'blocks': ['1B',
#     '2A',
#     '2B',
#     '3A',
#     '3B',
#     '4A',
#     '4B',
#     '5A',
#     '5B',
#     '6A',
#     '6B',
#     '8A',
#     '8B',
#     '9A',
#     '9B',
#     '10A',
#     '10B',
#     '11A',
#     '11B',
#     '12A',
#     '12B',
#     '13A',
#     '13B'],
#    'Z': 'NIGHTS  NIGHTS  NIGHTS  OFF NIGHTS  NIGHTS  NIGHTS NIGHTS NIGHTS  NIGHTS  OFF NIGHTS  NIGHTS  NIGHTS  *POST'},
#   'type3': {'blocks': ['7A'],
#    'Z': 'NIGHTS  NIGHTS  NIGHTS  OFF NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  OFF'},
#   'type4': {'blocks': ['7B'],
#    'Z': 'NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  OFF NIGHTS  NIGHTS  NIGHTS *POST'},
#   'type5': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'],
#    'Z': 'NIGHTS NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS *POST'}},
#  'NATO/DATO': {'type1': {'blocks': ['4A',
#     '4B',
#     '5A',
#     '5B',
#     '6A',
#     '6B',
#     '8A',
#     '8B',
#     '9A',
#     '9B',
#     '10A',
#     '10B',
#     '11A',
#     '11B',
#     '12A',
#     '12B',
#     '13A',
#     '13B'],
#    'Z': 'OFF NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO OFF NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO'},
#   'type2': {'blocks': ['7A'],
#    'Z': 'OFF NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO OFF NATO/DATO NATO/DATO NATO/DATO'},
#   'type3': {'blocks': ['7B'],
#    'Z': 'NATO/DATO NATO/DATO NATO/DATO OFF NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO'},
#   'type4': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'],
#    'Z': 'NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO'}},
#  'Relief': {'type1': {'blocks': ['1A'],
#    'Z': 'OFF TRIAGE  MPC_DAY  NW_RESIDENT MPC_NIGHTS/NW_RESIDENT NW_INTERN  POST'},
#   'type2': {'blocks': ['1B', '2A', '2B', '3A', '3B'],
#    'Z': 'OFF TRIAGE  OFF NW_RESIDENT MPC/NW_RESIDENT NW_INTERN  POST OFF  TRIAGE  OFF NW_RESIDENT MPC/NW_RESIDENT NW_INTERN  POST'},
#   'type3': {'blocks': ['7A'],
#    'Z': 'NATO/DATO TRIAGE  OFF NW_RESIDENT WOLF  NW_INTERN  POST  NATO/DATO TRIAGE  OFF NW_RESIDENT *POST'},
#   'type4': {'blocks': ['7B'],
#    'Z': 'WOLF  NW_INTERN  POST  NATO/DATO TRIAGE  OFF NW_RESIDENT WOLF  NW_INTERN  POST'},
#   'type5': {'blocks': ['4A',
#     '4B',
#     '5A',
#     '5B',
#     '6A',
#     '6B',
#     '8A',
#     '8B',
#     '9A',
#     '9B',
#     '10A',
#     '10B',
#     '11A',
#     '11B',
#     '12A',
#     '12B',
#     '13A',
#     '13B'],
#    'Z': 'NATO/DATO TRIAGE  OFF NW_RESIDENT WOLF  NW_INTERN POST NATO/DATO TRIAGE  OFF NW_RESIDENT WOLF  NW_INTERN POST'}},
#  'Triage': {'type1': {'blocks': ['1A'], 'Z': 'ON  OFF ON  ON  ON  ON  ON'},
#   'type2': {'blocks': ['1B',
#     '2A',
#     '2B',
#     '3A',
#     '3B',
#     '4A',
#     '4B',
#     '5A',
#     '5B',
#     '6A',
#     '6B',
#     '8A',
#     '8B',
#     '9A',
#     '9B',
#     '10A',
#     '10B',
#     '11A',
#     '11B',
#     '12A',
#     '12B',
#     '13A',
#     '13B'],
#    'Z': 'ON  OFF ON  ON  ON  ON  ON ON OFF ON  ON  ON  ON  ON'},
#   'type3': {'blocks': ['7A'],
#    'Z': 'ON  OFF ON  ON  ON  ON  ON  ON  OFF ON  ON'},
#   'type4': {'blocks': ['7B'], 'Z': 'ON  ON  ON  ON  OFF ON  ON  ON  ON  ON'},
#   'type5': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'],
#    'Z': 'ON  ON  ON  ON  ON  ON  ON'}},
#  'Jeopardy': {'type1': {'blocks': ['1A',
#     '2A',
#     '3A',
#     '4A',
#     '5A',
#     '6A',
#     '7A',
#     '8A',
#     '9A',
#     '10A',
#     '11A',
#     '12A',
#     '13A',
#     '1B',
#     '2B',
#     '3B',
#     '4B',
#     '5B',
#     '6B',
#     '7B',
#     '8B',
#     '9B',
#     '10B',
#     '11B',
#     '12B',
#     '13B',
#     'HOLIDAY 1',
#     'HOLIDAY 2'],
#    'Z': 'JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY'}},
#  'Off': {'type1': {'blocks': ['1A',
#     '2A',
#     '3A',
#     '4A',
#     '5A',
#     '6A',
#     '7A',
#     '8A',
#     '9A',
#     '10A',
#     '11A',
#     '12A',
#     '13A',
#     '1B',
#     '2B',
#     '3B',
#     '4B',
#     '5B',
#     '6B',
#     '7B',
#     '8B',
#     '9B',
#     '10B',
#     '11B',
#     '12B',
#     '13B',
#     'HOLIDAY 1',
#     'HOLIDAY 2'],
#    'Z': 'OFF OFF OFF OFF OFF OFF OFF OFF OFF OFF OFF OFF OFF OFF'}},
#  'Vacation': {'type1': {'blocks': ['1A',
#     '2A',
#     '3A',
#     '4A',
#     '5A',
#     '6A',
#     '7A',
#     '8A',
#     '9A',
#     '10A',
#     '11A',
#     '12A',
#     '13A',
#     '1B',
#     '2B',
#     '3B',
#     '4B',
#     '5B',
#     '6B',
#     '7B',
#     '8B',
#     '9B',
#     '10B',
#     '11B',
#     '12B',
#     '13B',
#     'HOLIDAY 1',
#     'HOLIDAY 2'],
#    'Z': 'VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION'}}}

# %%
def get_schedule(resident_name, master_schedule):
    """gets the specific intern's schedule from the table"""
    filtered_df = master_schedule[master_schedule.iloc[:, 0] == resident_name]
    return (filtered_df.squeeze().to_list()[1:])

# %%
master_schedule
# Out:
#                      name             1A              1B                  2A  \
# 0                     NaN  7/1/25-7/7/25  7/8/25-7/21/25      7/22/25-8/4/25
# 1             Kuzma_Irena      Gen Cards    Firm JAR - E  Cardiomyopathy - 2
# 2          Karatela_Maham     Longcope-A        MICU - E        Longcope - C
# 3           Zeitoun_Ralph      Janeway-C         CCU - C         Janeway - C
# 4            Chabaan_Lara          Liver       BMICU - 2        Firm JAR - C
# ..                    ...            ...             ...                 ...
# 100  Lopez-Silva_Carolina   Firm JAR - C      Ambulatory       Pathway-MedEd
# 101            Ozkan_Bige   Firm JAR - B      Ambulatory        Brancati - B
# 102         Chang_Michael     Ambulatory          Solids        Firm JAR - D
# 103          Fatteh_Maria             CJ              ED          Ambulatory
# 104           Buyske_John       MICU - A      Ambulatory         Janeway - B
#
#                  2B                  3A              3B                  4A  \
# 0    8/5/25-8/18/25      8/19/25-9/1/25  9/2/25-9/15/25     9/16/25-9/29/25
# 1        Ambulatory     Pathway-DataSci        Elective            Vacation
# 2        Ambulatory            Elective     Night Watch            Vacation
# 3        Ambulatory            Vacation        Elective            MICU - A
# 4        Ambulatory            Jeopardy        Vacation            Elective
# ..              ...                 ...             ...                 ...
# 100        Vacation  Cardiomyopathy - 4      Ambulatory            Elective
# 101        Vacation     Pathway-DataSci      Ambulatory  Cardiomyopathy - 1
# 102        Vacation     Pathway-DataSci      Ambulatory            Jeopardy
# 103        Vacation              Solids    Firm JAR - B          Ambulatory
# 104        Vacation            MICU - E      Ambulatory             Janeway
#
#                    4B                  5A  ...               9A  \
# 0    9/30/25-10/13/25   10/14/25-10/27/25  ...  2/10/26-2/23/26
# 1          Ambulatory             CCU - A  ...         Brancati
# 2          Ambulatory            Longcope  ...              CCU
# 3          Ambulatory             Janeway  ...           Triage
# 4          Ambulatory  Cardiomyopathy - 3  ...            Liver
# ..                ...                 ...  ...              ...
# 100          Brancati         Night Watch  ...         Jeopardy
# 101          BCCU - 2            Elective  ...            Liver
# 102               MTL          Ambulatory  ...       Ambulatory
# 103         NATO/DATO  Cardiomyopathy - 4  ...         Elective
# 104              Wolf            Elective  ...         Vacation
#
#                  9B              10A             10B             11A  \
# 0    2/24/26-3/9/26  3/10/26-3/23/26  3/24/26-4/6/26  4/7/26-4/20/26
# 1          Vacation            Liver      Ambulatory              CJ
# 2          Longcope             Wolf      Ambulatory        Longcope
# 3              MICU         Elective      Ambulatory         Janeway
# 4             Liver         Vacation      Ambulatory            MICU
# ..              ...              ...             ...             ...
# 100      Ambulatory         Elective            Polk       Gen Cards
# 101      Ambulatory         Vacation  Cardiomyopathy             CCU
# 102  Cardiomyopathy         Elective          Solids      Ambulatory
# 103        Elective       Ambulatory           Liver        Vacation
# 104      Ambulatory          City HD         City HD       NATO/DATO
#
#                 11B             12A             12B             13A  \
# 0    4/21/26-5/4/26  5/5/26-5/18/26  5/19/26-6/1/26  6/2/26-6/15/26
# 1    Cardiomyopathy             CCU      Ambulatory  Cardiomyopathy
# 2              MICU        Vacation      Ambulatory            MICU
# 3            Relief        Jeopardy      Ambulatory        Vacation
# 4    Cardiomyopathy        Elective      Ambulatory           Liver
# ..              ...             ...             ...             ...
# 100      Ambulatory  Cardiomyopathy           Liver        Brancati
# 101      Ambulatory       Gen Cards            BCCU             CCU
# 102           BMICU             MTL        Elective      Ambulatory
# 103           BMICU      Ambulatory  Cardiomyopathy           Leuks
# 104      Ambulatory            MICU         Janeway        Jeopardy
#
#                  13B
# 0    6/16/26-6/30/26
# 1     Cardiomyopathy
# 2           Elective
# 3           Elective
# 4               MICU
# ..               ...
# 100       Ambulatory
# 101       Ambulatory
# 102             MICU
# 103         Brancati
# 104       Ambulatory
#
# [105 rows x 29 columns]

# %%
print(master_schedule)

header_row = master_schedule[master_schedule['name'].isna()].iloc[0]
print(header_row)
# Step 2: Create new column names by combining old column name + row value
new_columns = [f"{col} {header_row[col]}" if col != 'name' else 'name' for col in master_schedule.columns]

# Step 3: Remove the row with NaN in 'name'
master_schedule = master_schedule[master_schedule['name'].notna()].copy()

# Step 4: Assign new column names
master_schedule.columns = new_columns

print(master_schedule)


master_schedule.replace("Supervisor", "Wolf", inplace=True)

master_schedule.sort_values('name').to_csv('/Users/cjyoon/Dropbox/Osler/Osler_shiny/jarsar2025/block_view_jarsar.tsv', sep='\t', index=False)
# Out:
#                      name             1A              1B                  2A  \
# 0                     NaN  7/1/25-7/7/25  7/8/25-7/21/25      7/22/25-8/4/25
# 1             Kuzma_Irena      Gen Cards    Firm JAR - E  Cardiomyopathy - 2
# 2          Karatela_Maham     Longcope-A        MICU - E        Longcope - C
# 3           Zeitoun_Ralph      Janeway-C         CCU - C         Janeway - C
# 4            Chabaan_Lara          Liver       BMICU - 2        Firm JAR - C
# ..                    ...            ...             ...                 ...
# 100  Lopez-Silva_Carolina   Firm JAR - C      Ambulatory       Pathway-MedEd
# 101            Ozkan_Bige   Firm JAR - B      Ambulatory        Brancati - B
# 102         Chang_Michael     Ambulatory          Solids        Firm JAR - D
# 103          Fatteh_Maria             CJ              ED          Ambulatory
# 104           Buyske_John       MICU - A      Ambulatory         Janeway - B
#
#                  2B                  3A              3B                  4A  \
# 0    8/5/25-8/18/25      8/19/25-9/1/25  9/2/25-9/15/25     9/16/25-9/29/25
# 1        Ambulatory     Pathway-DataSci        Elective            Vacation
# 2        Ambulatory            Elective     Night Watch            Vacation
# 3        Ambulatory            Vacation        Elective            MICU - A
# 4        Ambulatory            Jeopardy        Vacation            Elective
# ..              ...                 ...             ...                 ...
# 100        Vacation  Cardiomyopathy - 4      Ambulatory            Elective
# 101        Vacation     Pathway-DataSci      Ambulatory  Cardiomyopathy - 1
# 102        Vacation     Pathway-DataSci      Ambulatory            Jeopardy
# 103        Vacation              Solids    Firm JAR - B          Ambulatory
# 104        Vacation            MICU - E      Ambulatory             Janeway
#
#                    4B                  5A  ...               9A  \
# 0    9/30/25-10/13/25   10/14/25-10/27/25  ...  2/10/26-2/23/26
# 1          Ambulatory             CCU - A  ...         Brancati
# 2          Ambulatory            Longcope  ...              CCU
# 3          Ambulatory             Janeway  ...           Triage
# 4          Ambulatory  Cardiomyopathy - 3  ...            Liver
# ..                ...                 ...  ...              ...
# 100          Brancati         Night Watch  ...         Jeopardy
# 101          BCCU - 2            Elective  ...            Liver
# 102               MTL          Ambulatory  ...       Ambulatory
# 103         NATO/DATO  Cardiomyopathy - 4  ...         Elective
# 104              Wolf            Elective  ...         Vacation
#
#                  9B              10A             10B             11A  \
# 0    2/24/26-3/9/26  3/10/26-3/23/26  3/24/26-4/6/26  4/7/26-4/20/26
# 1          Vacation            Liver      Ambulatory              CJ
# 2          Longcope             Wolf      Ambulatory        Longcope
# 3              MICU         Elective      Ambulatory         Janeway
# 4             Liver         Vacation      Ambulatory            MICU
# ..              ...              ...             ...             ...
# 100      Ambulatory         Elective            Polk       Gen Cards
# 101      Ambulatory         Vacation  Cardiomyopathy             CCU
# 102  Cardiomyopathy         Elective          Solids      Ambulatory
# 103        Elective       Ambulatory           Liver        Vacation
# 104      Ambulatory          City HD         City HD       NATO/DATO
#
#                 11B             12A             12B             13A  \
# 0    4/21/26-5/4/26  5/5/26-5/18/26  5/19/26-6/1/26  6/2/26-6/15/26
# 1    Cardiomyopathy             CCU      Ambulatory  Cardiomyopathy
# 2              MICU        Vacation      Ambulatory            MICU
# 3            Relief        Jeopardy      Ambulatory        Vacation
# 4    Cardiomyopathy        Elective      Ambulatory           Liver
# ..              ...             ...             ...             ...
# 100      Ambulatory  Cardiomyopathy           Liver        Brancati
# 101      Ambulatory       Gen Cards            BCCU             CCU
# 102           BMICU             MTL        Elective      Ambulatory
# 103           BMICU      Ambulatory  Cardiomyopathy           Leuks
# 104      Ambulatory            MICU         Janeway        Jeopardy
#
#                  13B
# 0    6/16/26-6/30/26
# 1     Cardiomyopathy
# 2           Elective
# 3           Elective
# 4               MICU
# ..               ...
# 100       Ambulatory
# 101       Ambulatory
# 102             MICU
# 103         Brancati
# 104       Ambulatory
#
# [105 rows x 29 columns]
# name                       NaN
# 1A               7/1/25-7/7/25
# 1B              7/8/25-7/21/25
# 2A              7/22/25-8/4/25
# 2B              8/5/25-8/18/25
# 3A              8/19/25-9/1/25
# 3B              9/2/25-9/15/25
# 4A             9/16/25-9/29/25
# 4B            9/30/25-10/13/25
# 5A           10/14/25-10/27/25
# 5B           10/28/25-11/10/25
# 6A           11/11/25-11/24/25
# 6B            11/25/25-12/8/25
# 7A            12/9/25-12/19/25
# HOLIDAY 1    12/20/25-12/26/25
# HOLIDAY 2      12/27/25-1/2/26
# 7B              1/3/26-1/12/26
# 8A             1/13/26-1/26/26
# 8B              1/27/26-2/9/26
# 9A             2/10/26-2/23/26
# 9B              2/24/26-3/9/26
# 10A            3/10/26-3/23/26
# 10B             3/24/26-4/6/26
# 11A             4/7/26-4/20/26
# 11B             4/21/26-5/4/26
# 12A             5/5/26-5/18/26
# 12B             5/19/26-6/1/26
# 13A             6/2/26-6/15/26
# 13B            6/16/26-6/30/26
# Name: 0, dtype: object
#                      name 1A 7/1/25-7/7/25 1B 7/8/25-7/21/25  \
# 1             Kuzma_Irena        Gen Cards      Firm JAR - E
# 2          Karatela_Maham       Longcope-A          MICU - E
# 3           Zeitoun_Ralph        Janeway-C           CCU - C
# 4            Chabaan_Lara            Liver         BMICU - 2
# 5           Morcos_George         Elective          Jeopardy
# ..                    ...              ...               ...
# 100  Lopez-Silva_Carolina     Firm JAR - C        Ambulatory
# 101            Ozkan_Bige     Firm JAR - B        Ambulatory
# 102         Chang_Michael       Ambulatory            Solids
# 103          Fatteh_Maria               CJ                ED
# 104           Buyske_John         MICU - A        Ambulatory
#
#       2A 7/22/25-8/4/25 2B 8/5/25-8/18/25   3A 8/19/25-9/1/25  \
# 1    Cardiomyopathy - 2        Ambulatory     Pathway-DataSci
# 2          Longcope - C        Ambulatory            Elective
# 3           Janeway - C        Ambulatory            Vacation
# 4          Firm JAR - C        Ambulatory            Jeopardy
# 5          Firm JAR - A        Ambulatory  Cardiomyopathy - 1
# ..                  ...               ...                 ...
# 100       Pathway-MedEd          Vacation  Cardiomyopathy - 4
# 101        Brancati - B          Vacation     Pathway-DataSci
# 102        Firm JAR - D          Vacation     Pathway-DataSci
# 103          Ambulatory          Vacation              Solids
# 104         Janeway - B          Vacation            MICU - E
#
#     3B 9/2/25-9/15/25  4A 9/16/25-9/29/25 4B 9/30/25-10/13/25  \
# 1            Elective            Vacation          Ambulatory
# 2         Night Watch            Vacation          Ambulatory
# 3            Elective            MICU - A          Ambulatory
# 4            Vacation            Elective          Ambulatory
# 5               Liver            BCCU - 2          Ambulatory
# ..                ...                 ...                 ...
# 100        Ambulatory            Elective            Brancati
# 101        Ambulatory  Cardiomyopathy - 1            BCCU - 2
# 102        Ambulatory            Jeopardy                 MTL
# 103      Firm JAR - B          Ambulatory           NATO/DATO
# 104        Ambulatory             Janeway                Wolf
#
#     5A 10/14/25-10/27/25  ... 9A 2/10/26-2/23/26 9B 2/24/26-3/9/26  \
# 1                CCU - A  ...           Brancati          Vacation
# 2               Longcope  ...                CCU          Longcope
# 3                Janeway  ...             Triage              MICU
# 4     Cardiomyopathy - 3  ...              Liver             Liver
# 5               Vacation  ...               Polk          Brancati
# ..                   ...  ...                ...               ...
# 100          Night Watch  ...           Jeopardy        Ambulatory
# 101             Elective  ...              Liver        Ambulatory
# 102           Ambulatory  ...         Ambulatory    Cardiomyopathy
# 103   Cardiomyopathy - 4  ...           Elective          Elective
# 104             Elective  ...           Vacation        Ambulatory
#
#     10A 3/10/26-3/23/26 10B 3/24/26-4/6/26 11A 4/7/26-4/20/26  \
# 1                 Liver         Ambulatory                 CJ
# 2                  Wolf         Ambulatory           Longcope
# 3              Elective         Ambulatory            Janeway
# 4              Vacation         Ambulatory               MICU
# 5             Gen Cards         Ambulatory                 CJ
# ..                  ...                ...                ...
# 100            Elective               Polk          Gen Cards
# 101            Vacation     Cardiomyopathy                CCU
# 102            Elective             Solids         Ambulatory
# 103          Ambulatory              Liver           Vacation
# 104             City HD            City HD          NATO/DATO
#
#     11B 4/21/26-5/4/26 12A 5/5/26-5/18/26 12B 5/19/26-6/1/26  \
# 1       Cardiomyopathy                CCU         Ambulatory
# 2                 MICU           Vacation         Ambulatory
# 3               Relief           Jeopardy         Ambulatory
# 4       Cardiomyopathy           Elective         Ambulatory
# 5             Vacation                CCU         Ambulatory
# ..                 ...                ...                ...
# 100         Ambulatory     Cardiomyopathy              Liver
# 101         Ambulatory          Gen Cards               BCCU
# 102              BMICU                MTL           Elective
# 103              BMICU         Ambulatory     Cardiomyopathy
# 104         Ambulatory               MICU            Janeway
#
#     13A 6/2/26-6/15/26 13B 6/16/26-6/30/26
# 1       Cardiomyopathy      Cardiomyopathy
# 2                 MICU            Elective
# 3             Vacation            Elective
# 4                Liver                MICU
# 5                 BCCU      Cardiomyopathy
# ..                 ...                 ...
# 100           Brancati          Ambulatory
# 101                CCU          Ambulatory
# 102         Ambulatory                MICU
# 103              Leuks            Brancati
# 104           Jeopardy          Ambulatory
#
# [104 rows x 29 columns]

# %%
#july1_offset = my_dict['july1_offset']
# Create a calendar and event


for resident_name in resident_names:
    date_list = []
    schedule_list = []        
    my_blocks = (get_schedule(resident_name, master_schedule))
    print(my_blocks)
    

    calendar = Calendar()
    event = Event()
    with open(f"/Users/cjyoon/Dropbox/Osler/Osler_shiny/jarsar2025/schedule/{resident_name}_schedule.tsv", "w") as g:
        g.write('name\tdate\tschedule\n')
        for block_id, rotation in zip(my_dict['block_dates'].keys(), my_blocks):
            if 1:
                if not isinstance(rotation, str):
                    rotation = ' '

                rotation = re.sub('\s', '', rotation)

                print(block_id, rotation)
                
                block_days = block_dates(block_id, my_dict)        
                print(block_days)
                try:
                    call_cycle = get_specific_rotation_schedule(block_id.upper(), rotation, my_dict)
                except:
                    # if specific call cycle is unknown for a rotation, then default to unknown so manual creation can be made
                    if rotation == ' ':
                        call_cycle = [' '] * 14
                    else:
                        call_cycle = ['-'] * 14



                # check if block call cycle ends in a post call
                block_days = add_date_postcall_into_next_block(call_cycle, block_days)

                # Loop through each date and corresponding schedule
                for date, schedule in zip(block_days, call_cycle):
                    
                    # For Bayview units
                    if re.search(r'BCCU|BMICU', rotation):
                        if rotation=='BCCU':
                            rotation='BCCU-1'
                        elif rotation=="BMICU":
                            rotation='BMICU-1'
                        schedule = bayview_conversion[get_bayview_schedule(rotation, date.strftime("%Y-%m-%d"), bayview_schedule)]
                        print(f'{rotation} bla {schedule}')
                    # For oncology rotations/ambo where schedule is only per weekdays basis
                    elif rotation in ['MTL', 'Leuks', 'Solids', 'Ambulatory', 'Subspecialty', 'Psych', 'UCM', 'AddictionMedicine', 'Geri', 'Elective', 'Heme']:                       
                        schedule = oncology_schedule(rotation, date)
                    elif re.search(r'Pathway|Women|HIV|HCH', rotation):
                        schedule=oncology_schedule(rotation, date)
                        
                        
                    else:
                        pass
                    
                    
                    event = Event()  # Create a new event object inside the loop
                    if rotation == 'Supervisor': # change supervisor into more commonly referred Wolf
                        rotation = 'Wolf'
                        
                    if rotation == 'MPClinic'
                        rotation = 'MP_Clinic'
                        
                        
                    event.name = f'{block_id} {rotation} {schedule}'
                    event.begin = date
                    event.make_all_day()  # Make the event an all-day event
                    print(date, block_id, rotation, schedule)
                    # Add event to calendar
                    calendar.events.add(event)
                    date_string = date.strftime('%m-%d-%Y')
                    g.write(f'{resident_name}\t{date_string}\t{event.name}\n')



        # Write the calendar to a .ics file
        with open(f"/Users/cjyoon/Dropbox/Osler/Osler_shiny/www/schedule2025/{resident_name}_schedule.ics", "w") as f:
            f.writelines(calendar.serialize_iter())
# Out:
# ['Gen Cards', 'Firm JAR - E', 'Cardiomyopathy - 2', 'Ambulatory', 'Pathway-DataSci', 'Elective', 'Vacation', 'Ambulatory', 'CCU - A', 'Jeopardy', 'Elective', 'Ambulatory', 'MICU - B', 'Off', 'BCCU - 3', 'BCCU', 'NATO/DATO', 'Ambulatory', 'Brancati', 'Vacation', 'Liver', 'Ambulatory', 'CJ', 'Cardiomyopathy', 'CCU', 'Ambulatory', 'Cardiomyopathy', 'Cardiomyopathy']
# 1A GenCards
# [datetime.datetime(2025, 7, 1, 0, 0), datetime.datetime(2025, 7, 2, 0, 0), datetime.datetime(2025, 7, 3, 0, 0), datetime.datetime(2025, 7, 4, 0, 0), datetime.datetime(2025, 7, 5, 0, 0), datetime.datetime(2025, 7, 6, 0, 0), datetime.datetime(2025, 7, 7, 0, 0)]
# GenCards
# Z
# {'type1': {'blocks': ['1A'], 'Z': 'DAY DAY OFF DAY DAY DAY DAY'}, 'type2': {'blocks': ['1B', '2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B'], 'Z': 'DAY DAY DAY OFF DAY DAY DAY DAY DAY OFF DAY DAY DAY DAY'}, 'type3': {'blocks': ['7A'], 'Z': 'DAY DAY DAY OFF DAY DAY DAY DAY DAY OFF DAY'}, 'type5': {'blocks': ['7B'], 'Z': 'DAY DAY DAY DAY DAY OFF DAY DAY DAY DAY'}, 'type6': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'DAY DAY DAY DAY DAY DAY DAY'}}
# ['1A']
# 1A
# DAY
# 2025-07-01 00:00:00 1A GenCards DAY
# 2025-07-02 00:00:00 1A GenCards DAY
# 2025-07-03 00:00:00 1A GenCards OFF
# 2025-07-04 00:00:00 1A GenCards DAY
# 2025-07-05 00:00:00 1A GenCards DAY
# 2025-07-06 00:00:00 1A GenCards DAY
# 2025-07-07 00:00:00 1A GenCards DAY
# 1B FirmJAR-E
# [datetime.datetime(2025, 7, 8, 0, 0), datetime.datetime(2025, 7, 9, 0, 0), datetime.datetime(2025, 7, 10, 0, 0), datetime.datetime(2025, 7, 11, 0, 0), datetime.datetime(2025, 7, 12, 0, 0), datetime.datetime(2025, 7, 13, 0, 0), datetime.datetime(2025, 7, 14, 0, 0), datetime.datetime(2025, 7, 15, 0, 0), datetime.datetime(2025, 7, 16, 0, 0), datetime.datetime(2025, 7, 17, 0, 0), datetime.datetime(2025, 7, 18, 0, 0), datetime.datetime(2025, 7, 19, 0, 0), datetime.datetime(2025, 7, 20, 0, 0), datetime.datetime(2025, 7, 21, 0, 0)]
# FirmJAR
# E
# {'type1': {'blocks': ['1A'], 'A': 'BARKER  OFF BARKER  BARKER  BARKER  BARKER  BARKER/THAYER', 'B': 'JANEWAY OFF JANEWAY JANEWAY/LONGCOPE  JANEWAY JANEWAY JANEWAY', 'C': 'LONGCOPE  LONGCOPE/JANEWAY  LONGCOPE  OFF LONGCOPE  LONGCOPE  LONGCOPE', 'D': 'THAYER  BARKER/THAYER THAYER  THAYER  THAYER  THAYER  OFF', 'E': 'BRANCATI  BRANCATI  BRANCATI  BRANCATI/MPC  BRANCATI  BRANCATI  OFF', 'F': 'MPC MPC MPC OFF MPC MPC MPC/BRANCATI'}, 'type2': {'blocks': ['1B', '2A', '2B', '3A', '3B'], 'A': 'BARKER  BARKER  BARKER  BARKER  BARKER/THAYER BARKER/THAYER BARKER BARKER BARKER  BARKER  BARKER  OFF OFF BARKER', 'B': 'JANEWAY JANEWAY JANEWAY JANEWAY OFF OFF JANEWAY JANEWAY JANEWAY JANEWAY JANEWAY JANEWAY/LONGCOPE  JANEWAY/LONGCOPE  JANEWAY', 'C': 'LONGCOPE  LONGCOPE  LONGCOPE  LONGCOPE  LONGCOPE/JANEWAY  LONGCOPE/JANEWAY  LONGCOPE LONGCOPE LONGCOPE  LONGCOPE  LONGCOPE  OFF OFF LONGCOPE', 'D': 'THAYER  THAYER  THAYER  THAYER  OFF OFF THAYER THAYER THAYER  THAYER  THAYER  THAYER/BARKER THAYER/BARKER THAYER', 'E': 'BRANCATI  BRANCATI  BRANCATI/MPC  BRANCATI  BRANCATI  BRANCATI  OFF BRANCATI  BRANCATI  BRANCATI/MPC  BRANCATI  BRANCATI  BRANCATI  OFF', 'F': 'MPC MPC OFF MPC MPC MPC MPC/BRANCATI MPC  MPC OFF MPC MPC MPC MPC/BRANCATI'}}
# ['1A']
# ['1B', '2A', '2B', '3A', '3B']
# 1B
# OFF
# 2025-07-08 00:00:00 1B FirmJAR-E BRANCATI
# 2025-07-09 00:00:00 1B FirmJAR-E BRANCATI
# 2025-07-10 00:00:00 1B FirmJAR-E BRANCATI/MPC
# 2025-07-11 00:00:00 1B FirmJAR-E BRANCATI
# 2025-07-12 00:00:00 1B FirmJAR-E BRANCATI
# 2025-07-13 00:00:00 1B FirmJAR-E BRANCATI
# 2025-07-14 00:00:00 1B FirmJAR-E OFF
# 2025-07-15 00:00:00 1B FirmJAR-E BRANCATI
# 2025-07-16 00:00:00 1B FirmJAR-E BRANCATI
# 2025-07-17 00:00:00 1B FirmJAR-E BRANCATI/MPC
# 2025-07-18 00:00:00 1B FirmJAR-E BRANCATI
# 2025-07-19 00:00:00 1B FirmJAR-E BRANCATI
# 2025-07-20 00:00:00 1B FirmJAR-E BRANCATI
# 2025-07-21 00:00:00 1B FirmJAR-E OFF
# 2A Cardiomyopathy-2
# [datetime.datetime(2025, 7, 22, 0, 0), datetime.datetime(2025, 7, 23, 0, 0), datetime.datetime(2025, 7, 24, 0, 0), datetime.datetime(2025, 7, 25, 0, 0), datetime.datetime(2025, 7, 26, 0, 0), datetime.datetime(2025, 7, 27, 0, 0), datetime.datetime(2025, 7, 28, 0, 0), datetime.datetime(2025, 7, 29, 0, 0), datetime.datetime(2025, 7, 30, 0, 0), datetime.datetime(2025, 7, 31, 0, 0), datetime.datetime(2025, 8, 1, 0, 0), datetime.datetime(2025, 8, 2, 0, 0), datetime.datetime(2025, 8, 3, 0, 0), datetime.datetime(2025, 8, 4, 0, 0)]
# Cardiomyopathy
# 2
# {'type1': {'blocks': ['1A'], '1': 'CALL  POST  GENCARDS DAY CALL  POST  OFF', '2': 'DAY CALL  POST  OFF DAY CALL  POST', '3': 'DAY DAY CALL  POST  OFF DAY CALL  POST', '4': 'POST  DAY DAY CALL  POST  OFF DAY'}, 'type2': {'blocks': ['1B', '2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B'], '1': 'CALL  POST  OFF DAY CALL  POST  DAY DAY CALL  POST  OFF DAY CALL  POST', '2': 'DAY CALL  POST  GENCARDS DAY CALL  POST  OFF DAY CALL  POST  OFF DAY CALL  *POST', '3': 'DAY DAY CALL  POST  OFF DAY CALL  POST  DAY DAY CALL  POST  OFF DAY', '4': 'POST DAY DAY CALL  POST  OFF DAY CALL  POST  GENCARDS DAY CALL  POST  OFF'}, 'type3': {'blocks': ['7A'], '1': 'CALL  POST  OFF DAY CALL  POST  DAY DAY CALL  POST  DAY', '2': 'DAY CALL  POST  GENCARDS DAY CALL  POST  OFF DAY CALL  POST', '3': 'DAY DAY CALL  POST  OFF DAY CALL  POST  DAY DAY CALL', '4': 'POST  DAY DAY CALL  POST  OFF DAY CALL  POST  GENCARDS DAY'}, 'type4': {'blocks': ['7B'], '1': 'CALL  POST  DAY DAY CALL  POST  OFF DAY CALL  POST', '2': 'DAY CALL  POST  OFF DAY CALL  POST  OFF DAY CALL', '3': 'OFF DAY CALL  POST  DAY DAY CALL  POST  OFF DAY', '4': 'POST  OFF DAY CALL  POST  GENCARDS DAY CALL  POST  OFF'}, 'type6': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], '1': 'CALL  POST  DAY CALL  POST  DAY CALL  *POST', '2': 'DAY CALL  POST  DAY CALL  POST  DAY', '3': 'DAY DAY CALL  POST  DAY CALL  POST'}}
# ['1A']
# ['1B', '2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B']
# 2A
# *POST
# 2025-07-22 00:00:00 2A Cardiomyopathy-2 DAY
# 2025-07-23 00:00:00 2A Cardiomyopathy-2 CALL
# 2025-07-24 00:00:00 2A Cardiomyopathy-2 POST
# 2025-07-25 00:00:00 2A Cardiomyopathy-2 GENCARDS
# 2025-07-26 00:00:00 2A Cardiomyopathy-2 DAY
# 2025-07-27 00:00:00 2A Cardiomyopathy-2 CALL
# 2025-07-28 00:00:00 2A Cardiomyopathy-2 POST
# 2025-07-29 00:00:00 2A Cardiomyopathy-2 OFF
# 2025-07-30 00:00:00 2A Cardiomyopathy-2 DAY
# 2025-07-31 00:00:00 2A Cardiomyopathy-2 CALL
# 2025-08-01 00:00:00 2A Cardiomyopathy-2 POST
# 2025-08-02 00:00:00 2A Cardiomyopathy-2 OFF
# 2025-08-03 00:00:00 2A Cardiomyopathy-2 DAY
# 2025-08-04 00:00:00 2A Cardiomyopathy-2 CALL
# 2025-08-05 00:00:00 2A Cardiomyopathy-2 *POST
# 2B Ambulatory
# [datetime.datetime(2025, 8, 5, 0, 0), datetime.datetime(2025, 8, 6, 0, 0), datetime.datetime(2025, 8, 7, 0, 0), datetime.datetime(2025, 8, 8, 0, 0), datetime.datetime(2025, 8, 9, 0, 0), datetime.datetime(2025, 8, 10, 0, 0), datetime.datetime(2025, 8, 11, 0, 0), datetime.datetime(2025, 8, 12, 0, 0), datetime.datetime(2025, 8, 13, 0, 0), datetime.datetime(2025, 8, 14, 0, 0), datetime.datetime(2025, 8, 15, 0, 0), datetime.datetime(2025, 8, 16, 0, 0), datetime.datetime(2025, 8, 17, 0, 0), datetime.datetime(2025, 8, 18, 0, 0)]
# Ambulatory
# Z
# -
# 2025-08-05 00:00:00 2B Ambulatory DAY
# 2025-08-06 00:00:00 2B Ambulatory DAY
# 2025-08-07 00:00:00 2B Ambulatory DAY
# 2025-08-08 00:00:00 2B Ambulatory DAY
# 2025-08-09 00:00:00 2B Ambulatory OFF
# 2025-08-10 00:00:00 2B Ambulatory OFF
# 2025-08-11 00:00:00 2B Ambulatory DAY
# 2025-08-12 00:00:00 2B Ambulatory DAY
# 2025-08-13 00:00:00 2B Ambulatory DAY
# 2025-08-14 00:00:00 2B Ambulatory DAY
# 2025-08-15 00:00:00 2B Ambulatory DAY
# 2025-08-16 00:00:00 2B Ambulatory OFF
# 2025-08-17 00:00:00 2B Ambulatory OFF
# 2025-08-18 00:00:00 2B Ambulatory DAY
# 3A Pathway-DataSci
# [datetime.datetime(2025, 8, 19, 0, 0), datetime.datetime(2025, 8, 20, 0, 0), datetime.datetime(2025, 8, 21, 0, 0), datetime.datetime(2025, 8, 22, 0, 0), datetime.datetime(2025, 8, 23, 0, 0), datetime.datetime(2025, 8, 24, 0, 0), datetime.datetime(2025, 8, 25, 0, 0), datetime.datetime(2025, 8, 26, 0, 0), datetime.datetime(2025, 8, 27, 0, 0), datetime.datetime(2025, 8, 28, 0, 0), datetime.datetime(2025, 8, 29, 0, 0), datetime.datetime(2025, 8, 30, 0, 0), datetime.datetime(2025, 8, 31, 0, 0), datetime.datetime(2025, 9, 1, 0, 0)]
# Pathway
# DataSci
# -
# 2025-08-19 00:00:00 3A Pathway-DataSci DAY
# 2025-08-20 00:00:00 3A Pathway-DataSci DAY
# 2025-08-21 00:00:00 3A Pathway-DataSci DAY
# 2025-08-22 00:00:00 3A Pathway-DataSci DAY
# 2025-08-23 00:00:00 3A Pathway-DataSci OFF
# 2025-08-24 00:00:00 3A Pathway-DataSci OFF
# 2025-08-25 00:00:00 3A Pathway-DataSci DAY
# 2025-08-26 00:00:00 3A Pathway-DataSci DAY
# 2025-08-27 00:00:00 3A Pathway-DataSci DAY
# 2025-08-28 00:00:00 3A Pathway-DataSci DAY
# 2025-08-29 00:00:00 3A Pathway-DataSci DAY
# 2025-08-30 00:00:00 3A Pathway-DataSci OFF
# 2025-08-31 00:00:00 3A Pathway-DataSci OFF
# 2025-09-01 00:00:00 3A Pathway-DataSci DAY
# 3B Elective
# [datetime.datetime(2025, 9, 2, 0, 0), datetime.datetime(2025, 9, 3, 0, 0), datetime.datetime(2025, 9, 4, 0, 0), datetime.datetime(2025, 9, 5, 0, 0), datetime.datetime(2025, 9, 6, 0, 0), datetime.datetime(2025, 9, 7, 0, 0), datetime.datetime(2025, 9, 8, 0, 0), datetime.datetime(2025, 9, 9, 0, 0), datetime.datetime(2025, 9, 10, 0, 0), datetime.datetime(2025, 9, 11, 0, 0), datetime.datetime(2025, 9, 12, 0, 0), datetime.datetime(2025, 9, 13, 0, 0), datetime.datetime(2025, 9, 14, 0, 0), datetime.datetime(2025, 9, 15, 0, 0)]
# Elective
# Z
# -
# 2025-09-02 00:00:00 3B Elective DAY
# 2025-09-03 00:00:00 3B Elective DAY
# 2025-09-04 00:00:00 3B Elective DAY
# 2025-09-05 00:00:00 3B Elective DAY
# 2025-09-06 00:00:00 3B Elective OFF
# 2025-09-07 00:00:00 3B Elective OFF
# 2025-09-08 00:00:00 3B Elective DAY
# 2025-09-09 00:00:00 3B Elective DAY
# 2025-09-10 00:00:00 3B Elective DAY
# 2025-09-11 00:00:00 3B Elective DAY
# 2025-09-12 00:00:00 3B Elective DAY
# 2025-09-13 00:00:00 3B Elective OFF
# 2025-09-14 00:00:00 3B Elective OFF
# 2025-09-15 00:00:00 3B Elective DAY
# 4A Vacation
# [datetime.datetime(2025, 9, 16, 0, 0), datetime.datetime(2025, 9, 17, 0, 0), datetime.datetime(2025, 9, 18, 0, 0), datetime.datetime(2025, 9, 19, 0, 0), datetime.datetime(2025, 9, 20, 0, 0), datetime.datetime(2025, 9, 21, 0, 0), datetime.datetime(2025, 9, 22, 0, 0), datetime.datetime(2025, 9, 23, 0, 0), datetime.datetime(2025, 9, 24, 0, 0), datetime.datetime(2025, 9, 25, 0, 0), datetime.datetime(2025, 9, 26, 0, 0), datetime.datetime(2025, 9, 27, 0, 0), datetime.datetime(2025, 9, 28, 0, 0), datetime.datetime(2025, 9, 29, 0, 0)]
# Vacation
# Z
# {'type1': {'blocks': ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION'}}
# ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2']
# 4A
# VACATION
# 2025-09-16 00:00:00 4A Vacation VACATION
# 2025-09-17 00:00:00 4A Vacation VACATION
# 2025-09-18 00:00:00 4A Vacation VACATION
# 2025-09-19 00:00:00 4A Vacation VACATION
# 2025-09-20 00:00:00 4A Vacation VACATION
# 2025-09-21 00:00:00 4A Vacation VACATION
# 2025-09-22 00:00:00 4A Vacation VACATION
# 2025-09-23 00:00:00 4A Vacation VACATION
# 2025-09-24 00:00:00 4A Vacation VACATION
# 2025-09-25 00:00:00 4A Vacation VACATION
# 2025-09-26 00:00:00 4A Vacation VACATION
# 2025-09-27 00:00:00 4A Vacation VACATION
# 2025-09-28 00:00:00 4A Vacation VACATION
# 2025-09-29 00:00:00 4A Vacation VACATION
# 4B Ambulatory
# [datetime.datetime(2025, 9, 30, 0, 0), datetime.datetime(2025, 10, 1, 0, 0), datetime.datetime(2025, 10, 2, 0, 0), datetime.datetime(2025, 10, 3, 0, 0), datetime.datetime(2025, 10, 4, 0, 0), datetime.datetime(2025, 10, 5, 0, 0), datetime.datetime(2025, 10, 6, 0, 0), datetime.datetime(2025, 10, 7, 0, 0), datetime.datetime(2025, 10, 8, 0, 0), datetime.datetime(2025, 10, 9, 0, 0), datetime.datetime(2025, 10, 10, 0, 0), datetime.datetime(2025, 10, 11, 0, 0), datetime.datetime(2025, 10, 12, 0, 0), datetime.datetime(2025, 10, 13, 0, 0)]
# Ambulatory
# Z
# -
# 2025-09-30 00:00:00 4B Ambulatory DAY
# 2025-10-01 00:00:00 4B Ambulatory DAY
# 2025-10-02 00:00:00 4B Ambulatory DAY
# 2025-10-03 00:00:00 4B Ambulatory DAY
# 2025-10-04 00:00:00 4B Ambulatory OFF
# 2025-10-05 00:00:00 4B Ambulatory OFF
# 2025-10-06 00:00:00 4B Ambulatory DAY
# 2025-10-07 00:00:00 4B Ambulatory DAY
# 2025-10-08 00:00:00 4B Ambulatory DAY
# 2025-10-09 00:00:00 4B Ambulatory DAY
# 2025-10-10 00:00:00 4B Ambulatory DAY
# 2025-10-11 00:00:00 4B Ambulatory OFF
# 2025-10-12 00:00:00 4B Ambulatory OFF
# 2025-10-13 00:00:00 4B Ambulatory DAY
# 5A CCU-A
# [datetime.datetime(2025, 10, 14, 0, 0), datetime.datetime(2025, 10, 15, 0, 0), datetime.datetime(2025, 10, 16, 0, 0), datetime.datetime(2025, 10, 17, 0, 0), datetime.datetime(2025, 10, 18, 0, 0), datetime.datetime(2025, 10, 19, 0, 0), datetime.datetime(2025, 10, 20, 0, 0), datetime.datetime(2025, 10, 21, 0, 0), datetime.datetime(2025, 10, 22, 0, 0), datetime.datetime(2025, 10, 23, 0, 0), datetime.datetime(2025, 10, 24, 0, 0), datetime.datetime(2025, 10, 25, 0, 0), datetime.datetime(2025, 10, 26, 0, 0), datetime.datetime(2025, 10, 27, 0, 0)]
# CCU
# A
# {'type1': {'blocks': ['1A'], 'A': 'POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'GOOD  CALL  POST  OFF CALL  POST  GOOD'}, 'type2a': {'blocks': ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL POST GOOD  CALL  POST  OFF CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST GOOD CALL  POST  OFF CALL  POST  GOOD'}, 'type2b': {'blocks': ['1B', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B'], 'A': 'GOOD  CALL  POST  OFF CALL  POST  GOOD CALL POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'POST  GOOD  CALL  POST  OFF CALL  POST GOOD CALL  POST  OFF CALL  POST  GOOD', 'C': 'CALL  POST  OFF CALL  POST  GOOD  CALL POST OFF CALL  POST  GOOD  CALL  POST'}, 'type4': {'blocks': ['7A'], 'A': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'B': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'C': 'GOOD  CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST'}, 'type5': {'blocks': ['7B'], 'A': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'B': 'CALL  POST  OFF CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'C': 'OFF CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF'}, 'type6': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'GOOD  CALL  POST  GOOD  CALL  POST  GOOD', 'B': 'POST  GOOD  CALL  POST  GOOD  CALL  POST', 'C': 'CALL  POST  GOOD  CALL  POST  GOOD  CALL  *POST'}}
# ['1A']
# ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A']
# 5A
# POST
# 2025-10-14 00:00:00 5A CCU-A CALL
# 2025-10-15 00:00:00 5A CCU-A POST
# 2025-10-16 00:00:00 5A CCU-A GOOD
# 2025-10-17 00:00:00 5A CCU-A CALL
# 2025-10-18 00:00:00 5A CCU-A POST
# 2025-10-19 00:00:00 5A CCU-A OFF
# 2025-10-20 00:00:00 5A CCU-A CALL
# 2025-10-21 00:00:00 5A CCU-A POST
# 2025-10-22 00:00:00 5A CCU-A GOOD
# 2025-10-23 00:00:00 5A CCU-A CALL
# 2025-10-24 00:00:00 5A CCU-A POST
# 2025-10-25 00:00:00 5A CCU-A OFF
# 2025-10-26 00:00:00 5A CCU-A CALL
# 2025-10-27 00:00:00 5A CCU-A POST
# 5B Jeopardy
# [datetime.datetime(2025, 10, 28, 0, 0), datetime.datetime(2025, 10, 29, 0, 0), datetime.datetime(2025, 10, 30, 0, 0), datetime.datetime(2025, 10, 31, 0, 0), datetime.datetime(2025, 11, 1, 0, 0), datetime.datetime(2025, 11, 2, 0, 0), datetime.datetime(2025, 11, 3, 0, 0), datetime.datetime(2025, 11, 4, 0, 0), datetime.datetime(2025, 11, 5, 0, 0), datetime.datetime(2025, 11, 6, 0, 0), datetime.datetime(2025, 11, 7, 0, 0), datetime.datetime(2025, 11, 8, 0, 0), datetime.datetime(2025, 11, 9, 0, 0), datetime.datetime(2025, 11, 10, 0, 0)]
# Jeopardy
# Z
# {'type1': {'blocks': ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY'}}
# ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2']
# 5B
# JEOPARDY
# 2025-10-28 00:00:00 5B Jeopardy JEOPARDY
# 2025-10-29 00:00:00 5B Jeopardy JEOPARDY
# 2025-10-30 00:00:00 5B Jeopardy JEOPARDY
# 2025-10-31 00:00:00 5B Jeopardy JEOPARDY
# 2025-11-01 00:00:00 5B Jeopardy JEOPARDY
# 2025-11-02 00:00:00 5B Jeopardy JEOPARDY
# 2025-11-03 00:00:00 5B Jeopardy JEOPARDY
# 2025-11-04 00:00:00 5B Jeopardy JEOPARDY
# 2025-11-05 00:00:00 5B Jeopardy JEOPARDY
# 2025-11-06 00:00:00 5B Jeopardy JEOPARDY
# 2025-11-07 00:00:00 5B Jeopardy JEOPARDY
# 2025-11-08 00:00:00 5B Jeopardy JEOPARDY
# 2025-11-09 00:00:00 5B Jeopardy JEOPARDY
# 2025-11-10 00:00:00 5B Jeopardy JEOPARDY
# 6A Elective
# [datetime.datetime(2025, 11, 11, 0, 0), datetime.datetime(2025, 11, 12, 0, 0), datetime.datetime(2025, 11, 13, 0, 0), datetime.datetime(2025, 11, 14, 0, 0), datetime.datetime(2025, 11, 15, 0, 0), datetime.datetime(2025, 11, 16, 0, 0), datetime.datetime(2025, 11, 17, 0, 0), datetime.datetime(2025, 11, 18, 0, 0), datetime.datetime(2025, 11, 19, 0, 0), datetime.datetime(2025, 11, 20, 0, 0), datetime.datetime(2025, 11, 21, 0, 0), datetime.datetime(2025, 11, 22, 0, 0), datetime.datetime(2025, 11, 23, 0, 0), datetime.datetime(2025, 11, 24, 0, 0)]
# Elective
# Z
# -
# 2025-11-11 00:00:00 6A Elective DAY
# 2025-11-12 00:00:00 6A Elective DAY
# 2025-11-13 00:00:00 6A Elective DAY
# 2025-11-14 00:00:00 6A Elective DAY
# 2025-11-15 00:00:00 6A Elective OFF
# 2025-11-16 00:00:00 6A Elective OFF
# 2025-11-17 00:00:00 6A Elective DAY
# 2025-11-18 00:00:00 6A Elective DAY
# 2025-11-19 00:00:00 6A Elective DAY
# 2025-11-20 00:00:00 6A Elective DAY
# 2025-11-21 00:00:00 6A Elective DAY
# 2025-11-22 00:00:00 6A Elective OFF
# 2025-11-23 00:00:00 6A Elective OFF
# 2025-11-24 00:00:00 6A Elective DAY
# 6B Ambulatory
# [datetime.datetime(2025, 11, 25, 0, 0), datetime.datetime(2025, 11, 26, 0, 0), datetime.datetime(2025, 11, 27, 0, 0), datetime.datetime(2025, 11, 28, 0, 0), datetime.datetime(2025, 11, 29, 0, 0), datetime.datetime(2025, 11, 30, 0, 0), datetime.datetime(2025, 12, 1, 0, 0), datetime.datetime(2025, 12, 2, 0, 0), datetime.datetime(2025, 12, 3, 0, 0), datetime.datetime(2025, 12, 4, 0, 0), datetime.datetime(2025, 12, 5, 0, 0), datetime.datetime(2025, 12, 6, 0, 0), datetime.datetime(2025, 12, 7, 0, 0), datetime.datetime(2025, 12, 8, 0, 0)]
# Ambulatory
# Z
# -
# 2025-11-25 00:00:00 6B Ambulatory DAY
# 2025-11-26 00:00:00 6B Ambulatory DAY
# 2025-11-27 00:00:00 6B Ambulatory DAY
# 2025-11-28 00:00:00 6B Ambulatory DAY
# 2025-11-29 00:00:00 6B Ambulatory OFF
# 2025-11-30 00:00:00 6B Ambulatory OFF
# 2025-12-01 00:00:00 6B Ambulatory DAY
# 2025-12-02 00:00:00 6B Ambulatory DAY
# 2025-12-03 00:00:00 6B Ambulatory DAY
# 2025-12-04 00:00:00 6B Ambulatory DAY
# 2025-12-05 00:00:00 6B Ambulatory DAY
# 2025-12-06 00:00:00 6B Ambulatory OFF
# 2025-12-07 00:00:00 6B Ambulatory OFF
# 2025-12-08 00:00:00 6B Ambulatory DAY
# 7A MICU-B
# [datetime.datetime(2025, 12, 9, 0, 0), datetime.datetime(2025, 12, 10, 0, 0), datetime.datetime(2025, 12, 11, 0, 0), datetime.datetime(2025, 12, 12, 0, 0), datetime.datetime(2025, 12, 13, 0, 0), datetime.datetime(2025, 12, 14, 0, 0), datetime.datetime(2025, 12, 15, 0, 0), datetime.datetime(2025, 12, 16, 0, 0), datetime.datetime(2025, 12, 17, 0, 0), datetime.datetime(2025, 12, 18, 0, 0), datetime.datetime(2025, 12, 19, 0, 0)]
# MICU
# B
# {'type1': {'blocks': ['1A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF'}, 'type2a': {'blocks': ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF'}, 'type2b': {'blocks': ['1B', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B'], 'A': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'C': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'D': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'E': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'F': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST'}, 'type3': {'blocks': ['7A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST', 'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD'}, 'type4': {'blocks': ['7B'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST'}, 'type5': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'GOOD  CALL  POST  GOOD  CALL  POST  GOOD', 'B': 'POST  GOOD  CALL  POST  GOOD  CALL  POST', 'C': 'CALL  POST  GOOD  CALL  POST  GOOD  CALL *POST', 'D': 'GOOD  CALL  POST  GOOD  CALL  POST  GOOD', 'E': 'POST  GOOD  CALL  POST  GOOD  CALL  POST', 'F': 'CALL  POST  GOOD  CALL  POST  GOOD  CALL *POST'}}
# ['1A']
# ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A']
# ['1B', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B']
# ['7A']
# 7A
# *POST
# 2025-12-09 00:00:00 7A MICU-B OFF
# 2025-12-10 00:00:00 7A MICU-B CALL
# 2025-12-11 00:00:00 7A MICU-B POST
# 2025-12-12 00:00:00 7A MICU-B GOOD
# 2025-12-13 00:00:00 7A MICU-B CALL
# 2025-12-14 00:00:00 7A MICU-B POST
# 2025-12-15 00:00:00 7A MICU-B OFF
# 2025-12-16 00:00:00 7A MICU-B CALL
# 2025-12-17 00:00:00 7A MICU-B POST
# 2025-12-18 00:00:00 7A MICU-B GOOD
# 2025-12-19 00:00:00 7A MICU-B CALL
# 2025-12-20 00:00:00 7A MICU-B *POST
# Holiday 1 Off
# [datetime.datetime(2025, 12, 20, 0, 0), datetime.datetime(2025, 12, 21, 0, 0), datetime.datetime(2025, 12, 22, 0, 0), datetime.datetime(2025, 12, 23, 0, 0), datetime.datetime(2025, 12, 24, 0, 0), datetime.datetime(2025, 12, 25, 0, 0), datetime.datetime(2025, 12, 26, 0, 0)]
# Off
# Z
# {'type1': {'blocks': ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'OFF OFF OFF OFF OFF OFF OFF OFF OFF OFF OFF OFF OFF OFF'}}
# ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2']
# HOLIDAY 1
# OFF
# 2025-12-20 00:00:00 Holiday 1 Off OFF
# 2025-12-21 00:00:00 Holiday 1 Off OFF
# 2025-12-22 00:00:00 Holiday 1 Off OFF
# 2025-12-23 00:00:00 Holiday 1 Off OFF
# 2025-12-24 00:00:00 Holiday 1 Off OFF
# 2025-12-25 00:00:00 Holiday 1 Off OFF
# 2025-12-26 00:00:00 Holiday 1 Off OFF
# Holiday 2 BCCU-3
# [datetime.datetime(2025, 12, 27, 0, 0), datetime.datetime(2025, 12, 28, 0, 0), datetime.datetime(2025, 12, 29, 0, 0), datetime.datetime(2025, 12, 30, 0, 0), datetime.datetime(2025, 12, 31, 0, 0), datetime.datetime(2026, 1, 1, 0, 0), datetime.datetime(2026, 1, 2, 0, 0)]
# BCCU
# 3
# -
# BCCU-3 bla OFF
# 2025-12-27 00:00:00 Holiday 2 BCCU-3 OFF
# BCCU-3 bla CALL
# 2025-12-28 00:00:00 Holiday 2 BCCU-3 CALL
# BCCU-3 bla POST
# 2025-12-29 00:00:00 Holiday 2 BCCU-3 POST
# BCCU-3 bla CONT
# 2025-12-30 00:00:00 Holiday 2 BCCU-3 CONT
# BCCU-3 bla CALL
# 2025-12-31 00:00:00 Holiday 2 BCCU-3 CALL
# BCCU-3 bla POST
# 2026-01-01 00:00:00 Holiday 2 BCCU-3 POST
# BCCU-3 bla OFF
# 2026-01-02 00:00:00 Holiday 2 BCCU-3 OFF
# 7B BCCU
# [datetime.datetime(2026, 1, 3, 0, 0), datetime.datetime(2026, 1, 4, 0, 0), datetime.datetime(2026, 1, 5, 0, 0), datetime.datetime(2026, 1, 6, 0, 0), datetime.datetime(2026, 1, 7, 0, 0), datetime.datetime(2026, 1, 8, 0, 0), datetime.datetime(2026, 1, 9, 0, 0), datetime.datetime(2026, 1, 10, 0, 0), datetime.datetime(2026, 1, 11, 0, 0), datetime.datetime(2026, 1, 12, 0, 0)]
# BCCU
# Z
# -
# BCCU-1 bla CONT
# 2026-01-03 00:00:00 7B BCCU-1 CONT
# BCCU-1 bla CALL
# 2026-01-04 00:00:00 7B BCCU-1 CALL
# BCCU-1 bla POST
# 2026-01-05 00:00:00 7B BCCU-1 POST
# BCCU-1 bla OFF
# 2026-01-06 00:00:00 7B BCCU-1 OFF
# BCCU-1 bla CALL
# 2026-01-07 00:00:00 7B BCCU-1 CALL
# BCCU-1 bla POST
# 2026-01-08 00:00:00 7B BCCU-1 POST
# BCCU-1 bla CONT
# 2026-01-09 00:00:00 7B BCCU-1 CONT
# BCCU-1 bla CALL
# 2026-01-10 00:00:00 7B BCCU-1 CALL
# BCCU-1 bla POST
# 2026-01-11 00:00:00 7B BCCU-1 POST
# BCCU-1 bla OFF
# 2026-01-12 00:00:00 7B BCCU-1 OFF
# 8A NATO/DATO
# [datetime.datetime(2026, 1, 13, 0, 0), datetime.datetime(2026, 1, 14, 0, 0), datetime.datetime(2026, 1, 15, 0, 0), datetime.datetime(2026, 1, 16, 0, 0), datetime.datetime(2026, 1, 17, 0, 0), datetime.datetime(2026, 1, 18, 0, 0), datetime.datetime(2026, 1, 19, 0, 0), datetime.datetime(2026, 1, 20, 0, 0), datetime.datetime(2026, 1, 21, 0, 0), datetime.datetime(2026, 1, 22, 0, 0), datetime.datetime(2026, 1, 23, 0, 0), datetime.datetime(2026, 1, 24, 0, 0), datetime.datetime(2026, 1, 25, 0, 0), datetime.datetime(2026, 1, 26, 0, 0)]
# NATO/DATO
# Z
# {'type1': {'blocks': ['4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B'], 'Z': 'OFF NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO OFF NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO'}, 'type2': {'blocks': ['7A'], 'Z': 'OFF NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO OFF NATO/DATO NATO/DATO NATO/DATO'}, 'type3': {'blocks': ['7B'], 'Z': 'NATO/DATO NATO/DATO NATO/DATO OFF NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO'}, 'type4': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO'}}
# ['4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B']
# 8A
# NATO/DATO
# 2026-01-13 00:00:00 8A NATO/DATO OFF
# 2026-01-14 00:00:00 8A NATO/DATO NATO/DATO
# 2026-01-15 00:00:00 8A NATO/DATO NATO/DATO
# 2026-01-16 00:00:00 8A NATO/DATO NATO/DATO
# 2026-01-17 00:00:00 8A NATO/DATO NATO/DATO
# 2026-01-18 00:00:00 8A NATO/DATO NATO/DATO
# 2026-01-19 00:00:00 8A NATO/DATO NATO/DATO
# 2026-01-20 00:00:00 8A NATO/DATO OFF
# 2026-01-21 00:00:00 8A NATO/DATO NATO/DATO
# 2026-01-22 00:00:00 8A NATO/DATO NATO/DATO
# 2026-01-23 00:00:00 8A NATO/DATO NATO/DATO
# 2026-01-24 00:00:00 8A NATO/DATO NATO/DATO
# 2026-01-25 00:00:00 8A NATO/DATO NATO/DATO
# 2026-01-26 00:00:00 8A NATO/DATO NATO/DATO
# 8B Ambulatory
# [datetime.datetime(2026, 1, 27, 0, 0), datetime.datetime(2026, 1, 28, 0, 0), datetime.datetime(2026, 1, 29, 0, 0), datetime.datetime(2026, 1, 30, 0, 0), datetime.datetime(2026, 1, 31, 0, 0), datetime.datetime(2026, 2, 1, 0, 0), datetime.datetime(2026, 2, 2, 0, 0), datetime.datetime(2026, 2, 3, 0, 0), datetime.datetime(2026, 2, 4, 0, 0), datetime.datetime(2026, 2, 5, 0, 0), datetime.datetime(2026, 2, 6, 0, 0), datetime.datetime(2026, 2, 7, 0, 0), datetime.datetime(2026, 2, 8, 0, 0), datetime.datetime(2026, 2, 9, 0, 0)]
# Ambulatory
# Z
# -
# 2026-01-27 00:00:00 8B Ambulatory DAY
# 2026-01-28 00:00:00 8B Ambulatory DAY
# 2026-01-29 00:00:00 8B Ambulatory DAY
# 2026-01-30 00:00:00 8B Ambulatory DAY
# 2026-01-31 00:00:00 8B Ambulatory OFF
# 2026-02-01 00:00:00 8B Ambulatory OFF
# 2026-02-02 00:00:00 8B Ambulatory DAY
# 2026-02-03 00:00:00 8B Ambulatory DAY
# 2026-02-04 00:00:00 8B Ambulatory DAY
# 2026-02-05 00:00:00 8B Ambulatory DAY
# 2026-02-06 00:00:00 8B Ambulatory DAY
# 2026-02-07 00:00:00 8B Ambulatory OFF
# 2026-02-08 00:00:00 8B Ambulatory OFF
# 2026-02-09 00:00:00 8B Ambulatory DAY
# 9A Brancati
# [datetime.datetime(2026, 2, 10, 0, 0), datetime.datetime(2026, 2, 11, 0, 0), datetime.datetime(2026, 2, 12, 0, 0), datetime.datetime(2026, 2, 13, 0, 0), datetime.datetime(2026, 2, 14, 0, 0), datetime.datetime(2026, 2, 15, 0, 0), datetime.datetime(2026, 2, 16, 0, 0), datetime.datetime(2026, 2, 17, 0, 0), datetime.datetime(2026, 2, 18, 0, 0), datetime.datetime(2026, 2, 19, 0, 0), datetime.datetime(2026, 2, 20, 0, 0), datetime.datetime(2026, 2, 21, 0, 0), datetime.datetime(2026, 2, 22, 0, 0), datetime.datetime(2026, 2, 23, 0, 0)]
# Brancati
# Z
# {'type1': {'blocks': ['1A'], 'A': 'DAYS  DAYS  BOOK  DAYS* OFF BOOK  DAYS', 'B': 'DAYS  DAYS  OFF NIGHTS  NIGHTS  NIGHTS  NIGHTS  *POST', 'C': 'NIGHTS  NIGHTS  NIGHTS  HALFDAY*  BOOK  OFF DAYS'}, 'type2': {'blocks': ['1B', '2A', '2B', '3A', '3B'], 'A': 'DAYS  DAYS  DAYS  DAYS  OFF OFF DAYS NIGHTS NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  *POST', 'B': 'DAYS  DAYS  DAYS  DAYS  BOOK  BOOK  DAYS BOOK BOOK  DAYS  DAYS  OFF OFF DAYS ', 'C': 'NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS POST OFF DAYS  DAYS  BOOK  BOOK  DAYS'}, 'type3_': {'blocks': ['4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B'], 'A': 'OLDS  OLDS  OLDS  OLDS  BOOK  BOOK  OLDS NEWS NEWS  NEWS  NEWS  OFF OFF NEWS', 'B': 'NEWS  NEWS  NEWS  NEWS  OFF OFF NEWS OLDS OLDS  OLDS  OLDS  BOOK  BOOK  OLDS', 'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK OFF/BOOK NEWS/OLDS'}, 'type4_': {'blocks': ['7A'], 'A': 'NEWS  NEWS  NEWS  NEWS  OFF BOOK  OLDS  OLDS  OLDS  OLDS  OLDS ', 'B': 'OLDS  OLDS  OLDS  OLDS  BOOK  OFF NEWS  NEWS  NEWS  NEWS  NEWS', 'Z': 'NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK BOOK/OFF OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS'}, 'type5_': {'blocks': ['7B'], 'A': 'OFF OFF NEWS  NEWS  OLDS  OLDS  OLDS  BOOK  BOOK  OLDS', 'B': 'BOOK  BOOK  OLDS  OLDS  NEWS  NEWS  NEWS  OFF OFF NEWS', 'Z': 'OFF/BOOK OFF/BOOK NEWS/OLDS NEWS/OLDS OLDS/NEWS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS'}, 'type6_': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'OLDS  OLDS  OLDS  NEWS  NEWS  NEWS  NEWS', 'B': 'NEWS  NEWS  NEWS  OLDS  OLDS  OLDS  OLDS', 'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS'}}
# ['1A']
# ['1B', '2A', '2B', '3A', '3B']
# ['4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B']
# 9A
# NEWS/OLDS
# 2026-02-10 00:00:00 9A Brancati OLDS/NEWS
# 2026-02-11 00:00:00 9A Brancati OLDS/NEWS
# 2026-02-12 00:00:00 9A Brancati OLDS/NEWS
# 2026-02-13 00:00:00 9A Brancati OLDS/NEWS
# 2026-02-14 00:00:00 9A Brancati BOOK/OFF
# 2026-02-15 00:00:00 9A Brancati BOOK/OFF
# 2026-02-16 00:00:00 9A Brancati OLDS/NEWS
# 2026-02-17 00:00:00 9A Brancati NEWS/OLDS
# 2026-02-18 00:00:00 9A Brancati NEWS/OLDS
# 2026-02-19 00:00:00 9A Brancati NEWS/OLDS
# 2026-02-20 00:00:00 9A Brancati NEWS/OLDS
# 2026-02-21 00:00:00 9A Brancati OFF/BOOK
# 2026-02-22 00:00:00 9A Brancati OFF/BOOK
# 2026-02-23 00:00:00 9A Brancati NEWS/OLDS
# 9B Vacation
# [datetime.datetime(2026, 2, 24, 0, 0), datetime.datetime(2026, 2, 25, 0, 0), datetime.datetime(2026, 2, 26, 0, 0), datetime.datetime(2026, 2, 27, 0, 0), datetime.datetime(2026, 2, 28, 0, 0), datetime.datetime(2026, 3, 1, 0, 0), datetime.datetime(2026, 3, 2, 0, 0), datetime.datetime(2026, 3, 3, 0, 0), datetime.datetime(2026, 3, 4, 0, 0), datetime.datetime(2026, 3, 5, 0, 0), datetime.datetime(2026, 3, 6, 0, 0), datetime.datetime(2026, 3, 7, 0, 0), datetime.datetime(2026, 3, 8, 0, 0), datetime.datetime(2026, 3, 9, 0, 0)]
# Vacation
# Z
# {'type1': {'blocks': ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION'}}
# ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2']
# 9B
# VACATION
# 2026-02-24 00:00:00 9B Vacation VACATION
# 2026-02-25 00:00:00 9B Vacation VACATION
# 2026-02-26 00:00:00 9B Vacation VACATION
# 2026-02-27 00:00:00 9B Vacation VACATION
# 2026-02-28 00:00:00 9B Vacation VACATION
# 2026-03-01 00:00:00 9B Vacation VACATION
# 2026-03-02 00:00:00 9B Vacation VACATION
# 2026-03-03 00:00:00 9B Vacation VACATION
# 2026-03-04 00:00:00 9B Vacation VACATION
# 2026-03-05 00:00:00 9B Vacation VACATION
# 2026-03-06 00:00:00 9B Vacation VACATION
# 2026-03-07 00:00:00 9B Vacation VACATION
# 2026-03-08 00:00:00 9B Vacation VACATION
# 2026-03-09 00:00:00 9B Vacation VACATION
# 10A Liver
# [datetime.datetime(2026, 3, 10, 0, 0), datetime.datetime(2026, 3, 11, 0, 0), datetime.datetime(2026, 3, 12, 0, 0), datetime.datetime(2026, 3, 13, 0, 0), datetime.datetime(2026, 3, 14, 0, 0), datetime.datetime(2026, 3, 15, 0, 0), datetime.datetime(2026, 3, 16, 0, 0), datetime.datetime(2026, 3, 17, 0, 0), datetime.datetime(2026, 3, 18, 0, 0), datetime.datetime(2026, 3, 19, 0, 0), datetime.datetime(2026, 3, 20, 0, 0), datetime.datetime(2026, 3, 21, 0, 0), datetime.datetime(2026, 3, 22, 0, 0), datetime.datetime(2026, 3, 23, 0, 0)]
# Subspecialty
# Z
# {'type1_': {'blocks': ['1A'], 'A': 'DAYS  DAYS  DAYS  DAYS  BOOK  OFF DAYS', 'B': 'DAYS  DAYS  DAYS  DAYS  OFF BOOK  DAYS', 'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF OFF/BOOK DAYS/DAYS'}, 'type2_': {'blocks': ['1B', '2A', '2B', '3A', '3B', '4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B'], 'A': 'DAYS  DAYS  DAYS  DAYS  BOOK  BOOK  DAYS DAYS DAYS  DAYS  DAYS  OFF OFF DAYS', 'B': 'DAYS  DAYS  DAYS  DAYS  OFF OFF DAYS DAYS DAYS  DAYS  DAYS  BOOK  BOOK  DAYS', 'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF BOOK/OFF DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS OFF/BOOK OFF/BOOK DAYS/DAYS'}, 'type3_': {'blocks': ['7A'], 'A': 'DAYS  DAYS  DAYS  DAYS  BOOK  OFF DAYS  DAYS  DAYS  DAYS  DAYS', 'B': 'DAYS  DAYS  DAYS  DAYS  OFF BOOK  DAYS  DAYS  DAYS  DAYS  DAYS', 'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF OFF/BOOK DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS'}, 'type4_': {'blocks': ['7B'], 'A': 'OFF OFF DAYS  DAYS  DAYS  DAYS  DAYS  BOOK  BOOK  DAYS', 'B': 'BOOK  BOOK  DAYS  DAYS  DAYS  DAYS  DAYS  OFF OFF DAYS', 'Z': 'OFF/BOOK OFF/BOOK DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF BOOK/OFF DAYS/DAYS'}, 'type5_': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'DAYS  DAYS  DAYS  DAYS  DAYS  DAYS  DAYS', 'B': 'DAYS  DAYS  DAYS  DAYS  DAYS  DAYS  DAYS', 'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS'}}
# ['1A']
# ['1B', '2A', '2B', '3A', '3B', '4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B']
# 10A
# DAYS/DAYS
# 2026-03-10 00:00:00 10A Liver DAYS/DAYS
# 2026-03-11 00:00:00 10A Liver DAYS/DAYS
# 2026-03-12 00:00:00 10A Liver DAYS/DAYS
# 2026-03-13 00:00:00 10A Liver DAYS/DAYS
# 2026-03-14 00:00:00 10A Liver BOOK/OFF
# 2026-03-15 00:00:00 10A Liver BOOK/OFF
# 2026-03-16 00:00:00 10A Liver DAYS/DAYS
# 2026-03-17 00:00:00 10A Liver DAYS/DAYS
# 2026-03-18 00:00:00 10A Liver DAYS/DAYS
# 2026-03-19 00:00:00 10A Liver DAYS/DAYS
# 2026-03-20 00:00:00 10A Liver DAYS/DAYS
# 2026-03-21 00:00:00 10A Liver OFF/BOOK
# 2026-03-22 00:00:00 10A Liver OFF/BOOK
# 2026-03-23 00:00:00 10A Liver DAYS/DAYS
# 10B Ambulatory
# [datetime.datetime(2026, 3, 24, 0, 0), datetime.datetime(2026, 3, 25, 0, 0), datetime.datetime(2026, 3, 26, 0, 0), datetime.datetime(2026, 3, 27, 0, 0), datetime.datetime(2026, 3, 28, 0, 0), datetime.datetime(2026, 3, 29, 0, 0), datetime.datetime(2026, 3, 30, 0, 0), datetime.datetime(2026, 3, 31, 0, 0), datetime.datetime(2026, 4, 1, 0, 0), datetime.datetime(2026, 4, 2, 0, 0), datetime.datetime(2026, 4, 3, 0, 0), datetime.datetime(2026, 4, 4, 0, 0), datetime.datetime(2026, 4, 5, 0, 0), datetime.datetime(2026, 4, 6, 0, 0)]
# Ambulatory
# Z
# -
# 2026-03-24 00:00:00 10B Ambulatory DAY
# 2026-03-25 00:00:00 10B Ambulatory DAY
# 2026-03-26 00:00:00 10B Ambulatory DAY
# 2026-03-27 00:00:00 10B Ambulatory DAY
# 2026-03-28 00:00:00 10B Ambulatory OFF
# 2026-03-29 00:00:00 10B Ambulatory OFF
# 2026-03-30 00:00:00 10B Ambulatory DAY
# 2026-03-31 00:00:00 10B Ambulatory DAY
# 2026-04-01 00:00:00 10B Ambulatory DAY
# 2026-04-02 00:00:00 10B Ambulatory DAY
# 2026-04-03 00:00:00 10B Ambulatory DAY
# 2026-04-04 00:00:00 10B Ambulatory OFF
# 2026-04-05 00:00:00 10B Ambulatory OFF
# 2026-04-06 00:00:00 10B Ambulatory DAY
# 11A CJ
# [datetime.datetime(2026, 4, 7, 0, 0), datetime.datetime(2026, 4, 8, 0, 0), datetime.datetime(2026, 4, 9, 0, 0), datetime.datetime(2026, 4, 10, 0, 0), datetime.datetime(2026, 4, 11, 0, 0), datetime.datetime(2026, 4, 12, 0, 0), datetime.datetime(2026, 4, 13, 0, 0), datetime.datetime(2026, 4, 14, 0, 0), datetime.datetime(2026, 4, 15, 0, 0), datetime.datetime(2026, 4, 16, 0, 0), datetime.datetime(2026, 4, 17, 0, 0), datetime.datetime(2026, 4, 18, 0, 0), datetime.datetime(2026, 4, 19, 0, 0), datetime.datetime(2026, 4, 20, 0, 0)]
# Subspecialty
# Z
# {'type1_': {'blocks': ['1A'], 'A': 'DAYS  DAYS  DAYS  DAYS  BOOK  OFF DAYS', 'B': 'DAYS  DAYS  DAYS  DAYS  OFF BOOK  DAYS', 'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF OFF/BOOK DAYS/DAYS'}, 'type2_': {'blocks': ['1B', '2A', '2B', '3A', '3B', '4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B'], 'A': 'DAYS  DAYS  DAYS  DAYS  BOOK  BOOK  DAYS DAYS DAYS  DAYS  DAYS  OFF OFF DAYS', 'B': 'DAYS  DAYS  DAYS  DAYS  OFF OFF DAYS DAYS DAYS  DAYS  DAYS  BOOK  BOOK  DAYS', 'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF BOOK/OFF DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS OFF/BOOK OFF/BOOK DAYS/DAYS'}, 'type3_': {'blocks': ['7A'], 'A': 'DAYS  DAYS  DAYS  DAYS  BOOK  OFF DAYS  DAYS  DAYS  DAYS  DAYS', 'B': 'DAYS  DAYS  DAYS  DAYS  OFF BOOK  DAYS  DAYS  DAYS  DAYS  DAYS', 'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF OFF/BOOK DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS'}, 'type4_': {'blocks': ['7B'], 'A': 'OFF OFF DAYS  DAYS  DAYS  DAYS  DAYS  BOOK  BOOK  DAYS', 'B': 'BOOK  BOOK  DAYS  DAYS  DAYS  DAYS  DAYS  OFF OFF DAYS', 'Z': 'OFF/BOOK OFF/BOOK DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF BOOK/OFF DAYS/DAYS'}, 'type5_': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'DAYS  DAYS  DAYS  DAYS  DAYS  DAYS  DAYS', 'B': 'DAYS  DAYS  DAYS  DAYS  DAYS  DAYS  DAYS', 'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS'}}
# ['1A']
# ['1B', '2A', '2B', '3A', '3B', '4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B']
# 11A
# DAYS/DAYS
# 2026-04-07 00:00:00 11A CJ DAYS/DAYS
# 2026-04-08 00:00:00 11A CJ DAYS/DAYS
# 2026-04-09 00:00:00 11A CJ DAYS/DAYS
# 2026-04-10 00:00:00 11A CJ DAYS/DAYS
# 2026-04-11 00:00:00 11A CJ BOOK/OFF
# 2026-04-12 00:00:00 11A CJ BOOK/OFF
# 2026-04-13 00:00:00 11A CJ DAYS/DAYS
# 2026-04-14 00:00:00 11A CJ DAYS/DAYS
# 2026-04-15 00:00:00 11A CJ DAYS/DAYS
# 2026-04-16 00:00:00 11A CJ DAYS/DAYS
# 2026-04-17 00:00:00 11A CJ DAYS/DAYS
# 2026-04-18 00:00:00 11A CJ OFF/BOOK
# 2026-04-19 00:00:00 11A CJ OFF/BOOK
# 2026-04-20 00:00:00 11A CJ DAYS/DAYS
# 11B Cardiomyopathy
# [datetime.datetime(2026, 4, 21, 0, 0), datetime.datetime(2026, 4, 22, 0, 0), datetime.datetime(2026, 4, 23, 0, 0), datetime.datetime(2026, 4, 24, 0, 0), datetime.datetime(2026, 4, 25, 0, 0), datetime.datetime(2026, 4, 26, 0, 0), datetime.datetime(2026, 4, 27, 0, 0), datetime.datetime(2026, 4, 28, 0, 0), datetime.datetime(2026, 4, 29, 0, 0), datetime.datetime(2026, 4, 30, 0, 0), datetime.datetime(2026, 5, 1, 0, 0), datetime.datetime(2026, 5, 2, 0, 0), datetime.datetime(2026, 5, 3, 0, 0), datetime.datetime(2026, 5, 4, 0, 0)]
# Cardiomyopathy
# Z
# {'type1': {'blocks': ['1A'], '1': 'CALL  POST  GENCARDS DAY CALL  POST  OFF', '2': 'DAY CALL  POST  OFF DAY CALL  POST', '3': 'DAY DAY CALL  POST  OFF DAY CALL  POST', '4': 'POST  DAY DAY CALL  POST  OFF DAY'}, 'type2': {'blocks': ['1B', '2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B'], '1': 'CALL  POST  OFF DAY CALL  POST  DAY DAY CALL  POST  OFF DAY CALL  POST', '2': 'DAY CALL  POST  GENCARDS DAY CALL  POST  OFF DAY CALL  POST  OFF DAY CALL  *POST', '3': 'DAY DAY CALL  POST  OFF DAY CALL  POST  DAY DAY CALL  POST  OFF DAY', '4': 'POST DAY DAY CALL  POST  OFF DAY CALL  POST  GENCARDS DAY CALL  POST  OFF'}, 'type3': {'blocks': ['7A'], '1': 'CALL  POST  OFF DAY CALL  POST  DAY DAY CALL  POST  DAY', '2': 'DAY CALL  POST  GENCARDS DAY CALL  POST  OFF DAY CALL  POST', '3': 'DAY DAY CALL  POST  OFF DAY CALL  POST  DAY DAY CALL', '4': 'POST  DAY DAY CALL  POST  OFF DAY CALL  POST  GENCARDS DAY'}, 'type4': {'blocks': ['7B'], '1': 'CALL  POST  DAY DAY CALL  POST  OFF DAY CALL  POST', '2': 'DAY CALL  POST  OFF DAY CALL  POST  OFF DAY CALL', '3': 'OFF DAY CALL  POST  DAY DAY CALL  POST  OFF DAY', '4': 'POST  OFF DAY CALL  POST  GENCARDS DAY CALL  POST  OFF'}, 'type6': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], '1': 'CALL  POST  DAY CALL  POST  DAY CALL  *POST', '2': 'DAY CALL  POST  DAY CALL  POST  DAY', '3': 'DAY DAY CALL  POST  DAY CALL  POST'}}
# ['1A']
# ['1B', '2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B']
# 11B
# -
# 2026-04-21 00:00:00 11B Cardiomyopathy -
# 2026-04-22 00:00:00 11B Cardiomyopathy -
# 2026-04-23 00:00:00 11B Cardiomyopathy -
# 2026-04-24 00:00:00 11B Cardiomyopathy -
# 2026-04-25 00:00:00 11B Cardiomyopathy -
# 2026-04-26 00:00:00 11B Cardiomyopathy -
# 2026-04-27 00:00:00 11B Cardiomyopathy -
# 2026-04-28 00:00:00 11B Cardiomyopathy -
# 2026-04-29 00:00:00 11B Cardiomyopathy -
# 2026-04-30 00:00:00 11B Cardiomyopathy -
# 2026-05-01 00:00:00 11B Cardiomyopathy -
# 2026-05-02 00:00:00 11B Cardiomyopathy -
# 2026-05-03 00:00:00 11B Cardiomyopathy -
# 2026-05-04 00:00:00 11B Cardiomyopathy -
# 12A CCU
# [datetime.datetime(2026, 5, 5, 0, 0), datetime.datetime(2026, 5, 6, 0, 0), datetime.datetime(2026, 5, 7, 0, 0), datetime.datetime(2026, 5, 8, 0, 0), datetime.datetime(2026, 5, 9, 0, 0), datetime.datetime(2026, 5, 10, 0, 0), datetime.datetime(2026, 5, 11, 0, 0), datetime.datetime(2026, 5, 12, 0, 0), datetime.datetime(2026, 5, 13, 0, 0), datetime.datetime(2026, 5, 14, 0, 0), datetime.datetime(2026, 5, 15, 0, 0), datetime.datetime(2026, 5, 16, 0, 0), datetime.datetime(2026, 5, 17, 0, 0), datetime.datetime(2026, 5, 18, 0, 0)]
# CCU
# Z
# {'type1': {'blocks': ['1A'], 'A': 'POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'GOOD  CALL  POST  OFF CALL  POST  GOOD'}, 'type2a': {'blocks': ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL POST GOOD  CALL  POST  OFF CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST GOOD CALL  POST  OFF CALL  POST  GOOD'}, 'type2b': {'blocks': ['1B', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B'], 'A': 'GOOD  CALL  POST  OFF CALL  POST  GOOD CALL POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'POST  GOOD  CALL  POST  OFF CALL  POST GOOD CALL  POST  OFF CALL  POST  GOOD', 'C': 'CALL  POST  OFF CALL  POST  GOOD  CALL POST OFF CALL  POST  GOOD  CALL  POST'}, 'type4': {'blocks': ['7A'], 'A': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'B': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'C': 'GOOD  CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST'}, 'type5': {'blocks': ['7B'], 'A': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'B': 'CALL  POST  OFF CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'C': 'OFF CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF'}, 'type6': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'GOOD  CALL  POST  GOOD  CALL  POST  GOOD', 'B': 'POST  GOOD  CALL  POST  GOOD  CALL  POST', 'C': 'CALL  POST  GOOD  CALL  POST  GOOD  CALL  *POST'}}
# ['1A']
# ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A']
# 12A
# -
# 2026-05-05 00:00:00 12A CCU -
# 2026-05-06 00:00:00 12A CCU -
# 2026-05-07 00:00:00 12A CCU -
# 2026-05-08 00:00:00 12A CCU -
# 2026-05-09 00:00:00 12A CCU -
# 2026-05-10 00:00:00 12A CCU -
# 2026-05-11 00:00:00 12A CCU -
# 2026-05-12 00:00:00 12A CCU -
# 2026-05-13 00:00:00 12A CCU -
# 2026-05-14 00:00:00 12A CCU -
# 2026-05-15 00:00:00 12A CCU -
# 2026-05-16 00:00:00 12A CCU -
# 2026-05-17 00:00:00 12A CCU -
# 2026-05-18 00:00:00 12A CCU -
# 12B Ambulatory
# [datetime.datetime(2026, 5, 19, 0, 0), datetime.datetime(2026, 5, 20, 0, 0), datetime.datetime(2026, 5, 21, 0, 0), datetime.datetime(2026, 5, 22, 0, 0), datetime.datetime(2026, 5, 23, 0, 0), datetime.datetime(2026, 5, 24, 0, 0), datetime.datetime(2026, 5, 25, 0, 0), datetime.datetime(2026, 5, 26, 0, 0), datetime.datetime(2026, 5, 27, 0, 0), datetime.datetime(2026, 5, 28, 0, 0), datetime.datetime(2026, 5, 29, 0, 0), datetime.datetime(2026, 5, 30, 0, 0), datetime.datetime(2026, 5, 31, 0, 0), datetime.datetime(2026, 6, 1, 0, 0)]
# Ambulatory
# Z
# -
# 2026-05-19 00:00:00 12B Ambulatory DAY
# 2026-05-20 00:00:00 12B Ambulatory DAY
# 2026-05-21 00:00:00 12B Ambulatory DAY
# 2026-05-22 00:00:00 12B Ambulatory DAY
# 2026-05-23 00:00:00 12B Ambulatory OFF
# 2026-05-24 00:00:00 12B Ambulatory OFF
# 2026-05-25 00:00:00 12B Ambulatory DAY
# 2026-05-26 00:00:00 12B Ambulatory DAY
# 2026-05-27 00:00:00 12B Ambulatory DAY
# 2026-05-28 00:00:00 12B Ambulatory DAY
# 2026-05-29 00:00:00 12B Ambulatory DAY
# 2026-05-30 00:00:00 12B Ambulatory OFF
# 2026-05-31 00:00:00 12B Ambulatory OFF
# 2026-06-01 00:00:00 12B Ambulatory DAY
# 13A Cardiomyopathy
# [datetime.datetime(2026, 6, 2, 0, 0), datetime.datetime(2026, 6, 3, 0, 0), datetime.datetime(2026, 6, 4, 0, 0), datetime.datetime(2026, 6, 5, 0, 0), datetime.datetime(2026, 6, 6, 0, 0), datetime.datetime(2026, 6, 7, 0, 0), datetime.datetime(2026, 6, 8, 0, 0), datetime.datetime(2026, 6, 9, 0, 0), datetime.datetime(2026, 6, 10, 0, 0), datetime.datetime(2026, 6, 11, 0, 0), datetime.datetime(2026, 6, 12, 0, 0), datetime.datetime(2026, 6, 13, 0, 0), datetime.datetime(2026, 6, 14, 0, 0), datetime.datetime(2026, 6, 15, 0, 0)]
# Cardiomyopathy
# Z
# ...
# [datetime.datetime(2026, 2, 24, 0, 0), datetime.datetime(2026, 2, 25, 0, 0), datetime.datetime(2026, 2, 26, 0, 0), datetime.datetime(2026, 2, 27, 0, 0), datetime.datetime(2026, 2, 28, 0, 0), datetime.datetime(2026, 3, 1, 0, 0), datetime.datetime(2026, 3, 2, 0, 0), datetime.datetime(2026, 3, 3, 0, 0), datetime.datetime(2026, 3, 4, 0, 0), datetime.datetime(2026, 3, 5, 0, 0), datetime.datetime(2026, 3, 6, 0, 0), datetime.datetime(2026, 3, 7, 0, 0), datetime.datetime(2026, 3, 8, 0, 0), datetime.datetime(2026, 3, 9, 0, 0)]
# Ambulatory
# Z
# -
# 2026-02-24 00:00:00 9B Ambulatory DAY
# 2026-02-25 00:00:00 9B Ambulatory DAY
# 2026-02-26 00:00:00 9B Ambulatory DAY
# 2026-02-27 00:00:00 9B Ambulatory DAY
# 2026-02-28 00:00:00 9B Ambulatory OFF
# 2026-03-01 00:00:00 9B Ambulatory OFF
# 2026-03-02 00:00:00 9B Ambulatory DAY
# 2026-03-03 00:00:00 9B Ambulatory DAY
# 2026-03-04 00:00:00 9B Ambulatory DAY
# 2026-03-05 00:00:00 9B Ambulatory DAY
# 2026-03-06 00:00:00 9B Ambulatory DAY
# 2026-03-07 00:00:00 9B Ambulatory OFF
# 2026-03-08 00:00:00 9B Ambulatory OFF
# 2026-03-09 00:00:00 9B Ambulatory DAY
# 10A CityHD
# [datetime.datetime(2026, 3, 10, 0, 0), datetime.datetime(2026, 3, 11, 0, 0), datetime.datetime(2026, 3, 12, 0, 0), datetime.datetime(2026, 3, 13, 0, 0), datetime.datetime(2026, 3, 14, 0, 0), datetime.datetime(2026, 3, 15, 0, 0), datetime.datetime(2026, 3, 16, 0, 0), datetime.datetime(2026, 3, 17, 0, 0), datetime.datetime(2026, 3, 18, 0, 0), datetime.datetime(2026, 3, 19, 0, 0), datetime.datetime(2026, 3, 20, 0, 0), datetime.datetime(2026, 3, 21, 0, 0), datetime.datetime(2026, 3, 22, 0, 0), datetime.datetime(2026, 3, 23, 0, 0)]
# CityHD
# Z
# -
# 2026-03-10 00:00:00 10A CityHD -
# 2026-03-11 00:00:00 10A CityHD -
# 2026-03-12 00:00:00 10A CityHD -
# 2026-03-13 00:00:00 10A CityHD -
# 2026-03-14 00:00:00 10A CityHD -
# 2026-03-15 00:00:00 10A CityHD -
# 2026-03-16 00:00:00 10A CityHD -
# 2026-03-17 00:00:00 10A CityHD -
# 2026-03-18 00:00:00 10A CityHD -
# 2026-03-19 00:00:00 10A CityHD -
# 2026-03-20 00:00:00 10A CityHD -
# 2026-03-21 00:00:00 10A CityHD -
# 2026-03-22 00:00:00 10A CityHD -
# 2026-03-23 00:00:00 10A CityHD -
# 10B CityHD
# [datetime.datetime(2026, 3, 24, 0, 0), datetime.datetime(2026, 3, 25, 0, 0), datetime.datetime(2026, 3, 26, 0, 0), datetime.datetime(2026, 3, 27, 0, 0), datetime.datetime(2026, 3, 28, 0, 0), datetime.datetime(2026, 3, 29, 0, 0), datetime.datetime(2026, 3, 30, 0, 0), datetime.datetime(2026, 3, 31, 0, 0), datetime.datetime(2026, 4, 1, 0, 0), datetime.datetime(2026, 4, 2, 0, 0), datetime.datetime(2026, 4, 3, 0, 0), datetime.datetime(2026, 4, 4, 0, 0), datetime.datetime(2026, 4, 5, 0, 0), datetime.datetime(2026, 4, 6, 0, 0)]
# CityHD
# Z
# -
# 2026-03-24 00:00:00 10B CityHD -
# 2026-03-25 00:00:00 10B CityHD -
# 2026-03-26 00:00:00 10B CityHD -
# 2026-03-27 00:00:00 10B CityHD -
# 2026-03-28 00:00:00 10B CityHD -
# 2026-03-29 00:00:00 10B CityHD -
# 2026-03-30 00:00:00 10B CityHD -
# 2026-03-31 00:00:00 10B CityHD -
# 2026-04-01 00:00:00 10B CityHD -
# 2026-04-02 00:00:00 10B CityHD -
# 2026-04-03 00:00:00 10B CityHD -
# 2026-04-04 00:00:00 10B CityHD -
# 2026-04-05 00:00:00 10B CityHD -
# 2026-04-06 00:00:00 10B CityHD -
# 11A NATO/DATO
# [datetime.datetime(2026, 4, 7, 0, 0), datetime.datetime(2026, 4, 8, 0, 0), datetime.datetime(2026, 4, 9, 0, 0), datetime.datetime(2026, 4, 10, 0, 0), datetime.datetime(2026, 4, 11, 0, 0), datetime.datetime(2026, 4, 12, 0, 0), datetime.datetime(2026, 4, 13, 0, 0), datetime.datetime(2026, 4, 14, 0, 0), datetime.datetime(2026, 4, 15, 0, 0), datetime.datetime(2026, 4, 16, 0, 0), datetime.datetime(2026, 4, 17, 0, 0), datetime.datetime(2026, 4, 18, 0, 0), datetime.datetime(2026, 4, 19, 0, 0), datetime.datetime(2026, 4, 20, 0, 0)]
# NATO/DATO
# Z
# {'type1': {'blocks': ['4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B'], 'Z': 'OFF NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO OFF NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO'}, 'type2': {'blocks': ['7A'], 'Z': 'OFF NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO OFF NATO/DATO NATO/DATO NATO/DATO'}, 'type3': {'blocks': ['7B'], 'Z': 'NATO/DATO NATO/DATO NATO/DATO OFF NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO'}, 'type4': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO NATO/DATO'}}
# ['4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B']
# 11A
# NATO/DATO
# 2026-04-07 00:00:00 11A NATO/DATO OFF
# 2026-04-08 00:00:00 11A NATO/DATO NATO/DATO
# 2026-04-09 00:00:00 11A NATO/DATO NATO/DATO
# 2026-04-10 00:00:00 11A NATO/DATO NATO/DATO
# 2026-04-11 00:00:00 11A NATO/DATO NATO/DATO
# 2026-04-12 00:00:00 11A NATO/DATO NATO/DATO
# 2026-04-13 00:00:00 11A NATO/DATO NATO/DATO
# 2026-04-14 00:00:00 11A NATO/DATO OFF
# 2026-04-15 00:00:00 11A NATO/DATO NATO/DATO
# 2026-04-16 00:00:00 11A NATO/DATO NATO/DATO
# 2026-04-17 00:00:00 11A NATO/DATO NATO/DATO
# 2026-04-18 00:00:00 11A NATO/DATO NATO/DATO
# 2026-04-19 00:00:00 11A NATO/DATO NATO/DATO
# 2026-04-20 00:00:00 11A NATO/DATO NATO/DATO
# 11B Ambulatory
# [datetime.datetime(2026, 4, 21, 0, 0), datetime.datetime(2026, 4, 22, 0, 0), datetime.datetime(2026, 4, 23, 0, 0), datetime.datetime(2026, 4, 24, 0, 0), datetime.datetime(2026, 4, 25, 0, 0), datetime.datetime(2026, 4, 26, 0, 0), datetime.datetime(2026, 4, 27, 0, 0), datetime.datetime(2026, 4, 28, 0, 0), datetime.datetime(2026, 4, 29, 0, 0), datetime.datetime(2026, 4, 30, 0, 0), datetime.datetime(2026, 5, 1, 0, 0), datetime.datetime(2026, 5, 2, 0, 0), datetime.datetime(2026, 5, 3, 0, 0), datetime.datetime(2026, 5, 4, 0, 0)]
# Ambulatory
# Z
# -
# 2026-04-21 00:00:00 11B Ambulatory DAY
# 2026-04-22 00:00:00 11B Ambulatory DAY
# 2026-04-23 00:00:00 11B Ambulatory DAY
# 2026-04-24 00:00:00 11B Ambulatory DAY
# 2026-04-25 00:00:00 11B Ambulatory OFF
# 2026-04-26 00:00:00 11B Ambulatory OFF
# 2026-04-27 00:00:00 11B Ambulatory DAY
# 2026-04-28 00:00:00 11B Ambulatory DAY
# 2026-04-29 00:00:00 11B Ambulatory DAY
# 2026-04-30 00:00:00 11B Ambulatory DAY
# 2026-05-01 00:00:00 11B Ambulatory DAY
# 2026-05-02 00:00:00 11B Ambulatory OFF
# 2026-05-03 00:00:00 11B Ambulatory OFF
# 2026-05-04 00:00:00 11B Ambulatory DAY
# 12A MICU
# [datetime.datetime(2026, 5, 5, 0, 0), datetime.datetime(2026, 5, 6, 0, 0), datetime.datetime(2026, 5, 7, 0, 0), datetime.datetime(2026, 5, 8, 0, 0), datetime.datetime(2026, 5, 9, 0, 0), datetime.datetime(2026, 5, 10, 0, 0), datetime.datetime(2026, 5, 11, 0, 0), datetime.datetime(2026, 5, 12, 0, 0), datetime.datetime(2026, 5, 13, 0, 0), datetime.datetime(2026, 5, 14, 0, 0), datetime.datetime(2026, 5, 15, 0, 0), datetime.datetime(2026, 5, 16, 0, 0), datetime.datetime(2026, 5, 17, 0, 0), datetime.datetime(2026, 5, 18, 0, 0)]
# MICU
# Z
# {'type1': {'blocks': ['1A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF'}, 'type2a': {'blocks': ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF'}, 'type2b': {'blocks': ['1B', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B'], 'A': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'C': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'D': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'E': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'F': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST'}, 'type3': {'blocks': ['7A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST', 'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD'}, 'type4': {'blocks': ['7B'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST'}, 'type5': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'GOOD  CALL  POST  GOOD  CALL  POST  GOOD', 'B': 'POST  GOOD  CALL  POST  GOOD  CALL  POST', 'C': 'CALL  POST  GOOD  CALL  POST  GOOD  CALL *POST', 'D': 'GOOD  CALL  POST  GOOD  CALL  POST  GOOD', 'E': 'POST  GOOD  CALL  POST  GOOD  CALL  POST', 'F': 'CALL  POST  GOOD  CALL  POST  GOOD  CALL *POST'}}
# ['1A']
# ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A']
# 12A
# -
# 2026-05-05 00:00:00 12A MICU -
# 2026-05-06 00:00:00 12A MICU -
# 2026-05-07 00:00:00 12A MICU -
# 2026-05-08 00:00:00 12A MICU -
# 2026-05-09 00:00:00 12A MICU -
# 2026-05-10 00:00:00 12A MICU -
# 2026-05-11 00:00:00 12A MICU -
# 2026-05-12 00:00:00 12A MICU -
# 2026-05-13 00:00:00 12A MICU -
# 2026-05-14 00:00:00 12A MICU -
# 2026-05-15 00:00:00 12A MICU -
# 2026-05-16 00:00:00 12A MICU -
# 2026-05-17 00:00:00 12A MICU -
# 2026-05-18 00:00:00 12A MICU -
# 12B Janeway
# [datetime.datetime(2026, 5, 19, 0, 0), datetime.datetime(2026, 5, 20, 0, 0), datetime.datetime(2026, 5, 21, 0, 0), datetime.datetime(2026, 5, 22, 0, 0), datetime.datetime(2026, 5, 23, 0, 0), datetime.datetime(2026, 5, 24, 0, 0), datetime.datetime(2026, 5, 25, 0, 0), datetime.datetime(2026, 5, 26, 0, 0), datetime.datetime(2026, 5, 27, 0, 0), datetime.datetime(2026, 5, 28, 0, 0), datetime.datetime(2026, 5, 29, 0, 0), datetime.datetime(2026, 5, 30, 0, 0), datetime.datetime(2026, 5, 31, 0, 0), datetime.datetime(2026, 6, 1, 0, 0)]
# FirmSAR
# Z
# {'type1': {'blocks': ['1A'], 'A': 'OLDS  OLDS  BOOK  OLDS  OFF BOOK  NEWS', 'B': 'NEWS  NEWS  OFF NIGHTS  NIGHTS  NIGHTS  NIGHTS  *POST', 'C': 'NIGHTS  NIGHTS  NIGHTS  NEWS*  BOOK  OFF OLDS'}, 'type2': {'blocks': ['1B', '2A', '2B', '3A', '3B'], 'A': 'NEWS  NEWS  OLDS  OLDS  BOOK  BOOK  NIGHTS NIGHTS NIGHTS  NIGHTS  NEWS* OFF OFF NEWS', 'B': 'NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NEWS OFF  OFF NEWS  OLDS  BOOK  BOOK  OLDS', 'C': 'OLDS  OLDS  NEWS  NEWS  OFF OFF OLDS BOOK BOOK  OLDS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  *POST'}, 'type3_': {'blocks': ['4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B'], 'A': 'OLDS  OLDS  OLDS  OLDS  BOOK  BOOK  OLDS NEWS NEWS  NEWS  NEWS  OFF OFF NEWS', 'B': 'NEWS  NEWS  NEWS  NEWS  OFF OFF NEWS OLDS OLDS  OLDS  OLDS  BOOK  BOOK  OLDS', 'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK OFF/BOOK NEWS/OLDS'}, 'type4_': {'blocks': ['7A'], 'A': 'NEWS  NEWS  NEWS  NEWS  OFF BOOK  OLDS  OLDS  OLDS  OLDS  OLDS', 'B': 'OLDS  OLDS  OLDS  OLDS  BOOK  OFF NEWS  NEWS  NEWS  NEWS  NEWS', 'Z': 'NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK BOOK/OFF OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS'}, 'type5_': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'OLDS  OLDS  OLDS  NEWS  NEWS  NEWS  NEWS', 'B': 'NEWS  NEWS  NEWS  OLDS  OLDS  OLDS  OLDS', 'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS'}, 'type6_': {'blocks': ['7B'], 'A': 'OFF OFF NEWS  NEWS  NEWS  OLDS  OLDS  BOOK  BOOK  OLDS', 'B': 'BOOK  BOOK  OLDS  OLDS  OLDS  NEWS  NEWS  OFF OFF NEWS', 'Z': 'OFF/BOOK OFF/BOOK NEWS/OLDS NEWS/OLDS NEWS/OLDS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS'}}
# ['1A']
# ['1B', '2A', '2B', '3A', '3B']
# ['4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B']
# 12B
# NEWS/OLDS
# 2026-05-19 00:00:00 12B Janeway OLDS/NEWS
# 2026-05-20 00:00:00 12B Janeway OLDS/NEWS
# 2026-05-21 00:00:00 12B Janeway OLDS/NEWS
# 2026-05-22 00:00:00 12B Janeway OLDS/NEWS
# 2026-05-23 00:00:00 12B Janeway BOOK/OFF
# 2026-05-24 00:00:00 12B Janeway BOOK/OFF
# 2026-05-25 00:00:00 12B Janeway OLDS/NEWS
# 2026-05-26 00:00:00 12B Janeway NEWS/OLDS
# 2026-05-27 00:00:00 12B Janeway NEWS/OLDS
# 2026-05-28 00:00:00 12B Janeway NEWS/OLDS
# 2026-05-29 00:00:00 12B Janeway NEWS/OLDS
# 2026-05-30 00:00:00 12B Janeway OFF/BOOK
# 2026-05-31 00:00:00 12B Janeway OFF/BOOK
# 2026-06-01 00:00:00 12B Janeway NEWS/OLDS
# 13A Jeopardy
# [datetime.datetime(2026, 6, 2, 0, 0), datetime.datetime(2026, 6, 3, 0, 0), datetime.datetime(2026, 6, 4, 0, 0), datetime.datetime(2026, 6, 5, 0, 0), datetime.datetime(2026, 6, 6, 0, 0), datetime.datetime(2026, 6, 7, 0, 0), datetime.datetime(2026, 6, 8, 0, 0), datetime.datetime(2026, 6, 9, 0, 0), datetime.datetime(2026, 6, 10, 0, 0), datetime.datetime(2026, 6, 11, 0, 0), datetime.datetime(2026, 6, 12, 0, 0), datetime.datetime(2026, 6, 13, 0, 0), datetime.datetime(2026, 6, 14, 0, 0), datetime.datetime(2026, 6, 15, 0, 0)]
# Jeopardy
# Z
# {'type1': {'blocks': ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY'}}
# ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2']
# 13A
# JEOPARDY
# 2026-06-02 00:00:00 13A Jeopardy JEOPARDY
# 2026-06-03 00:00:00 13A Jeopardy JEOPARDY
# 2026-06-04 00:00:00 13A Jeopardy JEOPARDY
# 2026-06-05 00:00:00 13A Jeopardy JEOPARDY
# 2026-06-06 00:00:00 13A Jeopardy JEOPARDY
# 2026-06-07 00:00:00 13A Jeopardy JEOPARDY
# 2026-06-08 00:00:00 13A Jeopardy JEOPARDY
# 2026-06-09 00:00:00 13A Jeopardy JEOPARDY
# 2026-06-10 00:00:00 13A Jeopardy JEOPARDY
# 2026-06-11 00:00:00 13A Jeopardy JEOPARDY
# 2026-06-12 00:00:00 13A Jeopardy JEOPARDY
# 2026-06-13 00:00:00 13A Jeopardy JEOPARDY
# 2026-06-14 00:00:00 13A Jeopardy JEOPARDY
# 2026-06-15 00:00:00 13A Jeopardy JEOPARDY
# 13B Ambulatory
# [datetime.datetime(2026, 6, 16, 0, 0), datetime.datetime(2026, 6, 17, 0, 0), datetime.datetime(2026, 6, 18, 0, 0), datetime.datetime(2026, 6, 19, 0, 0), datetime.datetime(2026, 6, 20, 0, 0), datetime.datetime(2026, 6, 21, 0, 0), datetime.datetime(2026, 6, 22, 0, 0), datetime.datetime(2026, 6, 23, 0, 0), datetime.datetime(2026, 6, 24, 0, 0), datetime.datetime(2026, 6, 25, 0, 0), datetime.datetime(2026, 6, 26, 0, 0), datetime.datetime(2026, 6, 27, 0, 0), datetime.datetime(2026, 6, 28, 0, 0), datetime.datetime(2026, 6, 29, 0, 0), datetime.datetime(2026, 6, 30, 0, 0)]
# Ambulatory
# Z
# -
# 2026-06-16 00:00:00 13B Ambulatory DAY
# 2026-06-17 00:00:00 13B Ambulatory DAY
# 2026-06-18 00:00:00 13B Ambulatory DAY
# 2026-06-19 00:00:00 13B Ambulatory DAY
# 2026-06-20 00:00:00 13B Ambulatory OFF
# 2026-06-21 00:00:00 13B Ambulatory OFF
# 2026-06-22 00:00:00 13B Ambulatory DAY
# 2026-06-23 00:00:00 13B Ambulatory DAY
# 2026-06-24 00:00:00 13B Ambulatory DAY
# 2026-06-25 00:00:00 13B Ambulatory DAY
# 2026-06-26 00:00:00 13B Ambulatory DAY
# 2026-06-27 00:00:00 13B Ambulatory OFF
# 2026-06-28 00:00:00 13B Ambulatory OFF
# 2026-06-29 00:00:00 13B Ambulatory DAY

# %%
a=re.search(r'Ambulatory|Elective|UH|HIV|HCH', rotation)

print(a)
# Out:
# <re.Match object; span=(0, 10), match='Ambulatory'>

# %%
rotation
# Out:
# 'Ambulatory'

# %%
get_specific_rotation_schedule('8A', 'NightWatch', my_dict)
# Out:
# NightWatch
# Z
# {'type1': {'blocks': ['1A'], 'Z': 'NIGHTS  NIGHTS  NIGHTS  OFF NIGHTS  NIGHTS  NIGHTS  *POST'}, 'type2': {'blocks': ['1B', '2A', '2B', '3A', '3B', '4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B'], 'Z': 'NIGHTS  NIGHTS  NIGHTS  OFF NIGHTS  NIGHTS  NIGHTS NIGHTS NIGHTS  NIGHTS  OFF NIGHTS  NIGHTS  NIGHTS  *POST'}, 'type3': {'blocks': ['7A'], 'Z': 'NIGHTS  NIGHTS  NIGHTS  OFF NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  OFF'}, 'type4': {'blocks': ['7B'], 'Z': 'NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  OFF NIGHTS  NIGHTS  NIGHTS *POST'}, 'type5': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'NIGHTS NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS *POST'}}
# ['1A']
# ['1B', '2A', '2B', '3A', '3B', '4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B']
# 8A
# ['NIGHTS',
#  'NIGHTS',
#  'NIGHTS',
#  'OFF',
#  'NIGHTS',
#  'NIGHTS',
#  'NIGHTS',
#  'NIGHTS',
#  'NIGHTS',
#  'NIGHTS',
#  'OFF',
#  'NIGHTS',
#  'NIGHTS',
#  'NIGHTS',
#  '*POST']
