# %%
import icalendar
import pytz, zoneinfo, dateutil.tz  # timezone libraries
import datetime, icalendar
import pyaml
import pandas as pd 
import numpy as np
import yaml
from datetime import datetime, timedelta
import re
from ics import Calendar, Event

# %%
def convert_datestring (datestring):
    format = "%m/%d/%Y"
    date_object = datetime.strptime(datestring, format)
    return date_object


def get_start_end_dates(block_id, my_dict):
    start, end = (my_dict['block_dates'][block_id].split())
    start = convert_datestring(start)
    end = convert_datestring(end)
    return start, end


def date_lists(start_date, end_date):
    current_date = start_date
    dates = []
    while current_date <= end_date:
        dates.append(current_date)
        current_date += timedelta(days=1)
    return dates
    

        
def block_dates (block_id, my_dict):
    """get start and end date for each block by going through the master yaml """
    start_date, end_date = (get_start_end_dates(block_id, my_dict))
    block_duration = date_lists(start_date, end_date)    
    return block_duration
 

def add_date_postcall_into_next_block(call_cycle, block_days):
    print(call_cycle[-1])
    if re.search(r'^\*', call_cycle[-1]):
        # Step 1: Get the last date in the list
        last_date = block_days[-1]

        # Step 2: Calculate the next date (assuming consecutive days, so add 1 day)
        next_date = last_date + timedelta(days=1)

        # Step 3: Add the new date to the list
        block_days.append(next_date)
    return block_days
    
    
def get_specific_rotation_schedule(block_id, rotation, my_dict):
    rotation = re.sub('\s', '', rotation)
    

        
    try:
        rotation, individual = rotation.split('-')
    except:
        rotation = rotation
        individual = 'Z'
        
    if re.search('Janeway|Barker|Longcope|Thayer', rotation):
        rotation_category = 'FirmSAR'    
    elif re.search('CJ|Polk|MEG|Liver', rotation):
        rotation_category = 'Subspecialty'    
        
    elif re.search('Pathway|Elective|Research|Geri|UH|Addiction', rotation):
        # these rotation have MTWTF rotation with weekends off
        rotation_category = 'Ambulatory'
    else:
        rotation_category = rotation
    print(rotation_category)
    print(individual)
    print(my_dict[rotation_category])
    for schedule_type, schedule in my_dict[rotation_category].items():
        print(schedule['blocks'])
        if block_id in schedule['blocks']:
            print(block_id)
            return schedule[individual].split()
    # if no schedule is found return '-' list
    return ['-'] *14

# %%
# Read master tables

    
with open("/Users/cjyoon/Dropbox/Osler/Osler_shiny/jarsar2025//call_schedule_master.yaml") as f:
    my_dict = yaml.safe_load(f)

    

    
master_schedule = pd.read_excel('/Users/cjyoon/Dropbox/Osler/Osler_shiny/jarsar2025/Resident Schedule 2025-2026.xlsx', sheet_name='Schedule')
resident_names = master_schedule.iloc[:, 0].to_list()
series = pd.Series(resident_names)

# Remove NaN values
cleaned_series = series.dropna()

# Convert back to a list
resident_names = cleaned_series.tolist()
print(resident_names)
len(resident_names)


def update_values_to_uppercase(data):
    """
    Recursively updates all string values in a nested dictionary to uppercase.
    """
    if isinstance(data, dict):
        return {key: update_values_to_uppercase(value) for key, value in data.items()}
    elif isinstance(data, list):
        return [update_values_to_uppercase(item) for item in data]
    elif isinstance(data, str):
        return data.upper()
    else:
        return data


def add_combined_key(data):
    for key, value in data.items():
        if key.endswith('_') and isinstance(value, dict) and 'A' in value and 'B' in value:
            # Create a list of combined A and B values
            combined = [f"{a.strip()}/{b.strip()}" for (a, b) in zip(value['A'].split(), value['B'].split())]
            value['Z'] = ' '.join(combined)
    return data


def oncology_schedule(rotation, date):
    schedule = 'DAY'
    
    if date.weekday() == 0 and rotation == 'Leuks': #off day is Monday
        schedule = 'OFF'
    elif date.weekday() == 5 and rotation in ['Solids', 'MTL']: #off day is Saturday
        schedule = 'OFF'
    elif date.weekday() == 5 and rotation == 'Ambulatory': #ambo off day is Saturday and Sunday
        schedule = 'OFF'   
    elif date.weekday() == 6 and rotation == 'Ambulatory': #ambo off day is Saturday and Sunday
        schedule = 'OFF'
    else:
        pass
    
    return schedule

# bayview schedule to stadard call formats
bayview_conversion = dict({'On-Call': 'CALL', 'Post-Call': 'POST', 'Continuity': 'CONT', 'Off': "OFF"})

# read in bayview schedule and format column to a string form of dates     
bayview_schedule = pd.read_excel('/Users/cjyoon/Dropbox/Osler/Osler_shiny/jarsar/Bayview_Unit_Table.xlsx')
# Convert columns to string format
# Convert columns to datetime where possible
new_columns = []
for col in bayview_schedule.columns:
    try:
        # Attempt to convert to datetime and format as string
        new_columns.append(pd.to_datetime(col).strftime('%Y-%m-%d'))
    except (ValueError, TypeError):
        # If conversion fails, keep the original column name
        new_columns.append(col)

# Assign the new column names
bayview_schedule.columns = new_columns

def get_bayview_schedule(rotation, date, schedule_df):
    """
    Retrieve the schedule for a specific rotation and date.
    
    Args:
    rotation (str): The rotation type, e.g., 'BMICU-1'.
    date (datetime): The date for which to get the schedule.
    schedule_df (pd.DataFrame): The schedule DataFrame.
    
    Returns:
    str: The schedule activity for the given rotation and date.
    """
#     # Convert the date to string format
#     date_str = date.strftime('%Y-%m-%d')
    
#     # Debug: Print column names and check for the date
#     if date_str not in schedule_df.columns:
#         return f"Date {date_str} not found in the schedule.\nAvailable dates: {schedule_df.columns.tolist()}"

    try:
        # Find the schedule for the given rotation and date
        result = schedule_df.loc[schedule_df['Unnamed: 0'] == rotation, date]
        if not result.empty:
            return result.values[0]
        else:
            return f"Rotation {rotation} not found."
    except KeyError:
        return f"Error occurred while looking up the schedule."


updated_dict = dict()
for key, value in my_dict.items():
    updated_val =  add_combined_key(my_dict[key])
    updated_dict.update({key: updated_val})
    
    
updated_dict = update_values_to_uppercase(updated_dict)
my_dict = updated_dict # overwrite after adding the 'Z' keys for blocks which specific resident role is not defined
# Out:
# ['Kannan_Suraj', 'Stathopoulos_Anna', 'Sequeira_Lynette', 'Yimer_Diborah', 'Kosoko_Idris', 'Tran_Thi My Linh', 'Bediako_Hilary', 'Emetu_Sophia', 'McGredy_Maxine', 'Bhatla_Anjali', 'Nimgaonkar_Vivek', 'Gaona_Geyner', 'Buyske_John', 'Gao_Ruiyi', 'Hassan_Hussein', 'Sun_Aaron', 'Malhi_Jasmine', 'McFalls_Caya', 'Gasperetti_Alessio', 'Schumacher_Sarah', 'Ghanem_Paola', 'Bai_Eric', 'Price_Meghan', 'Robertson_Nicole', 'Udoh_Karen', 'Kahl_Madison', 'Lang_Kate', 'Coyne_Liam', 'Mansour_Alexandra', 'Moon_Mackenzie', 'Rosas_Lauren', 'Ramesh_Harrine', 'Aduboffour_Akwasi', 'Cao Zhang_Alexander', 'Zeitoun_Ralph', 'Rahim_Muhammed', 'Wilson_Grant', 'Phillips_Ashley', 'Jo_Allen', 'Hutto_David', 'Patel_Hamza', 'Shim_Jalene', 'Connolly_John', 'Chew_Chris', 'Kim_Yoo Jin', 'Elshafeey_Abdallah', 'Verma_Sanjana', 'Kankaria_Rohan', 'Gharios_Charbel', 'Masucci_Vianca', 'Sokolsky_Mark', 'Wang, Tiffany', 'Alshawkani_Yazan', 'Javaid_Aamir', 'Choi_David', 'Calhoun_Cody', 'Abou Diwan_Elizabeth', 'Bshesh_Khalifa', 'Arora_Arshia', 'Hill_Kristi', 'Verma_Rohan', 'Hawkins_Stephanie', 'Mhaimeed_Nada', 'Faber_Erik', 'Masood_Areeb', 'Shekhar_Soumya', 'Rappaport_Jeffrey', 'Zale_Andrew', 'Mhaimeed_Omar', 'Meyer_David', 'Plott_Cara', 'Amundson_Danielle', 'Dong_Matthew', 'Dobbs_John', 'Gupta_Vrinda', 'Corty_Edward', 'Johnson_Adrienne', 'Kodali_Sreeja', 'Preston_Anna', 'Sandoval_Raquel', 'Silvas_Andrea', 'Garba_Deen', 'Gami_Abhi', 'Morris_Eli', 'Gilbert_Ross', 'McLeish_Colin', 'Schonman_Ian', 'Subrahmanyan_Rishi', 'Jang_Sarah', 'Kikuchi_Daniel', 'Avoke_Dorothy', 'Rajaei_Jennia', 'Zerjav_Dylan', 'Gomes_Ed', 'You_Jonathan', 'Stanwyck_Lynn', 'Blazoski_Cameron', 'Karatela_Maham', 'Kee_Dustin', 'Zheng_Melanie', 'Tang_Olive', 'Goplerud_Dana', 'Pronovost_Henry', 'Delgado_Nathalie']

# %%
def get_schedule(resident_name, master_schedule):
    """gets the specific intern's schedule from the table"""
    filtered_df = master_schedule[master_schedule.iloc[:, 0] == resident_name]
    return (filtered_df.squeeze().to_list()[1:])

# %%
print(master_schedule)
new_column_names = [f"{col} {master_schedule.iloc[1, idx]}" for idx, col in enumerate(master_schedule.columns) if not isinstance(col, float)]

# Update the column names in the DataFrame
master_schedule.columns = new_column_names
print(new_column_names)


master_table_tsv = master_schedule.iloc[3:].fillna('')
master_table_tsv.columns.values[0] = 'name'
master_table_tsv.replace("Supervisor", "Wolf", inplace=True)

master_table_tsv.sort_values('name').to_csv('/Users/cjyoon/Dropbox/Osler/Osler_shiny/block_schedule/jar_sar_block_view.tsv', sep='\t', index=False)
# Out:
#                   name    1A 7/1/24-7/8/24 1B 7/9/24-7/22/24  \
# 0                  NaN                 NaN               NaN
# 1                  NaN       7/1/24-7/8/24    7/9/24-7/22/24
# 2                  NaN                Blue             Green
# 3         Kannan_Suraj  Cardiomyopathy - D         BMICU - 3
# 4    Stathopoulos_Anna          Barker - B          MICU - A
# ..                 ...                 ...               ...
# 102      Zheng_Melanie          Ambulatory        Thayer - A
# 103         Tang_Olive          Ambulatory      Longcope - B
# 104      Goplerud_Dana                Peds              Peds
# 105    Pronovost_Henry          Ambulatory      Brancati - A
# 106   Delgado_Nathalie          Ambulatory          Jeopardy
#
#     2A 7/23/24-8/5/24 2B 8/6/24-8/19/24 3A 8/20/24-9/2/24 3B 9/3/24-9/16/24  \
# 0               MedEd               NaN               NaN               NaN
# 1      7/23/24-8/5/24    8/6/24-8/19/24    8/20/24-9/2/24    9/3/24-9/16/24
# 2              Yellow               Red              Blue             Green
# 3        Brancati - C        Ambulatory                CJ          Elective
# 4              Relief        Ambulatory          Vacation                ED
# ..                ...               ...               ...               ...
# 102          MICU - A        Thayer - C        Ambulatory          Jeopardy
# 103          Jeopardy      Longcope - A        Ambulatory          MICU - B
# 104              Peds              Peds        Thayer - A         MP Clinic
# 105     Pathway-MedEd          Vacation        Ambulatory                CJ
# 106          Vacation        Thayer - A        Ambulatory        Thayer - A
#
#     4A 9/17/24-9/30/24 4B 10/1/24-10/14/24 5A 10/15/24-10/28/24  ...  \
# 0                   QI                 NaN                  PSP  ...
# 1      9/17/24-9/30/24    10/1/24-10/14/24    10/15/24-10/28/24  ...
# 2               Yellow                 Red                 Blue  ...
# 3             Vacation          Ambulatory             BCCU - 2  ...
# 4             MICU - E          Ambulatory               Barker  ...
# ..                 ...                 ...                  ...  ...
# 102           MICU - F              Triage           Ambulatory  ...
# 103         Supervisor            Vacation           Ambulatory  ...
# 104         Pathway-QI              Thayer                 Peds  ...
# 105           BCCU - 1             CCU - B           Ambulatory  ...
# 106           Jeopardy            MICU - A           Ambulatory  ...
#
#     9B 2/25/25-3/10/25 10A 3/11/25-3/24/25     10B 3/25/25-4/7/25  \
# 0                  NaN                 NaN                    NaN
# 1      2/25/25-3/10/25     3/11/25-3/24/25         3/25/25-4/7/25
# 2                Green              Yellow                    Red
# 3             MICU - E              Barker             Ambulatory
# 4               Barker            Elective             Ambulatory
# ..                 ...                 ...                    ...
# 102           Elective              Thayer                     ED
# 103           Longcope            MICU - D               Elective
# 104            HIV/HCV                Peds                   Peds
# 105            CCU - C                 MPC               MICU - F
# 106           Elective            Vacation  Correctional medicine
#
#     11A 4/8/25-4/21/25  11B 4/22/25-5/5/25 12A 5/6/25-5/19/25  \
# 0                  NaN                 NaN                NaN
# 1       4/8/25-4/21/25      4/22/25-5/5/25     5/6/25-5/19/25
# 2                 Blue               Green             Yellow
# 3              CCU - A            BCCU - 2             Barker
# 4            BMICU - 3            Jeopardy             Barker
# ..                 ...                 ...                ...
# 102         Ambulatory              Thayer           Elective
# 103         Ambulatory            Elective           MICU - C
# 104               Peds                Peds           MICU - F
# 105         Ambulatory  Cardiomyopathy - B               Polk
# 106         Ambulatory             City HD            City HD
#
#     12B 5/20/25-6/2/25 13A 6/3/25-6/16/25 13B 6/17/25-6/30/25 Unnamed: 29 nan
# 0                  NaN                NaN                 NaN             NaN
# 1       5/20/25-6/2/25     6/3/25-6/16/25     6/17/25-6/30/25             NaN
# 2                  Red               Blue               Green             NaN
# 3           Ambulatory            CCU - A             CCU - B             NaN
# 4           Ambulatory           Vacation            MICU - F             NaN
# ..                 ...                ...                 ...             ...
# 102           Vacation         Ambulatory                 MTL             NaN
# 103           Vacation         Ambulatory             CCU - C             NaN
# 104           Vacation             Thayer            Jeopardy             NaN
# 105           Vacation         Ambulatory                  CJ             NaN
# 106     Women's Health         Ambulatory                  ED             NaN
#
# [107 rows x 30 columns]
# ['name nan', '1A 7/1/24-7/8/24 7/1/24-7/8/24', '1B 7/9/24-7/22/24 7/9/24-7/22/24', '2A 7/23/24-8/5/24 7/23/24-8/5/24', '2B 8/6/24-8/19/24 8/6/24-8/19/24', '3A 8/20/24-9/2/24 8/20/24-9/2/24', '3B 9/3/24-9/16/24 9/3/24-9/16/24', '4A 9/17/24-9/30/24 9/17/24-9/30/24', '4B 10/1/24-10/14/24 10/1/24-10/14/24', '5A 10/15/24-10/28/24 10/15/24-10/28/24', '5B 10/29/24-11/11/24 10/29/24-11/11/24', '6A 11/12/24-11/25/24 11/12/24-11/25/24', '6B 11/26/24-12/9/24 11/26/24-12/9/24', '7A 12/10/24-12/19/24 12/10/24-12/19/24', 'HOLIDAY 1 12/20/24-12/26/24 12/20/24-12/26/24', 'HOLIDAY 2 12/27/24-1/2/25 12/27/24-1/2/25', '7B 1/3/25-1/13/25 1/3/25-1/13/25', '8A 1/14/25-1/27/25 1/14/25-1/27/25', '8B 1/28/25-2/10/25 1/28/25-2/10/25', '9A 2/11/25-2/24/25 2/11/25-2/24/25', '9B 2/25/25-3/10/25 2/25/25-3/10/25', '10A 3/11/25-3/24/25 3/11/25-3/24/25', '10B 3/25/25-4/7/25 3/25/25-4/7/25', '11A 4/8/25-4/21/25 4/8/25-4/21/25', '11B 4/22/25-5/5/25 4/22/25-5/5/25', '12A 5/6/25-5/19/25 5/6/25-5/19/25', '12B 5/20/25-6/2/25 5/20/25-6/2/25', '13A 6/3/25-6/16/25 6/3/25-6/16/25', '13B 6/17/25-6/30/25 6/17/25-6/30/25', 'Unnamed: 29 nan nan']

# %%
#july1_offset = my_dict['july1_offset']
# Create a calendar and event


for resident_name in resident_names:
    date_list = []
    schedule_list = []        
    my_blocks = (get_schedule(resident_name, master_schedule))
    print(my_blocks)
    

    calendar = Calendar()
    event = Event()
    with open(f"/Users/cjyoon/Dropbox/Osler/Osler_shiny/jar_sar_schedule/{resident_name}_schedule.tsv", "w") as g:
        g.write('name\tdate\tschedule\n')
        for block_id, rotation in zip(my_dict['block_dates'].keys(), my_blocks):
            if 1:
                if not isinstance(rotation, str):
                    rotation = ' '

                rotation = re.sub('\s', '', rotation)

                print(block_id, rotation)
                
                block_days = block_dates(block_id, my_dict)        
                print(block_days)
                try:
                    call_cycle = get_specific_rotation_schedule(block_id.upper(), rotation, my_dict)
                except:
                    # if specific call cycle is unknown for a rotation, then default to unknown so manual creation can be made
                    if rotation == ' ':
                        call_cycle = [' '] * 14
                    else:
                        call_cycle = ['-'] * 14



                # check if block call cycle ends in a post call
                block_days = add_date_postcall_into_next_block(call_cycle, block_days)

                # Loop through each date and corresponding schedule
                for date, schedule in zip(block_days, call_cycle):
                    
                    # For Bayview units
                    if re.search(r'BCCU|BMICU', rotation):
                        schedule = bayview_conversion[get_bayview_schedule(rotation, date.strftime("%Y-%m-%d"), bayview_schedule)]
                        print(f'{rotation} bla {schedule}')
                    # For oncology rotations/ambo where schedule is only per weekdays basis
                    elif rotation in ['MTL', 'Leuks', 'Solids', 'Ambulatory']:                       
                        schedule = oncology_schedule(rotation, date)
                    else:
                        pass
                    
                    
                    event = Event()  # Create a new event object inside the loop
                    if rotation == 'Supervisor': # change supervisor into more commonly referred Wolf
                        rotation = 'Wolf'
                    event.name = f'{block_id} {rotation} {schedule}'
                    event.begin = date
                    event.make_all_day()  # Make the event an all-day event
                    print(date, block_id, rotation, schedule)
                    # Add event to calendar
                    calendar.events.add(event)
                    date_string = date.strftime('%m-%d-%Y')
                    g.write(f'{resident_name}\t{date_string}\t{event.name}\n')



        # Write the calendar to a .ics file
        with open(f"/Users/cjyoon/Dropbox/Osler/Osler_shiny/jar_sar_schedule/{resident_name}_schedule.ics", "w") as f:
            f.writelines(calendar.serialize_iter())
# Out:
# ['Cardiomyopathy - D', 'BMICU - 3', 'Brancati - C', 'Ambulatory', 'CJ', 'Elective', 'Vacation', 'Ambulatory', 'BCCU - 2', 'Gen Cards - C', 'Liver', 'Ambulatory', 'MICU - E', 'MICU - E', 'Off', 'Cardiomyopathy - D', 'CCU - C', 'Ambulatory', 'Vacation', 'MICU - E', 'Barker', 'Ambulatory', 'CCU - A', 'BCCU - 2', 'Barker', 'Ambulatory', 'CCU - A', 'CCU - B', nan]
# 1A Cardiomyopathy-D
# [datetime.datetime(2024, 7, 1, 0, 0), datetime.datetime(2024, 7, 2, 0, 0), datetime.datetime(2024, 7, 3, 0, 0), datetime.datetime(2024, 7, 4, 0, 0), datetime.datetime(2024, 7, 5, 0, 0), datetime.datetime(2024, 7, 6, 0, 0), datetime.datetime(2024, 7, 7, 0, 0), datetime.datetime(2024, 7, 8, 0, 0)]
# Cardiomyopathy
# D
# {'type1': {'blocks': ['1A'], 'B': 'POST GOOD SHORT CALL  POST  OFF SHORT CALL  *POST', 'D': 'SHORT CALL  POST  GOOD  SHORT CALL  POST  OFF'}, 'type2': {'blocks': ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A'], 'B': 'SHORT CALL  POST  OFF SHORT CALL  POST GOOD SHORT CALL  POST  OFF SHORT CALL *POST', 'D': 'POST GOOD  SHORT CALL  POST  OFF SHORT CALL  POST  GOOD  SHORT CALL  POST  OFF'}, 'type3': {'blocks': ['2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B'], 'B': 'POST  GOOD  SHORT CALL  POST  OFF SHORT CALL  POST  GOOD  SHORT CALL  POST  OFF', 'D': 'SHORT CALL  POST  OFF SHORT CALL  POST GOOD SHORT CALL  POST  OFF SHORT CALL  *POST'}, 'type4': {'blocks': ['7A'], 'B': 'SHORT CALL  POST  OFF SHORT CALL  POST  GOOD  SHORT CALL  *POST', 'D': 'POST  GOOD  SHORT CALL  POST  OFF SHORT CALL  POST  GOOD'}, 'type5': {'blocks': ['7B'], 'B': 'CALL  POST  OFF SHORT CALL  POST  GOOD  SHORT CALL  POST  OFF', 'D': 'OFF SHORT CALL  POST  GOOD  SHORT CALL  POST  OFF SHORT CALL  *POST'}, 'type6': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'B': 'POST  OFF SHORT CALL  POST  GOOD  SHORT', 'D': 'SHORT  CALL  POST  OFF SHORT CALL  POST'}}
# ['1A']
# 1A
# OFF
# 2024-07-01 00:00:00 1A Cardiomyopathy-D SHORT
# 2024-07-02 00:00:00 1A Cardiomyopathy-D CALL
# 2024-07-03 00:00:00 1A Cardiomyopathy-D POST
# 2024-07-04 00:00:00 1A Cardiomyopathy-D GOOD
# 2024-07-05 00:00:00 1A Cardiomyopathy-D SHORT
# 2024-07-06 00:00:00 1A Cardiomyopathy-D CALL
# 2024-07-07 00:00:00 1A Cardiomyopathy-D POST
# 2024-07-08 00:00:00 1A Cardiomyopathy-D OFF
# 1B BMICU-3
# [datetime.datetime(2024, 7, 9, 0, 0), datetime.datetime(2024, 7, 10, 0, 0), datetime.datetime(2024, 7, 11, 0, 0), datetime.datetime(2024, 7, 12, 0, 0), datetime.datetime(2024, 7, 13, 0, 0), datetime.datetime(2024, 7, 14, 0, 0), datetime.datetime(2024, 7, 15, 0, 0), datetime.datetime(2024, 7, 16, 0, 0), datetime.datetime(2024, 7, 17, 0, 0), datetime.datetime(2024, 7, 18, 0, 0), datetime.datetime(2024, 7, 19, 0, 0), datetime.datetime(2024, 7, 20, 0, 0), datetime.datetime(2024, 7, 21, 0, 0), datetime.datetime(2024, 7, 22, 0, 0)]
# BMICU
# 3
# -
# BMICU-3 bla OFF
# 2024-07-09 00:00:00 1B BMICU-3 OFF
# BMICU-3 bla CALL
# 2024-07-10 00:00:00 1B BMICU-3 CALL
# BMICU-3 bla POST
# 2024-07-11 00:00:00 1B BMICU-3 POST
# BMICU-3 bla CONT
# 2024-07-12 00:00:00 1B BMICU-3 CONT
# BMICU-3 bla CALL
# 2024-07-13 00:00:00 1B BMICU-3 CALL
# BMICU-3 bla POST
# 2024-07-14 00:00:00 1B BMICU-3 POST
# BMICU-3 bla OFF
# 2024-07-15 00:00:00 1B BMICU-3 OFF
# BMICU-3 bla CALL
# 2024-07-16 00:00:00 1B BMICU-3 CALL
# BMICU-3 bla POST
# 2024-07-17 00:00:00 1B BMICU-3 POST
# BMICU-3 bla CONT
# 2024-07-18 00:00:00 1B BMICU-3 CONT
# BMICU-3 bla CALL
# 2024-07-19 00:00:00 1B BMICU-3 CALL
# BMICU-3 bla POST
# 2024-07-20 00:00:00 1B BMICU-3 POST
# BMICU-3 bla OFF
# 2024-07-21 00:00:00 1B BMICU-3 OFF
# BMICU-3 bla CALL
# 2024-07-22 00:00:00 1B BMICU-3 CALL
# 2A Brancati-C
# [datetime.datetime(2024, 7, 23, 0, 0), datetime.datetime(2024, 7, 24, 0, 0), datetime.datetime(2024, 7, 25, 0, 0), datetime.datetime(2024, 7, 26, 0, 0), datetime.datetime(2024, 7, 27, 0, 0), datetime.datetime(2024, 7, 28, 0, 0), datetime.datetime(2024, 7, 29, 0, 0), datetime.datetime(2024, 7, 30, 0, 0), datetime.datetime(2024, 7, 31, 0, 0), datetime.datetime(2024, 8, 1, 0, 0), datetime.datetime(2024, 8, 2, 0, 0), datetime.datetime(2024, 8, 3, 0, 0), datetime.datetime(2024, 8, 4, 0, 0), datetime.datetime(2024, 8, 5, 0, 0)]
# Brancati
# C
# {'type1': {'blocks': ['1A'], 'A': 'NEWS OFF  OLDS  BOOK  OLDS  NIGHTS  NIGHTS  NIGHTS  *POST', 'B': 'BOOK  NIGHTS  NIGHTS  NIGHTS  NEWS^ OFF NEWS', 'C': 'NIGHTS  NEWS^  OFF NEWS  OLDS  BOOK  OLDS'}, 'type2': {'blocks': ['1B', '2A', '2B', '3A', '3B'], 'A': 'DAYS  DAYS  DAYS  DAYS  BOOK  BOOK  NIGHTS NIGHTS NIGHTS  NIGHTS  NEWS^  OFF OFF DAYS', 'B': 'NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NEWS^ OFF OFF DAYS  DAYS  BOOK  BOOK  DAYS', 'C': 'DAYS  DAYS  DAYS  DAYS  OFF OFF DAYS BOOK BOOK  DAYS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  *POST'}, 'type3_': {'blocks': ['4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B'], 'A': 'OLDS  OLDS  OLDS  OLDS  BOOK  BOOK  OLDS NEWS NEWS  NEWS  NEWS  OFF OFF NEWS', 'B': 'NEWS  NEWS  NEWS  NEWS  OFF OFF NEWS OLDS OLDS  OLDS  OLDS  BOOK  BOOK  OLDS', 'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK OFF/BOOK NEWS/OLDS'}, 'type4_': {'blocks': ['7A'], 'A': 'NEWS  NEWS  NEWS  NEWS  OFF BOOK  OLDS  OLDS  OLDS  OLDS', 'B': 'OLDS  OLDS  OLDS  OLDS  BOOK  OFF NEWS  NEWS  NEWS  NEWS', 'Z': 'NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK BOOK/OFF OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS'}, 'type5_': {'blocks': ['7B'], 'A': 'NEWS  OFF OFF NEWS  NEWS  OLDS  OLDS  OLDS  BOOK  BOOK  OLDS', 'B': 'OLDS  BOOK  BOOK  OLDS  OLDS  NEWS  NEWS  NEWS  OFF OFF NEWS', 'Z': 'NEWS/OLDS OFF/BOOK OFF/BOOK NEWS/OLDS NEWS/OLDS OLDS/NEWS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS'}, 'type6_': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'OLDS  OLDS  OLDS  NEWS  NEWS  NEWS  NEWS', 'B': 'NEWS  NEWS  NEWS  OLDS  OLDS  OLDS  OLDS', 'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS'}}
# ['1A']
# ['1B', '2A', '2B', '3A', '3B']
# 2A
# *POST
# 2024-07-23 00:00:00 2A Brancati-C DAYS
# 2024-07-24 00:00:00 2A Brancati-C DAYS
# 2024-07-25 00:00:00 2A Brancati-C DAYS
# 2024-07-26 00:00:00 2A Brancati-C DAYS
# 2024-07-27 00:00:00 2A Brancati-C OFF
# 2024-07-28 00:00:00 2A Brancati-C OFF
# 2024-07-29 00:00:00 2A Brancati-C DAYS
# 2024-07-30 00:00:00 2A Brancati-C BOOK
# 2024-07-31 00:00:00 2A Brancati-C BOOK
# 2024-08-01 00:00:00 2A Brancati-C DAYS
# 2024-08-02 00:00:00 2A Brancati-C NIGHTS
# 2024-08-03 00:00:00 2A Brancati-C NIGHTS
# 2024-08-04 00:00:00 2A Brancati-C NIGHTS
# 2024-08-05 00:00:00 2A Brancati-C NIGHTS
# 2024-08-06 00:00:00 2A Brancati-C *POST
# 2B Ambulatory
# [datetime.datetime(2024, 8, 6, 0, 0), datetime.datetime(2024, 8, 7, 0, 0), datetime.datetime(2024, 8, 8, 0, 0), datetime.datetime(2024, 8, 9, 0, 0), datetime.datetime(2024, 8, 10, 0, 0), datetime.datetime(2024, 8, 11, 0, 0), datetime.datetime(2024, 8, 12, 0, 0), datetime.datetime(2024, 8, 13, 0, 0), datetime.datetime(2024, 8, 14, 0, 0), datetime.datetime(2024, 8, 15, 0, 0), datetime.datetime(2024, 8, 16, 0, 0), datetime.datetime(2024, 8, 17, 0, 0), datetime.datetime(2024, 8, 18, 0, 0), datetime.datetime(2024, 8, 19, 0, 0)]
# Ambulatory
# Z
# -
# 2024-08-06 00:00:00 2B Ambulatory DAY
# 2024-08-07 00:00:00 2B Ambulatory DAY
# 2024-08-08 00:00:00 2B Ambulatory DAY
# 2024-08-09 00:00:00 2B Ambulatory DAY
# 2024-08-10 00:00:00 2B Ambulatory OFF
# 2024-08-11 00:00:00 2B Ambulatory OFF
# 2024-08-12 00:00:00 2B Ambulatory DAY
# 2024-08-13 00:00:00 2B Ambulatory DAY
# 2024-08-14 00:00:00 2B Ambulatory DAY
# 2024-08-15 00:00:00 2B Ambulatory DAY
# 2024-08-16 00:00:00 2B Ambulatory DAY
# 2024-08-17 00:00:00 2B Ambulatory OFF
# 2024-08-18 00:00:00 2B Ambulatory OFF
# 2024-08-19 00:00:00 2B Ambulatory DAY
# 3A CJ
# [datetime.datetime(2024, 8, 20, 0, 0), datetime.datetime(2024, 8, 21, 0, 0), datetime.datetime(2024, 8, 22, 0, 0), datetime.datetime(2024, 8, 23, 0, 0), datetime.datetime(2024, 8, 24, 0, 0), datetime.datetime(2024, 8, 25, 0, 0), datetime.datetime(2024, 8, 26, 0, 0), datetime.datetime(2024, 8, 27, 0, 0), datetime.datetime(2024, 8, 28, 0, 0), datetime.datetime(2024, 8, 29, 0, 0), datetime.datetime(2024, 8, 30, 0, 0), datetime.datetime(2024, 8, 31, 0, 0), datetime.datetime(2024, 9, 1, 0, 0), datetime.datetime(2024, 9, 2, 0, 0)]
# Subspecialty
# Z
# {'type1': {'blocks': ['1A'], 'A': 'DAYS  DAYS  DAYS  DAYS  DAYS  BOOK  OFF DAYS', 'B': 'DAYS  DAYS  DAYS  DAYS  DAYS  OFF BOOK  DAYS'}, 'type2_': {'blocks': ['1B', '2A', '2B', '3A', '3B', '4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B'], 'A': 'DAYS  DAYS  DAYS  DAYS  BOOK  BOOK  DAYS DAYS DAYS  DAYS  DAYS  OFF OFF DAYS', 'B': 'DAYS  DAYS  DAYS  DAYS  OFF OFF DAYS DAYS DAYS  DAYS  DAYS  BOOK  BOOK  DAYS', 'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF BOOK/OFF DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS OFF/BOOK OFF/BOOK DAYS/DAYS'}, 'type3_': {'blocks': ['7A'], 'A': 'DAYS  DAYS  DAYS  BOOK  OFF DAYS  DAYS  DAYS  DAYS  DAYS', 'B': 'DAYS  DAYS  DAYS  OFF BOOK  DAYS  DAYS  DAYS  DAYS  DAYS', 'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF OFF/BOOK DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS'}, 'type4_': {'blocks': ['7B'], 'A': 'DAYS  OFF OFF DAYS  DAYS  DAYS  DAYS  DAYS  BOOK  BOOK  DAYS', 'B': 'DAYS  BOOK  BOOK  DAYS  DAYS  DAYS  DAYS  DAYS  OFF OFF DAYS', 'Z': 'DAYS/DAYS OFF/BOOK OFF/BOOK DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF BOOK/OFF DAYS/DAYS'}, 'type5_': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'DAYS  DAYS  DAYS  DAYS  DAYS  DAYS  DAYS', 'B': 'DAYS  DAYS  DAYS  DAYS  DAYS  DAYS  DAYS', 'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS'}}
# ['1A']
# ['1B', '2A', '2B', '3A', '3B', '4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B']
# 3A
# DAYS/DAYS
# 2024-08-20 00:00:00 3A CJ DAYS/DAYS
# 2024-08-21 00:00:00 3A CJ DAYS/DAYS
# 2024-08-22 00:00:00 3A CJ DAYS/DAYS
# 2024-08-23 00:00:00 3A CJ DAYS/DAYS
# 2024-08-24 00:00:00 3A CJ BOOK/OFF
# 2024-08-25 00:00:00 3A CJ BOOK/OFF
# 2024-08-26 00:00:00 3A CJ DAYS/DAYS
# 2024-08-27 00:00:00 3A CJ DAYS/DAYS
# 2024-08-28 00:00:00 3A CJ DAYS/DAYS
# 2024-08-29 00:00:00 3A CJ DAYS/DAYS
# 2024-08-30 00:00:00 3A CJ DAYS/DAYS
# 2024-08-31 00:00:00 3A CJ OFF/BOOK
# 2024-09-01 00:00:00 3A CJ OFF/BOOK
# 2024-09-02 00:00:00 3A CJ DAYS/DAYS
# 3B Elective
# [datetime.datetime(2024, 9, 3, 0, 0), datetime.datetime(2024, 9, 4, 0, 0), datetime.datetime(2024, 9, 5, 0, 0), datetime.datetime(2024, 9, 6, 0, 0), datetime.datetime(2024, 9, 7, 0, 0), datetime.datetime(2024, 9, 8, 0, 0), datetime.datetime(2024, 9, 9, 0, 0), datetime.datetime(2024, 9, 10, 0, 0), datetime.datetime(2024, 9, 11, 0, 0), datetime.datetime(2024, 9, 12, 0, 0), datetime.datetime(2024, 9, 13, 0, 0), datetime.datetime(2024, 9, 14, 0, 0), datetime.datetime(2024, 9, 15, 0, 0), datetime.datetime(2024, 9, 16, 0, 0)]
# Ambulatory
# Z
# -
# 2024-09-03 00:00:00 3B Elective -
# 2024-09-04 00:00:00 3B Elective -
# 2024-09-05 00:00:00 3B Elective -
# 2024-09-06 00:00:00 3B Elective -
# 2024-09-07 00:00:00 3B Elective -
# 2024-09-08 00:00:00 3B Elective -
# 2024-09-09 00:00:00 3B Elective -
# 2024-09-10 00:00:00 3B Elective -
# 2024-09-11 00:00:00 3B Elective -
# 2024-09-12 00:00:00 3B Elective -
# 2024-09-13 00:00:00 3B Elective -
# 2024-09-14 00:00:00 3B Elective -
# 2024-09-15 00:00:00 3B Elective -
# 2024-09-16 00:00:00 3B Elective -
# 4A Vacation
# [datetime.datetime(2024, 9, 17, 0, 0), datetime.datetime(2024, 9, 18, 0, 0), datetime.datetime(2024, 9, 19, 0, 0), datetime.datetime(2024, 9, 20, 0, 0), datetime.datetime(2024, 9, 21, 0, 0), datetime.datetime(2024, 9, 22, 0, 0), datetime.datetime(2024, 9, 23, 0, 0), datetime.datetime(2024, 9, 24, 0, 0), datetime.datetime(2024, 9, 25, 0, 0), datetime.datetime(2024, 9, 26, 0, 0), datetime.datetime(2024, 9, 27, 0, 0), datetime.datetime(2024, 9, 28, 0, 0), datetime.datetime(2024, 9, 29, 0, 0), datetime.datetime(2024, 9, 30, 0, 0)]
# Vacation
# Z
# {'type1': {'blocks': ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION'}}
# ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2']
# 4A
# VACATION
# 2024-09-17 00:00:00 4A Vacation VACATION
# 2024-09-18 00:00:00 4A Vacation VACATION
# 2024-09-19 00:00:00 4A Vacation VACATION
# 2024-09-20 00:00:00 4A Vacation VACATION
# 2024-09-21 00:00:00 4A Vacation VACATION
# 2024-09-22 00:00:00 4A Vacation VACATION
# 2024-09-23 00:00:00 4A Vacation VACATION
# 2024-09-24 00:00:00 4A Vacation VACATION
# 2024-09-25 00:00:00 4A Vacation VACATION
# 2024-09-26 00:00:00 4A Vacation VACATION
# 2024-09-27 00:00:00 4A Vacation VACATION
# 2024-09-28 00:00:00 4A Vacation VACATION
# 2024-09-29 00:00:00 4A Vacation VACATION
# 2024-09-30 00:00:00 4A Vacation VACATION
# 4B Ambulatory
# [datetime.datetime(2024, 10, 1, 0, 0), datetime.datetime(2024, 10, 2, 0, 0), datetime.datetime(2024, 10, 3, 0, 0), datetime.datetime(2024, 10, 4, 0, 0), datetime.datetime(2024, 10, 5, 0, 0), datetime.datetime(2024, 10, 6, 0, 0), datetime.datetime(2024, 10, 7, 0, 0), datetime.datetime(2024, 10, 8, 0, 0), datetime.datetime(2024, 10, 9, 0, 0), datetime.datetime(2024, 10, 10, 0, 0), datetime.datetime(2024, 10, 11, 0, 0), datetime.datetime(2024, 10, 12, 0, 0), datetime.datetime(2024, 10, 13, 0, 0), datetime.datetime(2024, 10, 14, 0, 0)]
# Ambulatory
# Z
# -
# 2024-10-01 00:00:00 4B Ambulatory DAY
# 2024-10-02 00:00:00 4B Ambulatory DAY
# 2024-10-03 00:00:00 4B Ambulatory DAY
# 2024-10-04 00:00:00 4B Ambulatory DAY
# 2024-10-05 00:00:00 4B Ambulatory OFF
# 2024-10-06 00:00:00 4B Ambulatory OFF
# 2024-10-07 00:00:00 4B Ambulatory DAY
# 2024-10-08 00:00:00 4B Ambulatory DAY
# 2024-10-09 00:00:00 4B Ambulatory DAY
# 2024-10-10 00:00:00 4B Ambulatory DAY
# 2024-10-11 00:00:00 4B Ambulatory DAY
# 2024-10-12 00:00:00 4B Ambulatory OFF
# 2024-10-13 00:00:00 4B Ambulatory OFF
# 2024-10-14 00:00:00 4B Ambulatory DAY
# 5A BCCU-2
# [datetime.datetime(2024, 10, 15, 0, 0), datetime.datetime(2024, 10, 16, 0, 0), datetime.datetime(2024, 10, 17, 0, 0), datetime.datetime(2024, 10, 18, 0, 0), datetime.datetime(2024, 10, 19, 0, 0), datetime.datetime(2024, 10, 20, 0, 0), datetime.datetime(2024, 10, 21, 0, 0), datetime.datetime(2024, 10, 22, 0, 0), datetime.datetime(2024, 10, 23, 0, 0), datetime.datetime(2024, 10, 24, 0, 0), datetime.datetime(2024, 10, 25, 0, 0), datetime.datetime(2024, 10, 26, 0, 0), datetime.datetime(2024, 10, 27, 0, 0), datetime.datetime(2024, 10, 28, 0, 0)]
# BCCU
# 2
# -
# BCCU-2 bla OFF
# 2024-10-15 00:00:00 5A BCCU-2 OFF
# BCCU-2 bla CALL
# 2024-10-16 00:00:00 5A BCCU-2 CALL
# BCCU-2 bla POST
# 2024-10-17 00:00:00 5A BCCU-2 POST
# BCCU-2 bla CONT
# 2024-10-18 00:00:00 5A BCCU-2 CONT
# BCCU-2 bla CALL
# 2024-10-19 00:00:00 5A BCCU-2 CALL
# BCCU-2 bla POST
# 2024-10-20 00:00:00 5A BCCU-2 POST
# BCCU-2 bla OFF
# 2024-10-21 00:00:00 5A BCCU-2 OFF
# BCCU-2 bla CALL
# 2024-10-22 00:00:00 5A BCCU-2 CALL
# BCCU-2 bla POST
# 2024-10-23 00:00:00 5A BCCU-2 POST
# BCCU-2 bla CONT
# 2024-10-24 00:00:00 5A BCCU-2 CONT
# BCCU-2 bla CALL
# 2024-10-25 00:00:00 5A BCCU-2 CALL
# BCCU-2 bla POST
# 2024-10-26 00:00:00 5A BCCU-2 POST
# BCCU-2 bla OFF
# 2024-10-27 00:00:00 5A BCCU-2 OFF
# BCCU-2 bla CALL
# 2024-10-28 00:00:00 5A BCCU-2 CALL
# 5B GenCards-C
# [datetime.datetime(2024, 10, 29, 0, 0), datetime.datetime(2024, 10, 30, 0, 0), datetime.datetime(2024, 10, 31, 0, 0), datetime.datetime(2024, 11, 1, 0, 0), datetime.datetime(2024, 11, 2, 0, 0), datetime.datetime(2024, 11, 3, 0, 0), datetime.datetime(2024, 11, 4, 0, 0), datetime.datetime(2024, 11, 5, 0, 0), datetime.datetime(2024, 11, 6, 0, 0), datetime.datetime(2024, 11, 7, 0, 0), datetime.datetime(2024, 11, 8, 0, 0), datetime.datetime(2024, 11, 9, 0, 0), datetime.datetime(2024, 11, 10, 0, 0), datetime.datetime(2024, 11, 11, 0, 0)]
# GenCards
# C
# {'type1': {'blocks': ['1A'], 'A': 'CALL POST GOOD  SHORT CALL  POST  OFF SHORT', 'C': 'OFF SHORT CALL  POST  OFF SHORT CALL  POST'}, 'type2': {'blocks': ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A'], 'A': 'GOOD  SHORT CALL  POST  OFF SHORT CALL POST GOOD  SHORT CALL  POST  OFF SHORT', 'C': 'CALL  POST  GOOD  SHORT CALL  POST  OFF SHORT CALL  POST  OFF SHORT CALL  POST'}, 'type3': {'blocks': ['2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B'], 'A': 'CALL  POST  GOOD  SHORT CALL  POST  OFF SHORT CALL  POST  OFF SHORT CALL  POST', 'C': 'GOOD  SHORT CALL  POST  OFF SHORT CALL POST GOOD  SHORT CALL  POST  OFF SHORT'}, 'type4': {'blocks': ['7A'], 'A': 'GOOD  SHORT CALL  POST  OFF SHORT CALL  POST  GOOD  SHORT', 'C': 'CALL  POST  GOOD  SHORT CALL  POST  OFF SHORT CALL  POST'}, 'type5': {'blocks': ['7B'], 'A': 'SHORT CALL  POST  OFF SHORT CALL  POST  GOOD  SHORT CALL  POST', 'C': 'POST  OFF SHORT CALL  POST  GOOD  SHORT CALL  POST  OFF SHORT'}, 'type6': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'CALL  POST  OFF SHORT CALL  POST  GOOD', 'C': 'GOOD  SHORT CALL  POST  OFF SHORT CALL  *POST'}}
# ['1A']
# ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A']
# ['2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B']
# 5B
# SHORT
# 2024-10-29 00:00:00 5B GenCards-C GOOD
# 2024-10-30 00:00:00 5B GenCards-C SHORT
# 2024-10-31 00:00:00 5B GenCards-C CALL
# 2024-11-01 00:00:00 5B GenCards-C POST
# 2024-11-02 00:00:00 5B GenCards-C OFF
# 2024-11-03 00:00:00 5B GenCards-C SHORT
# 2024-11-04 00:00:00 5B GenCards-C CALL
# 2024-11-05 00:00:00 5B GenCards-C POST
# 2024-11-06 00:00:00 5B GenCards-C GOOD
# 2024-11-07 00:00:00 5B GenCards-C SHORT
# 2024-11-08 00:00:00 5B GenCards-C CALL
# 2024-11-09 00:00:00 5B GenCards-C POST
# 2024-11-10 00:00:00 5B GenCards-C OFF
# 2024-11-11 00:00:00 5B GenCards-C SHORT
# 6A Liver
# [datetime.datetime(2024, 11, 12, 0, 0), datetime.datetime(2024, 11, 13, 0, 0), datetime.datetime(2024, 11, 14, 0, 0), datetime.datetime(2024, 11, 15, 0, 0), datetime.datetime(2024, 11, 16, 0, 0), datetime.datetime(2024, 11, 17, 0, 0), datetime.datetime(2024, 11, 18, 0, 0), datetime.datetime(2024, 11, 19, 0, 0), datetime.datetime(2024, 11, 20, 0, 0), datetime.datetime(2024, 11, 21, 0, 0), datetime.datetime(2024, 11, 22, 0, 0), datetime.datetime(2024, 11, 23, 0, 0), datetime.datetime(2024, 11, 24, 0, 0), datetime.datetime(2024, 11, 25, 0, 0)]
# Subspecialty
# Z
# {'type1': {'blocks': ['1A'], 'A': 'DAYS  DAYS  DAYS  DAYS  DAYS  BOOK  OFF DAYS', 'B': 'DAYS  DAYS  DAYS  DAYS  DAYS  OFF BOOK  DAYS'}, 'type2_': {'blocks': ['1B', '2A', '2B', '3A', '3B', '4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B'], 'A': 'DAYS  DAYS  DAYS  DAYS  BOOK  BOOK  DAYS DAYS DAYS  DAYS  DAYS  OFF OFF DAYS', 'B': 'DAYS  DAYS  DAYS  DAYS  OFF OFF DAYS DAYS DAYS  DAYS  DAYS  BOOK  BOOK  DAYS', 'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF BOOK/OFF DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS OFF/BOOK OFF/BOOK DAYS/DAYS'}, 'type3_': {'blocks': ['7A'], 'A': 'DAYS  DAYS  DAYS  BOOK  OFF DAYS  DAYS  DAYS  DAYS  DAYS', 'B': 'DAYS  DAYS  DAYS  OFF BOOK  DAYS  DAYS  DAYS  DAYS  DAYS', 'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF OFF/BOOK DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS'}, 'type4_': {'blocks': ['7B'], 'A': 'DAYS  OFF OFF DAYS  DAYS  DAYS  DAYS  DAYS  BOOK  BOOK  DAYS', 'B': 'DAYS  BOOK  BOOK  DAYS  DAYS  DAYS  DAYS  DAYS  OFF OFF DAYS', 'Z': 'DAYS/DAYS OFF/BOOK OFF/BOOK DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS BOOK/OFF BOOK/OFF DAYS/DAYS'}, 'type5_': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'DAYS  DAYS  DAYS  DAYS  DAYS  DAYS  DAYS', 'B': 'DAYS  DAYS  DAYS  DAYS  DAYS  DAYS  DAYS', 'Z': 'DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS DAYS/DAYS'}}
# ['1A']
# ['1B', '2A', '2B', '3A', '3B', '4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B']
# 6A
# DAYS/DAYS
# 2024-11-12 00:00:00 6A Liver DAYS/DAYS
# 2024-11-13 00:00:00 6A Liver DAYS/DAYS
# 2024-11-14 00:00:00 6A Liver DAYS/DAYS
# 2024-11-15 00:00:00 6A Liver DAYS/DAYS
# 2024-11-16 00:00:00 6A Liver BOOK/OFF
# 2024-11-17 00:00:00 6A Liver BOOK/OFF
# 2024-11-18 00:00:00 6A Liver DAYS/DAYS
# 2024-11-19 00:00:00 6A Liver DAYS/DAYS
# 2024-11-20 00:00:00 6A Liver DAYS/DAYS
# 2024-11-21 00:00:00 6A Liver DAYS/DAYS
# 2024-11-22 00:00:00 6A Liver DAYS/DAYS
# 2024-11-23 00:00:00 6A Liver OFF/BOOK
# 2024-11-24 00:00:00 6A Liver OFF/BOOK
# 2024-11-25 00:00:00 6A Liver DAYS/DAYS
# 6B Ambulatory
# [datetime.datetime(2024, 11, 26, 0, 0), datetime.datetime(2024, 11, 27, 0, 0), datetime.datetime(2024, 11, 28, 0, 0), datetime.datetime(2024, 11, 29, 0, 0), datetime.datetime(2024, 11, 30, 0, 0), datetime.datetime(2024, 12, 1, 0, 0), datetime.datetime(2024, 12, 2, 0, 0), datetime.datetime(2024, 12, 3, 0, 0), datetime.datetime(2024, 12, 4, 0, 0), datetime.datetime(2024, 12, 5, 0, 0), datetime.datetime(2024, 12, 6, 0, 0), datetime.datetime(2024, 12, 7, 0, 0), datetime.datetime(2024, 12, 8, 0, 0), datetime.datetime(2024, 12, 9, 0, 0)]
# Ambulatory
# Z
# -
# 2024-11-26 00:00:00 6B Ambulatory DAY
# 2024-11-27 00:00:00 6B Ambulatory DAY
# 2024-11-28 00:00:00 6B Ambulatory DAY
# 2024-11-29 00:00:00 6B Ambulatory DAY
# 2024-11-30 00:00:00 6B Ambulatory OFF
# 2024-12-01 00:00:00 6B Ambulatory OFF
# 2024-12-02 00:00:00 6B Ambulatory DAY
# 2024-12-03 00:00:00 6B Ambulatory DAY
# 2024-12-04 00:00:00 6B Ambulatory DAY
# 2024-12-05 00:00:00 6B Ambulatory DAY
# 2024-12-06 00:00:00 6B Ambulatory DAY
# 2024-12-07 00:00:00 6B Ambulatory OFF
# 2024-12-08 00:00:00 6B Ambulatory OFF
# 2024-12-09 00:00:00 6B Ambulatory DAY
# 7A MICU-E
# [datetime.datetime(2024, 12, 10, 0, 0), datetime.datetime(2024, 12, 11, 0, 0), datetime.datetime(2024, 12, 12, 0, 0), datetime.datetime(2024, 12, 13, 0, 0), datetime.datetime(2024, 12, 14, 0, 0), datetime.datetime(2024, 12, 15, 0, 0), datetime.datetime(2024, 12, 16, 0, 0), datetime.datetime(2024, 12, 17, 0, 0), datetime.datetime(2024, 12, 18, 0, 0), datetime.datetime(2024, 12, 19, 0, 0)]
# MICU
# E
# {'type1': {'blocks': ['1A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF'}, 'type2a': {'blocks': ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'E': 'OFF CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'F': 'GOOD  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF'}, 'type2b': {'blocks': ['1B', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B'], 'A': 'OFF CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'C': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'D': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'E': 'GOOD  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'F': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST'}, 'type3': {'blocks': ['7A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST'}, 'type4': {'blocks': ['7B'], 'A': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'C': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'D': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'E': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'F': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST'}, 'type5': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'GOOD  CALL  POST  OFF CALL  POST  GOOD', 'D': 'POST  OFF CALL  POST  GOOD  CALL  POST', 'E': 'CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'F': 'DATO  CALL  POST  GOOD  CALL  POST  OFF'}}
# ['1A']
# ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A']
# ['1B', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B']
# ['7A']
# 7A
# OFF
# 2024-12-10 00:00:00 7A MICU-E GOOD
# 2024-12-11 00:00:00 7A MICU-E CALL
# 2024-12-12 00:00:00 7A MICU-E POST
# 2024-12-13 00:00:00 7A MICU-E OFF
# 2024-12-14 00:00:00 7A MICU-E CALL
# 2024-12-15 00:00:00 7A MICU-E POST
# 2024-12-16 00:00:00 7A MICU-E GOOD
# 2024-12-17 00:00:00 7A MICU-E CALL
# 2024-12-18 00:00:00 7A MICU-E POST
# 2024-12-19 00:00:00 7A MICU-E OFF
# Holiday 1 MICU-E
# [datetime.datetime(2024, 12, 20, 0, 0), datetime.datetime(2024, 12, 21, 0, 0), datetime.datetime(2024, 12, 22, 0, 0), datetime.datetime(2024, 12, 23, 0, 0), datetime.datetime(2024, 12, 24, 0, 0), datetime.datetime(2024, 12, 25, 0, 0), datetime.datetime(2024, 12, 26, 0, 0)]
# MICU
# E
# {'type1': {'blocks': ['1A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF'}, 'type2a': {'blocks': ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'E': 'OFF CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'F': 'GOOD  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF'}, 'type2b': {'blocks': ['1B', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B'], 'A': 'OFF CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'C': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'D': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'E': 'GOOD  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'F': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST'}, 'type3': {'blocks': ['7A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST'}, 'type4': {'blocks': ['7B'], 'A': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'C': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'D': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'E': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'F': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST'}, 'type5': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'GOOD  CALL  POST  OFF CALL  POST  GOOD', 'D': 'POST  OFF CALL  POST  GOOD  CALL  POST', 'E': 'CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'F': 'DATO  CALL  POST  GOOD  CALL  POST  OFF'}}
# ['1A']
# ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A']
# ['1B', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B']
# ['7A']
# ['7B']
# ['HOLIDAY 1', 'HOLIDAY 2']
# HOLIDAY 1
# *POST
# 2024-12-20 00:00:00 Holiday 1 MICU-E CALL
# 2024-12-21 00:00:00 Holiday 1 MICU-E POST
# 2024-12-22 00:00:00 Holiday 1 MICU-E OFF
# 2024-12-23 00:00:00 Holiday 1 MICU-E CALL
# 2024-12-24 00:00:00 Holiday 1 MICU-E POST
# 2024-12-25 00:00:00 Holiday 1 MICU-E GOOD
# 2024-12-26 00:00:00 Holiday 1 MICU-E CALL
# 2024-12-27 00:00:00 Holiday 1 MICU-E *POST
# Holiday 2 Off
# [datetime.datetime(2024, 12, 27, 0, 0), datetime.datetime(2024, 12, 28, 0, 0), datetime.datetime(2024, 12, 29, 0, 0), datetime.datetime(2024, 12, 30, 0, 0), datetime.datetime(2024, 12, 31, 0, 0), datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 2, 0, 0)]
# Off
# Z
# {'type1': {'blocks': ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'OFF OFF OFF OFF OFF OFF OFF OFF OFF OFF OFF OFF OFF OFF'}}
# ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2']
# HOLIDAY 2
# OFF
# 2024-12-27 00:00:00 Holiday 2 Off OFF
# 2024-12-28 00:00:00 Holiday 2 Off OFF
# 2024-12-29 00:00:00 Holiday 2 Off OFF
# 2024-12-30 00:00:00 Holiday 2 Off OFF
# 2024-12-31 00:00:00 Holiday 2 Off OFF
# 2025-01-01 00:00:00 Holiday 2 Off OFF
# 2025-01-02 00:00:00 Holiday 2 Off OFF
# 7B Cardiomyopathy-D
# [datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 13, 0, 0)]
# Cardiomyopathy
# D
# {'type1': {'blocks': ['1A'], 'B': 'POST GOOD SHORT CALL  POST  OFF SHORT CALL  *POST', 'D': 'SHORT CALL  POST  GOOD  SHORT CALL  POST  OFF'}, 'type2': {'blocks': ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A'], 'B': 'SHORT CALL  POST  OFF SHORT CALL  POST GOOD SHORT CALL  POST  OFF SHORT CALL *POST', 'D': 'POST GOOD  SHORT CALL  POST  OFF SHORT CALL  POST  GOOD  SHORT CALL  POST  OFF'}, 'type3': {'blocks': ['2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B'], 'B': 'POST  GOOD  SHORT CALL  POST  OFF SHORT CALL  POST  GOOD  SHORT CALL  POST  OFF', 'D': 'SHORT CALL  POST  OFF SHORT CALL  POST GOOD SHORT CALL  POST  OFF SHORT CALL  *POST'}, 'type4': {'blocks': ['7A'], 'B': 'SHORT CALL  POST  OFF SHORT CALL  POST  GOOD  SHORT CALL  *POST', 'D': 'POST  GOOD  SHORT CALL  POST  OFF SHORT CALL  POST  GOOD'}, 'type5': {'blocks': ['7B'], 'B': 'CALL  POST  OFF SHORT CALL  POST  GOOD  SHORT CALL  POST  OFF', 'D': 'OFF SHORT CALL  POST  GOOD  SHORT CALL  POST  OFF SHORT CALL  *POST'}, 'type6': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'B': 'POST  OFF SHORT CALL  POST  GOOD  SHORT', 'D': 'SHORT  CALL  POST  OFF SHORT CALL  POST'}}
# ['1A']
# ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A']
# ['2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B']
# ['7A']
# ['7B']
# 7B
# *POST
# 2025-01-03 00:00:00 7B Cardiomyopathy-D OFF
# 2025-01-04 00:00:00 7B Cardiomyopathy-D SHORT
# 2025-01-05 00:00:00 7B Cardiomyopathy-D CALL
# 2025-01-06 00:00:00 7B Cardiomyopathy-D POST
# 2025-01-07 00:00:00 7B Cardiomyopathy-D GOOD
# 2025-01-08 00:00:00 7B Cardiomyopathy-D SHORT
# 2025-01-09 00:00:00 7B Cardiomyopathy-D CALL
# 2025-01-10 00:00:00 7B Cardiomyopathy-D POST
# 2025-01-11 00:00:00 7B Cardiomyopathy-D OFF
# 2025-01-12 00:00:00 7B Cardiomyopathy-D SHORT
# 2025-01-13 00:00:00 7B Cardiomyopathy-D CALL
# 2025-01-14 00:00:00 7B Cardiomyopathy-D *POST
# 8A CCU-C
# [datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 15, 0, 0), datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 21, 0, 0), datetime.datetime(2025, 1, 22, 0, 0), datetime.datetime(2025, 1, 23, 0, 0), datetime.datetime(2025, 1, 24, 0, 0), datetime.datetime(2025, 1, 25, 0, 0), datetime.datetime(2025, 1, 26, 0, 0), datetime.datetime(2025, 1, 27, 0, 0)]
# CCU
# C
# {'type1': {'blocks': ['1A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD'}, 'type2a': {'blocks': ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST GOOD CALL  POST  OFF CALL  POST  GOOD'}, 'type2b': {'blocks': ['1B', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B'], 'A': 'GOOD  CALL  POST  OFF CALL  POST  GOOD CALL POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'POST  GOOD  CALL  POST  OFF CALL  POST GOOD CALL  POST  OFF CALL  POST  GOOD', 'C': 'CALL  POST  OFF CALL  POST  GOOD  CALL POST OFF CALL  POST  GOOD  CALL  POST'}, 'type4': {'blocks': ['7A'], 'A': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'B': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'C': 'GOOD  CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD'}, 'type5': {'blocks': ['7B'], 'A': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD'}, 'type6': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'GOOD  CALL  POST  GOOD  CALL  POST  GOOD', 'B': 'POST  GOOD  CALL  POST  GOOD  CALL  POST', 'C': 'CALL  POST  GOOD  CALL  POST  GOOD  CALL  *POST'}}
# ['1A']
# ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A']
# 8A
# GOOD
# 2025-01-14 00:00:00 8A CCU-C POST
# 2025-01-15 00:00:00 8A CCU-C GOOD
# 2025-01-16 00:00:00 8A CCU-C CALL
# 2025-01-17 00:00:00 8A CCU-C POST
# 2025-01-18 00:00:00 8A CCU-C OFF
# 2025-01-19 00:00:00 8A CCU-C CALL
# 2025-01-20 00:00:00 8A CCU-C POST
# 2025-01-21 00:00:00 8A CCU-C GOOD
# 2025-01-22 00:00:00 8A CCU-C CALL
# 2025-01-23 00:00:00 8A CCU-C POST
# 2025-01-24 00:00:00 8A CCU-C OFF
# 2025-01-25 00:00:00 8A CCU-C CALL
# 2025-01-26 00:00:00 8A CCU-C POST
# 2025-01-27 00:00:00 8A CCU-C GOOD
# 8B Ambulatory
# [datetime.datetime(2025, 1, 28, 0, 0), datetime.datetime(2025, 1, 29, 0, 0), datetime.datetime(2025, 1, 30, 0, 0), datetime.datetime(2025, 1, 31, 0, 0), datetime.datetime(2025, 2, 1, 0, 0), datetime.datetime(2025, 2, 2, 0, 0), datetime.datetime(2025, 2, 3, 0, 0), datetime.datetime(2025, 2, 4, 0, 0), datetime.datetime(2025, 2, 5, 0, 0), datetime.datetime(2025, 2, 6, 0, 0), datetime.datetime(2025, 2, 7, 0, 0), datetime.datetime(2025, 2, 8, 0, 0), datetime.datetime(2025, 2, 9, 0, 0), datetime.datetime(2025, 2, 10, 0, 0)]
# Ambulatory
# Z
# -
# 2025-01-28 00:00:00 8B Ambulatory DAY
# 2025-01-29 00:00:00 8B Ambulatory DAY
# 2025-01-30 00:00:00 8B Ambulatory DAY
# 2025-01-31 00:00:00 8B Ambulatory DAY
# 2025-02-01 00:00:00 8B Ambulatory OFF
# 2025-02-02 00:00:00 8B Ambulatory OFF
# 2025-02-03 00:00:00 8B Ambulatory DAY
# 2025-02-04 00:00:00 8B Ambulatory DAY
# 2025-02-05 00:00:00 8B Ambulatory DAY
# 2025-02-06 00:00:00 8B Ambulatory DAY
# 2025-02-07 00:00:00 8B Ambulatory DAY
# 2025-02-08 00:00:00 8B Ambulatory OFF
# 2025-02-09 00:00:00 8B Ambulatory OFF
# 2025-02-10 00:00:00 8B Ambulatory DAY
# 9A Vacation
# [datetime.datetime(2025, 2, 11, 0, 0), datetime.datetime(2025, 2, 12, 0, 0), datetime.datetime(2025, 2, 13, 0, 0), datetime.datetime(2025, 2, 14, 0, 0), datetime.datetime(2025, 2, 15, 0, 0), datetime.datetime(2025, 2, 16, 0, 0), datetime.datetime(2025, 2, 17, 0, 0), datetime.datetime(2025, 2, 18, 0, 0), datetime.datetime(2025, 2, 19, 0, 0), datetime.datetime(2025, 2, 20, 0, 0), datetime.datetime(2025, 2, 21, 0, 0), datetime.datetime(2025, 2, 22, 0, 0), datetime.datetime(2025, 2, 23, 0, 0), datetime.datetime(2025, 2, 24, 0, 0)]
# Vacation
# Z
# {'type1': {'blocks': ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION'}}
# ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2']
# 9A
# VACATION
# 2025-02-11 00:00:00 9A Vacation VACATION
# 2025-02-12 00:00:00 9A Vacation VACATION
# 2025-02-13 00:00:00 9A Vacation VACATION
# 2025-02-14 00:00:00 9A Vacation VACATION
# 2025-02-15 00:00:00 9A Vacation VACATION
# 2025-02-16 00:00:00 9A Vacation VACATION
# 2025-02-17 00:00:00 9A Vacation VACATION
# 2025-02-18 00:00:00 9A Vacation VACATION
# 2025-02-19 00:00:00 9A Vacation VACATION
# 2025-02-20 00:00:00 9A Vacation VACATION
# 2025-02-21 00:00:00 9A Vacation VACATION
# 2025-02-22 00:00:00 9A Vacation VACATION
# 2025-02-23 00:00:00 9A Vacation VACATION
# 2025-02-24 00:00:00 9A Vacation VACATION
# 9B MICU-E
# [datetime.datetime(2025, 2, 25, 0, 0), datetime.datetime(2025, 2, 26, 0, 0), datetime.datetime(2025, 2, 27, 0, 0), datetime.datetime(2025, 2, 28, 0, 0), datetime.datetime(2025, 3, 1, 0, 0), datetime.datetime(2025, 3, 2, 0, 0), datetime.datetime(2025, 3, 3, 0, 0), datetime.datetime(2025, 3, 4, 0, 0), datetime.datetime(2025, 3, 5, 0, 0), datetime.datetime(2025, 3, 6, 0, 0), datetime.datetime(2025, 3, 7, 0, 0), datetime.datetime(2025, 3, 8, 0, 0), datetime.datetime(2025, 3, 9, 0, 0), datetime.datetime(2025, 3, 10, 0, 0)]
# MICU
# E
# {'type1': {'blocks': ['1A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF'}, 'type2a': {'blocks': ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'E': 'OFF CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'F': 'GOOD  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF'}, 'type2b': {'blocks': ['1B', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B'], 'A': 'OFF CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'C': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'D': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'E': 'GOOD  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'F': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST'}, 'type3': {'blocks': ['7A'], 'A': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'C': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'D': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'E': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'F': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST'}, 'type4': {'blocks': ['7B'], 'A': 'OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'B': 'POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD', 'C': 'CALL  POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST', 'D': 'GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'E': 'POST  GOOD  CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF', 'F': 'CALL  POST  OFF CALL  POST  GOOD  CALL  POST  OFF CALL  POST'}, 'type5': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'POST  GOOD  CALL  POST  OFF CALL  POST', 'B': 'CALL  POST  GOOD  CALL  POST  OFF CALL  *POST', 'C': 'GOOD  CALL  POST  OFF CALL  POST  GOOD', 'D': 'POST  OFF CALL  POST  GOOD  CALL  POST', 'E': 'CALL  POST  OFF CALL  POST  GOOD  CALL  *POST', 'F': 'DATO  CALL  POST  GOOD  CALL  POST  OFF'}}
# ['1A']
# ['2A', '3A', '4A', '5A', '6A', '8A', '9A', '10A', '11A', '12A', '13A']
# ['1B', '2B', '3B', '4B', '5B', '6B', '8B', '9B', '10B', '11B', '12B', '13B']
# 9B
# OFF
# 2025-02-25 00:00:00 9B MICU-E GOOD
# 2025-02-26 00:00:00 9B MICU-E OFF
# 2025-02-27 00:00:00 9B MICU-E CALL
# 2025-02-28 00:00:00 9B MICU-E POST
# 2025-03-01 00:00:00 9B MICU-E GOOD
# 2025-03-02 00:00:00 9B MICU-E CALL
# 2025-03-03 00:00:00 9B MICU-E POST
# 2025-03-04 00:00:00 9B MICU-E OFF
# 2025-03-05 00:00:00 9B MICU-E CALL
# 2025-03-06 00:00:00 9B MICU-E POST
# 2025-03-07 00:00:00 9B MICU-E GOOD
# 2025-03-08 00:00:00 9B MICU-E CALL
# 2025-03-09 00:00:00 9B MICU-E POST
# 2025-03-10 00:00:00 9B MICU-E OFF
# 10A Barker
# [datetime.datetime(2025, 3, 11, 0, 0), datetime.datetime(2025, 3, 12, 0, 0), datetime.datetime(2025, 3, 13, 0, 0), datetime.datetime(2025, 3, 14, 0, 0), datetime.datetime(2025, 3, 15, 0, 0), datetime.datetime(2025, 3, 16, 0, 0), datetime.datetime(2025, 3, 17, 0, 0), datetime.datetime(2025, 3, 18, 0, 0), datetime.datetime(2025, 3, 19, 0, 0), datetime.datetime(2025, 3, 20, 0, 0), datetime.datetime(2025, 3, 21, 0, 0), datetime.datetime(2025, 3, 22, 0, 0), datetime.datetime(2025, 3, 23, 0, 0), datetime.datetime(2025, 3, 24, 0, 0)]
# FirmSAR
# Z
# {'type1': {'blocks': ['1A'], 'A': 'NEWS OFF OLDS  BOOK  OLDS  NIGHTS  NIGHTS  NIGHTS  *POST', 'B': 'OLDS BOOK NIGHTS  NIGHTS  NIGHTS  NEWS  OFF NEWS', 'C': 'NIGHTS NIGHTS  NEWS  OFF NEWS  OLDS  BOOK  OLDS'}, 'type2': {'blocks': ['1B', '2A', '2B', '3A', '3B'], 'A': 'OLDS  OLDS  BOOK  BOOK  OLDS  NIGHT NIGHT NIGHT NIGHT NIGHTS  NEWS  OFF OFF NEWS', 'B': 'NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NEWS  NEWS OFF  OFF NEWS  OLDS  BOOK  BOOK  OLDS', 'C': 'NEWS  NEWS  OFF OFF NEWS  OLDS  OLDS BOOK BOOK  OLDS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  *POST'}, 'type3_': {'blocks': ['4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B'], 'A': 'OLDS  OLDS  OLDS  OLDS  BOOK  BOOK  OLDS NEWS NEWS  NEWS  NEWS  OFF OFF NEWS', 'B': 'NEWS  NEWS  NEWS  NEWS  OFF OFF NEWS OLDS OLDS  OLDS  OLDS  BOOK  BOOK  OLDS', 'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK OFF/BOOK NEWS/OLDS'}, 'type4_': {'blocks': ['7A'], 'A': 'NEWS  NEWS  NEWS  NEWS  OFF BOOK  OLDS  OLDS  OLDS  OLDS', 'B': 'OLDS  OLDS  OLDS  OLDS  BOOK  OFF NEWS  NEWS  NEWS  NEWS', 'Z': 'NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK BOOK/OFF OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS'}, 'type5_': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'OLDS  OLDS  OLDS  NEWS  NEWS  NEWS  NEWS', 'B': 'NEWS  NEWS  NEWS  OLDS  OLDS  OLDS  OLDS', 'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS'}, 'type6_': {'blocks': ['7B'], 'A': 'NEWS  OFF OFF NEWS  NEWS  OLDS  OLDS  OLDS  BOOK  BOOK  OLDS', 'B': 'OLDS  BOOK  BOOK  OLDS  OLDS  NEWS  NEWS  NEWS  OFF OFF NEWS', 'Z': 'NEWS/OLDS OFF/BOOK OFF/BOOK NEWS/OLDS NEWS/OLDS OLDS/NEWS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS'}}
# ['1A']
# ['1B', '2A', '2B', '3A', '3B']
# ['4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B']
# 10A
# NEWS/OLDS
# 2025-03-11 00:00:00 10A Barker OLDS/NEWS
# 2025-03-12 00:00:00 10A Barker OLDS/NEWS
# 2025-03-13 00:00:00 10A Barker OLDS/NEWS
# 2025-03-14 00:00:00 10A Barker OLDS/NEWS
# 2025-03-15 00:00:00 10A Barker BOOK/OFF
# 2025-03-16 00:00:00 10A Barker BOOK/OFF
# 2025-03-17 00:00:00 10A Barker OLDS/NEWS
# 2025-03-18 00:00:00 10A Barker NEWS/OLDS
# 2025-03-19 00:00:00 10A Barker NEWS/OLDS
# 2025-03-20 00:00:00 10A Barker NEWS/OLDS
# 2025-03-21 00:00:00 10A Barker NEWS/OLDS
# 2025-03-22 00:00:00 10A Barker OFF/BOOK
# 2025-03-23 00:00:00 10A Barker OFF/BOOK
# 2025-03-24 00:00:00 10A Barker NEWS/OLDS
# 10B Ambulatory
# [datetime.datetime(2025, 3, 25, 0, 0), datetime.datetime(2025, 3, 26, 0, 0), datetime.datetime(2025, 3, 27, 0, 0), datetime.datetime(2025, 3, 28, 0, 0), datetime.datetime(2025, 3, 29, 0, 0), datetime.datetime(2025, 3, 30, 0, 0), datetime.datetime(2025, 3, 31, 0, 0), datetime.datetime(2025, 4, 1, 0, 0), datetime.datetime(2025, 4, 2, 0, 0), datetime.datetime(2025, 4, 3, 0, 0), datetime.datetime(2025, 4, 4, 0, 0), datetime.datetime(2025, 4, 5, 0, 0), datetime.datetime(2025, 4, 6, 0, 0), datetime.datetime(2025, 4, 7, 0, 0)]
# Ambulatory
# Z
# -
# 2025-03-25 00:00:00 10B Ambulatory DAY
# 2025-03-26 00:00:00 10B Ambulatory DAY
# 2025-03-27 00:00:00 10B Ambulatory DAY
# 2025-03-28 00:00:00 10B Ambulatory DAY
# 2025-03-29 00:00:00 10B Ambulatory OFF
# 2025-03-30 00:00:00 10B Ambulatory OFF
# 2025-03-31 00:00:00 10B Ambulatory DAY
# 2025-04-01 00:00:00 10B Ambulatory DAY
# 2025-04-02 00:00:00 10B Ambulatory DAY
# 2025-04-03 00:00:00 10B Ambulatory DAY
# 2025-04-04 00:00:00 10B Ambulatory DAY
# 2025-04-05 00:00:00 10B Ambulatory OFF
# 2025-04-06 00:00:00 10B Ambulatory OFF
# 2025-04-07 00:00:00 10B Ambulatory DAY
# 11A CCU-A
# [datetime.datetime(2025, 4, 8, 0, 0), datetime.datetime(2025, 4, 9, 0, 0), datetime.datetime(2025, 4, 10, 0, 0), datetime.datetime(2025, 4, 11, 0, 0), datetime.datetime(2025, 4, 12, 0, 0), datetime.datetime(2025, 4, 13, 0, 0), datetime.datetime(2025, 4, 14, 0, 0), datetime.datetime(2025, 4, 15, 0, 0), datetime.datetime(2025, 4, 16, 0, 0), datetime.datetime(2025, 4, 17, 0, 0), datetime.datetime(2025, 4, 18, 0, 0), datetime.datetime(2025, 4, 19, 0, 0), datetime.datetime(2025, 4, 20, 0, 0), datetime.datetime(2025, 4, 21, 0, 0)]
# CCU
# A
# ...
# Ambulatory
# Z
# -
# 2025-02-25 00:00:00 9B Elective -
# 2025-02-26 00:00:00 9B Elective -
# 2025-02-27 00:00:00 9B Elective -
# 2025-02-28 00:00:00 9B Elective -
# 2025-03-01 00:00:00 9B Elective -
# 2025-03-02 00:00:00 9B Elective -
# 2025-03-03 00:00:00 9B Elective -
# 2025-03-04 00:00:00 9B Elective -
# 2025-03-05 00:00:00 9B Elective -
# 2025-03-06 00:00:00 9B Elective -
# 2025-03-07 00:00:00 9B Elective -
# 2025-03-08 00:00:00 9B Elective -
# 2025-03-09 00:00:00 9B Elective -
# 2025-03-10 00:00:00 9B Elective -
# 10A Ambulatory
# [datetime.datetime(2025, 3, 11, 0, 0), datetime.datetime(2025, 3, 12, 0, 0), datetime.datetime(2025, 3, 13, 0, 0), datetime.datetime(2025, 3, 14, 0, 0), datetime.datetime(2025, 3, 15, 0, 0), datetime.datetime(2025, 3, 16, 0, 0), datetime.datetime(2025, 3, 17, 0, 0), datetime.datetime(2025, 3, 18, 0, 0), datetime.datetime(2025, 3, 19, 0, 0), datetime.datetime(2025, 3, 20, 0, 0), datetime.datetime(2025, 3, 21, 0, 0), datetime.datetime(2025, 3, 22, 0, 0), datetime.datetime(2025, 3, 23, 0, 0), datetime.datetime(2025, 3, 24, 0, 0)]
# Ambulatory
# Z
# -
# 2025-03-11 00:00:00 10A Ambulatory DAY
# 2025-03-12 00:00:00 10A Ambulatory DAY
# 2025-03-13 00:00:00 10A Ambulatory DAY
# 2025-03-14 00:00:00 10A Ambulatory DAY
# 2025-03-15 00:00:00 10A Ambulatory OFF
# 2025-03-16 00:00:00 10A Ambulatory OFF
# 2025-03-17 00:00:00 10A Ambulatory DAY
# 2025-03-18 00:00:00 10A Ambulatory DAY
# 2025-03-19 00:00:00 10A Ambulatory DAY
# 2025-03-20 00:00:00 10A Ambulatory DAY
# 2025-03-21 00:00:00 10A Ambulatory DAY
# 2025-03-22 00:00:00 10A Ambulatory OFF
# 2025-03-23 00:00:00 10A Ambulatory OFF
# 2025-03-24 00:00:00 10A Ambulatory DAY
# 10B Jeopardy
# [datetime.datetime(2025, 3, 25, 0, 0), datetime.datetime(2025, 3, 26, 0, 0), datetime.datetime(2025, 3, 27, 0, 0), datetime.datetime(2025, 3, 28, 0, 0), datetime.datetime(2025, 3, 29, 0, 0), datetime.datetime(2025, 3, 30, 0, 0), datetime.datetime(2025, 3, 31, 0, 0), datetime.datetime(2025, 4, 1, 0, 0), datetime.datetime(2025, 4, 2, 0, 0), datetime.datetime(2025, 4, 3, 0, 0), datetime.datetime(2025, 4, 4, 0, 0), datetime.datetime(2025, 4, 5, 0, 0), datetime.datetime(2025, 4, 6, 0, 0), datetime.datetime(2025, 4, 7, 0, 0)]
# Jeopardy
# Z
# {'type1': {'blocks': ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY'}}
# ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2']
# 10B
# JEOPARDY
# 2025-03-25 00:00:00 10B Jeopardy JEOPARDY
# 2025-03-26 00:00:00 10B Jeopardy JEOPARDY
# 2025-03-27 00:00:00 10B Jeopardy JEOPARDY
# 2025-03-28 00:00:00 10B Jeopardy JEOPARDY
# 2025-03-29 00:00:00 10B Jeopardy JEOPARDY
# 2025-03-30 00:00:00 10B Jeopardy JEOPARDY
# 2025-03-31 00:00:00 10B Jeopardy JEOPARDY
# 2025-04-01 00:00:00 10B Jeopardy JEOPARDY
# 2025-04-02 00:00:00 10B Jeopardy JEOPARDY
# 2025-04-03 00:00:00 10B Jeopardy JEOPARDY
# 2025-04-04 00:00:00 10B Jeopardy JEOPARDY
# 2025-04-05 00:00:00 10B Jeopardy JEOPARDY
# 2025-04-06 00:00:00 10B Jeopardy JEOPARDY
# 2025-04-07 00:00:00 10B Jeopardy JEOPARDY
# 11A Jeopardy
# [datetime.datetime(2025, 4, 8, 0, 0), datetime.datetime(2025, 4, 9, 0, 0), datetime.datetime(2025, 4, 10, 0, 0), datetime.datetime(2025, 4, 11, 0, 0), datetime.datetime(2025, 4, 12, 0, 0), datetime.datetime(2025, 4, 13, 0, 0), datetime.datetime(2025, 4, 14, 0, 0), datetime.datetime(2025, 4, 15, 0, 0), datetime.datetime(2025, 4, 16, 0, 0), datetime.datetime(2025, 4, 17, 0, 0), datetime.datetime(2025, 4, 18, 0, 0), datetime.datetime(2025, 4, 19, 0, 0), datetime.datetime(2025, 4, 20, 0, 0), datetime.datetime(2025, 4, 21, 0, 0)]
# Jeopardy
# Z
# {'type1': {'blocks': ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY'}}
# ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2']
# 11A
# JEOPARDY
# 2025-04-08 00:00:00 11A Jeopardy JEOPARDY
# 2025-04-09 00:00:00 11A Jeopardy JEOPARDY
# 2025-04-10 00:00:00 11A Jeopardy JEOPARDY
# 2025-04-11 00:00:00 11A Jeopardy JEOPARDY
# 2025-04-12 00:00:00 11A Jeopardy JEOPARDY
# 2025-04-13 00:00:00 11A Jeopardy JEOPARDY
# 2025-04-14 00:00:00 11A Jeopardy JEOPARDY
# 2025-04-15 00:00:00 11A Jeopardy JEOPARDY
# 2025-04-16 00:00:00 11A Jeopardy JEOPARDY
# 2025-04-17 00:00:00 11A Jeopardy JEOPARDY
# 2025-04-18 00:00:00 11A Jeopardy JEOPARDY
# 2025-04-19 00:00:00 11A Jeopardy JEOPARDY
# 2025-04-20 00:00:00 11A Jeopardy JEOPARDY
# 2025-04-21 00:00:00 11A Jeopardy JEOPARDY
# 11B Vacation
# [datetime.datetime(2025, 4, 22, 0, 0), datetime.datetime(2025, 4, 23, 0, 0), datetime.datetime(2025, 4, 24, 0, 0), datetime.datetime(2025, 4, 25, 0, 0), datetime.datetime(2025, 4, 26, 0, 0), datetime.datetime(2025, 4, 27, 0, 0), datetime.datetime(2025, 4, 28, 0, 0), datetime.datetime(2025, 4, 29, 0, 0), datetime.datetime(2025, 4, 30, 0, 0), datetime.datetime(2025, 5, 1, 0, 0), datetime.datetime(2025, 5, 2, 0, 0), datetime.datetime(2025, 5, 3, 0, 0), datetime.datetime(2025, 5, 4, 0, 0), datetime.datetime(2025, 5, 5, 0, 0)]
# Vacation
# Z
# {'type1': {'blocks': ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION VACATION'}}
# ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2']
# 11B
# VACATION
# 2025-04-22 00:00:00 11B Vacation VACATION
# 2025-04-23 00:00:00 11B Vacation VACATION
# 2025-04-24 00:00:00 11B Vacation VACATION
# 2025-04-25 00:00:00 11B Vacation VACATION
# 2025-04-26 00:00:00 11B Vacation VACATION
# 2025-04-27 00:00:00 11B Vacation VACATION
# 2025-04-28 00:00:00 11B Vacation VACATION
# 2025-04-29 00:00:00 11B Vacation VACATION
# 2025-04-30 00:00:00 11B Vacation VACATION
# 2025-05-01 00:00:00 11B Vacation VACATION
# 2025-05-02 00:00:00 11B Vacation VACATION
# 2025-05-03 00:00:00 11B Vacation VACATION
# 2025-05-04 00:00:00 11B Vacation VACATION
# 2025-05-05 00:00:00 11B Vacation VACATION
# 12A Ambulatory
# [datetime.datetime(2025, 5, 6, 0, 0), datetime.datetime(2025, 5, 7, 0, 0), datetime.datetime(2025, 5, 8, 0, 0), datetime.datetime(2025, 5, 9, 0, 0), datetime.datetime(2025, 5, 10, 0, 0), datetime.datetime(2025, 5, 11, 0, 0), datetime.datetime(2025, 5, 12, 0, 0), datetime.datetime(2025, 5, 13, 0, 0), datetime.datetime(2025, 5, 14, 0, 0), datetime.datetime(2025, 5, 15, 0, 0), datetime.datetime(2025, 5, 16, 0, 0), datetime.datetime(2025, 5, 17, 0, 0), datetime.datetime(2025, 5, 18, 0, 0), datetime.datetime(2025, 5, 19, 0, 0)]
# Ambulatory
# Z
# -
# 2025-05-06 00:00:00 12A Ambulatory DAY
# 2025-05-07 00:00:00 12A Ambulatory DAY
# 2025-05-08 00:00:00 12A Ambulatory DAY
# 2025-05-09 00:00:00 12A Ambulatory DAY
# 2025-05-10 00:00:00 12A Ambulatory OFF
# 2025-05-11 00:00:00 12A Ambulatory OFF
# 2025-05-12 00:00:00 12A Ambulatory DAY
# 2025-05-13 00:00:00 12A Ambulatory DAY
# 2025-05-14 00:00:00 12A Ambulatory DAY
# 2025-05-15 00:00:00 12A Ambulatory DAY
# 2025-05-16 00:00:00 12A Ambulatory DAY
# 2025-05-17 00:00:00 12A Ambulatory OFF
# 2025-05-18 00:00:00 12A Ambulatory OFF
# 2025-05-19 00:00:00 12A Ambulatory DAY
# 12B Jeopardy
# [datetime.datetime(2025, 5, 20, 0, 0), datetime.datetime(2025, 5, 21, 0, 0), datetime.datetime(2025, 5, 22, 0, 0), datetime.datetime(2025, 5, 23, 0, 0), datetime.datetime(2025, 5, 24, 0, 0), datetime.datetime(2025, 5, 25, 0, 0), datetime.datetime(2025, 5, 26, 0, 0), datetime.datetime(2025, 5, 27, 0, 0), datetime.datetime(2025, 5, 28, 0, 0), datetime.datetime(2025, 5, 29, 0, 0), datetime.datetime(2025, 5, 30, 0, 0), datetime.datetime(2025, 5, 31, 0, 0), datetime.datetime(2025, 6, 1, 0, 0), datetime.datetime(2025, 6, 2, 0, 0)]
# Jeopardy
# Z
# {'type1': {'blocks': ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2'], 'Z': 'JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY JEOPARDY'}}
# ['1A', '2A', '3A', '4A', '5A', '6A', '7A', '8A', '9A', '10A', '11A', '12A', '13A', '1B', '2B', '3B', '4B', '5B', '6B', '7B', '8B', '9B', '10B', '11B', '12B', '13B', 'HOLIDAY 1', 'HOLIDAY 2']
# 12B
# JEOPARDY
# 2025-05-20 00:00:00 12B Jeopardy JEOPARDY
# 2025-05-21 00:00:00 12B Jeopardy JEOPARDY
# 2025-05-22 00:00:00 12B Jeopardy JEOPARDY
# 2025-05-23 00:00:00 12B Jeopardy JEOPARDY
# 2025-05-24 00:00:00 12B Jeopardy JEOPARDY
# 2025-05-25 00:00:00 12B Jeopardy JEOPARDY
# 2025-05-26 00:00:00 12B Jeopardy JEOPARDY
# 2025-05-27 00:00:00 12B Jeopardy JEOPARDY
# 2025-05-28 00:00:00 12B Jeopardy JEOPARDY
# 2025-05-29 00:00:00 12B Jeopardy JEOPARDY
# 2025-05-30 00:00:00 12B Jeopardy JEOPARDY
# 2025-05-31 00:00:00 12B Jeopardy JEOPARDY
# 2025-06-01 00:00:00 12B Jeopardy JEOPARDY
# 2025-06-02 00:00:00 12B Jeopardy JEOPARDY
# 13A Brancati
# [datetime.datetime(2025, 6, 3, 0, 0), datetime.datetime(2025, 6, 4, 0, 0), datetime.datetime(2025, 6, 5, 0, 0), datetime.datetime(2025, 6, 6, 0, 0), datetime.datetime(2025, 6, 7, 0, 0), datetime.datetime(2025, 6, 8, 0, 0), datetime.datetime(2025, 6, 9, 0, 0), datetime.datetime(2025, 6, 10, 0, 0), datetime.datetime(2025, 6, 11, 0, 0), datetime.datetime(2025, 6, 12, 0, 0), datetime.datetime(2025, 6, 13, 0, 0), datetime.datetime(2025, 6, 14, 0, 0), datetime.datetime(2025, 6, 15, 0, 0), datetime.datetime(2025, 6, 16, 0, 0)]
# Brancati
# Z
# {'type1': {'blocks': ['1A'], 'A': 'NEWS OFF  OLDS  BOOK  OLDS  NIGHTS  NIGHTS  NIGHTS  *POST', 'B': 'BOOK  NIGHTS  NIGHTS  NIGHTS  NEWS^ OFF NEWS', 'C': 'NIGHTS  NEWS^  OFF NEWS  OLDS  BOOK  OLDS'}, 'type2': {'blocks': ['1B', '2A', '2B', '3A', '3B'], 'A': 'DAYS  DAYS  DAYS  DAYS  BOOK  BOOK  NIGHTS NIGHTS NIGHTS  NIGHTS  NEWS^  OFF OFF DAYS', 'B': 'NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NEWS^ OFF OFF DAYS  DAYS  BOOK  BOOK  DAYS', 'C': 'DAYS  DAYS  DAYS  DAYS  OFF OFF DAYS BOOK BOOK  DAYS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  *POST'}, 'type3_': {'blocks': ['4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B'], 'A': 'OLDS  OLDS  OLDS  OLDS  BOOK  BOOK  OLDS NEWS NEWS  NEWS  NEWS  OFF OFF NEWS', 'B': 'NEWS  NEWS  NEWS  NEWS  OFF OFF NEWS OLDS OLDS  OLDS  OLDS  BOOK  BOOK  OLDS', 'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK OFF/BOOK NEWS/OLDS'}, 'type4_': {'blocks': ['7A'], 'A': 'NEWS  NEWS  NEWS  NEWS  OFF BOOK  OLDS  OLDS  OLDS  OLDS', 'B': 'OLDS  OLDS  OLDS  OLDS  BOOK  OFF NEWS  NEWS  NEWS  NEWS', 'Z': 'NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK BOOK/OFF OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS'}, 'type5_': {'blocks': ['7B'], 'A': 'NEWS  OFF OFF NEWS  NEWS  OLDS  OLDS  OLDS  BOOK  BOOK  OLDS', 'B': 'OLDS  BOOK  BOOK  OLDS  OLDS  NEWS  NEWS  NEWS  OFF OFF NEWS', 'Z': 'NEWS/OLDS OFF/BOOK OFF/BOOK NEWS/OLDS NEWS/OLDS OLDS/NEWS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS'}, 'type6_': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'OLDS  OLDS  OLDS  NEWS  NEWS  NEWS  NEWS', 'B': 'NEWS  NEWS  NEWS  OLDS  OLDS  OLDS  OLDS', 'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS'}}
# ['1A']
# ['1B', '2A', '2B', '3A', '3B']
# ['4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B']
# 13A
# NEWS/OLDS
# 2025-06-03 00:00:00 13A Brancati OLDS/NEWS
# 2025-06-04 00:00:00 13A Brancati OLDS/NEWS
# 2025-06-05 00:00:00 13A Brancati OLDS/NEWS
# 2025-06-06 00:00:00 13A Brancati OLDS/NEWS
# 2025-06-07 00:00:00 13A Brancati BOOK/OFF
# 2025-06-08 00:00:00 13A Brancati BOOK/OFF
# 2025-06-09 00:00:00 13A Brancati OLDS/NEWS
# 2025-06-10 00:00:00 13A Brancati NEWS/OLDS
# 2025-06-11 00:00:00 13A Brancati NEWS/OLDS
# 2025-06-12 00:00:00 13A Brancati NEWS/OLDS
# 2025-06-13 00:00:00 13A Brancati NEWS/OLDS
# 2025-06-14 00:00:00 13A Brancati OFF/BOOK
# 2025-06-15 00:00:00 13A Brancati OFF/BOOK
# 2025-06-16 00:00:00 13A Brancati NEWS/OLDS
# 13B Janeway
# [datetime.datetime(2025, 6, 17, 0, 0), datetime.datetime(2025, 6, 18, 0, 0), datetime.datetime(2025, 6, 19, 0, 0), datetime.datetime(2025, 6, 20, 0, 0), datetime.datetime(2025, 6, 21, 0, 0), datetime.datetime(2025, 6, 22, 0, 0), datetime.datetime(2025, 6, 23, 0, 0), datetime.datetime(2025, 6, 24, 0, 0), datetime.datetime(2025, 6, 25, 0, 0), datetime.datetime(2025, 6, 26, 0, 0), datetime.datetime(2025, 6, 27, 0, 0), datetime.datetime(2025, 6, 28, 0, 0), datetime.datetime(2025, 6, 29, 0, 0), datetime.datetime(2025, 6, 30, 0, 0)]
# FirmSAR
# Z
# {'type1': {'blocks': ['1A'], 'A': 'NEWS OFF OLDS  BOOK  OLDS  NIGHTS  NIGHTS  NIGHTS  *POST', 'B': 'OLDS BOOK NIGHTS  NIGHTS  NIGHTS  NEWS  OFF NEWS', 'C': 'NIGHTS NIGHTS  NEWS  OFF NEWS  OLDS  BOOK  OLDS'}, 'type2': {'blocks': ['1B', '2A', '2B', '3A', '3B'], 'A': 'OLDS  OLDS  BOOK  BOOK  OLDS  NIGHT NIGHT NIGHT NIGHT NIGHTS  NEWS  OFF OFF NEWS', 'B': 'NIGHTS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  NEWS  NEWS OFF  OFF NEWS  OLDS  BOOK  BOOK  OLDS', 'C': 'NEWS  NEWS  OFF OFF NEWS  OLDS  OLDS BOOK BOOK  OLDS  NIGHTS  NIGHTS  NIGHTS  NIGHTS  *POST'}, 'type3_': {'blocks': ['4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B'], 'A': 'OLDS  OLDS  OLDS  OLDS  BOOK  BOOK  OLDS NEWS NEWS  NEWS  NEWS  OFF OFF NEWS', 'B': 'NEWS  NEWS  NEWS  NEWS  OFF OFF NEWS OLDS OLDS  OLDS  OLDS  BOOK  BOOK  OLDS', 'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK OFF/BOOK NEWS/OLDS'}, 'type4_': {'blocks': ['7A'], 'A': 'NEWS  NEWS  NEWS  NEWS  OFF BOOK  OLDS  OLDS  OLDS  OLDS', 'B': 'OLDS  OLDS  OLDS  OLDS  BOOK  OFF NEWS  NEWS  NEWS  NEWS', 'Z': 'NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS OFF/BOOK BOOK/OFF OLDS/NEWS OLDS/NEWS OLDS/NEWS OLDS/NEWS'}, 'type5_': {'blocks': ['HOLIDAY 1', 'HOLIDAY 2'], 'A': 'OLDS  OLDS  OLDS  NEWS  NEWS  NEWS  NEWS', 'B': 'NEWS  NEWS  NEWS  OLDS  OLDS  OLDS  OLDS', 'Z': 'OLDS/NEWS OLDS/NEWS OLDS/NEWS NEWS/OLDS NEWS/OLDS NEWS/OLDS NEWS/OLDS'}, 'type6_': {'blocks': ['7B'], 'A': 'NEWS  OFF OFF NEWS  NEWS  OLDS  OLDS  OLDS  BOOK  BOOK  OLDS', 'B': 'OLDS  BOOK  BOOK  OLDS  OLDS  NEWS  NEWS  NEWS  OFF OFF NEWS', 'Z': 'NEWS/OLDS OFF/BOOK OFF/BOOK NEWS/OLDS NEWS/OLDS OLDS/NEWS OLDS/NEWS OLDS/NEWS BOOK/OFF BOOK/OFF OLDS/NEWS'}}
# ['1A']
# ['1B', '2A', '2B', '3A', '3B']
# ['4A', '4B', '5A', '5B', '6A', '6B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B']
# 13B
# NEWS/OLDS
# 2025-06-17 00:00:00 13B Janeway OLDS/NEWS
# 2025-06-18 00:00:00 13B Janeway OLDS/NEWS
# 2025-06-19 00:00:00 13B Janeway OLDS/NEWS
# 2025-06-20 00:00:00 13B Janeway OLDS/NEWS
# 2025-06-21 00:00:00 13B Janeway BOOK/OFF
# 2025-06-22 00:00:00 13B Janeway BOOK/OFF
# 2025-06-23 00:00:00 13B Janeway OLDS/NEWS
# 2025-06-24 00:00:00 13B Janeway NEWS/OLDS
# 2025-06-25 00:00:00 13B Janeway NEWS/OLDS
# 2025-06-26 00:00:00 13B Janeway NEWS/OLDS
# 2025-06-27 00:00:00 13B Janeway NEWS/OLDS
# 2025-06-28 00:00:00 13B Janeway OFF/BOOK
# 2025-06-29 00:00:00 13B Janeway OFF/BOOK
# 2025-06-30 00:00:00 13B Janeway NEWS/OLDS
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
