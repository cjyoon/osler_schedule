# %%
import icalendar
import pytz, zoneinfo, dateutil.tz  # timezone libraries
import datetime, icalendar
import pyaml
import pandas as pd 
import numpy as np
import yaml
from datetime import datetime, timedelta
import re
from ics import Calendar, Event

# %%
def convert_datestring (datestring):
    format = "%m/%d/%Y"
    date_object = datetime.strptime(datestring, format)
    return date_object


def get_start_end_dates(block_id, my_dict):
    start, end = (my_dict['block_dates'][block_id].split())
    start = convert_datestring(start)
    end = convert_datestring(end)
    return start, end


def date_lists(start_date, end_date):
    current_date = start_date
    dates = []
    while current_date <= end_date:
        dates.append(current_date)
        current_date += timedelta(days=1)
    return dates
    
    
def get_specific_rotation_schedule(block_id, rotation, my_dict):
    rotation = re.sub('\s', '', rotation)
    

        
    try:
        rotation, individual = rotation.split('-')
        individual = individual[0] # gets the first character of an individual (A, B, C, D, E, F etc.)
    except:
        rotation = rotation
        individual = 'A'
        
    if re.search('Janeway|Barker|Longcope|Thayer', rotation):
        rotation_category = 'O'    
    elif re.search('CJ|Polk|MEG', rotation):
        rotation_category = 'Subspecialty'    
        
    elif re.search('PCCU|Addiction', rotation):
        # these rotation have MTWTF rotation with weekends off
        rotation_category = 'Ambulatory'
    else:
        rotation_category = rotation
        
    for schedule_type, schedule in my_dict[rotation_category].items():
        if block_id in schedule['blocks']:
            return schedule[individual].split()
        
        
        
def block_dates (block_id, my_dict):
    """get start and end date for each block by going through the master yaml """
    start_date, end_date = (get_start_end_dates(block_id, my_dict))
    block_duration = date_lists(start_date, end_date)    
    return block_duration
 

def add_date_postcall_into_next_block(call_cycle, block_days):
    print(call_cycle[-1])
    if re.search(r'^\*', call_cycle[-1]):
        # Step 1: Get the last date in the list
        last_date = block_days[-1]

        # Step 2: Calculate the next date (assuming consecutive days, so add 1 day)
        next_date = last_date + timedelta(days=1)

        # Step 3: Add the new date to the list
        block_days.append(next_date)
    return block_days
    



def oncology_schedule(rotation, date):
    if rotation== 'Subspecialty': # if subspecialty rotation, default is 'nights'
        schedule = 'NIGHT'
    else:
        schedule = 'DAY'
    
    if date.weekday() == 6 and rotation in ['Solids', 'MTL', 'Leuks']: #off day is Sunday
        schedule = 'OFF'
    elif date.weekday() == 5 and rotation in ['Ambulatory', 'UCM', 'AddictionMedicine', 'Psych']: #ambo off day is Saturday and Sunday
        schedule = 'OFF'   
    elif date.weekday() == 6 and rotation in ['Ambulatory', 'UCM', 'AddictionMedicine', 'Psych']: #ambo off day is Saturday and Sunday
        schedule = 'OFF'
    elif date.weekday() == 6 and rotation == 'Subspecialty': # subspecialty intern off on Sunday
        schedule = 'OFF'
    else:
        pass
    
    return schedule

# %%
# Read master tables

    
with open("/Users/cjyoon/Dropbox/Osler/Osler_shiny/intern/call_schedule_master.yaml") as f:
    my_dict = yaml.safe_load(f)

    
master_schedule = pd.read_excel('/Users/cjyoon/Dropbox/Osler/Osler_shiny/intern/Intern Schedule 2024-2025.xlsx', sheet_name='Schedule')
resident_names = master_schedule.iloc[:, 0].to_list()
series = pd.Series(resident_names)

# Remove NaN values
cleaned_series = series.dropna()

# Convert back to a list
resident_names = cleaned_series.tolist()
print(resident_names)
# Out:
# ['Holler_Albert', 'Weinstein_Robert', 'Littman_Emily', 'Rao_Rohit', 'Mathias_Trevor', 'Carter_Julia', 'Reddy_Tina', 'Fatteh_Maria', 'Kim_Minjoo', 'Mollenkopf_Sarah', 'Tracey_Evan', 'Alexander_Mathew', 'Bothwell_James', 'Ermolovich_Jake', 'Payne_Lauren', 'Ancha_Bhavya', 'Kodukula_Sai', 'Yeudall_Scott', 'OPH_Pan-Doh_Nathan', 'OPH_Shah_Rohan', 'Arahirwa_Victor', 'ED_CCU', 'Chabaan_Lara', 'Suresh_Abhilash', 'Riddick_Erica', 'Ye_Congxie', 'Yoon_Christopher', 'Kesaf_Ayse', 'Mhaimeed_Nour', 'Potharazu_Archit', 'Clinton_Ivor', 'Lopez-Silva_Carolina', 'Ozkan_Bige', 'ED_MICU_2', 'Morcos_George', 'Kuzma_Irena', 'ED_MICU', 'Cazimir_Catherine', 'Lopez_Christina', 'Guo_Matthew', 'Bullock_Avery', 'Pazzi_Carlotta', 'Broshkevitch_Anna', 'Lutz_Lydia', 'Rodriguez-Fernandez_Monica', 'Moore_Erica', 'Murphy_Cara', 'Goren_Lea', 'Chang_Michael', 'Jabboure_Fayez', 'Vasoya_Roshan', 'Tarasco_Alexander', 'Koul_Kayshap', 'Khunsriraksakul_Chachrit', 'Zarker_Andrew', 'Ziogos_Timos', 'OPH_Ali_Muhammad', 'OPH_Morello_Tim', 'OPH_Kim_Suzie', 'ED_CCU_2']

# %%
def get_schedule(resident_name, master_schedule):
    """gets the specific intern's schedule from the table"""
    filtered_df = master_schedule[master_schedule.iloc[:, 0] == resident_name]
    return (filtered_df.squeeze().to_list()[1:])

# %%
new_column_names = [
    f"{col} {master_schedule.iloc[0, idx].strftime('%m/%d/%y')}-{master_schedule.iloc[1, idx].strftime('%m/%d/%y')}"
    if not isinstance(master_schedule.iloc[0, idx], float) and not isinstance(master_schedule.iloc[1, idx], float) 
    else f"{col}"
    for idx, col in enumerate(master_schedule.columns) if not isinstance(col, float)
]

# Update the column names in the DataFrame
master_schedule.columns = new_column_names
print(new_column_names)


master_table_tsv = master_schedule.iloc[3:].fillna('')
master_table_tsv.columns.values[0] = 'name'
master_table_tsv.replace("Subspecialty", "NightWatch", inplace=True)

master_table_tsv.sort_values('name').to_csv('/Users/cjyoon/Dropbox/Osler/Osler_shiny/block_schedule/intern_block_view.tsv', sep='\t', index=False)
# Out:
# ['Unnamed: 0', '1A 07/01/24-07/10/24', '1B 07/11/24-07/24/24', '2A 07/25/24-08/07/24', '2B 08/08/24-08/21/24', '3A 08/22/24-09/04/24', '3B 09/05/24-09/18/24', '4A 09/19/24-10/02/24', '4B 10/03/24-10/16/24', '5A 10/17/24-10/30/24', '5B 10/31/24-11/13/24', '6A 11/14/24-11/27/24', '6B 11/28/24-12/11/24', '7A 12/12/24-12/19/24', 'HOLIDAY 1 12/20/24-12/26/24', 'HOLIDAY 2 12/27/24-01/02/25', '7B 01/03/25-01/15/25', '8A 01/16/25-01/29/25', '8B 01/30/25-02/12/25', '9A 02/13/25-02/26/25', '9B 02/27/25-03/12/25', '10A 03/13/25-03/26/25', '10B 03/27/25-04/09/25', '11A 04/10/25-04/23/25', '11B 04/24/25-05/07/25', '12A 05/08/25-05/21/25', '12B 05/22/25-06/04/25', '13A 06/05/25-06/18/25', '13B 06/19/25-06/30/23']

# %%
master_table_tsv.sort_values('name')
# Out:
#                           name 1A 07/01/24-07/10/24   1B 07/11/24-07/24/24  \
# 58
# 13            Alexander_Mathew           Ambulatory               MICU - F
# 17                Ancha_Bhavya              MPC - C           Brancati - D
# 22             Arahirwa_Victor           Thayer - D             Thayer - D
# 14              Bothwell_James              CCU - A             Ambulatory
# 44           Broshkevitch_Anna                 Peds                   Peds
# 42               Bullock_Avery           Thayer - B             Thayer - B
# 7                 Carter_Julia           Ambulatory                 Solids
# 39           Cazimir_Catherine               Solids               MICU - A
# 24                Chabaan_Lara          Liver (MEG)             Ambulatory
# 50               Chang_Michael           Thayer - C             Thayer - C
# 32                Clinton_Ivor                Leuks              Pulm (CJ)
# 23                      ED_CCU
# 62                    ED_CCU_2
# 38                     ED_MICU
# 35                   ED_MICU_2
# 15             Ermolovich_Jake           Barker - A             Barker - A
# 9                 Fatteh_Maria           Ambulatory                MPC - A
# 49                   Goren_Lea         Brancati - B             Ambulatory
# 41                 Guo_Matthew         Brancati - A             Ambulatory
# 51              Jabboure_Fayez             MICU - D           Brancati - B
# 29                  Kesaf_Ayse           NightWatch             Ambulatory
# 55    Khunsriraksakul_Chachrit                  MTL             Ambulatory
# 10                  Kim_Minjoo           Ambulatory               MICU - B
# 18                Kodukula_Sai             MICU - B       Gen Cards (PCCU)
# 54                Koul_Kayshap              MPC - B             Ambulatory
# 37                 Kuzma_Irena              CCU - B             Ambulatory
# 4                Littman_Emily           Ambulatory                CCU - B
# 33        Lopez-Silva_Carolina             MICU - E                    MTL
# 40             Lopez_Christina             MICU - F              MP Clinic
# 45                  Lutz_Lydia                 Peds                   Peds
# 6               Mathias_Trevor           Ambulatory           Longcope - B
# 30               Mhaimeed_Nour         Longcope - A           Longcope - A
# 11            Mollenkopf_Sarah           Ambulatory                CCU - A
# 47                 Moore_Erica           Thayer - A             Thayer - A
# 36               Morcos_George              CCU - C             Ambulatory
# 48                 Murphy_Cara           Barker - B             Barker - B
# 59            OPH_Ali_Muhammad                                Brancati - C
# 61               OPH_Kim_Suzie         Brancati - D
# 60             OPH_Morello_Tim         Brancati - C
# 20          OPH_Pan-Doh_Nathan
# 21              OPH_Shah_Rohan                                Brancati - A
# 34                  Ozkan_Bige          Janeway - A            Janeway - A
# 16                Payne_Lauren           Barker - D             Barker - D
# 43              Pazzi_Carlotta             MICU - C                  Leuks
# 31            Potharazu_Archit         Longcope - D           Longcope - D
# 5                    Rao_Rohit           Ambulatory               MICU - C
# 8                   Reddy_Tina           Ambulatory                CCU - C
# 26               Riddick_Erica            MP Clinic               MICU - E
# 46  Rodriguez-Fernandez_Monica         Longcope - B             Ambulatory
# 25             Suresh_Abhilash          Janeway - C            Janeway - C
# 53           Tarasco_Alexander          Janeway - B            Janeway - B
# 12                 Tracey_Evan           Ambulatory             NightWatch
# 52               Vasoya_Roshan              MPC - A  MPC - A / Liver (MEG)
# 3             Weinstein_Robert           Ambulatory               MICU - D
# 27                  Ye_Congxie             MICU - A             Ambulatory
# 19               Yeudall_Scott           Barker - C             Barker - C
# 28            Yoon_Christopher          Janeway - D            Janeway - D
# 56               Zarker_Andrew         Longcope - C           Longcope - C
# 57                Ziogos_Timos            Pulm (CJ)                MPC - B
#
#    2A 07/25/24-08/07/24 2B 08/08/24-08/21/24 3A 08/22/24-09/04/24  \
# 58  2024-07-29 00:00:00                       2024-08-25 00:00:00
# 13           Thayer - C           Thayer - C           Ambulatory
# 17           Ambulatory             MICU - D           Barker - D
# 22           Ambulatory         Brancati - B             MICU - B
# 14           Barker - B           Barker - B              MPC - A
# 44                 Peds            MP Clinic           Barker - B
# 42             MICU - A           Ambulatory             Vacation
# 7          Longcope - D         Longcope - D           Ambulatory
# 39           Ambulatory           NightWatch          Janeway - D
# 24         Longcope - A         Longcope - A             Vacation
# 50           Ambulatory             MICU - E           Thayer - D
# 32           Ambulatory         Longcope - B         Longcope - B
# 23              CCU - B              CCU - C              CCU - A
# 62
# 38             MICU - E             MICU - F             MICU - D
# 35
# 15              MPC - C           Ambulatory               Solids
# 9           Janeway - C          Janeway - C           Ambulatory
# 49           Thayer - A           Thayer - A             MICU - E
# 41           Thayer - B           Thayer - B              MPC - B
# 51          Liver (MEG)           Ambulatory           Thayer - A
# 29           Barker - A           Barker - A              CCU - C
# 55                Leuks              MPC - B             Vacation
# 10           Barker - C           Barker - C           Ambulatory
# 18             MICU - D           Ambulatory         Longcope - C
# 54         Brancati - D              CCU - B          Janeway - C
# 37          Janeway - A          Janeway - A             MICU - A
# 4            NightWatch                  MTL           Ambulatory
# 33              MPC - A           Ambulatory         Longcope - A
# 40         Longcope - C         Longcope - C                 Peds
# 45            MP Clinic                 Peds           Thayer - B
# 6          Longcope - B             MICU - B           Ambulatory
# 30             MICU - B           Ambulatory             Vacation
# 11           Thayer - D           Thayer - D           Ambulatory
# 47              MPC - B           Ambulatory             MICU - C
# 36         Brancati - A                Leuks              MPC - C
# 48             MICU - F           Ambulatory                  MTL
# 59
# 61
# 60                                                   Brancati - A
# 20                                                   Brancati - C
# 21
# 34             MICU - C           Ambulatory                Leuks
# 16           Ambulatory         Brancati - A           Barker - C
# 43            Pulm (CJ)           Ambulatory           Barker - A
# 31           Ambulatory              MPC - A             Vacation
# 5                   MTL             Vacation           Ambulatory
# 8          Brancati - C             Vacation           Ambulatory
# 26          Janeway - B          Janeway - B                 Peds
# 46              CCU - C         Brancati - D         Longcope - D
# 25     Gen Cards (PCCU)           Ambulatory              CCU - B
# 53              CCU - A           Ambulatory          Janeway - B
# 12               Solids              CCU - A           Ambulatory
# 52           Ambulatory             Vacation           Thayer - C
# 3           Janeway - D          Janeway - D           Ambulatory
# 27         Brancati - B              MPC - C           NightWatch
# 19           Ambulatory             MICU - A         Brancati - B
# 28           Ambulatory               Solids             MICU - F
# 56           Ambulatory             MICU - C         Brancati - D
# 57           Ambulatory         Brancati - C          Janeway - A
#
#    3B 09/05/24-09/18/24 4A 09/19/24-10/02/24 4B 10/03/24-10/16/24  \
# 58                       2024-09-22 00:00:00
# 13         Brancati - B             Vacation           NightWatch
# 17           Barker - D           Ambulatory               Solids
# 22             Vacation           Ambulatory           Thayer - B
# 14           Ambulatory                  MTL             Vacation
# 44           Barker - B             MICU - B            MP Clinic
# 42                  MTL           Thayer - B           Ambulatory
# 7              MICU - C         Brancati - D              CCU - C
# 39          Janeway - D           Ambulatory              CCU - A
# 24           Ambulatory         Longcope - C         Longcope - C
# 50           Thayer - D           Ambulatory           Thayer - D
# 32              MPC - C           Ambulatory         Longcope - B
# 23              CCU - B              CCU - A              CCU - B
# 62
# 38             MICU - E             MICU - D             MICU - E
# 35
# 15             Vacation             MICU - A           Ambulatory
# 9               CCU - C           NightWatch             MICU - A
# 49           Ambulatory           Thayer - D             Vacation
# 41           Ambulatory           Thayer - C           Thayer - C
# 51           Thayer - A              MPC - A           Ambulatory
# 29           Ambulatory             MICU - C             Vacation
# 55           Ambulatory         Longcope - A         Longcope - A
# 10              CCU - A           Barker - D           Barker - D
# 18         Longcope - C              MPC - B           Ambulatory
# 54           Ambulatory          Janeway - D          Janeway - D
# 37           Ambulatory             Vacation         Brancati - D
# 4              Vacation           Thayer - A           Thayer - A
# 33         Longcope - A              CCU - B           Ambulatory
# 40                 Peds                 Peds                 Peds
# 45           Thayer - B            MP Clinic             MICU - F
# 6                 Leuks             MICU - E             Vacation
# 30         Longcope - B         Longcope - B           Ambulatory
# 11              MPC - B             Vacation             MICU - D
# 47           NightWatch         Brancati - B           Ambulatory
# 36           Ambulatory           Barker - C           Barker - C
# 48             Vacation             MICU - F           Ambulatory
# 59         Brancati - C                              Brancati - C
# 61         Brancati - A
# 60                                                   Brancati - A
# 20                              Brancati - C
# 21                              Brancati - A
# 34         Brancati - D              CCU - C           Ambulatory
# 16           Barker - C           Ambulatory                Leuks
# 43           Barker - A              MPC - C           Ambulatory
# 31             MICU - D           Ambulatory         Longcope - D
# 5               MPC - A           Barker - B           Barker - B
# 8              MICU - F          Janeway - B          Janeway - B
# 26                 Peds                 Peds                 Peds
# 46           Ambulatory             Vacation             MICU - C
# 25          Janeway - C          Janeway - C           Ambulatory
# 53          Janeway - B                Leuks           Ambulatory
# 12         Longcope - D         Longcope - D              MPC - C
# 52           Thayer - C           Ambulatory             MICU - B
# 3              MICU - A               Solids         Brancati - B
# 27           Ambulatory          Janeway - A          Janeway - A
# 19             Vacation           Ambulatory              MPC - B
# 28          Janeway - A           Ambulatory              MPC - A
# 56               Solids           Ambulatory             Vacation
# 57             Vacation           Ambulatory          Janeway - C
#
#    5A 10/17/24-10/30/24  ... 9A 02/13/25-02/26/25 9B 02/27/25-03/12/25  \
# 58  2024-10-20 00:00:00  ...                       2024-03-09 00:00:00
# 13           Ambulatory  ...           Ambulatory             MICU - F
# 17           Barker - C  ...           Barker - A         Brancati - B
# 22           Thayer - B  ...           Thayer - C              MPC - B
# 14             MICU - E  ...           Barker - C           Ambulatory
# 44                 Peds  ...              CCU - A            MP Clinic
# 42         Brancati - B  ...           Thayer - B           Thayer - B
# 7            Ambulatory  ...           Ambulatory             Vacation
# 39          Janeway - D  ...          Janeway - C          Janeway - C
# 24             MICU - A  ...             MICU - D           Ambulatory
# 50           Thayer - D  ...         Brancati - D             MICU - A
# 32         Longcope - B  ...         Longcope - C         Longcope - C
# 23              CCU - A  ...              CCU - B              CCU - B
# 62                       ...
# 38             MICU - D  ...             MICU - E            MICU - E
# 35                       ...
# 15           Barker - A  ...                Leuks             MICU - C
# 9            Ambulatory  ...           Ambulatory          Janeway - A
# 49              MPC - B  ...           Thayer - D           Ambulatory
# 41             Vacation  ...              CCU - C           Ambulatory
# 51             MICU - F  ...                  MTL              CCU - C
# 29              MPC - A  ...             MICU - A           Ambulatory
# 55              CCU - C  ...        Brancati - A            Ambulatory
# 10           Ambulatory  ...           Ambulatory           Barker - A
# 18             Vacation  ...         Longcope - B         Longcope - B
# 54             Vacation  ...             MICU - B           Ambulatory
# 37               Solids  ...           NightWatch           Ambulatory
# 4            Ambulatory  ...           Ambulatory           Thayer - C
# 33             Vacation  ...              MPC - A             Vacation
# 40         Longcope - A  ...                 Peds                 Peds
# 45                 Peds  ...            MP Clinic         Brancati - A
# 6            Ambulatory  ...           Ambulatory              MPC - C
# 30           NightWatch  ...         Longcope - A         Longcope - A
# 11           Ambulatory  ...           Ambulatory                Psych
# 47           Thayer - C  ...           Thayer - A           Thayer - A
# 36             Vacation  ...             MICU - F           Ambulatory
# 48              CCU - B  ...               Solids           Barker - C
# 59                       ...                              Brancati - D
# 61         Brancati - A  ...         Brancati - C
# 60                       ...         Brancati - B
# 20                   ED  ...
# 21         Brancati - C  ...                             Brancati - C
# 34              MPC - C  ...              MPC - B          Janeway - B
# 16             Vacation  ...   Addiction Medicine   Addiction Medicine
# 43           Barker - B  ...           Barker - B           Barker - B
# 31         Longcope - D  ...             Vacation              MPC - A
# 5            Ambulatory  ...           Ambulatory               Solids
# 8            Ambulatory  ...           Ambulatory           NightWatch
# 26          Janeway - A  ...                 Peds                 Peds
# 46                Leuks  ...             Vacation           Ambulatory
# 25         Brancati - D  ...             MICU - C                Leuks
# 53             MICU - C  ...   Addiction Medicine   Addiction Medicine
# 12           Ambulatory  ...           Ambulatory         Longcope - D
# 52           Thayer - A  ...              MPC - C          Thayer - D
# 3            Ambulatory  ...           Ambulatory             Vacation
# 27             MICU - B  ...          Janeway - B           Ambulatory
# 19           Barker - D  ...           Barker - D           Barker - D
# 28          Janeway - B  ...          Janeway - A             MICU - B
# 56         Longcope - C  ...         Longcope - D             MICU - D
# 57          Janeway - C  ...          Janeway - D          Janeway - D
#
#    10A 03/13/25-03/26/25 10B 03/27/25-04/09/25 11A 04/10/25-04/23/25  \
# 58                         2024-04-06 00:00:00
# 13            Thayer - B            Thayer - B            Ambulatory
# 17            Ambulatory               MPC - C            Barker - D
# 22            Ambulatory            Thayer - C               CCU - A
# 14         Brancati - C             Barker - A            Barker - A
# 44                  Peds                  Peds                  Peds
# 42               CCU - A            Ambulatory               MPC - B
# 7               MICU - D          Longcope - A            Ambulatory
# 39            Ambulatory           Janeway - B              MICU - F
# 24          Longcope - A              Vacation               CCU - C
# 50            Ambulatory            NightWatch            Thayer - B
# 32            Ambulatory               MPC - A          Longcope - C
# 23               CCU - B               CCU - B               CCU - B
# 62
# 38              MICU - E              MICU - E              MICU - E
# 35                                                          MICU - B
# 15            Barker - C            Ambulatory            Barker - B
# 9            Janeway - A              MICU - D            Ambulatory
# 49               CCU - C                Solids            Thayer - A
# 41            Thayer - A            Thayer - A               MPC - A
# 51            Thayer - D            Ambulatory            Thayer - C
# 29            Barker - B            Barker - B                 Leuks
# 55               MPC - C          Longcope - D              Vacation
# 10              MICU - B          Brancati - B            Ambulatory
# 18              MICU - A            Ambulatory          Brancati - A
# 54           Janeway - C           Janeway - C              Vacation
# 37           Janeway - D           Janeway - A              MICU - D
# 4             Thayer - C              MICU - C            Ambulatory
# 33                Solids            Ambulatory          Longcope - D
# 40          Longcope - C              Vacation             MP Clinic
# 45                  Peds                  Peds                  Peds
# 6           Longcope - B          Longcope - B            Ambulatory
# 30               MPC - B            Ambulatory          Longcope - A
# 11    Addiction Medicine    Addiction Medicine            Ambulatory
# 47               MPC - A            Ambulatory                Solids
# 36           Barker - A           Brancati - A              MICU - C
# 48              MICU - C            Ambulatory            NightWatch
# 59                                Brancati - C
# 61                                Brancati - D
# 60          Brancati - A
# 20          Brancati - B                                Brancati - C
# 21                                                      Brancati - D
# 34           Janeway - B            Ambulatory              MICU - A
# 16            Ambulatory                 Psych            Barker - C
# 43              Vacation            Ambulatory               MPC - C
# 31            Ambulatory          Longcope - C          Longcope - B
# 5               Vacation            Barker - C            Ambulatory
# 8               Vacation           Janeway - D            Ambulatory
# 26          Brancati - D             MP Clinic           Janeway - B
# 46    Addiction Medicine    Addiction Medicine                 Psych
# 25              MICU - F            Ambulatory           Janeway - A
# 53              Vacation            Ambulatory                   UCM
# 12          Longcope - D                 Leuks            Ambulatory
# 52            Ambulatory            Thayer - D            Thayer - D
# 3             NightWatch              MICU - B            Ambulatory
# 27                 Leuks               CCU - A           Janeway - C
# 19            Ambulatory               CCU - C          Brancati - B
# 28            Ambulatory              MICU - F           Janeway - D
# 56            Ambulatory               MPC - B              Vacation
# 57            Ambulatory              MICU - A              Vacation
#
#    11B 04/24/25-05/07/25 12A 05/08/25-05/21/25 12B 05/22/25-06/04/25  \
# 58   2024-05-04 00:00:00                         2024-06-01 00:00:00
# 13              Vacation            Thayer - B            Thayer - B
# 17            Barker - D            Ambulatory            NightWatch
# 22              Vacation            Ambulatory           Thayer - C
# 14            Ambulatory              MICU - A            Barker - B
# 44                  Peds          Brancati - B              Vacation
# 42            Thayer - A            Thayer - A            Ambulatory
# 7                  Leuks          Longcope - B               MPC - C
# 39           Janeway - D            Ambulatory                   MTL
# 24            Ambulatory          Longcope - D          Longcope - D
# 50            Thayer - B            Ambulatory               MPC - B
# 32              Vacation            Ambulatory                Solids
# 23               CCU - B          CCU - C (HL)          CCU - B (HL)
# 62                                CCU - B (AK)          CCU - C (AK)
# 38              MICU - E              MICU - E              MICU - E
# 35              MICU - B
# 15              Vacation               CCU - A            Ambulatory
# 9                    MTL               MPC - A          Brancati - B
# 49            Ambulatory            Thayer - C             MICU  - D
# 41            Ambulatory              Vacation              MICU - B
# 51            Thayer - C              Vacation            Ambulatory
# 29            Ambulatory              Vacation               MPC - A
# 55            Ambulatory              MICU - B          Longcope - B
# 10            NightWatch            Barker - A            Barker - A
# 18               MPC - B              Vacation            Ambulatory
# 54            Ambulatory              MICU - D           Janeway - B
# 37            Ambulatory           Janeway - A              Vacation
# 4           Brancati - B               MPC - C            Thayer - A
# 33          Longcope - D              MICU - F            Ambulatory
# 40          Longcope - C                  Peds                  Peds
# 45                  Peds              Vacation               CCU - A
# 6                CCU - C                Solids              MICU - F
# 30          Longcope - A                   MTL            Ambulatory
# 11            Thayer - D            Thayer - D              Vacation
# 47              MICU - A              Vacation            Ambulatory
# 36            Ambulatory            Barker - B              Vacation
# 48            Barker - C            Barker - C            Ambulatory
# 59          Brancati - C                                Brancati - C
# 61                                Brancati - C
# 60          Brancati - D
# 20                                                      Brancati - D
# 21                               Brancati - A
# 34              Vacation          Brancati - D            Ambulatory
# 16              Vacation            Ambulatory           Barker - C
# 43                Solids              MICU - C            Ambulatory
# 31          Longcope - B            Ambulatory              MICU - C
# 5                CCU - A            Barker - D            Barker - D
# 8               MICU - C                 Leuks           Janeway - A
# 26           Janeway - B                  Peds                  Peds
# 46            Ambulatory          Longcope - A          Longcope - A
# 25              MPC - A            Janeway - B            Ambulatory
# 53           Janeway - C           Janeway - C            Ambulatory
# 12              Vacation          Longcope - C          Longcope - C
# 52              MICU - D            Ambulatory            Thayer - D
# 3           Brancati - A           Janeway - D           Janeway - D
# 27            Ambulatory               MPC - B              Vacation
# 19            Barker - B            Ambulatory              MICU - A
# 28           Janeway - A            Ambulatory         Brancati - A
# 56              MICU - F            Ambulatory                 Leuks
# 57               MPC - C            Ambulatory           Janeway - C
#
#    13A 06/05/25-06/18/25 13B 06/19/25-06/30/23
# 58                         2024-06-30 00:00:00
# 13            Ambulatory               CCU - B
# 17              MICU - D              Vacation
# 22          Brancati - D              MICU - F
# 14               CCU - A            Ambulatory
# 44            Barker - D            Barker - D
# 42              MICU - C              Vacation
# 7             Ambulatory              MICU - B
# 39               MPC - A              Vacation
# 24               MPC - C            Ambulatory
# 50           Thayer - A                  Leuks
# 32              MICU - B          Brancati - C
# 23               CCU - B               CCU - C
# 62
# 38              MICU - E              MICU - E
# 35
# 15               MPC - B            Barker - B
# 9             Ambulatory               Janeway
# 49              Vacation            Ambulatory
# 41            Thayer - B            Ambulatory
# 51             MICU - A            Thayer - B*
# 29            Barker - B            Ambulatory
# 55          Longcope - B            Ambulatory
# 10            Ambulatory            Barker - C
# 18          Longcope - C          Longcope - C
# 54                   MTL            Ambulatory
# 37           Janeway - A            Ambulatory
# 4             Ambulatory              Vacation
# 33          Longcope - A          Longcope - A
# 40                  Peds                  Peds
# 45            Thayer - C            Thayer - C
# 6             Ambulatory         Longcope - B*
# 30              MICU - F              Vacation
# 11            Ambulatory            Thayer - A
# 47            Thayer - D            Thayer - D
# 36            NightWatch            Ambulatory
# 48              Vacation               MPC - A
# 59
# 61                                Brancati - D
# 60          Brancati - B
# 20                               Brancati - B
# 21          Brancati - C
# 34                Solids           Janeway - C
# 16            Barker - C               MPC - B
# 43            Barker - A            Barker - A
# 31          Brancati - A                   MTL
# 5             Ambulatory          Brancati - A
# 8             Ambulatory           Janeway - D
# 26                  Peds                  Peds
# 46                   UCM            Ambulatory
# 25              Vacation                Solids
# 53           Janeway - B          Janeway - B*
# 12            Ambulatory              MICU - C
# 52               CCU - C              Vacation
# 3             Ambulatory               CCU - A
# 27           Janeway - D            Ambulatory
# 19              Vacation            NightWatch
# 28                 Leuks               MPC - C
# 56          Longcope - D         Longcope - D
# 57           Janeway - C              MICU - A
#
# [60 rows x 29 columns]

# %%
july1_offset = my_dict['july1_offset']
for resident_name in resident_names:
    date_list = []
    schedule_list = []        
    my_blocks = (get_schedule(resident_name, master_schedule))
    print(my_blocks)
    

    calendar = Calendar()
    event = Event()
    with open(f"/Users/cjyoon/Dropbox/Osler/Osler_shiny/intern_schedule/{resident_name}_schedule.tsv", "w") as g:
        g.write('name\tdate\tschedule\n')
        for block_id, rotation in zip(my_dict['block_dates'].keys(), my_blocks):
            # only write out upto holiday block 2 since remaining scheudle has not been finalized yet
#             if block_id in ['7B', '8A', '8B', '9A', '9B', '10A', '10B', '11A', '11B', '12A', '12B', '13A', '13B']:
#             if block_id in ['1A', '1B', '2A', '2B', '3A', '3B', '4A', '4B', '5A', '5B', '6A', '6B', '7A', 'Holiday 1', 'Holiday2']:
            if 1:
        
                if not isinstance(rotation, str):
                    rotation = ' '
                
                rotation = re.sub('\s', '', rotation)

                print(block_id, rotation)

                block_days = block_dates(block_id, my_dict)        

                try:
                    call_cycle = get_specific_rotation_schedule(block_id, rotation, my_dict)
                except:
                    # if specific call cycle is unknown for a rotation, then default to unknown so manual creation can be made
                                        # if specific call cycle is unknown for a rotation, then default to unknown so manual creation can be made
                    if rotation == ' ':
                        call_cycle = [' '] * 14
                    else:
                        call_cycle = ['-'] * 14




                print(f'{block_days} {len(block_days)}')
                print(f'{call_cycle} {len(call_cycle)}')


                if block_id == '1A':
                    # create call cycle that is offset to account for different start date for july1 cycle
                    del call_cycle[:july1_offset]

                # check if block call cycle ends in a post call
                block_days = add_date_postcall_into_next_block(call_cycle, block_days)

                # Loop through each date and corresponding schedule
                for date, schedule in zip(block_days, call_cycle):
                    
                    if rotation in ['MTL', 'Leuks', 'Solids', 'Ambulatory', 'Subspecialty', 'Psych', 'UCM', 'AddictionMedicine']:
                        schedule = oncology_schedule(rotation, date)
                    
                    event = Event()  # Create a new event object inside the loop
                    if rotation == 'Subspecialty': # change Subspecialty into NightWatch more commonly referred.
                        rotation = 'NightWatch'
                    event.name = f'{block_id} {rotation} {schedule}'
                    event.begin = date
                    event.make_all_day()  # Make the event an all-day event
                    print(date, block_id, rotation, schedule)
                    # Add event to calendar
                    calendar.events.add(event)
                    date_string = date.strftime('%m-%d-%Y')
                    g.write(f'{resident_name}\t{date_string}\t{event.name}\n')



        # Write the calendar to a .ics file
        with open(f"/Users/cjyoon/Dropbox/Osler/Osler_shiny/intern_schedule/{resident_name}_schedule.ics", "w") as f:
            f.writelines(calendar.serialize_iter())
# Out:
# ['Ambulatory', 'MPC - C', 'Barker - D', 'Barker - D', 'Ambulatory', 'MICU - B', 'Barker - A', 'Barker - A', 'Ambulatory', 'Leuks', 'Vacation', 'MICU - D', 'Ambulatory', 'Off', 'Barker - B', 'Barker - C', 'Brancati - D', 'Solids', 'Ambulatory', 'CCU - A', 'Barker - D', 'Barker - D', 'Ambulatory', 'Barker - A', 'Subspecialty', 'Vacation', 'Ambulatory', 'MICU - D']
# 1A Ambulatory
# [datetime.datetime(2024, 7, 1, 0, 0), datetime.datetime(2024, 7, 2, 0, 0), datetime.datetime(2024, 7, 3, 0, 0), datetime.datetime(2024, 7, 4, 0, 0), datetime.datetime(2024, 7, 5, 0, 0), datetime.datetime(2024, 7, 6, 0, 0), datetime.datetime(2024, 7, 7, 0, 0), datetime.datetime(2024, 7, 8, 0, 0), datetime.datetime(2024, 7, 9, 0, 0), datetime.datetime(2024, 7, 10, 0, 0)] 10
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2024-07-01 00:00:00 1A Ambulatory DAY
# 2024-07-02 00:00:00 1A Ambulatory DAY
# 2024-07-03 00:00:00 1A Ambulatory DAY
# 2024-07-04 00:00:00 1A Ambulatory DAY
# 2024-07-05 00:00:00 1A Ambulatory DAY
# 2024-07-06 00:00:00 1A Ambulatory OFF
# 2024-07-07 00:00:00 1A Ambulatory OFF
# 2024-07-08 00:00:00 1A Ambulatory DAY
# 2024-07-09 00:00:00 1A Ambulatory DAY
# 2024-07-10 00:00:00 1A Ambulatory DAY
# 1B MPC-C
# [datetime.datetime(2024, 7, 11, 0, 0), datetime.datetime(2024, 7, 12, 0, 0), datetime.datetime(2024, 7, 13, 0, 0), datetime.datetime(2024, 7, 14, 0, 0), datetime.datetime(2024, 7, 15, 0, 0), datetime.datetime(2024, 7, 16, 0, 0), datetime.datetime(2024, 7, 17, 0, 0), datetime.datetime(2024, 7, 18, 0, 0), datetime.datetime(2024, 7, 19, 0, 0), datetime.datetime(2024, 7, 20, 0, 0), datetime.datetime(2024, 7, 21, 0, 0), datetime.datetime(2024, 7, 22, 0, 0), datetime.datetime(2024, 7, 23, 0, 0), datetime.datetime(2024, 7, 24, 0, 0)] 14
# ['POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD'] 14
# GOOD
# 2024-07-11 00:00:00 1B MPC-C POST
# 2024-07-12 00:00:00 1B MPC-C GOOD
# 2024-07-13 00:00:00 1B MPC-C CALL
# 2024-07-14 00:00:00 1B MPC-C POST
# 2024-07-15 00:00:00 1B MPC-C OFF
# 2024-07-16 00:00:00 1B MPC-C CALL
# 2024-07-17 00:00:00 1B MPC-C POST
# 2024-07-18 00:00:00 1B MPC-C GOOD
# 2024-07-19 00:00:00 1B MPC-C CALL
# 2024-07-20 00:00:00 1B MPC-C POST
# 2024-07-21 00:00:00 1B MPC-C OFF
# 2024-07-22 00:00:00 1B MPC-C CALL
# 2024-07-23 00:00:00 1B MPC-C POST
# 2024-07-24 00:00:00 1B MPC-C GOOD
# 2A Barker-D
# [datetime.datetime(2024, 7, 25, 0, 0), datetime.datetime(2024, 7, 26, 0, 0), datetime.datetime(2024, 7, 27, 0, 0), datetime.datetime(2024, 7, 28, 0, 0), datetime.datetime(2024, 7, 29, 0, 0), datetime.datetime(2024, 7, 30, 0, 0), datetime.datetime(2024, 7, 31, 0, 0), datetime.datetime(2024, 8, 1, 0, 0), datetime.datetime(2024, 8, 2, 0, 0), datetime.datetime(2024, 8, 3, 0, 0), datetime.datetime(2024, 8, 4, 0, 0), datetime.datetime(2024, 8, 5, 0, 0), datetime.datetime(2024, 8, 6, 0, 0), datetime.datetime(2024, 8, 7, 0, 0)] 14
# ['POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY'] 14
# DAY
# 2024-07-25 00:00:00 2A Barker-D POST
# 2024-07-26 00:00:00 2A Barker-D DAY
# 2024-07-27 00:00:00 2A Barker-D OFF
# 2024-07-28 00:00:00 2A Barker-D CALL
# 2024-07-29 00:00:00 2A Barker-D POST
# 2024-07-30 00:00:00 2A Barker-D DAY
# 2024-07-31 00:00:00 2A Barker-D GOOD
# 2024-08-01 00:00:00 2A Barker-D CALL
# 2024-08-02 00:00:00 2A Barker-D POST
# 2024-08-03 00:00:00 2A Barker-D DAY
# 2024-08-04 00:00:00 2A Barker-D OFF
# 2024-08-05 00:00:00 2A Barker-D CALL
# 2024-08-06 00:00:00 2A Barker-D POST
# 2024-08-07 00:00:00 2A Barker-D DAY
# 2B Barker-D
# [datetime.datetime(2024, 8, 8, 0, 0), datetime.datetime(2024, 8, 9, 0, 0), datetime.datetime(2024, 8, 10, 0, 0), datetime.datetime(2024, 8, 11, 0, 0), datetime.datetime(2024, 8, 12, 0, 0), datetime.datetime(2024, 8, 13, 0, 0), datetime.datetime(2024, 8, 14, 0, 0), datetime.datetime(2024, 8, 15, 0, 0), datetime.datetime(2024, 8, 16, 0, 0), datetime.datetime(2024, 8, 17, 0, 0), datetime.datetime(2024, 8, 18, 0, 0), datetime.datetime(2024, 8, 19, 0, 0), datetime.datetime(2024, 8, 20, 0, 0), datetime.datetime(2024, 8, 21, 0, 0)] 14
# ['GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', '*POST'] 15
# *POST
# 2024-08-08 00:00:00 2B Barker-D GOOD
# 2024-08-09 00:00:00 2B Barker-D CALL
# 2024-08-10 00:00:00 2B Barker-D POST
# 2024-08-11 00:00:00 2B Barker-D DAY
# 2024-08-12 00:00:00 2B Barker-D OFF
# 2024-08-13 00:00:00 2B Barker-D CALL
# 2024-08-14 00:00:00 2B Barker-D POST
# 2024-08-15 00:00:00 2B Barker-D DAY
# 2024-08-16 00:00:00 2B Barker-D OFF
# 2024-08-17 00:00:00 2B Barker-D CALL
# 2024-08-18 00:00:00 2B Barker-D POST
# 2024-08-19 00:00:00 2B Barker-D DAY
# 2024-08-20 00:00:00 2B Barker-D GOOD
# 2024-08-21 00:00:00 2B Barker-D CALL
# 2024-08-22 00:00:00 2B Barker-D *POST
# 3A Ambulatory
# [datetime.datetime(2024, 8, 22, 0, 0), datetime.datetime(2024, 8, 23, 0, 0), datetime.datetime(2024, 8, 24, 0, 0), datetime.datetime(2024, 8, 25, 0, 0), datetime.datetime(2024, 8, 26, 0, 0), datetime.datetime(2024, 8, 27, 0, 0), datetime.datetime(2024, 8, 28, 0, 0), datetime.datetime(2024, 8, 29, 0, 0), datetime.datetime(2024, 8, 30, 0, 0), datetime.datetime(2024, 8, 31, 0, 0), datetime.datetime(2024, 9, 1, 0, 0), datetime.datetime(2024, 9, 2, 0, 0), datetime.datetime(2024, 9, 3, 0, 0), datetime.datetime(2024, 9, 4, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2024-08-22 00:00:00 3A Ambulatory DAY
# 2024-08-23 00:00:00 3A Ambulatory DAY
# 2024-08-24 00:00:00 3A Ambulatory OFF
# 2024-08-25 00:00:00 3A Ambulatory OFF
# 2024-08-26 00:00:00 3A Ambulatory DAY
# 2024-08-27 00:00:00 3A Ambulatory DAY
# 2024-08-28 00:00:00 3A Ambulatory DAY
# 2024-08-29 00:00:00 3A Ambulatory DAY
# 2024-08-30 00:00:00 3A Ambulatory DAY
# 2024-08-31 00:00:00 3A Ambulatory OFF
# 2024-09-01 00:00:00 3A Ambulatory OFF
# 2024-09-02 00:00:00 3A Ambulatory DAY
# 2024-09-03 00:00:00 3A Ambulatory DAY
# 2024-09-04 00:00:00 3A Ambulatory DAY
# 3B MICU-B
# [datetime.datetime(2024, 9, 5, 0, 0), datetime.datetime(2024, 9, 6, 0, 0), datetime.datetime(2024, 9, 7, 0, 0), datetime.datetime(2024, 9, 8, 0, 0), datetime.datetime(2024, 9, 9, 0, 0), datetime.datetime(2024, 9, 10, 0, 0), datetime.datetime(2024, 9, 11, 0, 0), datetime.datetime(2024, 9, 12, 0, 0), datetime.datetime(2024, 9, 13, 0, 0), datetime.datetime(2024, 9, 14, 0, 0), datetime.datetime(2024, 9, 15, 0, 0), datetime.datetime(2024, 9, 16, 0, 0), datetime.datetime(2024, 9, 17, 0, 0), datetime.datetime(2024, 9, 18, 0, 0)] 14
# ['POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD'] 14
# GOOD
# 2024-09-05 00:00:00 3B MICU-B POST
# 2024-09-06 00:00:00 3B MICU-B GOOD
# 2024-09-07 00:00:00 3B MICU-B CALL
# 2024-09-08 00:00:00 3B MICU-B POST
# 2024-09-09 00:00:00 3B MICU-B OFF
# 2024-09-10 00:00:00 3B MICU-B CALL
# 2024-09-11 00:00:00 3B MICU-B POST
# 2024-09-12 00:00:00 3B MICU-B GOOD
# 2024-09-13 00:00:00 3B MICU-B CALL
# 2024-09-14 00:00:00 3B MICU-B POST
# 2024-09-15 00:00:00 3B MICU-B OFF
# 2024-09-16 00:00:00 3B MICU-B CALL
# 2024-09-17 00:00:00 3B MICU-B POST
# 2024-09-18 00:00:00 3B MICU-B GOOD
# 4A Barker-A
# [datetime.datetime(2024, 9, 19, 0, 0), datetime.datetime(2024, 9, 20, 0, 0), datetime.datetime(2024, 9, 21, 0, 0), datetime.datetime(2024, 9, 22, 0, 0), datetime.datetime(2024, 9, 23, 0, 0), datetime.datetime(2024, 9, 24, 0, 0), datetime.datetime(2024, 9, 25, 0, 0), datetime.datetime(2024, 9, 26, 0, 0), datetime.datetime(2024, 9, 27, 0, 0), datetime.datetime(2024, 9, 28, 0, 0), datetime.datetime(2024, 9, 29, 0, 0), datetime.datetime(2024, 9, 30, 0, 0), datetime.datetime(2024, 10, 1, 0, 0), datetime.datetime(2024, 10, 2, 0, 0)] 14
# ['CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST'] 14
# POST
# 2024-09-19 00:00:00 4A Barker-A CALL
# 2024-09-20 00:00:00 4A Barker-A POST
# 2024-09-21 00:00:00 4A Barker-A DAY
# 2024-09-22 00:00:00 4A Barker-A OFF
# 2024-09-23 00:00:00 4A Barker-A CALL
# 2024-09-24 00:00:00 4A Barker-A POST
# 2024-09-25 00:00:00 4A Barker-A DAY
# 2024-09-26 00:00:00 4A Barker-A GOOD
# 2024-09-27 00:00:00 4A Barker-A CALL
# 2024-09-28 00:00:00 4A Barker-A POST
# 2024-09-29 00:00:00 4A Barker-A DAY
# 2024-09-30 00:00:00 4A Barker-A OFF
# 2024-10-01 00:00:00 4A Barker-A CALL
# 2024-10-02 00:00:00 4A Barker-A POST
# 4B Barker-A
# [datetime.datetime(2024, 10, 3, 0, 0), datetime.datetime(2024, 10, 4, 0, 0), datetime.datetime(2024, 10, 5, 0, 0), datetime.datetime(2024, 10, 6, 0, 0), datetime.datetime(2024, 10, 7, 0, 0), datetime.datetime(2024, 10, 8, 0, 0), datetime.datetime(2024, 10, 9, 0, 0), datetime.datetime(2024, 10, 10, 0, 0), datetime.datetime(2024, 10, 11, 0, 0), datetime.datetime(2024, 10, 12, 0, 0), datetime.datetime(2024, 10, 13, 0, 0), datetime.datetime(2024, 10, 14, 0, 0), datetime.datetime(2024, 10, 15, 0, 0), datetime.datetime(2024, 10, 16, 0, 0)] 14
# ['DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD'] 14
# GOOD
# 2024-10-03 00:00:00 4B Barker-A DAY
# 2024-10-04 00:00:00 4B Barker-A OFF
# 2024-10-05 00:00:00 4B Barker-A CALL
# 2024-10-06 00:00:00 4B Barker-A POST
# 2024-10-07 00:00:00 4B Barker-A DAY
# 2024-10-08 00:00:00 4B Barker-A GOOD
# 2024-10-09 00:00:00 4B Barker-A CALL
# 2024-10-10 00:00:00 4B Barker-A POST
# 2024-10-11 00:00:00 4B Barker-A DAY
# 2024-10-12 00:00:00 4B Barker-A OFF
# 2024-10-13 00:00:00 4B Barker-A CALL
# 2024-10-14 00:00:00 4B Barker-A POST
# 2024-10-15 00:00:00 4B Barker-A DAY
# 2024-10-16 00:00:00 4B Barker-A GOOD
# 5A Ambulatory
# [datetime.datetime(2024, 10, 17, 0, 0), datetime.datetime(2024, 10, 18, 0, 0), datetime.datetime(2024, 10, 19, 0, 0), datetime.datetime(2024, 10, 20, 0, 0), datetime.datetime(2024, 10, 21, 0, 0), datetime.datetime(2024, 10, 22, 0, 0), datetime.datetime(2024, 10, 23, 0, 0), datetime.datetime(2024, 10, 24, 0, 0), datetime.datetime(2024, 10, 25, 0, 0), datetime.datetime(2024, 10, 26, 0, 0), datetime.datetime(2024, 10, 27, 0, 0), datetime.datetime(2024, 10, 28, 0, 0), datetime.datetime(2024, 10, 29, 0, 0), datetime.datetime(2024, 10, 30, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2024-10-17 00:00:00 5A Ambulatory DAY
# 2024-10-18 00:00:00 5A Ambulatory DAY
# 2024-10-19 00:00:00 5A Ambulatory OFF
# 2024-10-20 00:00:00 5A Ambulatory OFF
# 2024-10-21 00:00:00 5A Ambulatory DAY
# 2024-10-22 00:00:00 5A Ambulatory DAY
# 2024-10-23 00:00:00 5A Ambulatory DAY
# 2024-10-24 00:00:00 5A Ambulatory DAY
# 2024-10-25 00:00:00 5A Ambulatory DAY
# 2024-10-26 00:00:00 5A Ambulatory OFF
# 2024-10-27 00:00:00 5A Ambulatory OFF
# 2024-10-28 00:00:00 5A Ambulatory DAY
# 2024-10-29 00:00:00 5A Ambulatory DAY
# 2024-10-30 00:00:00 5A Ambulatory DAY
# 5B Leuks
# [datetime.datetime(2024, 10, 31, 0, 0), datetime.datetime(2024, 11, 1, 0, 0), datetime.datetime(2024, 11, 2, 0, 0), datetime.datetime(2024, 11, 3, 0, 0), datetime.datetime(2024, 11, 4, 0, 0), datetime.datetime(2024, 11, 5, 0, 0), datetime.datetime(2024, 11, 6, 0, 0), datetime.datetime(2024, 11, 7, 0, 0), datetime.datetime(2024, 11, 8, 0, 0), datetime.datetime(2024, 11, 9, 0, 0), datetime.datetime(2024, 11, 10, 0, 0), datetime.datetime(2024, 11, 11, 0, 0), datetime.datetime(2024, 11, 12, 0, 0), datetime.datetime(2024, 11, 13, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2024-10-31 00:00:00 5B Leuks DAY
# 2024-11-01 00:00:00 5B Leuks DAY
# 2024-11-02 00:00:00 5B Leuks DAY
# 2024-11-03 00:00:00 5B Leuks OFF
# 2024-11-04 00:00:00 5B Leuks DAY
# 2024-11-05 00:00:00 5B Leuks DAY
# 2024-11-06 00:00:00 5B Leuks DAY
# 2024-11-07 00:00:00 5B Leuks DAY
# 2024-11-08 00:00:00 5B Leuks DAY
# 2024-11-09 00:00:00 5B Leuks DAY
# 2024-11-10 00:00:00 5B Leuks OFF
# 2024-11-11 00:00:00 5B Leuks DAY
# 2024-11-12 00:00:00 5B Leuks DAY
# 2024-11-13 00:00:00 5B Leuks DAY
# 6A Vacation
# [datetime.datetime(2024, 11, 14, 0, 0), datetime.datetime(2024, 11, 15, 0, 0), datetime.datetime(2024, 11, 16, 0, 0), datetime.datetime(2024, 11, 17, 0, 0), datetime.datetime(2024, 11, 18, 0, 0), datetime.datetime(2024, 11, 19, 0, 0), datetime.datetime(2024, 11, 20, 0, 0), datetime.datetime(2024, 11, 21, 0, 0), datetime.datetime(2024, 11, 22, 0, 0), datetime.datetime(2024, 11, 23, 0, 0), datetime.datetime(2024, 11, 24, 0, 0), datetime.datetime(2024, 11, 25, 0, 0), datetime.datetime(2024, 11, 26, 0, 0), datetime.datetime(2024, 11, 27, 0, 0)] 14
# ['VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION'] 14
# VACATION
# 2024-11-14 00:00:00 6A Vacation VACATION
# 2024-11-15 00:00:00 6A Vacation VACATION
# 2024-11-16 00:00:00 6A Vacation VACATION
# 2024-11-17 00:00:00 6A Vacation VACATION
# 2024-11-18 00:00:00 6A Vacation VACATION
# 2024-11-19 00:00:00 6A Vacation VACATION
# 2024-11-20 00:00:00 6A Vacation VACATION
# 2024-11-21 00:00:00 6A Vacation VACATION
# 2024-11-22 00:00:00 6A Vacation VACATION
# 2024-11-23 00:00:00 6A Vacation VACATION
# 2024-11-24 00:00:00 6A Vacation VACATION
# 2024-11-25 00:00:00 6A Vacation VACATION
# 2024-11-26 00:00:00 6A Vacation VACATION
# 2024-11-27 00:00:00 6A Vacation VACATION
# 6B MICU-D
# [datetime.datetime(2024, 11, 28, 0, 0), datetime.datetime(2024, 11, 29, 0, 0), datetime.datetime(2024, 11, 30, 0, 0), datetime.datetime(2024, 12, 1, 0, 0), datetime.datetime(2024, 12, 2, 0, 0), datetime.datetime(2024, 12, 3, 0, 0), datetime.datetime(2024, 12, 4, 0, 0), datetime.datetime(2024, 12, 5, 0, 0), datetime.datetime(2024, 12, 6, 0, 0), datetime.datetime(2024, 12, 7, 0, 0), datetime.datetime(2024, 12, 8, 0, 0), datetime.datetime(2024, 12, 9, 0, 0), datetime.datetime(2024, 12, 10, 0, 0), datetime.datetime(2024, 12, 11, 0, 0)] 14
# ['OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', '*POST'] 15
# *POST
# 2024-11-28 00:00:00 6B MICU-D OFF
# 2024-11-29 00:00:00 6B MICU-D CALL
# 2024-11-30 00:00:00 6B MICU-D POST
# 2024-12-01 00:00:00 6B MICU-D GOOD
# 2024-12-02 00:00:00 6B MICU-D CALL
# 2024-12-03 00:00:00 6B MICU-D POST
# 2024-12-04 00:00:00 6B MICU-D OFF
# 2024-12-05 00:00:00 6B MICU-D CALL
# 2024-12-06 00:00:00 6B MICU-D POST
# 2024-12-07 00:00:00 6B MICU-D GOOD
# 2024-12-08 00:00:00 6B MICU-D CALL
# 2024-12-09 00:00:00 6B MICU-D POST
# 2024-12-10 00:00:00 6B MICU-D OFF
# 2024-12-11 00:00:00 6B MICU-D CALL
# 2024-12-12 00:00:00 6B MICU-D *POST
# 7A Ambulatory
# [datetime.datetime(2024, 12, 12, 0, 0), datetime.datetime(2024, 12, 13, 0, 0), datetime.datetime(2024, 12, 14, 0, 0), datetime.datetime(2024, 12, 15, 0, 0), datetime.datetime(2024, 12, 16, 0, 0), datetime.datetime(2024, 12, 17, 0, 0), datetime.datetime(2024, 12, 18, 0, 0), datetime.datetime(2024, 12, 19, 0, 0)] 8
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2024-12-12 00:00:00 7A Ambulatory DAY
# 2024-12-13 00:00:00 7A Ambulatory DAY
# 2024-12-14 00:00:00 7A Ambulatory OFF
# 2024-12-15 00:00:00 7A Ambulatory OFF
# 2024-12-16 00:00:00 7A Ambulatory DAY
# 2024-12-17 00:00:00 7A Ambulatory DAY
# 2024-12-18 00:00:00 7A Ambulatory DAY
# 2024-12-19 00:00:00 7A Ambulatory DAY
# Holiday 1 Off
# [datetime.datetime(2024, 12, 20, 0, 0), datetime.datetime(2024, 12, 21, 0, 0), datetime.datetime(2024, 12, 22, 0, 0), datetime.datetime(2024, 12, 23, 0, 0), datetime.datetime(2024, 12, 24, 0, 0), datetime.datetime(2024, 12, 25, 0, 0), datetime.datetime(2024, 12, 26, 0, 0)] 7
# ['OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF'] 14
# OFF
# 2024-12-20 00:00:00 Holiday 1 Off OFF
# 2024-12-21 00:00:00 Holiday 1 Off OFF
# 2024-12-22 00:00:00 Holiday 1 Off OFF
# 2024-12-23 00:00:00 Holiday 1 Off OFF
# 2024-12-24 00:00:00 Holiday 1 Off OFF
# 2024-12-25 00:00:00 Holiday 1 Off OFF
# 2024-12-26 00:00:00 Holiday 1 Off OFF
# Holiday 2 Barker-B
# [datetime.datetime(2024, 12, 27, 0, 0), datetime.datetime(2024, 12, 28, 0, 0), datetime.datetime(2024, 12, 29, 0, 0), datetime.datetime(2024, 12, 30, 0, 0), datetime.datetime(2024, 12, 31, 0, 0), datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 2, 0, 0)] 7
# ['CALL', 'POST', 'DAY', 'CALL', 'POST', 'DAY', 'CALL', '*POST'] 8
# *POST
# 2024-12-27 00:00:00 Holiday 2 Barker-B CALL
# 2024-12-28 00:00:00 Holiday 2 Barker-B POST
# 2024-12-29 00:00:00 Holiday 2 Barker-B DAY
# 2024-12-30 00:00:00 Holiday 2 Barker-B CALL
# 2024-12-31 00:00:00 Holiday 2 Barker-B POST
# 2025-01-01 00:00:00 Holiday 2 Barker-B DAY
# 2025-01-02 00:00:00 Holiday 2 Barker-B CALL
# 2025-01-03 00:00:00 Holiday 2 Barker-B *POST
# 7B Barker-C
# [datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 15, 0, 0)] 13
# ['POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST'] 13
# POST
# 2025-01-03 00:00:00 7B Barker-C POST
# 2025-01-04 00:00:00 7B Barker-C DAY
# 2025-01-05 00:00:00 7B Barker-C OFF
# 2025-01-06 00:00:00 7B Barker-C CALL
# 2025-01-07 00:00:00 7B Barker-C POST
# 2025-01-08 00:00:00 7B Barker-C DAY
# 2025-01-09 00:00:00 7B Barker-C GOOD
# 2025-01-10 00:00:00 7B Barker-C CALL
# 2025-01-11 00:00:00 7B Barker-C POST
# 2025-01-12 00:00:00 7B Barker-C DAY
# 2025-01-13 00:00:00 7B Barker-C OFF
# 2025-01-14 00:00:00 7B Barker-C CALL
# 2025-01-15 00:00:00 7B Barker-C POST
# 8A Brancati-D
# [datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 21, 0, 0), datetime.datetime(2025, 1, 22, 0, 0), datetime.datetime(2025, 1, 23, 0, 0), datetime.datetime(2025, 1, 24, 0, 0), datetime.datetime(2025, 1, 25, 0, 0), datetime.datetime(2025, 1, 26, 0, 0), datetime.datetime(2025, 1, 27, 0, 0), datetime.datetime(2025, 1, 28, 0, 0), datetime.datetime(2025, 1, 29, 0, 0)] 14
# ['NIGHT', 'NIGHT', 'NIGHT', 'NIGHT', 'POST', 'OFF', 'DAY', 'DAY', 'DAY', 'OFF', 'DAY', 'DAY', 'DAY', 'OFF'] 14
# OFF
# 2025-01-16 00:00:00 8A Brancati-D NIGHT
# 2025-01-17 00:00:00 8A Brancati-D NIGHT
# 2025-01-18 00:00:00 8A Brancati-D NIGHT
# 2025-01-19 00:00:00 8A Brancati-D NIGHT
# 2025-01-20 00:00:00 8A Brancati-D POST
# 2025-01-21 00:00:00 8A Brancati-D OFF
# 2025-01-22 00:00:00 8A Brancati-D DAY
# 2025-01-23 00:00:00 8A Brancati-D DAY
# 2025-01-24 00:00:00 8A Brancati-D DAY
# 2025-01-25 00:00:00 8A Brancati-D OFF
# 2025-01-26 00:00:00 8A Brancati-D DAY
# 2025-01-27 00:00:00 8A Brancati-D DAY
# 2025-01-28 00:00:00 8A Brancati-D DAY
# 2025-01-29 00:00:00 8A Brancati-D OFF
# 8B Solids
# [datetime.datetime(2025, 1, 30, 0, 0), datetime.datetime(2025, 1, 31, 0, 0), datetime.datetime(2025, 2, 1, 0, 0), datetime.datetime(2025, 2, 2, 0, 0), datetime.datetime(2025, 2, 3, 0, 0), datetime.datetime(2025, 2, 4, 0, 0), datetime.datetime(2025, 2, 5, 0, 0), datetime.datetime(2025, 2, 6, 0, 0), datetime.datetime(2025, 2, 7, 0, 0), datetime.datetime(2025, 2, 8, 0, 0), datetime.datetime(2025, 2, 9, 0, 0), datetime.datetime(2025, 2, 10, 0, 0), datetime.datetime(2025, 2, 11, 0, 0), datetime.datetime(2025, 2, 12, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2025-01-30 00:00:00 8B Solids DAY
# 2025-01-31 00:00:00 8B Solids DAY
# 2025-02-01 00:00:00 8B Solids DAY
# 2025-02-02 00:00:00 8B Solids OFF
# 2025-02-03 00:00:00 8B Solids DAY
# 2025-02-04 00:00:00 8B Solids DAY
# 2025-02-05 00:00:00 8B Solids DAY
# 2025-02-06 00:00:00 8B Solids DAY
# 2025-02-07 00:00:00 8B Solids DAY
# 2025-02-08 00:00:00 8B Solids DAY
# 2025-02-09 00:00:00 8B Solids OFF
# 2025-02-10 00:00:00 8B Solids DAY
# 2025-02-11 00:00:00 8B Solids DAY
# 2025-02-12 00:00:00 8B Solids DAY
# 9A Ambulatory
# [datetime.datetime(2025, 2, 13, 0, 0), datetime.datetime(2025, 2, 14, 0, 0), datetime.datetime(2025, 2, 15, 0, 0), datetime.datetime(2025, 2, 16, 0, 0), datetime.datetime(2025, 2, 17, 0, 0), datetime.datetime(2025, 2, 18, 0, 0), datetime.datetime(2025, 2, 19, 0, 0), datetime.datetime(2025, 2, 20, 0, 0), datetime.datetime(2025, 2, 21, 0, 0), datetime.datetime(2025, 2, 22, 0, 0), datetime.datetime(2025, 2, 23, 0, 0), datetime.datetime(2025, 2, 24, 0, 0), datetime.datetime(2025, 2, 25, 0, 0), datetime.datetime(2025, 2, 26, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2025-02-13 00:00:00 9A Ambulatory DAY
# 2025-02-14 00:00:00 9A Ambulatory DAY
# 2025-02-15 00:00:00 9A Ambulatory OFF
# 2025-02-16 00:00:00 9A Ambulatory OFF
# 2025-02-17 00:00:00 9A Ambulatory DAY
# 2025-02-18 00:00:00 9A Ambulatory DAY
# 2025-02-19 00:00:00 9A Ambulatory DAY
# 2025-02-20 00:00:00 9A Ambulatory DAY
# 2025-02-21 00:00:00 9A Ambulatory DAY
# 2025-02-22 00:00:00 9A Ambulatory OFF
# 2025-02-23 00:00:00 9A Ambulatory OFF
# 2025-02-24 00:00:00 9A Ambulatory DAY
# 2025-02-25 00:00:00 9A Ambulatory DAY
# 2025-02-26 00:00:00 9A Ambulatory DAY
# 9B CCU-A
# [datetime.datetime(2025, 2, 27, 0, 0), datetime.datetime(2025, 2, 28, 0, 0), datetime.datetime(2025, 3, 1, 0, 0), datetime.datetime(2025, 3, 2, 0, 0), datetime.datetime(2025, 3, 3, 0, 0), datetime.datetime(2025, 3, 4, 0, 0), datetime.datetime(2025, 3, 5, 0, 0), datetime.datetime(2025, 3, 6, 0, 0), datetime.datetime(2025, 3, 7, 0, 0), datetime.datetime(2025, 3, 8, 0, 0), datetime.datetime(2025, 3, 9, 0, 0), datetime.datetime(2025, 3, 10, 0, 0), datetime.datetime(2025, 3, 11, 0, 0), datetime.datetime(2025, 3, 12, 0, 0)] 14
# ['GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', '*POST'] 15
# *POST
# 2025-02-27 00:00:00 9B CCU-A GOOD
# 2025-02-28 00:00:00 9B CCU-A CALL
# 2025-03-01 00:00:00 9B CCU-A POST
# 2025-03-02 00:00:00 9B CCU-A OFF
# 2025-03-03 00:00:00 9B CCU-A CALL
# 2025-03-04 00:00:00 9B CCU-A POST
# 2025-03-05 00:00:00 9B CCU-A GOOD
# 2025-03-06 00:00:00 9B CCU-A CALL
# 2025-03-07 00:00:00 9B CCU-A POST
# 2025-03-08 00:00:00 9B CCU-A OFF
# 2025-03-09 00:00:00 9B CCU-A CALL
# 2025-03-10 00:00:00 9B CCU-A POST
# 2025-03-11 00:00:00 9B CCU-A GOOD
# 2025-03-12 00:00:00 9B CCU-A CALL
# 2025-03-13 00:00:00 9B CCU-A *POST
# 10A Barker-D
# [datetime.datetime(2025, 3, 13, 0, 0), datetime.datetime(2025, 3, 14, 0, 0), datetime.datetime(2025, 3, 15, 0, 0), datetime.datetime(2025, 3, 16, 0, 0), datetime.datetime(2025, 3, 17, 0, 0), datetime.datetime(2025, 3, 18, 0, 0), datetime.datetime(2025, 3, 19, 0, 0), datetime.datetime(2025, 3, 20, 0, 0), datetime.datetime(2025, 3, 21, 0, 0), datetime.datetime(2025, 3, 22, 0, 0), datetime.datetime(2025, 3, 23, 0, 0), datetime.datetime(2025, 3, 24, 0, 0), datetime.datetime(2025, 3, 25, 0, 0), datetime.datetime(2025, 3, 26, 0, 0)] 14
# ['POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY'] 14
# DAY
# 2025-03-13 00:00:00 10A Barker-D POST
# 2025-03-14 00:00:00 10A Barker-D DAY
# 2025-03-15 00:00:00 10A Barker-D OFF
# 2025-03-16 00:00:00 10A Barker-D CALL
# 2025-03-17 00:00:00 10A Barker-D POST
# 2025-03-18 00:00:00 10A Barker-D DAY
# 2025-03-19 00:00:00 10A Barker-D GOOD
# 2025-03-20 00:00:00 10A Barker-D CALL
# 2025-03-21 00:00:00 10A Barker-D POST
# 2025-03-22 00:00:00 10A Barker-D DAY
# 2025-03-23 00:00:00 10A Barker-D OFF
# 2025-03-24 00:00:00 10A Barker-D CALL
# 2025-03-25 00:00:00 10A Barker-D POST
# 2025-03-26 00:00:00 10A Barker-D DAY
# 10B Barker-D
# [datetime.datetime(2025, 3, 27, 0, 0), datetime.datetime(2025, 3, 28, 0, 0), datetime.datetime(2025, 3, 29, 0, 0), datetime.datetime(2025, 3, 30, 0, 0), datetime.datetime(2025, 3, 31, 0, 0), datetime.datetime(2025, 4, 1, 0, 0), datetime.datetime(2025, 4, 2, 0, 0), datetime.datetime(2025, 4, 3, 0, 0), datetime.datetime(2025, 4, 4, 0, 0), datetime.datetime(2025, 4, 5, 0, 0), datetime.datetime(2025, 4, 6, 0, 0), datetime.datetime(2025, 4, 7, 0, 0), datetime.datetime(2025, 4, 8, 0, 0), datetime.datetime(2025, 4, 9, 0, 0)] 14
# ['GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', '*POST'] 15
# *POST
# 2025-03-27 00:00:00 10B Barker-D GOOD
# 2025-03-28 00:00:00 10B Barker-D CALL
# 2025-03-29 00:00:00 10B Barker-D POST
# 2025-03-30 00:00:00 10B Barker-D DAY
# 2025-03-31 00:00:00 10B Barker-D OFF
# 2025-04-01 00:00:00 10B Barker-D CALL
# 2025-04-02 00:00:00 10B Barker-D POST
# 2025-04-03 00:00:00 10B Barker-D DAY
# 2025-04-04 00:00:00 10B Barker-D OFF
# 2025-04-05 00:00:00 10B Barker-D CALL
# 2025-04-06 00:00:00 10B Barker-D POST
# 2025-04-07 00:00:00 10B Barker-D DAY
# 2025-04-08 00:00:00 10B Barker-D GOOD
# 2025-04-09 00:00:00 10B Barker-D CALL
# 2025-04-10 00:00:00 10B Barker-D *POST
# 11A Ambulatory
# [datetime.datetime(2025, 4, 10, 0, 0), datetime.datetime(2025, 4, 11, 0, 0), datetime.datetime(2025, 4, 12, 0, 0), datetime.datetime(2025, 4, 13, 0, 0), datetime.datetime(2025, 4, 14, 0, 0), datetime.datetime(2025, 4, 15, 0, 0), datetime.datetime(2025, 4, 16, 0, 0), datetime.datetime(2025, 4, 17, 0, 0), datetime.datetime(2025, 4, 18, 0, 0), datetime.datetime(2025, 4, 19, 0, 0), datetime.datetime(2025, 4, 20, 0, 0), datetime.datetime(2025, 4, 21, 0, 0), datetime.datetime(2025, 4, 22, 0, 0), datetime.datetime(2025, 4, 23, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2025-04-10 00:00:00 11A Ambulatory DAY
# 2025-04-11 00:00:00 11A Ambulatory DAY
# 2025-04-12 00:00:00 11A Ambulatory OFF
# 2025-04-13 00:00:00 11A Ambulatory OFF
# 2025-04-14 00:00:00 11A Ambulatory DAY
# 2025-04-15 00:00:00 11A Ambulatory DAY
# 2025-04-16 00:00:00 11A Ambulatory DAY
# 2025-04-17 00:00:00 11A Ambulatory DAY
# 2025-04-18 00:00:00 11A Ambulatory DAY
# 2025-04-19 00:00:00 11A Ambulatory OFF
# 2025-04-20 00:00:00 11A Ambulatory OFF
# 2025-04-21 00:00:00 11A Ambulatory DAY
# 2025-04-22 00:00:00 11A Ambulatory DAY
# 2025-04-23 00:00:00 11A Ambulatory DAY
# 11B Barker-A
# [datetime.datetime(2025, 4, 24, 0, 0), datetime.datetime(2025, 4, 25, 0, 0), datetime.datetime(2025, 4, 26, 0, 0), datetime.datetime(2025, 4, 27, 0, 0), datetime.datetime(2025, 4, 28, 0, 0), datetime.datetime(2025, 4, 29, 0, 0), datetime.datetime(2025, 4, 30, 0, 0), datetime.datetime(2025, 5, 1, 0, 0), datetime.datetime(2025, 5, 2, 0, 0), datetime.datetime(2025, 5, 3, 0, 0), datetime.datetime(2025, 5, 4, 0, 0), datetime.datetime(2025, 5, 5, 0, 0), datetime.datetime(2025, 5, 6, 0, 0), datetime.datetime(2025, 5, 7, 0, 0)] 14
# ['DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD'] 14
# GOOD
# 2025-04-24 00:00:00 11B Barker-A DAY
# 2025-04-25 00:00:00 11B Barker-A OFF
# 2025-04-26 00:00:00 11B Barker-A CALL
# 2025-04-27 00:00:00 11B Barker-A POST
# 2025-04-28 00:00:00 11B Barker-A DAY
# 2025-04-29 00:00:00 11B Barker-A GOOD
# 2025-04-30 00:00:00 11B Barker-A CALL
# 2025-05-01 00:00:00 11B Barker-A POST
# 2025-05-02 00:00:00 11B Barker-A DAY
# 2025-05-03 00:00:00 11B Barker-A OFF
# 2025-05-04 00:00:00 11B Barker-A CALL
# 2025-05-05 00:00:00 11B Barker-A POST
# 2025-05-06 00:00:00 11B Barker-A DAY
# 2025-05-07 00:00:00 11B Barker-A GOOD
# 12A Subspecialty
# [datetime.datetime(2025, 5, 8, 0, 0), datetime.datetime(2025, 5, 9, 0, 0), datetime.datetime(2025, 5, 10, 0, 0), datetime.datetime(2025, 5, 11, 0, 0), datetime.datetime(2025, 5, 12, 0, 0), datetime.datetime(2025, 5, 13, 0, 0), datetime.datetime(2025, 5, 14, 0, 0), datetime.datetime(2025, 5, 15, 0, 0), datetime.datetime(2025, 5, 16, 0, 0), datetime.datetime(2025, 5, 17, 0, 0), datetime.datetime(2025, 5, 18, 0, 0), datetime.datetime(2025, 5, 19, 0, 0), datetime.datetime(2025, 5, 20, 0, 0), datetime.datetime(2025, 5, 21, 0, 0)] 14
# ['NIGHTS', 'NIGHTS', 'NIGHTS', 'OFF', 'NIGHTS', 'NIGHTS', 'NIGHTS', 'NIGHTS', 'NIGHTS', 'NIGHTS', 'OFF', 'NIGHTS', 'NIGHTS', 'NIGHTS', 'POST'] 15
# POST
# 2025-05-08 00:00:00 12A NightWatch NIGHT
# 2025-05-09 00:00:00 12A NightWatch NIGHTS
# 2025-05-10 00:00:00 12A NightWatch NIGHTS
# 2025-05-11 00:00:00 12A NightWatch OFF
# 2025-05-12 00:00:00 12A NightWatch NIGHTS
# 2025-05-13 00:00:00 12A NightWatch NIGHTS
# 2025-05-14 00:00:00 12A NightWatch NIGHTS
# 2025-05-15 00:00:00 12A NightWatch NIGHTS
# 2025-05-16 00:00:00 12A NightWatch NIGHTS
# 2025-05-17 00:00:00 12A NightWatch NIGHTS
# 2025-05-18 00:00:00 12A NightWatch OFF
# 2025-05-19 00:00:00 12A NightWatch NIGHTS
# 2025-05-20 00:00:00 12A NightWatch NIGHTS
# 2025-05-21 00:00:00 12A NightWatch NIGHTS
# 12B Vacation
# [datetime.datetime(2025, 5, 22, 0, 0), datetime.datetime(2025, 5, 23, 0, 0), datetime.datetime(2025, 5, 24, 0, 0), datetime.datetime(2025, 5, 25, 0, 0), datetime.datetime(2025, 5, 26, 0, 0), datetime.datetime(2025, 5, 27, 0, 0), datetime.datetime(2025, 5, 28, 0, 0), datetime.datetime(2025, 5, 29, 0, 0), datetime.datetime(2025, 5, 30, 0, 0), datetime.datetime(2025, 5, 31, 0, 0), datetime.datetime(2025, 6, 1, 0, 0), datetime.datetime(2025, 6, 2, 0, 0), datetime.datetime(2025, 6, 3, 0, 0), datetime.datetime(2025, 6, 4, 0, 0)] 14
# ['VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION'] 14
# VACATION
# 2025-05-22 00:00:00 12B Vacation VACATION
# 2025-05-23 00:00:00 12B Vacation VACATION
# 2025-05-24 00:00:00 12B Vacation VACATION
# 2025-05-25 00:00:00 12B Vacation VACATION
# 2025-05-26 00:00:00 12B Vacation VACATION
# 2025-05-27 00:00:00 12B Vacation VACATION
# 2025-05-28 00:00:00 12B Vacation VACATION
# 2025-05-29 00:00:00 12B Vacation VACATION
# 2025-05-30 00:00:00 12B Vacation VACATION
# 2025-05-31 00:00:00 12B Vacation VACATION
# 2025-06-01 00:00:00 12B Vacation VACATION
# 2025-06-02 00:00:00 12B Vacation VACATION
# 2025-06-03 00:00:00 12B Vacation VACATION
# 2025-06-04 00:00:00 12B Vacation VACATION
# 13A Ambulatory
# [datetime.datetime(2025, 6, 5, 0, 0), datetime.datetime(2025, 6, 6, 0, 0), datetime.datetime(2025, 6, 7, 0, 0), datetime.datetime(2025, 6, 8, 0, 0), datetime.datetime(2025, 6, 9, 0, 0), datetime.datetime(2025, 6, 10, 0, 0), datetime.datetime(2025, 6, 11, 0, 0), datetime.datetime(2025, 6, 12, 0, 0), datetime.datetime(2025, 6, 13, 0, 0), datetime.datetime(2025, 6, 14, 0, 0), datetime.datetime(2025, 6, 15, 0, 0), datetime.datetime(2025, 6, 16, 0, 0), datetime.datetime(2025, 6, 17, 0, 0), datetime.datetime(2025, 6, 18, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2025-06-05 00:00:00 13A Ambulatory DAY
# 2025-06-06 00:00:00 13A Ambulatory DAY
# 2025-06-07 00:00:00 13A Ambulatory OFF
# 2025-06-08 00:00:00 13A Ambulatory OFF
# 2025-06-09 00:00:00 13A Ambulatory DAY
# 2025-06-10 00:00:00 13A Ambulatory DAY
# 2025-06-11 00:00:00 13A Ambulatory DAY
# 2025-06-12 00:00:00 13A Ambulatory DAY
# 2025-06-13 00:00:00 13A Ambulatory DAY
# 2025-06-14 00:00:00 13A Ambulatory OFF
# 2025-06-15 00:00:00 13A Ambulatory OFF
# 2025-06-16 00:00:00 13A Ambulatory DAY
# 2025-06-17 00:00:00 13A Ambulatory DAY
# 2025-06-18 00:00:00 13A Ambulatory DAY
# 13B MICU-D
# [datetime.datetime(2025, 6, 19, 0, 0), datetime.datetime(2025, 6, 20, 0, 0), datetime.datetime(2025, 6, 21, 0, 0), datetime.datetime(2025, 6, 22, 0, 0), datetime.datetime(2025, 6, 23, 0, 0), datetime.datetime(2025, 6, 24, 0, 0), datetime.datetime(2025, 6, 25, 0, 0), datetime.datetime(2025, 6, 26, 0, 0), datetime.datetime(2025, 6, 27, 0, 0), datetime.datetime(2025, 6, 28, 0, 0), datetime.datetime(2025, 6, 29, 0, 0), datetime.datetime(2025, 6, 30, 0, 0)] 12
# ['OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST'] 12
# POST
# 2025-06-19 00:00:00 13B MICU-D OFF
# 2025-06-20 00:00:00 13B MICU-D CALL
# 2025-06-21 00:00:00 13B MICU-D POST
# 2025-06-22 00:00:00 13B MICU-D GOOD
# 2025-06-23 00:00:00 13B MICU-D CALL
# 2025-06-24 00:00:00 13B MICU-D POST
# 2025-06-25 00:00:00 13B MICU-D OFF
# 2025-06-26 00:00:00 13B MICU-D CALL
# 2025-06-27 00:00:00 13B MICU-D POST
# 2025-06-28 00:00:00 13B MICU-D GOOD
# 2025-06-29 00:00:00 13B MICU-D CALL
# 2025-06-30 00:00:00 13B MICU-D POST
# ['Ambulatory', 'MICU - D', 'Janeway - D', 'Janeway - D', 'Ambulatory', 'MICU - A', 'Solids', 'Brancati - B', 'Ambulatory', 'Janeway - B', 'Janeway - B', 'Vacation', 'Ambulatory', 'Leuks', 'Off', 'Janeway - A ', 'Janeway - A', 'MPC - C', 'Ambulatory', 'Vacation', 'Subspecialty', 'MICU - B', 'Ambulatory', 'Brancati - A', 'Janeway - D', 'Janeway - D', 'Ambulatory', 'CCU - A']
# 1A Ambulatory
# [datetime.datetime(2024, 7, 1, 0, 0), datetime.datetime(2024, 7, 2, 0, 0), datetime.datetime(2024, 7, 3, 0, 0), datetime.datetime(2024, 7, 4, 0, 0), datetime.datetime(2024, 7, 5, 0, 0), datetime.datetime(2024, 7, 6, 0, 0), datetime.datetime(2024, 7, 7, 0, 0), datetime.datetime(2024, 7, 8, 0, 0), datetime.datetime(2024, 7, 9, 0, 0), datetime.datetime(2024, 7, 10, 0, 0)] 10
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2024-07-01 00:00:00 1A Ambulatory DAY
# 2024-07-02 00:00:00 1A Ambulatory DAY
# 2024-07-03 00:00:00 1A Ambulatory DAY
# 2024-07-04 00:00:00 1A Ambulatory DAY
# 2024-07-05 00:00:00 1A Ambulatory DAY
# 2024-07-06 00:00:00 1A Ambulatory OFF
# 2024-07-07 00:00:00 1A Ambulatory OFF
# 2024-07-08 00:00:00 1A Ambulatory DAY
# 2024-07-09 00:00:00 1A Ambulatory DAY
# 2024-07-10 00:00:00 1A Ambulatory DAY
# 1B MICU-D
# [datetime.datetime(2024, 7, 11, 0, 0), datetime.datetime(2024, 7, 12, 0, 0), datetime.datetime(2024, 7, 13, 0, 0), datetime.datetime(2024, 7, 14, 0, 0), datetime.datetime(2024, 7, 15, 0, 0), datetime.datetime(2024, 7, 16, 0, 0), datetime.datetime(2024, 7, 17, 0, 0), datetime.datetime(2024, 7, 18, 0, 0), datetime.datetime(2024, 7, 19, 0, 0), datetime.datetime(2024, 7, 20, 0, 0), datetime.datetime(2024, 7, 21, 0, 0), datetime.datetime(2024, 7, 22, 0, 0), datetime.datetime(2024, 7, 23, 0, 0), datetime.datetime(2024, 7, 24, 0, 0)] 14
# ['OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', '*POST'] 15
# *POST
# 2024-07-11 00:00:00 1B MICU-D OFF
# 2024-07-12 00:00:00 1B MICU-D CALL
# 2024-07-13 00:00:00 1B MICU-D POST
# 2024-07-14 00:00:00 1B MICU-D GOOD
# 2024-07-15 00:00:00 1B MICU-D CALL
# 2024-07-16 00:00:00 1B MICU-D POST
# 2024-07-17 00:00:00 1B MICU-D OFF
# 2024-07-18 00:00:00 1B MICU-D CALL
# 2024-07-19 00:00:00 1B MICU-D POST
# 2024-07-20 00:00:00 1B MICU-D GOOD
# 2024-07-21 00:00:00 1B MICU-D CALL
# 2024-07-22 00:00:00 1B MICU-D POST
# 2024-07-23 00:00:00 1B MICU-D OFF
# 2024-07-24 00:00:00 1B MICU-D CALL
# 2024-07-25 00:00:00 1B MICU-D *POST
# 2A Janeway-D
# [datetime.datetime(2024, 7, 25, 0, 0), datetime.datetime(2024, 7, 26, 0, 0), datetime.datetime(2024, 7, 27, 0, 0), datetime.datetime(2024, 7, 28, 0, 0), datetime.datetime(2024, 7, 29, 0, 0), datetime.datetime(2024, 7, 30, 0, 0), datetime.datetime(2024, 7, 31, 0, 0), datetime.datetime(2024, 8, 1, 0, 0), datetime.datetime(2024, 8, 2, 0, 0), datetime.datetime(2024, 8, 3, 0, 0), datetime.datetime(2024, 8, 4, 0, 0), datetime.datetime(2024, 8, 5, 0, 0), datetime.datetime(2024, 8, 6, 0, 0), datetime.datetime(2024, 8, 7, 0, 0)] 14
# ['POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY'] 14
# DAY
# 2024-07-25 00:00:00 2A Janeway-D POST
# 2024-07-26 00:00:00 2A Janeway-D DAY
# 2024-07-27 00:00:00 2A Janeway-D OFF
# 2024-07-28 00:00:00 2A Janeway-D CALL
# 2024-07-29 00:00:00 2A Janeway-D POST
# 2024-07-30 00:00:00 2A Janeway-D DAY
# 2024-07-31 00:00:00 2A Janeway-D GOOD
# 2024-08-01 00:00:00 2A Janeway-D CALL
# 2024-08-02 00:00:00 2A Janeway-D POST
# 2024-08-03 00:00:00 2A Janeway-D DAY
# 2024-08-04 00:00:00 2A Janeway-D OFF
# 2024-08-05 00:00:00 2A Janeway-D CALL
# 2024-08-06 00:00:00 2A Janeway-D POST
# 2024-08-07 00:00:00 2A Janeway-D DAY
# 2B Janeway-D
# [datetime.datetime(2024, 8, 8, 0, 0), datetime.datetime(2024, 8, 9, 0, 0), datetime.datetime(2024, 8, 10, 0, 0), datetime.datetime(2024, 8, 11, 0, 0), datetime.datetime(2024, 8, 12, 0, 0), datetime.datetime(2024, 8, 13, 0, 0), datetime.datetime(2024, 8, 14, 0, 0), datetime.datetime(2024, 8, 15, 0, 0), datetime.datetime(2024, 8, 16, 0, 0), datetime.datetime(2024, 8, 17, 0, 0), datetime.datetime(2024, 8, 18, 0, 0), datetime.datetime(2024, 8, 19, 0, 0), datetime.datetime(2024, 8, 20, 0, 0), datetime.datetime(2024, 8, 21, 0, 0)] 14
# ['GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', '*POST'] 15
# *POST
# 2024-08-08 00:00:00 2B Janeway-D GOOD
# 2024-08-09 00:00:00 2B Janeway-D CALL
# 2024-08-10 00:00:00 2B Janeway-D POST
# 2024-08-11 00:00:00 2B Janeway-D DAY
# 2024-08-12 00:00:00 2B Janeway-D OFF
# 2024-08-13 00:00:00 2B Janeway-D CALL
# 2024-08-14 00:00:00 2B Janeway-D POST
# 2024-08-15 00:00:00 2B Janeway-D DAY
# 2024-08-16 00:00:00 2B Janeway-D OFF
# 2024-08-17 00:00:00 2B Janeway-D CALL
# 2024-08-18 00:00:00 2B Janeway-D POST
# 2024-08-19 00:00:00 2B Janeway-D DAY
# 2024-08-20 00:00:00 2B Janeway-D GOOD
# 2024-08-21 00:00:00 2B Janeway-D CALL
# 2024-08-22 00:00:00 2B Janeway-D *POST
# 3A Ambulatory
# [datetime.datetime(2024, 8, 22, 0, 0), datetime.datetime(2024, 8, 23, 0, 0), datetime.datetime(2024, 8, 24, 0, 0), datetime.datetime(2024, 8, 25, 0, 0), datetime.datetime(2024, 8, 26, 0, 0), datetime.datetime(2024, 8, 27, 0, 0), datetime.datetime(2024, 8, 28, 0, 0), datetime.datetime(2024, 8, 29, 0, 0), datetime.datetime(2024, 8, 30, 0, 0), datetime.datetime(2024, 8, 31, 0, 0), datetime.datetime(2024, 9, 1, 0, 0), datetime.datetime(2024, 9, 2, 0, 0), datetime.datetime(2024, 9, 3, 0, 0), datetime.datetime(2024, 9, 4, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2024-08-22 00:00:00 3A Ambulatory DAY
# 2024-08-23 00:00:00 3A Ambulatory DAY
# 2024-08-24 00:00:00 3A Ambulatory OFF
# 2024-08-25 00:00:00 3A Ambulatory OFF
# 2024-08-26 00:00:00 3A Ambulatory DAY
# 2024-08-27 00:00:00 3A Ambulatory DAY
# 2024-08-28 00:00:00 3A Ambulatory DAY
# 2024-08-29 00:00:00 3A Ambulatory DAY
# 2024-08-30 00:00:00 3A Ambulatory DAY
# 2024-08-31 00:00:00 3A Ambulatory OFF
# 2024-09-01 00:00:00 3A Ambulatory OFF
# 2024-09-02 00:00:00 3A Ambulatory DAY
# 2024-09-03 00:00:00 3A Ambulatory DAY
# 2024-09-04 00:00:00 3A Ambulatory DAY
# 3B MICU-A
# [datetime.datetime(2024, 9, 5, 0, 0), datetime.datetime(2024, 9, 6, 0, 0), datetime.datetime(2024, 9, 7, 0, 0), datetime.datetime(2024, 9, 8, 0, 0), datetime.datetime(2024, 9, 9, 0, 0), datetime.datetime(2024, 9, 10, 0, 0), datetime.datetime(2024, 9, 11, 0, 0), datetime.datetime(2024, 9, 12, 0, 0), datetime.datetime(2024, 9, 13, 0, 0), datetime.datetime(2024, 9, 14, 0, 0), datetime.datetime(2024, 9, 15, 0, 0), datetime.datetime(2024, 9, 16, 0, 0), datetime.datetime(2024, 9, 17, 0, 0), datetime.datetime(2024, 9, 18, 0, 0)] 14
# ['GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', '*POST'] 15
# *POST
# 2024-09-05 00:00:00 3B MICU-A GOOD
# 2024-09-06 00:00:00 3B MICU-A CALL
# 2024-09-07 00:00:00 3B MICU-A POST
# 2024-09-08 00:00:00 3B MICU-A OFF
# 2024-09-09 00:00:00 3B MICU-A CALL
# 2024-09-10 00:00:00 3B MICU-A POST
# 2024-09-11 00:00:00 3B MICU-A GOOD
# 2024-09-12 00:00:00 3B MICU-A CALL
# 2024-09-13 00:00:00 3B MICU-A POST
# 2024-09-14 00:00:00 3B MICU-A OFF
# 2024-09-15 00:00:00 3B MICU-A CALL
# 2024-09-16 00:00:00 3B MICU-A POST
# 2024-09-17 00:00:00 3B MICU-A GOOD
# 2024-09-18 00:00:00 3B MICU-A CALL
# 2024-09-19 00:00:00 3B MICU-A *POST
# 4A Solids
# [datetime.datetime(2024, 9, 19, 0, 0), datetime.datetime(2024, 9, 20, 0, 0), datetime.datetime(2024, 9, 21, 0, 0), datetime.datetime(2024, 9, 22, 0, 0), datetime.datetime(2024, 9, 23, 0, 0), datetime.datetime(2024, 9, 24, 0, 0), datetime.datetime(2024, 9, 25, 0, 0), datetime.datetime(2024, 9, 26, 0, 0), datetime.datetime(2024, 9, 27, 0, 0), datetime.datetime(2024, 9, 28, 0, 0), datetime.datetime(2024, 9, 29, 0, 0), datetime.datetime(2024, 9, 30, 0, 0), datetime.datetime(2024, 10, 1, 0, 0), datetime.datetime(2024, 10, 2, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2024-09-19 00:00:00 4A Solids DAY
# 2024-09-20 00:00:00 4A Solids DAY
# 2024-09-21 00:00:00 4A Solids DAY
# 2024-09-22 00:00:00 4A Solids OFF
# 2024-09-23 00:00:00 4A Solids DAY
# 2024-09-24 00:00:00 4A Solids DAY
# 2024-09-25 00:00:00 4A Solids DAY
# 2024-09-26 00:00:00 4A Solids DAY
# 2024-09-27 00:00:00 4A Solids DAY
# 2024-09-28 00:00:00 4A Solids DAY
# 2024-09-29 00:00:00 4A Solids OFF
# 2024-09-30 00:00:00 4A Solids DAY
# 2024-10-01 00:00:00 4A Solids DAY
# 2024-10-02 00:00:00 4A Solids DAY
# 4B Brancati-B
# [datetime.datetime(2024, 10, 3, 0, 0), datetime.datetime(2024, 10, 4, 0, 0), datetime.datetime(2024, 10, 5, 0, 0), datetime.datetime(2024, 10, 6, 0, 0), datetime.datetime(2024, 10, 7, 0, 0), datetime.datetime(2024, 10, 8, 0, 0), datetime.datetime(2024, 10, 9, 0, 0), datetime.datetime(2024, 10, 10, 0, 0), datetime.datetime(2024, 10, 11, 0, 0), datetime.datetime(2024, 10, 12, 0, 0), datetime.datetime(2024, 10, 13, 0, 0), datetime.datetime(2024, 10, 14, 0, 0), datetime.datetime(2024, 10, 15, 0, 0), datetime.datetime(2024, 10, 16, 0, 0)] 14
# ['DAY', 'OFF', 'OFF', 'DAY', 'DAY', 'DAY', 'OFF', 'NIGHT', 'NIGHT', 'NIGHT', 'NIGHT', 'NIGHT', 'NIGHT', 'NIGHT', '*POST'] 15
# *POST
# 2024-10-03 00:00:00 4B Brancati-B DAY
# 2024-10-04 00:00:00 4B Brancati-B OFF
# 2024-10-05 00:00:00 4B Brancati-B OFF
# 2024-10-06 00:00:00 4B Brancati-B DAY
# 2024-10-07 00:00:00 4B Brancati-B DAY
# 2024-10-08 00:00:00 4B Brancati-B DAY
# 2024-10-09 00:00:00 4B Brancati-B OFF
# 2024-10-10 00:00:00 4B Brancati-B NIGHT
# 2024-10-11 00:00:00 4B Brancati-B NIGHT
# 2024-10-12 00:00:00 4B Brancati-B NIGHT
# 2024-10-13 00:00:00 4B Brancati-B NIGHT
# 2024-10-14 00:00:00 4B Brancati-B NIGHT
# 2024-10-15 00:00:00 4B Brancati-B NIGHT
# 2024-10-16 00:00:00 4B Brancati-B NIGHT
# 2024-10-17 00:00:00 4B Brancati-B *POST
# 5A Ambulatory
# [datetime.datetime(2024, 10, 17, 0, 0), datetime.datetime(2024, 10, 18, 0, 0), datetime.datetime(2024, 10, 19, 0, 0), datetime.datetime(2024, 10, 20, 0, 0), datetime.datetime(2024, 10, 21, 0, 0), datetime.datetime(2024, 10, 22, 0, 0), datetime.datetime(2024, 10, 23, 0, 0), datetime.datetime(2024, 10, 24, 0, 0), datetime.datetime(2024, 10, 25, 0, 0), datetime.datetime(2024, 10, 26, 0, 0), datetime.datetime(2024, 10, 27, 0, 0), datetime.datetime(2024, 10, 28, 0, 0), datetime.datetime(2024, 10, 29, 0, 0), datetime.datetime(2024, 10, 30, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2024-10-17 00:00:00 5A Ambulatory DAY
# 2024-10-18 00:00:00 5A Ambulatory DAY
# 2024-10-19 00:00:00 5A Ambulatory OFF
# 2024-10-20 00:00:00 5A Ambulatory OFF
# 2024-10-21 00:00:00 5A Ambulatory DAY
# 2024-10-22 00:00:00 5A Ambulatory DAY
# 2024-10-23 00:00:00 5A Ambulatory DAY
# 2024-10-24 00:00:00 5A Ambulatory DAY
# 2024-10-25 00:00:00 5A Ambulatory DAY
# 2024-10-26 00:00:00 5A Ambulatory OFF
# 2024-10-27 00:00:00 5A Ambulatory OFF
# 2024-10-28 00:00:00 5A Ambulatory DAY
# 2024-10-29 00:00:00 5A Ambulatory DAY
# 2024-10-30 00:00:00 5A Ambulatory DAY
# 5B Janeway-B
# [datetime.datetime(2024, 10, 31, 0, 0), datetime.datetime(2024, 11, 1, 0, 0), datetime.datetime(2024, 11, 2, 0, 0), datetime.datetime(2024, 11, 3, 0, 0), datetime.datetime(2024, 11, 4, 0, 0), datetime.datetime(2024, 11, 5, 0, 0), datetime.datetime(2024, 11, 6, 0, 0), datetime.datetime(2024, 11, 7, 0, 0), datetime.datetime(2024, 11, 8, 0, 0), datetime.datetime(2024, 11, 9, 0, 0), datetime.datetime(2024, 11, 10, 0, 0), datetime.datetime(2024, 11, 11, 0, 0), datetime.datetime(2024, 11, 12, 0, 0), datetime.datetime(2024, 11, 13, 0, 0)] 14
# ['POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY'] 14
# DAY
# 2024-10-31 00:00:00 5B Janeway-B POST
# 2024-11-01 00:00:00 5B Janeway-B DAY
# 2024-11-02 00:00:00 5B Janeway-B OFF
# 2024-11-03 00:00:00 5B Janeway-B CALL
# 2024-11-04 00:00:00 5B Janeway-B POST
# 2024-11-05 00:00:00 5B Janeway-B DAY
# 2024-11-06 00:00:00 5B Janeway-B GOOD
# 2024-11-07 00:00:00 5B Janeway-B CALL
# 2024-11-08 00:00:00 5B Janeway-B POST
# 2024-11-09 00:00:00 5B Janeway-B DAY
# 2024-11-10 00:00:00 5B Janeway-B OFF
# 2024-11-11 00:00:00 5B Janeway-B CALL
# 2024-11-12 00:00:00 5B Janeway-B POST
# 2024-11-13 00:00:00 5B Janeway-B DAY
# 6A Janeway-B
# [datetime.datetime(2024, 11, 14, 0, 0), datetime.datetime(2024, 11, 15, 0, 0), datetime.datetime(2024, 11, 16, 0, 0), datetime.datetime(2024, 11, 17, 0, 0), datetime.datetime(2024, 11, 18, 0, 0), datetime.datetime(2024, 11, 19, 0, 0), datetime.datetime(2024, 11, 20, 0, 0), datetime.datetime(2024, 11, 21, 0, 0), datetime.datetime(2024, 11, 22, 0, 0), datetime.datetime(2024, 11, 23, 0, 0), datetime.datetime(2024, 11, 24, 0, 0), datetime.datetime(2024, 11, 25, 0, 0), datetime.datetime(2024, 11, 26, 0, 0), datetime.datetime(2024, 11, 27, 0, 0)] 14
# ['GOOD', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'OFF', 'CALL', 'POST', 'DAY', 'GOOD', 'CALL', '*POST'] 15
# *POST
# 2024-11-14 00:00:00 6A Janeway-B GOOD
# 2024-11-15 00:00:00 6A Janeway-B CALL
# 2024-11-16 00:00:00 6A Janeway-B POST
# 2024-11-17 00:00:00 6A Janeway-B DAY
# 2024-11-18 00:00:00 6A Janeway-B OFF
# 2024-11-19 00:00:00 6A Janeway-B CALL
# 2024-11-20 00:00:00 6A Janeway-B POST
# 2024-11-21 00:00:00 6A Janeway-B DAY
# 2024-11-22 00:00:00 6A Janeway-B OFF
# 2024-11-23 00:00:00 6A Janeway-B CALL
# 2024-11-24 00:00:00 6A Janeway-B POST
# 2024-11-25 00:00:00 6A Janeway-B DAY
# 2024-11-26 00:00:00 6A Janeway-B GOOD
# 2024-11-27 00:00:00 6A Janeway-B CALL
# 2024-11-28 00:00:00 6A Janeway-B *POST
# 6B Vacation
# [datetime.datetime(2024, 11, 28, 0, 0), datetime.datetime(2024, 11, 29, 0, 0), datetime.datetime(2024, 11, 30, 0, 0), datetime.datetime(2024, 12, 1, 0, 0), datetime.datetime(2024, 12, 2, 0, 0), datetime.datetime(2024, 12, 3, 0, 0), datetime.datetime(2024, 12, 4, 0, 0), datetime.datetime(2024, 12, 5, 0, 0), datetime.datetime(2024, 12, 6, 0, 0), datetime.datetime(2024, 12, 7, 0, 0), datetime.datetime(2024, 12, 8, 0, 0), datetime.datetime(2024, 12, 9, 0, 0), datetime.datetime(2024, 12, 10, 0, 0), datetime.datetime(2024, 12, 11, 0, 0)] 14
# ['VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION', 'VACATION'] 14
# VACATION
# 2024-11-28 00:00:00 6B Vacation VACATION
# 2024-11-29 00:00:00 6B Vacation VACATION
# 2024-11-30 00:00:00 6B Vacation VACATION
# 2024-12-01 00:00:00 6B Vacation VACATION
# 2024-12-02 00:00:00 6B Vacation VACATION
# 2024-12-03 00:00:00 6B Vacation VACATION
# 2024-12-04 00:00:00 6B Vacation VACATION
# 2024-12-05 00:00:00 6B Vacation VACATION
# 2024-12-06 00:00:00 6B Vacation VACATION
# 2024-12-07 00:00:00 6B Vacation VACATION
# 2024-12-08 00:00:00 6B Vacation VACATION
# 2024-12-09 00:00:00 6B Vacation VACATION
# 2024-12-10 00:00:00 6B Vacation VACATION
# 2024-12-11 00:00:00 6B Vacation VACATION
# 7A Ambulatory
# [datetime.datetime(2024, 12, 12, 0, 0), datetime.datetime(2024, 12, 13, 0, 0), datetime.datetime(2024, 12, 14, 0, 0), datetime.datetime(2024, 12, 15, 0, 0), datetime.datetime(2024, 12, 16, 0, 0), datetime.datetime(2024, 12, 17, 0, 0), datetime.datetime(2024, 12, 18, 0, 0), datetime.datetime(2024, 12, 19, 0, 0)] 8
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2024-12-12 00:00:00 7A Ambulatory DAY
# 2024-12-13 00:00:00 7A Ambulatory DAY
# 2024-12-14 00:00:00 7A Ambulatory OFF
# 2024-12-15 00:00:00 7A Ambulatory OFF
# 2024-12-16 00:00:00 7A Ambulatory DAY
# 2024-12-17 00:00:00 7A Ambulatory DAY
# 2024-12-18 00:00:00 7A Ambulatory DAY
# 2024-12-19 00:00:00 7A Ambulatory DAY
# Holiday 1 Leuks
# [datetime.datetime(2024, 12, 20, 0, 0), datetime.datetime(2024, 12, 21, 0, 0), datetime.datetime(2024, 12, 22, 0, 0), datetime.datetime(2024, 12, 23, 0, 0), datetime.datetime(2024, 12, 24, 0, 0), datetime.datetime(2024, 12, 25, 0, 0), datetime.datetime(2024, 12, 26, 0, 0)] 7
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2024-12-20 00:00:00 Holiday 1 Leuks DAY
# 2024-12-21 00:00:00 Holiday 1 Leuks DAY
# 2024-12-22 00:00:00 Holiday 1 Leuks OFF
# 2024-12-23 00:00:00 Holiday 1 Leuks DAY
# 2024-12-24 00:00:00 Holiday 1 Leuks DAY
# 2024-12-25 00:00:00 Holiday 1 Leuks DAY
# 2024-12-26 00:00:00 Holiday 1 Leuks DAY
# Holiday 2 Off
# [datetime.datetime(2024, 12, 27, 0, 0), datetime.datetime(2024, 12, 28, 0, 0), datetime.datetime(2024, 12, 29, 0, 0), datetime.datetime(2024, 12, 30, 0, 0), datetime.datetime(2024, 12, 31, 0, 0), datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 2, 0, 0)] 7
# ['OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF', 'OFF'] 14
# OFF
# 2024-12-27 00:00:00 Holiday 2 Off OFF
# 2024-12-28 00:00:00 Holiday 2 Off OFF
# 2024-12-29 00:00:00 Holiday 2 Off OFF
# 2024-12-30 00:00:00 Holiday 2 Off OFF
# 2024-12-31 00:00:00 Holiday 2 Off OFF
# 2025-01-01 00:00:00 Holiday 2 Off OFF
# ...
# 2024-11-22 00:00:00 6A  -
# 2024-11-23 00:00:00 6A  -
# 2024-11-24 00:00:00 6A  -
# 2024-11-25 00:00:00 6A  -
# 2024-11-26 00:00:00 6A  -
# 2024-11-27 00:00:00 6A  -
# 6B
# [datetime.datetime(2024, 11, 28, 0, 0), datetime.datetime(2024, 11, 29, 0, 0), datetime.datetime(2024, 11, 30, 0, 0), datetime.datetime(2024, 12, 1, 0, 0), datetime.datetime(2024, 12, 2, 0, 0), datetime.datetime(2024, 12, 3, 0, 0), datetime.datetime(2024, 12, 4, 0, 0), datetime.datetime(2024, 12, 5, 0, 0), datetime.datetime(2024, 12, 6, 0, 0), datetime.datetime(2024, 12, 7, 0, 0), datetime.datetime(2024, 12, 8, 0, 0), datetime.datetime(2024, 12, 9, 0, 0), datetime.datetime(2024, 12, 10, 0, 0), datetime.datetime(2024, 12, 11, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2024-11-28 00:00:00 6B  -
# 2024-11-29 00:00:00 6B  -
# 2024-11-30 00:00:00 6B  -
# 2024-12-01 00:00:00 6B  -
# 2024-12-02 00:00:00 6B  -
# 2024-12-03 00:00:00 6B  -
# 2024-12-04 00:00:00 6B  -
# 2024-12-05 00:00:00 6B  -
# 2024-12-06 00:00:00 6B  -
# 2024-12-07 00:00:00 6B  -
# 2024-12-08 00:00:00 6B  -
# 2024-12-09 00:00:00 6B  -
# 2024-12-10 00:00:00 6B  -
# 2024-12-11 00:00:00 6B  -
# 7A
# [datetime.datetime(2024, 12, 12, 0, 0), datetime.datetime(2024, 12, 13, 0, 0), datetime.datetime(2024, 12, 14, 0, 0), datetime.datetime(2024, 12, 15, 0, 0), datetime.datetime(2024, 12, 16, 0, 0), datetime.datetime(2024, 12, 17, 0, 0), datetime.datetime(2024, 12, 18, 0, 0), datetime.datetime(2024, 12, 19, 0, 0)] 8
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2024-12-12 00:00:00 7A  -
# 2024-12-13 00:00:00 7A  -
# 2024-12-14 00:00:00 7A  -
# 2024-12-15 00:00:00 7A  -
# 2024-12-16 00:00:00 7A  -
# 2024-12-17 00:00:00 7A  -
# 2024-12-18 00:00:00 7A  -
# 2024-12-19 00:00:00 7A  -
# Holiday 1
# [datetime.datetime(2024, 12, 20, 0, 0), datetime.datetime(2024, 12, 21, 0, 0), datetime.datetime(2024, 12, 22, 0, 0), datetime.datetime(2024, 12, 23, 0, 0), datetime.datetime(2024, 12, 24, 0, 0), datetime.datetime(2024, 12, 25, 0, 0), datetime.datetime(2024, 12, 26, 0, 0)] 7
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2024-12-20 00:00:00 Holiday 1  -
# 2024-12-21 00:00:00 Holiday 1  -
# 2024-12-22 00:00:00 Holiday 1  -
# 2024-12-23 00:00:00 Holiday 1  -
# 2024-12-24 00:00:00 Holiday 1  -
# 2024-12-25 00:00:00 Holiday 1  -
# 2024-12-26 00:00:00 Holiday 1  -
# Holiday 2
# [datetime.datetime(2024, 12, 27, 0, 0), datetime.datetime(2024, 12, 28, 0, 0), datetime.datetime(2024, 12, 29, 0, 0), datetime.datetime(2024, 12, 30, 0, 0), datetime.datetime(2024, 12, 31, 0, 0), datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 1, 2, 0, 0)] 7
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2024-12-27 00:00:00 Holiday 2  -
# 2024-12-28 00:00:00 Holiday 2  -
# 2024-12-29 00:00:00 Holiday 2  -
# 2024-12-30 00:00:00 Holiday 2  -
# 2024-12-31 00:00:00 Holiday 2  -
# 2025-01-01 00:00:00 Holiday 2  -
# 2025-01-02 00:00:00 Holiday 2  -
# 7B
# [datetime.datetime(2025, 1, 3, 0, 0), datetime.datetime(2025, 1, 4, 0, 0), datetime.datetime(2025, 1, 5, 0, 0), datetime.datetime(2025, 1, 6, 0, 0), datetime.datetime(2025, 1, 7, 0, 0), datetime.datetime(2025, 1, 8, 0, 0), datetime.datetime(2025, 1, 9, 0, 0), datetime.datetime(2025, 1, 10, 0, 0), datetime.datetime(2025, 1, 11, 0, 0), datetime.datetime(2025, 1, 12, 0, 0), datetime.datetime(2025, 1, 13, 0, 0), datetime.datetime(2025, 1, 14, 0, 0), datetime.datetime(2025, 1, 15, 0, 0)] 13
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2025-01-03 00:00:00 7B  -
# 2025-01-04 00:00:00 7B  -
# 2025-01-05 00:00:00 7B  -
# 2025-01-06 00:00:00 7B  -
# 2025-01-07 00:00:00 7B  -
# 2025-01-08 00:00:00 7B  -
# 2025-01-09 00:00:00 7B  -
# 2025-01-10 00:00:00 7B  -
# 2025-01-11 00:00:00 7B  -
# 2025-01-12 00:00:00 7B  -
# 2025-01-13 00:00:00 7B  -
# 2025-01-14 00:00:00 7B  -
# 2025-01-15 00:00:00 7B  -
# 8A
# [datetime.datetime(2025, 1, 16, 0, 0), datetime.datetime(2025, 1, 17, 0, 0), datetime.datetime(2025, 1, 18, 0, 0), datetime.datetime(2025, 1, 19, 0, 0), datetime.datetime(2025, 1, 20, 0, 0), datetime.datetime(2025, 1, 21, 0, 0), datetime.datetime(2025, 1, 22, 0, 0), datetime.datetime(2025, 1, 23, 0, 0), datetime.datetime(2025, 1, 24, 0, 0), datetime.datetime(2025, 1, 25, 0, 0), datetime.datetime(2025, 1, 26, 0, 0), datetime.datetime(2025, 1, 27, 0, 0), datetime.datetime(2025, 1, 28, 0, 0), datetime.datetime(2025, 1, 29, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2025-01-16 00:00:00 8A  -
# 2025-01-17 00:00:00 8A  -
# 2025-01-18 00:00:00 8A  -
# 2025-01-19 00:00:00 8A  -
# 2025-01-20 00:00:00 8A  -
# 2025-01-21 00:00:00 8A  -
# 2025-01-22 00:00:00 8A  -
# 2025-01-23 00:00:00 8A  -
# 2025-01-24 00:00:00 8A  -
# 2025-01-25 00:00:00 8A  -
# 2025-01-26 00:00:00 8A  -
# 2025-01-27 00:00:00 8A  -
# 2025-01-28 00:00:00 8A  -
# 2025-01-29 00:00:00 8A  -
# 8B
# [datetime.datetime(2025, 1, 30, 0, 0), datetime.datetime(2025, 1, 31, 0, 0), datetime.datetime(2025, 2, 1, 0, 0), datetime.datetime(2025, 2, 2, 0, 0), datetime.datetime(2025, 2, 3, 0, 0), datetime.datetime(2025, 2, 4, 0, 0), datetime.datetime(2025, 2, 5, 0, 0), datetime.datetime(2025, 2, 6, 0, 0), datetime.datetime(2025, 2, 7, 0, 0), datetime.datetime(2025, 2, 8, 0, 0), datetime.datetime(2025, 2, 9, 0, 0), datetime.datetime(2025, 2, 10, 0, 0), datetime.datetime(2025, 2, 11, 0, 0), datetime.datetime(2025, 2, 12, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2025-01-30 00:00:00 8B  -
# 2025-01-31 00:00:00 8B  -
# 2025-02-01 00:00:00 8B  -
# 2025-02-02 00:00:00 8B  -
# 2025-02-03 00:00:00 8B  -
# 2025-02-04 00:00:00 8B  -
# 2025-02-05 00:00:00 8B  -
# 2025-02-06 00:00:00 8B  -
# 2025-02-07 00:00:00 8B  -
# 2025-02-08 00:00:00 8B  -
# 2025-02-09 00:00:00 8B  -
# 2025-02-10 00:00:00 8B  -
# 2025-02-11 00:00:00 8B  -
# 2025-02-12 00:00:00 8B  -
# 9A
# [datetime.datetime(2025, 2, 13, 0, 0), datetime.datetime(2025, 2, 14, 0, 0), datetime.datetime(2025, 2, 15, 0, 0), datetime.datetime(2025, 2, 16, 0, 0), datetime.datetime(2025, 2, 17, 0, 0), datetime.datetime(2025, 2, 18, 0, 0), datetime.datetime(2025, 2, 19, 0, 0), datetime.datetime(2025, 2, 20, 0, 0), datetime.datetime(2025, 2, 21, 0, 0), datetime.datetime(2025, 2, 22, 0, 0), datetime.datetime(2025, 2, 23, 0, 0), datetime.datetime(2025, 2, 24, 0, 0), datetime.datetime(2025, 2, 25, 0, 0), datetime.datetime(2025, 2, 26, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2025-02-13 00:00:00 9A  -
# 2025-02-14 00:00:00 9A  -
# 2025-02-15 00:00:00 9A  -
# 2025-02-16 00:00:00 9A  -
# 2025-02-17 00:00:00 9A  -
# 2025-02-18 00:00:00 9A  -
# 2025-02-19 00:00:00 9A  -
# 2025-02-20 00:00:00 9A  -
# 2025-02-21 00:00:00 9A  -
# 2025-02-22 00:00:00 9A  -
# 2025-02-23 00:00:00 9A  -
# 2025-02-24 00:00:00 9A  -
# 2025-02-25 00:00:00 9A  -
# 2025-02-26 00:00:00 9A  -
# 9B
# [datetime.datetime(2025, 2, 27, 0, 0), datetime.datetime(2025, 2, 28, 0, 0), datetime.datetime(2025, 3, 1, 0, 0), datetime.datetime(2025, 3, 2, 0, 0), datetime.datetime(2025, 3, 3, 0, 0), datetime.datetime(2025, 3, 4, 0, 0), datetime.datetime(2025, 3, 5, 0, 0), datetime.datetime(2025, 3, 6, 0, 0), datetime.datetime(2025, 3, 7, 0, 0), datetime.datetime(2025, 3, 8, 0, 0), datetime.datetime(2025, 3, 9, 0, 0), datetime.datetime(2025, 3, 10, 0, 0), datetime.datetime(2025, 3, 11, 0, 0), datetime.datetime(2025, 3, 12, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2025-02-27 00:00:00 9B  -
# 2025-02-28 00:00:00 9B  -
# 2025-03-01 00:00:00 9B  -
# 2025-03-02 00:00:00 9B  -
# 2025-03-03 00:00:00 9B  -
# 2025-03-04 00:00:00 9B  -
# 2025-03-05 00:00:00 9B  -
# 2025-03-06 00:00:00 9B  -
# 2025-03-07 00:00:00 9B  -
# 2025-03-08 00:00:00 9B  -
# 2025-03-09 00:00:00 9B  -
# 2025-03-10 00:00:00 9B  -
# 2025-03-11 00:00:00 9B  -
# 2025-03-12 00:00:00 9B  -
# 10A
# [datetime.datetime(2025, 3, 13, 0, 0), datetime.datetime(2025, 3, 14, 0, 0), datetime.datetime(2025, 3, 15, 0, 0), datetime.datetime(2025, 3, 16, 0, 0), datetime.datetime(2025, 3, 17, 0, 0), datetime.datetime(2025, 3, 18, 0, 0), datetime.datetime(2025, 3, 19, 0, 0), datetime.datetime(2025, 3, 20, 0, 0), datetime.datetime(2025, 3, 21, 0, 0), datetime.datetime(2025, 3, 22, 0, 0), datetime.datetime(2025, 3, 23, 0, 0), datetime.datetime(2025, 3, 24, 0, 0), datetime.datetime(2025, 3, 25, 0, 0), datetime.datetime(2025, 3, 26, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2025-03-13 00:00:00 10A  -
# 2025-03-14 00:00:00 10A  -
# 2025-03-15 00:00:00 10A  -
# 2025-03-16 00:00:00 10A  -
# 2025-03-17 00:00:00 10A  -
# 2025-03-18 00:00:00 10A  -
# 2025-03-19 00:00:00 10A  -
# 2025-03-20 00:00:00 10A  -
# 2025-03-21 00:00:00 10A  -
# 2025-03-22 00:00:00 10A  -
# 2025-03-23 00:00:00 10A  -
# 2025-03-24 00:00:00 10A  -
# 2025-03-25 00:00:00 10A  -
# 2025-03-26 00:00:00 10A  -
# 10B
# [datetime.datetime(2025, 3, 27, 0, 0), datetime.datetime(2025, 3, 28, 0, 0), datetime.datetime(2025, 3, 29, 0, 0), datetime.datetime(2025, 3, 30, 0, 0), datetime.datetime(2025, 3, 31, 0, 0), datetime.datetime(2025, 4, 1, 0, 0), datetime.datetime(2025, 4, 2, 0, 0), datetime.datetime(2025, 4, 3, 0, 0), datetime.datetime(2025, 4, 4, 0, 0), datetime.datetime(2025, 4, 5, 0, 0), datetime.datetime(2025, 4, 6, 0, 0), datetime.datetime(2025, 4, 7, 0, 0), datetime.datetime(2025, 4, 8, 0, 0), datetime.datetime(2025, 4, 9, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2025-03-27 00:00:00 10B  -
# 2025-03-28 00:00:00 10B  -
# 2025-03-29 00:00:00 10B  -
# 2025-03-30 00:00:00 10B  -
# 2025-03-31 00:00:00 10B  -
# 2025-04-01 00:00:00 10B  -
# 2025-04-02 00:00:00 10B  -
# 2025-04-03 00:00:00 10B  -
# 2025-04-04 00:00:00 10B  -
# 2025-04-05 00:00:00 10B  -
# 2025-04-06 00:00:00 10B  -
# 2025-04-07 00:00:00 10B  -
# 2025-04-08 00:00:00 10B  -
# 2025-04-09 00:00:00 10B  -
# 11A
# [datetime.datetime(2025, 4, 10, 0, 0), datetime.datetime(2025, 4, 11, 0, 0), datetime.datetime(2025, 4, 12, 0, 0), datetime.datetime(2025, 4, 13, 0, 0), datetime.datetime(2025, 4, 14, 0, 0), datetime.datetime(2025, 4, 15, 0, 0), datetime.datetime(2025, 4, 16, 0, 0), datetime.datetime(2025, 4, 17, 0, 0), datetime.datetime(2025, 4, 18, 0, 0), datetime.datetime(2025, 4, 19, 0, 0), datetime.datetime(2025, 4, 20, 0, 0), datetime.datetime(2025, 4, 21, 0, 0), datetime.datetime(2025, 4, 22, 0, 0), datetime.datetime(2025, 4, 23, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2025-04-10 00:00:00 11A  -
# 2025-04-11 00:00:00 11A  -
# 2025-04-12 00:00:00 11A  -
# 2025-04-13 00:00:00 11A  -
# 2025-04-14 00:00:00 11A  -
# 2025-04-15 00:00:00 11A  -
# 2025-04-16 00:00:00 11A  -
# 2025-04-17 00:00:00 11A  -
# 2025-04-18 00:00:00 11A  -
# 2025-04-19 00:00:00 11A  -
# 2025-04-20 00:00:00 11A  -
# 2025-04-21 00:00:00 11A  -
# 2025-04-22 00:00:00 11A  -
# 2025-04-23 00:00:00 11A  -
# 11B
# [datetime.datetime(2025, 4, 24, 0, 0), datetime.datetime(2025, 4, 25, 0, 0), datetime.datetime(2025, 4, 26, 0, 0), datetime.datetime(2025, 4, 27, 0, 0), datetime.datetime(2025, 4, 28, 0, 0), datetime.datetime(2025, 4, 29, 0, 0), datetime.datetime(2025, 4, 30, 0, 0), datetime.datetime(2025, 5, 1, 0, 0), datetime.datetime(2025, 5, 2, 0, 0), datetime.datetime(2025, 5, 3, 0, 0), datetime.datetime(2025, 5, 4, 0, 0), datetime.datetime(2025, 5, 5, 0, 0), datetime.datetime(2025, 5, 6, 0, 0), datetime.datetime(2025, 5, 7, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2025-04-24 00:00:00 11B  -
# 2025-04-25 00:00:00 11B  -
# 2025-04-26 00:00:00 11B  -
# 2025-04-27 00:00:00 11B  -
# 2025-04-28 00:00:00 11B  -
# 2025-04-29 00:00:00 11B  -
# 2025-04-30 00:00:00 11B  -
# 2025-05-01 00:00:00 11B  -
# 2025-05-02 00:00:00 11B  -
# 2025-05-03 00:00:00 11B  -
# 2025-05-04 00:00:00 11B  -
# 2025-05-05 00:00:00 11B  -
# 2025-05-06 00:00:00 11B  -
# 2025-05-07 00:00:00 11B  -
# 12A CCU-B(AK)
# [datetime.datetime(2025, 5, 8, 0, 0), datetime.datetime(2025, 5, 9, 0, 0), datetime.datetime(2025, 5, 10, 0, 0), datetime.datetime(2025, 5, 11, 0, 0), datetime.datetime(2025, 5, 12, 0, 0), datetime.datetime(2025, 5, 13, 0, 0), datetime.datetime(2025, 5, 14, 0, 0), datetime.datetime(2025, 5, 15, 0, 0), datetime.datetime(2025, 5, 16, 0, 0), datetime.datetime(2025, 5, 17, 0, 0), datetime.datetime(2025, 5, 18, 0, 0), datetime.datetime(2025, 5, 19, 0, 0), datetime.datetime(2025, 5, 20, 0, 0), datetime.datetime(2025, 5, 21, 0, 0)] 14
# ['POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF'] 14
# OFF
# 2025-05-08 00:00:00 12A CCU-B(AK) POST
# 2025-05-09 00:00:00 12A CCU-B(AK) OFF
# 2025-05-10 00:00:00 12A CCU-B(AK) CALL
# 2025-05-11 00:00:00 12A CCU-B(AK) POST
# 2025-05-12 00:00:00 12A CCU-B(AK) GOOD
# 2025-05-13 00:00:00 12A CCU-B(AK) CALL
# 2025-05-14 00:00:00 12A CCU-B(AK) POST
# 2025-05-15 00:00:00 12A CCU-B(AK) OFF
# 2025-05-16 00:00:00 12A CCU-B(AK) CALL
# 2025-05-17 00:00:00 12A CCU-B(AK) POST
# 2025-05-18 00:00:00 12A CCU-B(AK) GOOD
# 2025-05-19 00:00:00 12A CCU-B(AK) CALL
# 2025-05-20 00:00:00 12A CCU-B(AK) POST
# 2025-05-21 00:00:00 12A CCU-B(AK) OFF
# 12B CCU-C(AK)
# [datetime.datetime(2025, 5, 22, 0, 0), datetime.datetime(2025, 5, 23, 0, 0), datetime.datetime(2025, 5, 24, 0, 0), datetime.datetime(2025, 5, 25, 0, 0), datetime.datetime(2025, 5, 26, 0, 0), datetime.datetime(2025, 5, 27, 0, 0), datetime.datetime(2025, 5, 28, 0, 0), datetime.datetime(2025, 5, 29, 0, 0), datetime.datetime(2025, 5, 30, 0, 0), datetime.datetime(2025, 5, 31, 0, 0), datetime.datetime(2025, 6, 1, 0, 0), datetime.datetime(2025, 6, 2, 0, 0), datetime.datetime(2025, 6, 3, 0, 0), datetime.datetime(2025, 6, 4, 0, 0)] 14
# ['CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST', 'GOOD', 'CALL', 'POST', 'OFF', 'CALL', 'POST'] 14
# POST
# 2025-05-22 00:00:00 12B CCU-C(AK) CALL
# 2025-05-23 00:00:00 12B CCU-C(AK) POST
# 2025-05-24 00:00:00 12B CCU-C(AK) GOOD
# 2025-05-25 00:00:00 12B CCU-C(AK) CALL
# 2025-05-26 00:00:00 12B CCU-C(AK) POST
# 2025-05-27 00:00:00 12B CCU-C(AK) OFF
# 2025-05-28 00:00:00 12B CCU-C(AK) CALL
# 2025-05-29 00:00:00 12B CCU-C(AK) POST
# 2025-05-30 00:00:00 12B CCU-C(AK) GOOD
# 2025-05-31 00:00:00 12B CCU-C(AK) CALL
# 2025-06-01 00:00:00 12B CCU-C(AK) POST
# 2025-06-02 00:00:00 12B CCU-C(AK) OFF
# 2025-06-03 00:00:00 12B CCU-C(AK) CALL
# 2025-06-04 00:00:00 12B CCU-C(AK) POST
# 13A
# [datetime.datetime(2025, 6, 5, 0, 0), datetime.datetime(2025, 6, 6, 0, 0), datetime.datetime(2025, 6, 7, 0, 0), datetime.datetime(2025, 6, 8, 0, 0), datetime.datetime(2025, 6, 9, 0, 0), datetime.datetime(2025, 6, 10, 0, 0), datetime.datetime(2025, 6, 11, 0, 0), datetime.datetime(2025, 6, 12, 0, 0), datetime.datetime(2025, 6, 13, 0, 0), datetime.datetime(2025, 6, 14, 0, 0), datetime.datetime(2025, 6, 15, 0, 0), datetime.datetime(2025, 6, 16, 0, 0), datetime.datetime(2025, 6, 17, 0, 0), datetime.datetime(2025, 6, 18, 0, 0)] 14
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2025-06-05 00:00:00 13A  -
# 2025-06-06 00:00:00 13A  -
# 2025-06-07 00:00:00 13A  -
# 2025-06-08 00:00:00 13A  -
# 2025-06-09 00:00:00 13A  -
# 2025-06-10 00:00:00 13A  -
# 2025-06-11 00:00:00 13A  -
# 2025-06-12 00:00:00 13A  -
# 2025-06-13 00:00:00 13A  -
# 2025-06-14 00:00:00 13A  -
# 2025-06-15 00:00:00 13A  -
# 2025-06-16 00:00:00 13A  -
# 2025-06-17 00:00:00 13A  -
# 2025-06-18 00:00:00 13A  -
# 13B
# [datetime.datetime(2025, 6, 19, 0, 0), datetime.datetime(2025, 6, 20, 0, 0), datetime.datetime(2025, 6, 21, 0, 0), datetime.datetime(2025, 6, 22, 0, 0), datetime.datetime(2025, 6, 23, 0, 0), datetime.datetime(2025, 6, 24, 0, 0), datetime.datetime(2025, 6, 25, 0, 0), datetime.datetime(2025, 6, 26, 0, 0), datetime.datetime(2025, 6, 27, 0, 0), datetime.datetime(2025, 6, 28, 0, 0), datetime.datetime(2025, 6, 29, 0, 0), datetime.datetime(2025, 6, 30, 0, 0)] 12
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-'] 14
# -
# 2025-06-19 00:00:00 13B  -
# 2025-06-20 00:00:00 13B  -
# 2025-06-21 00:00:00 13B  -
# 2025-06-22 00:00:00 13B  -
# 2025-06-23 00:00:00 13B  -
# 2025-06-24 00:00:00 13B  -
# 2025-06-25 00:00:00 13B  -
# 2025-06-26 00:00:00 13B  -
# 2025-06-27 00:00:00 13B  -
# 2025-06-28 00:00:00 13B  -
# 2025-06-29 00:00:00 13B  -
# 2025-06-30 00:00:00 13B  -

# %%
print(resident_name, block_id, rotation)
# Out:
# ED_CCU_2 13B

# %%
def authenticate_google_drive():
    creds = None

    # Use token.json to store the user's access and refresh tokens
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    
    # If there are no valid credentials, let the user log in and authorize the app
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            # Use the client_secret.json to start the OAuth flow
            flow = InstalledAppFlow.from_client_secrets_file(
                '/Users/cjyoon/Dropbox/Osler/osler/client_secret_257342927366-4q3itidpqit3vcehjca5rvlg9m2evhsi.apps.googleusercontent.com.json', SCOPES)
            creds = flow.run_local_server(port=0)
        
        # Save the credentials for future runs in token.json
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    # Build the Google Drive service object
    service = build('drive', 'v3', credentials=creds)
    return service



def upload_ics_to_drive(file_path):
    service = authenticate_google_drive()

    # Upload the file to Google Drive with the correct MIME type for .ics files
    file_metadata = {'name': os.path.basename(file_path), 'mimeType': 'text/calendar'}
    media = MediaFileUpload(file_path, mimetype='text/calendar', parent='osler_schedule' )
    file = service.files().create(body=file_metadata, media_body=media, fields='id').execute()

    # Make the file public and get the shareable link
    file_id = file.get('id')
    service.permissions().create(fileId=file_id, body={'type': 'anyone', 'role': 'reader'}).execute()
    shareable_url = f"https://drive.google.com/file/d/osler_schedule/{file_id}/view"
    
    return shareable_url


# for resident in resident_names:
#     file_path = f'/Users/cjyoon/Dropbox/Osler/osler/data/{resident}_schedule.ics'
#     shareable_link = upload_ics_to_drive(file_path)
#     print(f"{resident} schedule: {shareable_link}")
